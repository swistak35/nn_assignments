# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        #print(np.sum(m > 0.))
        #print(np.sum(m == 0.))
        #print(np.sum(m < 0.))
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
# class Layer(object):
#     def __init__(self, rng=None):
#         if rng is None:
#             rng = numpy.random
#         self.rng = rng
    
#     @property
#     def parameters(self):
#         return []
    
#     @property
#     def parameter_names(self):
#         return []
    
#     def get_gradients(self, dLdY, fprop_context):
#         return [] 

# class AffineLayer(Layer):
#     def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
#         super(AffineLayer, self).__init__(**kwargs)
#         if weight_init is None:
#             weight_init = IsotropicGaussian(std=0.2, mean=0.0)
#         if bias_init is None:
#             bias_init = Constant(0.0)

#         self.W = weight_init.generate(self.rng, (num_out, num_in))
#         self.b = bias_init.generate(self.rng, (num_out, 1))
    
#     @property
#     def parameters(self):
#         return [self.W, self.b]
    
#     @property
#     def parameter_names(self):
#         return ['W','b']
    
#     def fprop(self, X):
#         fprop_context = dict(X=X)
#         Y = np.dot(self.W, X) + self.b
#         return Y, fprop_context
    
#     def bprop(self, dLdY, fprop_context):
#         return self.W.T.dot(dLdY)
    
#     def get_gradients(self, dLdY, fprop_context):
#         X = fprop_context['X']
#         dLdW = np.dot(dLdY, X.T)
#         dLdb = dLdY.sum(1, keepdims=True)
#         return [dLdW, dLdb]
    
# class TanhLayer(Layer):
#     def __init__(self, **kwargs):
#         super(TanhLayer, self).__init__(**kwargs)
    
#     def fprop(self, X):
#         Y = np.tanh(X)
#         fprop_context = dict(Y=Y)
#         return Y, fprop_context
    
#     def bprop(self, dLdY, fprop_context):
#         Y = fprop_context['Y']
#         return dLdY * (1.0 - Y**2)

    
# class ReLULayer(Layer):
#     def __init__(self, **kwargs):
#         super(ReLULayer, self).__init__(**kwargs)
    
#     def fprop(self, X):
#         Y = np.maximum(X, 0.0)
#         fprop_context = dict(Y=Y)
#         return Y, fprop_context
    
#     def bprop(self, dLdY, fprop_context):
#         Y = fprop_context['Y']
#         return dLdY * (Y>0)

    
# class SoftMaxLayer(Layer):
#     def __init__(self, **kwargs):
#         super(SoftMaxLayer, self).__init__(**kwargs)
    
#     def compute_probabilities(self, X):
#         O = X - X.max(axis=0, keepdims=True)
#         O = np.exp(O)
#         O /= O.sum(axis=0, keepdims=True)
#         return O
    
#     def fprop_cost(self, X, Y):
#         NS = X.shape[1]
#         O = self.compute_probabilities(X)
#         Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
#         return Cost, O, dict(O=O, X=X, Y=Y)
    
#     def bprop_cost(self, fprop_context):
#         X = fprop_context['X']
#         Y = fprop_context['Y']
#         O = fprop_context['O']
#         NS = X.shape[1]
#         dLdX = O.copy()
#         dLdX[Y, range(NS)] -= 1.0
#         dLdX /= NS
#         return dLdX
    
# class FeedForwardNet(object):
#     def __init__(self, layers=None):
#         if layers is None:
#             layers = []
#         self.layers = layers
    
#     def add(self, layer):
#         self.layers.append(layer)
    
#     @property
#     def parameters(self):
#         params = []
#         for layer in self.layers:
#             params += layer.parameters
#         return params
    
#     @parameters.setter
#     def parameters(self, values):
#         for ownP, newP in zip(self.parameters, values):
#             ownP[...] = newP
    
#     @property
#     def parameter_names(self):
#         param_names = []
#         for layer in self.layers:
#             param_names += layer.parameter_names
#         return param_names
    
#     def fprop(self, X):
#         for layer in self.layers[:-1]:
#             X, fp_context = layer.fprop(X)
#         return self.layers[-1].compute_probabilities(X)
    
#     def get_cost_and_gradient(self, X, Y):
#         fp_contexts = []
#         for layer in self.layers[:-1]:
#             X, fp_context = layer.fprop(X)
#             fp_contexts.append(fp_context)
        
#         L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
#         dLdX = self.layers[-1].bprop_cost(fp_context)
        
#         dLdP = [] #gradient with respect to parameters
#         for i in xrange(len(self.layers)-1):
#             layer = self.layers[len(self.layers)-2-i]
#             fp_context = fp_contexts[len(self.layers)-2-i]
#             dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
#             dLdX = layer.bprop(dLdX, fp_context)
            
#         return L, O, dLdP

class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return [] 

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, dropout = None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.dropout = dropout
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X, with_dropout = False):
        fprop_context = dict(X=X)
        if with_dropout or (not self.dropout):
            Y = np.dot(self.W, X) + self.b
        else:
            Y = np.dot(self.W * self.dropout, X) + self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]

class InputDropoutLayer(Layer):
    def __init__(self, dropout, **kwargs):
        super(InputDropoutLayer, self).__init__(**kwargs)
        self.dropout = dropout
    
    def fprop(self, X, with_dropout = False):
        if with_dropout:
            choice = np.random.binomial(1, self.dropout, X.shape[0]).reshape(X.shape[0], 1)
            Y = X * choice
        else:
            Y = X
        return Y, dict()
    
    def bprop(self, dLdY, fprop_context):
        return dLdY
        
class TanhLayer(Layer):
    def __init__(self, dropout = None, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
        self.dropout = dropout
    
    def fprop(self, X, with_dropout = False):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, dropout = None, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
        self.dropout = dropout
    
    def fprop(self, X, with_dropout = False):
        Y = np.maximum(X, 0.0)
        if self.dropout and with_dropout:
            choice = np.random.binomial(1, self.dropout, Y.shape[0]).reshape(Y.shape[0], 1)
            Y *= choice
            fprop_context = dict(Y=Y, choice=choice)
        else:
            fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        dLdX = dLdY * (Y > 0)
        if self.dropout:
            choice = fprop_context['choice']
            dLdX *= choice
        return dLdX

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X, with_dropout = True)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
            
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
#GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=3)
# Out:
# At iteration 0, loss 1.020450, train error rate 30.000000%
# At iteration 1000, loss 0.052523, train error rate 2.000000%
# At iteration 2000, loss 0.044054, train error rate 1.333333%
# At iteration 3000, loss 0.041678, train error rate 1.333333%
# At iteration 4000, loss 0.040556, train error rate 1.333333%
# At iteration 5000, loss 0.039779, train error rate 1.333333%
# At iteration 6000, loss 0.039111, train error rate 1.333333%
# At iteration 7000, loss 0.038519, train error rate 1.333333%
# At iteration 8000, loss 0.038005, train error rate 1.333333%
# At iteration 9000, loss 0.037565, train error rate 1.333333%
# At iteration 10000, loss 0.037189, train error rate 1.333333%
# At iteration 11000, loss 0.036861, train error rate 1.333333%
# At iteration 12000, loss 0.036565, train error rate 1.333333%
# At iteration 13000, loss 0.036284, train error rate 1.333333%
# At iteration 14000, loss 0.036006, train error rate 1.333333%
# At iteration 15000, loss 0.035722, train error rate 1.333333%
# At iteration 16000, loss 0.035422, train error rate 1.333333%
# At iteration 17000, loss 0.035102, train error rate 1.333333%
# At iteration 18000, loss 0.034756, train error rate 1.333333%
# At iteration 19000, loss 0.034382, train error rate 1.333333%
# At iteration 20000, loss 0.033981, train error rate 1.333333%
# At iteration 21000, loss 0.033556, train error rate 1.333333%
# At iteration 22000, loss 0.033113, train error rate 1.333333%
# At iteration 23000, loss 0.032655, train error rate 1.333333%
# At iteration 24000, loss 0.032181, train error rate 1.333333%
# At iteration 25000, loss 0.031691, train error rate 1.333333%
# At iteration 26000, loss 0.031185, train error rate 1.333333%
# At iteration 27000, loss 0.030660, train error rate 1.333333%
# At iteration 28000, loss 0.030109, train error rate 1.333333%
# At iteration 29000, loss 0.029518, train error rate 1.333333%
# At iteration 30000, loss 0.028857, train error rate 1.333333%
# At iteration 31000, loss 0.028097, train error rate 1.333333%
# At iteration 32000, loss 0.027230, train error rate 1.333333%
# At iteration 33000, loss 0.026267, train error rate 1.333333%
# At iteration 34000, loss 0.025221, train error rate 1.333333%
# At iteration 35000, loss 0.024100, train error rate 1.333333%
# At iteration 36000, loss 0.022914, train error rate 1.333333%
# At iteration 37000, loss 0.021668, train error rate 1.333333%
# At iteration 38000, loss 0.020367, train error rate 1.333333%
# At iteration 39000, loss 0.019021, train error rate 0.666667%
# At iteration 40000, loss 0.017654, train error rate 0.666667%
# At iteration 41000, loss 0.016293, train error rate 0.666667%
# At iteration 42000, loss 0.014971, train error rate 0.666667%
# At iteration 43000, loss 0.013714, train error rate 0.000000%
# At iteration 44000, loss 0.012539, train error rate 0.000000%
# At iteration 45000, loss 0.011457, train error rate 0.000000%
# At iteration 46000, loss 0.010470, train error rate 0.000000%
# At iteration 47000, loss 0.009576, train error rate 0.000000%
# At iteration 48000, loss 0.008771, train error rate 0.000000%
# At iteration 49000, loss 0.008050, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
            
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
            
    return num_errs/num_examples

def print_stats(train_loss, train_errors, validation_errors):
    subplot(2,1,1)
    train_loss = np.array(train_loss)
    semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
    legend()

    subplot(2,1,2)
    train_errors = np.array(train_errors)
    plot(train_errors[:,0], train_errors[:,1], label='batch train error rate')
    validation_errors = np.array(validation_errors)
    plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
    ylim(0,0.2)
    legend()

class AlphaAlgExp:
    def __init__(self, initial = 5e-2, rate = 0.998):
        self.initial = initial
        self.rate = rate
    
    def __call__(self, i, e):
        return (self.initial * np.power(self.rate, e))
    
class AlphaAlgBct:
    def __init__(self, b = 1e3, c = 2e4):
        self.b = b
        self.c = c
    
    def __call__(self, i, e):
        return (self.b / (self.c + i))
    
class AlphaAlgConst:
    def __init__(self, constant = 1e-2):
        self.constant = constant
        
    def __call__(self, i, e):
        return self.constant
    
    
class MomentumAlgConst:
    def __init__(self, constant = 0.5):
        self.constant = constant
        
    def __call__(self, i):
        return self.constant
    
class MomentumAlg1:
    def __call__(self, i, e):
        return (1. - 3. / (5. + i))

class MomentumAlg2:
    def __call__(self, i, e, limit = 0.9):
        v = (1. - 3. / (5. + i))
        return (v if v < limit else limit)
    
class MomentumAlg3:
    def __init__(self, start = 0.5, stop = 0.9, epochs = 500):
        self.start = start
        self.stop = stop
        self.epochs = epochs
    
    def __call__(self, i, e):
        if e >= self.epochs:
            return self.stop
        else:
            c = e / self.epochs
            return c * self.start + (1. - c) * self.stop

def SGD(net, train_stream, validation_stream, test_stream,
        print_debug = True,
        epochs = 3,
        patience = 1.5,
        alpha_alg = AlphaAlgExp(),
        momentum_alg = MomentumAlg1(),
        regularization_rate = 1e-3,
        norm_limiting = None,
        dropout = None):
    
    print "Network configuration: "
    print ", ".join([ "%s%s" %(N, P.shape) for P, N in zip(net.parameters, net.parameter_names) ])
    
    i=0
    e=0
    
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    alpha = None
    
    train_errors = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = epochs
    patience_expansion = patience
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_errors.append((i,err_rate))
                if i % 100 == 0 and print_debug:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W' and regularization_rate:
                        G += regularization_rate * P
                        
                    
                    alpha = alpha_alg(i, e)
                    
                    epsilon = momentum_alg(i, e)
                    
                    #V = epsilon * V - (1. - epsilon) * alpha * G
                    V = epsilon * V - alpha * G
                    
                    P += V
                    
                    if N=='W' and norm_limiting:
                        nrm = np.norm(P, axis = 1)
                        P[nrm > norm_limiting] /= nrm[nrm > norm_limiting]
                            
                    
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)

            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            if print_debug or (e % 20 == 1):
                print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs [best: %f%%]" %(
                    e, val_error_rate, number_of_epochs, best_valid_error_rate)
        print "Finished with %d epochs (minibatch %d), with best valid error rate %f" % (e, i, best_valid_error_rate)
        print_stats(train_loss, train_errors, validation_errors)
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        print_stats(train_loss, train_errors, validation_errors)

# %%
net = FeedForwardNet([
        AffineLayer(784,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# Network configuration:
# W(10, 784), b(10, 1)
# At minibatch 100, batch loss 0.740973, batch error rate 27.000000%
# At minibatch 200, batch loss 0.680448, batch error rate 23.000000%
# At minibatch 300, batch loss 0.601968, batch error rate 19.000000%
# At minibatch 400, batch loss 0.543680, batch error rate 14.000000%
# At minibatch 500, batch loss 0.464686, batch error rate 16.000000%
# After epoch 1: valid_err_rate: 0.125300% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.360327, batch error rate 15.000000%
# At minibatch 700, batch loss 0.192809, batch error rate 6.000000%
# At minibatch 800, batch loss 0.474110, batch error rate 17.000000%
# At minibatch 900, batch loss 0.394569, batch error rate 9.000000%
# At minibatch 1000, batch loss 0.385914, batch error rate 13.000000%
# After epoch 2: valid_err_rate: 0.108500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.621349, batch error rate 15.000000%
# At minibatch 1200, batch loss 0.322686, batch error rate 9.000000%
# At minibatch 1300, batch loss 0.375372, batch error rate 13.000000%
# At minibatch 1400, batch loss 0.415682, batch error rate 15.000000%
# At minibatch 1500, batch loss 0.364343, batch error rate 13.000000%
# After epoch 3: valid_err_rate: 0.099600% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.342938, batch error rate 11.000000%
# At minibatch 1700, batch loss 0.247416, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.347736, batch error rate 11.000000%
# At minibatch 1900, batch loss 0.440091, batch error rate 15.000000%
# At minibatch 2000, batch loss 0.412682, batch error rate 10.000000%
# After epoch 4: valid_err_rate: 0.095700% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.344580, batch error rate 9.000000%
# At minibatch 2200, batch loss 0.340456, batch error rate 7.000000%
# At minibatch 2300, batch loss 0.214881, batch error rate 6.000000%
# At minibatch 2400, batch loss 0.275181, batch error rate 8.000000%
# At minibatch 2500, batch loss 0.454124, batch error rate 14.000000%
# After epoch 5: valid_err_rate: 0.093900% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.239873, batch error rate 6.000000%
# At minibatch 2700, batch loss 0.405343, batch error rate 12.000000%
# At minibatch 2800, batch loss 0.339708, batch error rate 11.000000%
# At minibatch 2900, batch loss 0.418900, batch error rate 12.000000%
# At minibatch 3000, batch loss 0.260233, batch error rate 11.000000%
# After epoch 6: valid_err_rate: 0.087800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.283751, batch error rate 7.000000%
# At minibatch 3200, batch loss 0.298385, batch error rate 9.000000%
# At minibatch 3300, batch loss 0.274503, batch error rate 9.000000%
# At minibatch 3400, batch loss 0.309766, batch error rate 8.000000%
# At minibatch 3500, batch loss 0.333230, batch error rate 14.000000%
# After epoch 7: valid_err_rate: 0.083700% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.271224, batch error rate 7.000000%
# At minibatch 3700, batch loss 0.251963, batch error rate 8.000000%
# At minibatch 3800, batch loss 0.328895, batch error rate 9.000000%
# At minibatch 3900, batch loss 0.338339, batch error rate 11.000000%
# At minibatch 4000, batch loss 0.367609, batch error rate 12.000000%
# After epoch 8: valid_err_rate: 0.084400% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.270506, batch error rate 9.000000%
# At minibatch 4200, batch loss 0.378331, batch error rate 13.000000%
# At minibatch 4300, batch loss 0.273683, batch error rate 13.000000%
# At minibatch 4400, batch loss 0.226347, batch error rate 6.000000%
# At minibatch 4500, batch loss 0.303648, batch error rate 8.000000%
# After epoch 9: valid_err_rate: 0.086400% currently going ot do 11 epochs
# At minibatch 4600, batch loss 0.547532, batch error rate 13.000000%
# At minibatch 4700, batch loss 0.318179, batch error rate 10.000000%
# At minibatch 4800, batch loss 0.394654, batch error rate 10.000000%
# At minibatch 4900, batch loss 0.286206, batch error rate 9.000000%
# At minibatch 5000, batch loss 0.434514, batch error rate 14.000000%
# After epoch 10: valid_err_rate: 0.082600% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.291171, batch error rate 12.000000%
# At minibatch 5200, batch loss 0.378254, batch error rate 13.000000%
# At minibatch 5300, batch loss 0.272216, batch error rate 5.000000%
# At minibatch 5400, batch loss 0.266956, batch error rate 9.000000%
# At minibatch 5500, batch loss 0.200407, batch error rate 3.000000%
# After epoch 11: valid_err_rate: 0.081600% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.218749, batch error rate 7.000000%
# At minibatch 5700, batch loss 0.252554, batch error rate 7.000000%
# At minibatch 5800, batch loss 0.298431, batch error rate 8.000000%
# At minibatch 5900, batch loss 0.354022, batch error rate 11.000000%
# At minibatch 6000, batch loss 0.147049, batch error rate 2.000000%
# After epoch 12: valid_err_rate: 0.081900% currently going ot do 17 epochs
# At minibatch 6100, batch loss 0.273258, batch error rate 6.000000%
# At minibatch 6200, batch loss 0.336471, batch error rate 9.000000%
# At minibatch 6300, batch loss 0.330006, batch error rate 10.000000%
# At minibatch 6400, batch loss 0.372628, batch error rate 12.000000%
# At minibatch 6500, batch loss 0.223340, batch error rate 7.000000%
# After epoch 13: valid_err_rate: 0.081600% currently going ot do 17 epochs
# At minibatch 6600, batch loss 0.175850, batch error rate 8.000000%
# At minibatch 6700, batch loss 0.226265, batch error rate 6.000000%
# At minibatch 6800, batch loss 0.259445, batch error rate 9.000000%
# At minibatch 6900, batch loss 0.309479, batch error rate 11.000000%
# At minibatch 7000, batch loss 0.306560, batch error rate 5.000000%
# After epoch 14: valid_err_rate: 0.083700% currently going ot do 17 epochs
# At minibatch 7100, batch loss 0.266203, batch error rate 6.000000%
# At minibatch 7200, batch loss 0.247998, batch error rate 8.000000%
# At minibatch 7300, batch loss 0.172085, batch error rate 4.000000%
# At minibatch 7400, batch loss 0.386859, batch error rate 14.000000%
# At minibatch 7500, batch loss 0.407505, batch error rate 7.000000%
# After epoch 15: valid_err_rate: 0.082100% currently going ot do 17 epochs
# At minibatch 7600, batch loss 0.245838, batch error rate 11.000000%
# At minibatch 7700, batch loss 0.278321, batch error rate 6.000000%
# At minibatch 7800, batch loss 0.287730, batch error rate 7.000000%
# At minibatch 7900, batch loss 0.322272, batch error rate 6.000000%
# At minibatch 8000, batch loss 0.358469, batch error rate 11.000000%
# After epoch 16: valid_err_rate: 0.080600% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.316656, batch error rate 7.000000%
# At minibatch 8200, batch loss 0.206162, batch error rate 6.000000%
# At minibatch 8300, batch loss 0.211224, batch error rate 6.000000%
# At minibatch 8400, batch loss 0.330906, batch error rate 12.000000%
# At minibatch 8500, batch loss 0.272456, batch error rate 5.000000%
# After epoch 17: valid_err_rate: 0.081400% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.559550, batch error rate 16.000000%
# At minibatch 8700, batch loss 0.226035, batch error rate 8.000000%
# At minibatch 8800, batch loss 0.649672, batch error rate 19.000000%
# At minibatch 8900, batch loss 0.247226, batch error rate 7.000000%
# At minibatch 9000, batch loss 0.169009, batch error rate 4.000000%
# After epoch 18: valid_err_rate: 0.077100% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.407508, batch error rate 8.000000%
# At minibatch 9200, batch loss 0.319961, batch error rate 10.000000%
# At minibatch 9300, batch loss 0.228650, batch error rate 5.000000%
# At minibatch 9400, batch loss 0.319512, batch error rate 8.000000%
# At minibatch 9500, batch loss 0.390527, batch error rate 9.000000%
# After epoch 19: valid_err_rate: 0.082300% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.175537, batch error rate 4.000000%
# At minibatch 9700, batch loss 0.198286, batch error rate 7.000000%
# At minibatch 9800, batch loss 0.200012, batch error rate 5.000000%
# At minibatch 9900, batch loss 0.225288, batch error rate 6.000000%
# At minibatch 10000, batch loss 0.253806, batch error rate 7.000000%
# After epoch 20: valid_err_rate: 0.079900% currently going ot do 28 epochs
# At minibatch 10100, batch loss 0.195985, batch error rate 5.000000%
# At minibatch 10200, batch loss 0.131755, batch error rate 3.000000%
# At minibatch 10300, batch loss 0.355605, batch error rate 12.000000%
# At minibatch 10400, batch loss 0.248060, batch error rate 8.000000%
# At minibatch 10500, batch loss 0.135279, batch error rate 4.000000%
# After epoch 21: valid_err_rate: 0.080900% currently going ot do 28 epochs
# At minibatch 10600, batch loss 0.275773, batch error rate 10.000000%
# At minibatch 10700, batch loss 0.199023, batch error rate 8.000000%
# At minibatch 10800, batch loss 0.441155, batch error rate 10.000000%
# At minibatch 10900, batch loss 0.268404, batch error rate 8.000000%
# At minibatch 11000, batch loss 0.164316, batch error rate 5.000000%
# After epoch 22: valid_err_rate: 0.077700% currently going ot do 28 epochs
# At minibatch 11100, batch loss 0.434933, batch error rate 9.000000%
# At minibatch 11200, batch loss 0.259283, batch error rate 6.000000%
# At minibatch 11300, batch loss 0.263089, batch error rate 8.000000%
# At minibatch 11400, batch loss 0.220842, batch error rate 7.000000%
# At minibatch 11500, batch loss 0.395512, batch error rate 12.000000%
# After epoch 23: valid_err_rate: 0.079400% currently going ot do 28 epochs
# At minibatch 11600, batch loss 0.271348, batch error rate 8.000000%
# At minibatch 11700, batch loss 0.218209, batch error rate 8.000000%
# At minibatch 11800, batch loss 0.229911, batch error rate 4.000000%
# At minibatch 11900, batch loss 0.232644, batch error rate 8.000000%
# At minibatch 12000, batch loss 0.267894, batch error rate 8.000000%
# After epoch 24: valid_err_rate: 0.078600% currently going ot do 28 epochs
# At minibatch 12100, batch loss 0.314995, batch error rate 8.000000%
# At minibatch 12200, batch loss 0.274134, batch error rate 11.000000%
# At minibatch 12300, batch loss 0.195476, batch error rate 8.000000%
# At minibatch 12400, batch loss 0.237909, batch error rate 8.000000%
# At minibatch 12500, batch loss 0.397571, batch error rate 13.000000%
# After epoch 25: valid_err_rate: 0.077000% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.275604, batch error rate 8.000000%
# At minibatch 12700, batch loss 0.306078, batch error rate 4.000000%
# At minibatch 12800, batch loss 0.360772, batch error rate 10.000000%
# At minibatch 12900, batch loss 0.325601, batch error rate 9.000000%
# At minibatch 13000, batch loss 0.264348, batch error rate 10.000000%
# After epoch 26: valid_err_rate: 0.081300% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.250911, batch error rate 9.000000%
# At minibatch 13200, batch loss 0.149137, batch error rate 6.000000%
# At minibatch 13300, batch loss 0.172229, batch error rate 4.000000%
# At minibatch 13400, batch loss 0.185516, batch error rate 6.000000%
# At minibatch 13500, batch loss 0.249912, batch error rate 7.000000%
# After epoch 27: valid_err_rate: 0.078700% currently going ot do 38 epochs
# At minibatch 13600, batch loss 0.218476, batch error rate 5.000000%
# At minibatch 13700, batch loss 0.307938, batch error rate 8.000000%
# At minibatch 13800, batch loss 0.278963, batch error rate 8.000000%
# At minibatch 13900, batch loss 0.220983, batch error rate 5.000000%
# At minibatch 14000, batch loss 0.378173, batch error rate 13.000000%
# After epoch 28: valid_err_rate: 0.080600% currently going ot do 38 epochs
# At minibatch 14100, batch loss 0.356031, batch error rate 11.000000%
# At minibatch 14200, batch loss 0.289292, batch error rate 8.000000%
# At minibatch 14300, batch loss 0.190228, batch error rate 7.000000%
# At minibatch 14400, batch loss 0.168910, batch error rate 6.000000%
# At minibatch 14500, batch loss 0.251000, batch error rate 9.000000%
# After epoch 29: valid_err_rate: 0.078000% currently going ot do 38 epochs
# At minibatch 14600, batch loss 0.385579, batch error rate 10.000000%
# At minibatch 14700, batch loss 0.263786, batch error rate 9.000000%
# At minibatch 14800, batch loss 0.410760, batch error rate 10.000000%
# At minibatch 14900, batch loss 0.310217, batch error rate 11.000000%
# At minibatch 15000, batch loss 0.309349, batch error rate 10.000000%
# After epoch 30: valid_err_rate: 0.077200% currently going ot do 38 epochs
# At minibatch 15100, batch loss 0.378734, batch error rate 13.000000%
# At minibatch 15200, batch loss 0.349693, batch error rate 9.000000%
# At minibatch 15300, batch loss 0.252741, batch error rate 6.000000%
# At minibatch 15400, batch loss 0.292960, batch error rate 12.000000%
# At minibatch 15500, batch loss 0.194670, batch error rate 4.000000%
# After epoch 31: valid_err_rate: 0.076600% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.363850, batch error rate 12.000000%
# At minibatch 15700, batch loss 0.165958, batch error rate 6.000000%
# At minibatch 15800, batch loss 0.203693, batch error rate 5.000000%
# At minibatch 15900, batch loss 0.238487, batch error rate 9.000000%
# At minibatch 16000, batch loss 0.205866, batch error rate 6.000000%
# After epoch 32: valid_err_rate: 0.078700% currently going ot do 47 epochs
# At minibatch 16100, batch loss 0.329135, batch error rate 10.000000%
# At minibatch 16200, batch loss 0.213682, batch error rate 6.000000%
# At minibatch 16300, batch loss 0.297423, batch error rate 9.000000%
# At minibatch 16400, batch loss 0.157609, batch error rate 5.000000%
# At minibatch 16500, batch loss 0.246421, batch error rate 6.000000%
# After epoch 33: valid_err_rate: 0.077200% currently going ot do 47 epochs
# At minibatch 16600, batch loss 0.275644, batch error rate 9.000000%
# At minibatch 16700, batch loss 0.187071, batch error rate 8.000000%
# At minibatch 16800, batch loss 0.222434, batch error rate 5.000000%
# At minibatch 16900, batch loss 0.408268, batch error rate 10.000000%
# At minibatch 17000, batch loss 0.136160, batch error rate 3.000000%
# After epoch 34: valid_err_rate: 0.080100% currently going ot do 47 epochs
# At minibatch 17100, batch loss 0.204477, batch error rate 5.000000%
# At minibatch 17200, batch loss 0.399261, batch error rate 7.000000%
# At minibatch 17300, batch loss 0.189866, batch error rate 6.000000%
# At minibatch 17400, batch loss 0.185976, batch error rate 5.000000%
# At minibatch 17500, batch loss 0.128960, batch error rate 4.000000%
# After epoch 35: valid_err_rate: 0.076700% currently going ot do 47 epochs
# At minibatch 17600, batch loss 0.248514, batch error rate 11.000000%
# At minibatch 17700, batch loss 0.201447, batch error rate 8.000000%
# At minibatch 17800, batch loss 0.287714, batch error rate 10.000000%
# At minibatch 17900, batch loss 0.337300, batch error rate 6.000000%
# At minibatch 18000, batch loss 0.241171, batch error rate 8.000000%
# After epoch 36: valid_err_rate: 0.076800% currently going ot do 47 epochs
# At minibatch 18100, batch loss 0.273514, batch error rate 8.000000%
# At minibatch 18200, batch loss 0.363529, batch error rate 11.000000%
# At minibatch 18300, batch loss 0.303283, batch error rate 11.000000%
# At minibatch 18400, batch loss 0.310583, batch error rate 11.000000%
# At minibatch 18500, batch loss 0.240133, batch error rate 7.000000%
# After epoch 37: valid_err_rate: 0.078300% currently going ot do 47 epochs
# At minibatch 18600, batch loss 0.197004, batch error rate 5.000000%
# At minibatch 18700, batch loss 0.263486, batch error rate 8.000000%
# At minibatch 18800, batch loss 0.306174, batch error rate 5.000000%
# At minibatch 18900, batch loss 0.407865, batch error rate 13.000000%
# At minibatch 19000, batch loss 0.114576, batch error rate 3.000000%
# After epoch 38: valid_err_rate: 0.077100% currently going ot do 47 epochs
# At minibatch 19100, batch loss 0.223235, batch error rate 7.000000%
# At minibatch 19200, batch loss 0.283659, batch error rate 9.000000%
# At minibatch 19300, batch loss 0.177418, batch error rate 6.000000%
# At minibatch 19400, batch loss 0.468941, batch error rate 10.000000%
# At minibatch 19500, batch loss 0.378501, batch error rate 7.000000%
# After epoch 39: valid_err_rate: 0.075900% currently going ot do 59 epochs
# At minibatch 19600, batch loss 0.409729, batch error rate 8.000000%
# At minibatch 19700, batch loss 0.223595, batch error rate 10.000000%
# At minibatch 19800, batch loss 0.362831, batch error rate 7.000000%
# At minibatch 19900, batch loss 0.250954, batch error rate 10.000000%
# At minibatch 20000, batch loss 0.122617, batch error rate 4.000000%
# After epoch 40: valid_err_rate: 0.076900% currently going ot do 59 epochs
# At minibatch 20100, batch loss 0.374917, batch error rate 13.000000%
# At minibatch 20200, batch loss 0.368446, batch error rate 7.000000%
# At minibatch 20300, batch loss 0.297117, batch error rate 8.000000%
# At minibatch 20400, batch loss 0.306425, batch error rate 11.000000%
# At minibatch 20500, batch loss 0.400859, batch error rate 13.000000%
# After epoch 41: valid_err_rate: 0.077300% currently going ot do 59 epochs
# At minibatch 20600, batch loss 0.216197, batch error rate 6.000000%
# At minibatch 20700, batch loss 0.101585, batch error rate 2.000000%
# At minibatch 20800, batch loss 0.266296, batch error rate 5.000000%
# At minibatch 20900, batch loss 0.324347, batch error rate 8.000000%
# At minibatch 21000, batch loss 0.282853, batch error rate 8.000000%
# After epoch 42: valid_err_rate: 0.077700% currently going ot do 59 epochs
# At minibatch 21100, batch loss 0.247575, batch error rate 8.000000%
# At minibatch 21200, batch loss 0.422547, batch error rate 12.000000%
# At minibatch 21300, batch loss 0.255078, batch error rate 10.000000%
# At minibatch 21400, batch loss 0.297020, batch error rate 5.000000%
# At minibatch 21500, batch loss 0.158143, batch error rate 8.000000%
# After epoch 43: valid_err_rate: 0.078000% currently going ot do 59 epochs
# At minibatch 21600, batch loss 0.282540, batch error rate 7.000000%
# At minibatch 21700, batch loss 0.291306, batch error rate 9.000000%
# At minibatch 21800, batch loss 0.130814, batch error rate 3.000000%
# At minibatch 21900, batch loss 0.361504, batch error rate 10.000000%
# At minibatch 22000, batch loss 0.324503, batch error rate 10.000000%
# After epoch 44: valid_err_rate: 0.076300% currently going ot do 59 epochs
# At minibatch 22100, batch loss 0.232805, batch error rate 7.000000%
# At minibatch 22200, batch loss 0.161768, batch error rate 5.000000%
# At minibatch 22300, batch loss 0.264781, batch error rate 8.000000%
# At minibatch 22400, batch loss 0.271878, batch error rate 10.000000%
# At minibatch 22500, batch loss 0.403866, batch error rate 13.000000%
# After epoch 45: valid_err_rate: 0.078500% currently going ot do 59 epochs
# At minibatch 22600, batch loss 0.281925, batch error rate 9.000000%
# At minibatch 22700, batch loss 0.184358, batch error rate 7.000000%
# At minibatch 22800, batch loss 0.322584, batch error rate 10.000000%
# At minibatch 22900, batch loss 0.271019, batch error rate 10.000000%
# At minibatch 23000, batch loss 0.340315, batch error rate 10.000000%
# After epoch 46: valid_err_rate: 0.078600% currently going ot do 59 epochs
# At minibatch 23100, batch loss 0.196063, batch error rate 7.000000%
# At minibatch 23200, batch loss 0.249115, batch error rate 6.000000%
# At minibatch 23300, batch loss 0.189504, batch error rate 4.000000%
# At minibatch 23400, batch loss 0.107182, batch error rate 3.000000%
# At minibatch 23500, batch loss 0.304607, batch error rate 11.000000%
# After epoch 47: valid_err_rate: 0.078800% currently going ot do 59 epochs
# At minibatch 23600, batch loss 0.222992, batch error rate 9.000000%
# At minibatch 23700, batch loss 0.336017, batch error rate 8.000000%
# At minibatch 23800, batch loss 0.242498, batch error rate 5.000000%
# At minibatch 23900, batch loss 0.261250, batch error rate 11.000000%
# At minibatch 24000, batch loss 0.261081, batch error rate 6.000000%
# After epoch 48: valid_err_rate: 0.075300% currently going ot do 73 epochs
# At minibatch 24100, batch loss 0.186310, batch error rate 7.000000%
# At minibatch 24200, batch loss 0.167915, batch error rate 5.000000%
# At minibatch 24300, batch loss 0.163118, batch error rate 4.000000%
# At minibatch 24400, batch loss 0.236165, batch error rate 7.000000%
# At minibatch 24500, batch loss 0.500112, batch error rate 14.000000%
# After epoch 49: valid_err_rate: 0.088400% currently going ot do 73 epochs
# At minibatch 24600, batch loss 0.112804, batch error rate 2.000000%
# At minibatch 24700, batch loss 0.287464, batch error rate 9.000000%
# At minibatch 24800, batch loss 0.213027, batch error rate 6.000000%
# At minibatch 24900, batch loss 0.242369, batch error rate 7.000000%
# At minibatch 25000, batch loss 0.299940, batch error rate 10.000000%
# After epoch 50: valid_err_rate: 0.072900% currently going ot do 76 epochs
# At minibatch 25100, batch loss 0.211094, batch error rate 7.000000%
# At minibatch 25200, batch loss 0.361232, batch error rate 9.000000%
# At minibatch 25300, batch loss 0.232993, batch error rate 8.000000%
# At minibatch 25400, batch loss 0.229573, batch error rate 6.000000%
# At minibatch 25500, batch loss 0.244965, batch error rate 7.000000%
# After epoch 51: valid_err_rate: 0.076000% currently going ot do 76 epochs
# At minibatch 25600, batch loss 0.270743, batch error rate 8.000000%
# At minibatch 25700, batch loss 0.260784, batch error rate 10.000000%
# At minibatch 25800, batch loss 0.267946, batch error rate 8.000000%
# At minibatch 25900, batch loss 0.133616, batch error rate 3.000000%
# At minibatch 26000, batch loss 0.239410, batch error rate 8.000000%
# After epoch 52: valid_err_rate: 0.074800% currently going ot do 76 epochs
# At minibatch 26100, batch loss 0.382184, batch error rate 7.000000%
# At minibatch 26200, batch loss 0.255339, batch error rate 5.000000%
# At minibatch 26300, batch loss 0.370808, batch error rate 9.000000%
# At minibatch 26400, batch loss 0.277039, batch error rate 8.000000%
# At minibatch 26500, batch loss 0.246942, batch error rate 7.000000%
# After epoch 53: valid_err_rate: 0.072700% currently going ot do 80 epochs
# At minibatch 26600, batch loss 0.290968, batch error rate 8.000000%
# At minibatch 26700, batch loss 0.378085, batch error rate 10.000000%
# At minibatch 26800, batch loss 0.374247, batch error rate 10.000000%
# At minibatch 26900, batch loss 0.311684, batch error rate 12.000000%
# At minibatch 27000, batch loss 0.187005, batch error rate 9.000000%
# After epoch 54: valid_err_rate: 0.072800% currently going ot do 80 epochs
# At minibatch 27100, batch loss 0.434759, batch error rate 12.000000%
# At minibatch 27200, batch loss 0.516823, batch error rate 12.000000%
# At minibatch 27300, batch loss 0.233174, batch error rate 5.000000%
# At minibatch 27400, batch loss 0.226079, batch error rate 6.000000%
# At minibatch 27500, batch loss 0.187508, batch error rate 5.000000%
# After epoch 55: valid_err_rate: 0.075200% currently going ot do 80 epochs
# At minibatch 27600, batch loss 0.117157, batch error rate 3.000000%
# At minibatch 27700, batch loss 0.430556, batch error rate 12.000000%
# At minibatch 27800, batch loss 0.162981, batch error rate 5.000000%
# At minibatch 27900, batch loss 0.256831, batch error rate 8.000000%
# At minibatch 28000, batch loss 0.185410, batch error rate 7.000000%
# After epoch 56: valid_err_rate: 0.074000% currently going ot do 80 epochs
# At minibatch 28100, batch loss 0.243222, batch error rate 9.000000%
# At minibatch 28200, batch loss 0.276426, batch error rate 4.000000%
# At minibatch 28300, batch loss 0.141153, batch error rate 4.000000%
# At minibatch 28400, batch loss 0.297936, batch error rate 13.000000%
# At minibatch 28500, batch loss 0.492080, batch error rate 8.000000%
# After epoch 57: valid_err_rate: 0.074200% currently going ot do 80 epochs
# At minibatch 28600, batch loss 0.194352, batch error rate 6.000000%
# At minibatch 28700, batch loss 0.178523, batch error rate 4.000000%
# At minibatch 28800, batch loss 0.413417, batch error rate 9.000000%
# At minibatch 28900, batch loss 0.345318, batch error rate 10.000000%
# At minibatch 29000, batch loss 0.153571, batch error rate 4.000000%
# After epoch 58: valid_err_rate: 0.075600% currently going ot do 80 epochs
# At minibatch 29100, batch loss 0.413496, batch error rate 15.000000%
# At minibatch 29200, batch loss 0.325660, batch error rate 11.000000%
# At minibatch 29300, batch loss 0.289345, batch error rate 6.000000%
# At minibatch 29400, batch loss 0.130669, batch error rate 2.000000%
# At minibatch 29500, batch loss 0.197866, batch error rate 6.000000%
# After epoch 59: valid_err_rate: 0.077800% currently going ot do 80 epochs
# At minibatch 29600, batch loss 0.267970, batch error rate 6.000000%
# At minibatch 29700, batch loss 0.189033, batch error rate 6.000000%
# At minibatch 29800, batch loss 0.182880, batch error rate 5.000000%
# At minibatch 29900, batch loss 0.374542, batch error rate 10.000000%
# At minibatch 30000, batch loss 0.251323, batch error rate 7.000000%
# After epoch 60: valid_err_rate: 0.078100% currently going ot do 80 epochs
# At minibatch 30100, batch loss 0.288432, batch error rate 6.000000%
# At minibatch 30200, batch loss 0.293799, batch error rate 7.000000%
# At minibatch 30300, batch loss 0.256967, batch error rate 8.000000%
# At minibatch 30400, batch loss 0.174047, batch error rate 5.000000%
# At minibatch 30500, batch loss 0.232266, batch error rate 5.000000%
# After epoch 61: valid_err_rate: 0.073600% currently going ot do 80 epochs
# At minibatch 30600, batch loss 0.215886, batch error rate 4.000000%
# At minibatch 30700, batch loss 0.405357, batch error rate 9.000000%
# At minibatch 30800, batch loss 0.384402, batch error rate 10.000000%
# At minibatch 30900, batch loss 0.406127, batch error rate 12.000000%
# At minibatch 31000, batch loss 0.216192, batch error rate 7.000000%
# After epoch 62: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 31100, batch loss 0.416884, batch error rate 11.000000%
# At minibatch 31200, batch loss 0.340921, batch error rate 9.000000%
# At minibatch 31300, batch loss 0.240431, batch error rate 9.000000%
# At minibatch 31400, batch loss 0.205909, batch error rate 7.000000%
# At minibatch 31500, batch loss 0.166855, batch error rate 4.000000%
# After epoch 63: valid_err_rate: 0.073400% currently going ot do 80 epochs
# At minibatch 31600, batch loss 0.201640, batch error rate 6.000000%
# At minibatch 31700, batch loss 0.266002, batch error rate 9.000000%
# At minibatch 31800, batch loss 0.125754, batch error rate 2.000000%
# At minibatch 31900, batch loss 0.317868, batch error rate 7.000000%
# At minibatch 32000, batch loss 0.262930, batch error rate 6.000000%
# After epoch 64: valid_err_rate: 0.077700% currently going ot do 80 epochs
# At minibatch 32100, batch loss 0.190049, batch error rate 6.000000%
# At minibatch 32200, batch loss 0.214746, batch error rate 5.000000%
# At minibatch 32300, batch loss 0.250524, batch error rate 8.000000%
# At minibatch 32400, batch loss 0.217614, batch error rate 4.000000%
# At minibatch 32500, batch loss 0.218063, batch error rate 5.000000%
# After epoch 65: valid_err_rate: 0.073500% currently going ot do 80 epochs
# At minibatch 32600, batch loss 0.154874, batch error rate 6.000000%
# At minibatch 32700, batch loss 0.191774, batch error rate 4.000000%
# At minibatch 32800, batch loss 0.340164, batch error rate 14.000000%
# At minibatch 32900, batch loss 0.345773, batch error rate 11.000000%
# At minibatch 33000, batch loss 0.344159, batch error rate 10.000000%
# After epoch 66: valid_err_rate: 0.074800% currently going ot do 80 epochs
# At minibatch 33100, batch loss 0.198900, batch error rate 6.000000%
# At minibatch 33200, batch loss 0.129303, batch error rate 3.000000%
# At minibatch 33300, batch loss 0.343612, batch error rate 12.000000%
# At minibatch 33400, batch loss 0.152916, batch error rate 2.000000%
# At minibatch 33500, batch loss 0.239631, batch error rate 8.000000%
# After epoch 67: valid_err_rate: 0.076600% currently going ot do 80 epochs
# At minibatch 33600, batch loss 0.251999, batch error rate 8.000000%
# At minibatch 33700, batch loss 0.268558, batch error rate 8.000000%
# At minibatch 33800, batch loss 0.167383, batch error rate 6.000000%
# At minibatch 33900, batch loss 0.287809, batch error rate 6.000000%
# At minibatch 34000, batch loss 0.212205, batch error rate 9.000000%
# After epoch 68: valid_err_rate: 0.076500% currently going ot do 80 epochs
# At minibatch 34100, batch loss 0.332858, batch error rate 9.000000%
# At minibatch 34200, batch loss 0.292982, batch error rate 9.000000%
# At minibatch 34300, batch loss 0.376241, batch error rate 16.000000%
# At minibatch 34400, batch loss 0.214889, batch error rate 6.000000%
# At minibatch 34500, batch loss 0.426535, batch error rate 11.000000%
# After epoch 69: valid_err_rate: 0.073100% currently going ot do 80 epochs
# At minibatch 34600, batch loss 0.312457, batch error rate 12.000000%
# At minibatch 34700, batch loss 0.195879, batch error rate 4.000000%
# At minibatch 34800, batch loss 0.320395, batch error rate 6.000000%
# At minibatch 34900, batch loss 0.389707, batch error rate 8.000000%
# At minibatch 35000, batch loss 0.402277, batch error rate 13.000000%
# After epoch 70: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 35100, batch loss 0.213005, batch error rate 6.000000%
# At minibatch 35200, batch loss 0.115307, batch error rate 2.000000%
# At minibatch 35300, batch loss 0.355527, batch error rate 9.000000%
# At minibatch 35400, batch loss 0.335941, batch error rate 10.000000%
# At minibatch 35500, batch loss 0.196660, batch error rate 5.000000%
# After epoch 71: valid_err_rate: 0.075200% currently going ot do 80 epochs
# At minibatch 35600, batch loss 0.432545, batch error rate 9.000000%
# At minibatch 35700, batch loss 0.261248, batch error rate 6.000000%
# At minibatch 35800, batch loss 0.225274, batch error rate 6.000000%
# At minibatch 35900, batch loss 0.196854, batch error rate 5.000000%
# At minibatch 36000, batch loss 0.301510, batch error rate 11.000000%
# After epoch 72: valid_err_rate: 0.073800% currently going ot do 80 epochs
# At minibatch 36100, batch loss 0.181046, batch error rate 6.000000%
# At minibatch 36200, batch loss 0.301011, batch error rate 8.000000%
# At minibatch 36300, batch loss 0.255940, batch error rate 9.000000%
# At minibatch 36400, batch loss 0.231640, batch error rate 7.000000%
# At minibatch 36500, batch loss 0.353715, batch error rate 13.000000%
# After epoch 73: valid_err_rate: 0.074900% currently going ot do 80 epochs
# At minibatch 36600, batch loss 0.247080, batch error rate 8.000000%
# At minibatch 36700, batch loss 0.247444, batch error rate 11.000000%
# At minibatch 36800, batch loss 0.152068, batch error rate 5.000000%
# At minibatch 36900, batch loss 0.287072, batch error rate 10.000000%
# At minibatch 37000, batch loss 0.141465, batch error rate 5.000000%
# After epoch 74: valid_err_rate: 0.078000% currently going ot do 80 epochs
# At minibatch 37100, batch loss 0.228414, batch error rate 7.000000%
# At minibatch 37200, batch loss 0.214678, batch error rate 5.000000%
# At minibatch 37300, batch loss 0.164372, batch error rate 4.000000%
# At minibatch 37400, batch loss 0.209843, batch error rate 6.000000%
# At minibatch 37500, batch loss 0.278802, batch error rate 8.000000%
# After epoch 75: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 37600, batch loss 0.280233, batch error rate 4.000000%
# At minibatch 37700, batch loss 0.272187, batch error rate 7.000000%
# At minibatch 37800, batch loss 0.209753, batch error rate 7.000000%
# At minibatch 37900, batch loss 0.410677, batch error rate 12.000000%
# At minibatch 38000, batch loss 0.203933, batch error rate 9.000000%
# After epoch 76: valid_err_rate: 0.077800% currently going ot do 80 epochs
# At minibatch 38100, batch loss 0.229977, batch error rate 8.000000%
# At minibatch 38200, batch loss 0.442982, batch error rate 12.000000%
# At minibatch 38300, batch loss 0.192894, batch error rate 7.000000%
# At minibatch 38400, batch loss 0.328600, batch error rate 7.000000%
# At minibatch 38500, batch loss 0.265915, batch error rate 6.000000%
# After epoch 77: valid_err_rate: 0.074600% currently going ot do 80 epochs
# At minibatch 38600, batch loss 0.343703, batch error rate 3.000000%
# At minibatch 38700, batch loss 0.479349, batch error rate 8.000000%
# At minibatch 38800, batch loss 0.169222, batch error rate 4.000000%
# At minibatch 38900, batch loss 0.198668, batch error rate 4.000000%
# At minibatch 39000, batch loss 0.239293, batch error rate 7.000000%
# After epoch 78: valid_err_rate: 0.073600% currently going ot do 80 epochs
# At minibatch 39100, batch loss 0.172373, batch error rate 4.000000%
# At minibatch 39200, batch loss 0.182658, batch error rate 6.000000%
# At minibatch 39300, batch loss 0.199119, batch error rate 7.000000%
# At minibatch 39400, batch loss 0.314168, batch error rate 7.000000%
# At minibatch 39500, batch loss 0.220843, batch error rate 5.000000%
# After epoch 79: valid_err_rate: 0.073700% currently going ot do 80 epochs
# At minibatch 39600, batch loss 0.244220, batch error rate 8.000000%
# At minibatch 39700, batch loss 0.227120, batch error rate 7.000000%
# At minibatch 39800, batch loss 0.170354, batch error rate 7.000000%
# At minibatch 39900, batch loss 0.175074, batch error rate 7.000000%
# At minibatch 40000, batch loss 0.255331, batch error rate 6.000000%
# After epoch 80: valid_err_rate: 0.075400% currently going ot do 80 epochs
# At minibatch 40100, batch loss 0.368457, batch error rate 8.000000%
# At minibatch 40200, batch loss 0.149208, batch error rate 7.000000%
# At minibatch 40300, batch loss 0.315956, batch error rate 9.000000%
# At minibatch 40400, batch loss 0.255082, batch error rate 10.000000%
# At minibatch 40500, batch loss 0.248717, batch error rate 6.000000%
# After epoch 81: valid_err_rate: 0.072800% currently going ot do 80 epochs
# Finished with 81 epochs (minibatch 40500), with best valid error rate 0.072700
# Test error rate: 0.076300

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlg1(rate = 1e-3),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg1())
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 0.361025, batch error rate 11.000000%
# At minibatch 200, batch loss 0.360373, batch error rate 10.000000%
# At minibatch 300, batch loss 0.354910, batch error rate 12.000000%
# At minibatch 400, batch loss 0.238891, batch error rate 9.000000%
# At minibatch 500, batch loss 0.131693, batch error rate 4.000000%
# After epoch 1: valid_err_rate: 0.059600% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.183866, batch error rate 5.000000%
# At minibatch 700, batch loss 0.071052, batch error rate 1.000000%
# At minibatch 800, batch loss 0.293823, batch error rate 9.000000%
# At minibatch 900, batch loss 0.122559, batch error rate 4.000000%
# At minibatch 1000, batch loss 0.093580, batch error rate 3.000000%
# After epoch 2: valid_err_rate: 0.041100% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.158893, batch error rate 5.000000%
# At minibatch 1200, batch loss 0.133334, batch error rate 5.000000%
# At minibatch 1300, batch loss 0.160749, batch error rate 4.000000%
# At minibatch 1400, batch loss 0.092120, batch error rate 3.000000%
# At minibatch 1500, batch loss 0.112340, batch error rate 3.000000%
# After epoch 3: valid_err_rate: 0.037900% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.060266, batch error rate 3.000000%
# At minibatch 1700, batch loss 0.086663, batch error rate 3.000000%
# At minibatch 1800, batch loss 0.060457, batch error rate 2.000000%
# At minibatch 1900, batch loss 0.122432, batch error rate 4.000000%
# At minibatch 2000, batch loss 0.109286, batch error rate 3.000000%
# After epoch 4: valid_err_rate: 0.036400% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.089274, batch error rate 4.000000%
# At minibatch 2200, batch loss 0.253411, batch error rate 10.000000%
# At minibatch 2300, batch loss 0.128552, batch error rate 7.000000%
# At minibatch 2400, batch loss 0.043774, batch error rate 1.000000%
# At minibatch 2500, batch loss 0.033858, batch error rate 0.000000%
# After epoch 5: valid_err_rate: 0.030600% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.026462, batch error rate 1.000000%
# At minibatch 2700, batch loss 0.071691, batch error rate 3.000000%
# At minibatch 2800, batch loss 0.094127, batch error rate 3.000000%
# At minibatch 2900, batch loss 0.075824, batch error rate 1.000000%
# At minibatch 3000, batch loss 0.044983, batch error rate 0.000000%
# After epoch 6: valid_err_rate: 0.030800% currently going ot do 8 epochs
# At minibatch 3100, batch loss 0.053518, batch error rate 2.000000%
# At minibatch 3200, batch loss 0.088773, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.024247, batch error rate 0.000000%
# At minibatch 3400, batch loss 0.045027, batch error rate 2.000000%
# At minibatch 3500, batch loss 0.061679, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.028900% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.071931, batch error rate 2.000000%
# At minibatch 3700, batch loss 0.017280, batch error rate 0.000000%
# At minibatch 3800, batch loss 0.035467, batch error rate 1.000000%
# At minibatch 3900, batch loss 0.052880, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.037966, batch error rate 0.000000%
# After epoch 8: valid_err_rate: 0.029200% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.087265, batch error rate 2.000000%
# At minibatch 4200, batch loss 0.035446, batch error rate 1.000000%
# At minibatch 4300, batch loss 0.040201, batch error rate 1.000000%
# At minibatch 4400, batch loss 0.013046, batch error rate 0.000000%
# At minibatch 4500, batch loss 0.034019, batch error rate 0.000000%
# After epoch 9: valid_err_rate: 0.024800% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.051945, batch error rate 1.000000%
# At minibatch 4700, batch loss 0.052244, batch error rate 3.000000%
# At minibatch 4800, batch loss 0.048825, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.039789, batch error rate 2.000000%
# At minibatch 5000, batch loss 0.097803, batch error rate 4.000000%
# After epoch 10: valid_err_rate: 0.027100% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.013953, batch error rate 0.000000%
# At minibatch 5200, batch loss 0.034599, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.033198, batch error rate 0.000000%
# At minibatch 5400, batch loss 0.015636, batch error rate 0.000000%
# At minibatch 5500, batch loss 0.020852, batch error rate 0.000000%
# After epoch 11: valid_err_rate: 0.024700% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.046321, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.030472, batch error rate 0.000000%
# At minibatch 5800, batch loss 0.081743, batch error rate 1.000000%
# At minibatch 5900, batch loss 0.032953, batch error rate 1.000000%
# At minibatch 6000, batch loss 0.020177, batch error rate 1.000000%
# After epoch 12: valid_err_rate: 0.023800% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.022013, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.060381, batch error rate 2.000000%
# At minibatch 6300, batch loss 0.037124, batch error rate 1.000000%
# At minibatch 6400, batch loss 0.048410, batch error rate 1.000000%
# At minibatch 6500, batch loss 0.034640, batch error rate 2.000000%
# After epoch 13: valid_err_rate: 0.024900% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.006771, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.016487, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.038041, batch error rate 1.000000%
# At minibatch 6900, batch loss 0.034395, batch error rate 1.000000%
# At minibatch 7000, batch loss 0.023462, batch error rate 0.000000%
# After epoch 14: valid_err_rate: 0.021900% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.030661, batch error rate 0.000000%
# At minibatch 7200, batch loss 0.022822, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.058509, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.025610, batch error rate 0.000000%
# At minibatch 7500, batch loss 0.068808, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.024100% currently going ot do 22 epochs
# At minibatch 7600, batch loss 0.022618, batch error rate 0.000000%
# At minibatch 7700, batch loss 0.030373, batch error rate 0.000000%
# At minibatch 7800, batch loss 0.084305, batch error rate 3.000000%
# At minibatch 7900, batch loss 0.031780, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.016397, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.023900% currently going ot do 22 epochs
# At minibatch 8100, batch loss 0.028386, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.023667, batch error rate 0.000000%
# At minibatch 8300, batch loss 0.020499, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.010954, batch error rate 0.000000%
# At minibatch 8500, batch loss 0.028692, batch error rate 0.000000%
# After epoch 17: valid_err_rate: 0.023400% currently going ot do 22 epochs
# At minibatch 8600, batch loss 0.010360, batch error rate 0.000000%
# At minibatch 8700, batch loss 0.034899, batch error rate 1.000000%
# At minibatch 8800, batch loss 0.024683, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.011348, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.069151, batch error rate 2.000000%
# After epoch 18: valid_err_rate: 0.023000% currently going ot do 22 epochs
# At minibatch 9100, batch loss 0.015384, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.014946, batch error rate 0.000000%
# At minibatch 9300, batch loss 0.037797, batch error rate 1.000000%
# At minibatch 9400, batch loss 0.018546, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.008890, batch error rate 0.000000%
# After epoch 19: valid_err_rate: 0.023200% currently going ot do 22 epochs
# At minibatch 9600, batch loss 0.011705, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.023945, batch error rate 0.000000%
# At minibatch 9800, batch loss 0.033785, batch error rate 2.000000%
# At minibatch 9900, batch loss 0.050704, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.033635, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.027500% currently going ot do 22 epochs
# At minibatch 10100, batch loss 0.019098, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.014932, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.039003, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.012700, batch error rate 0.000000%
# At minibatch 10500, batch loss 0.016891, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 0.022200% currently going ot do 22 epochs
# At minibatch 10600, batch loss 0.013290, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.024046, batch error rate 1.000000%
# At minibatch 10800, batch loss 0.037418, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.017729, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.006311, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.021600% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.021342, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.019742, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.054579, batch error rate 2.000000%
# At minibatch 11400, batch loss 0.016860, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.017384, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.021400% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.011951, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.031084, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.009249, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.014918, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.021416, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.021200% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.012070, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.026116, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.010819, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.015013, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.009028, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.020600% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.020740, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.025221, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.029117, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.024879, batch error rate 1.000000%
# At minibatch 13000, batch loss 0.041515, batch error rate 2.000000%
# After epoch 26: valid_err_rate: 0.021600% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.042322, batch error rate 1.000000%
# At minibatch 13200, batch loss 0.016738, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.023062, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.023010, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.028392, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.019900% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.022295, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.022864, batch error rate 0.000000%
# At minibatch 13800, batch loss 0.025517, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.015813, batch error rate 1.000000%
# At minibatch 14000, batch loss 0.013133, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.021400% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.015392, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.021809, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.040236, batch error rate 1.000000%
# At minibatch 14400, batch loss 0.014910, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.048812, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.020600% currently going ot do 41 epochs
# At minibatch 14600, batch loss 0.035972, batch error rate 1.000000%
# At minibatch 14700, batch loss 0.017445, batch error rate 0.000000%
# At minibatch 14800, batch loss 0.021876, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.042945, batch error rate 2.000000%
# At minibatch 15000, batch loss 0.026258, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.019900% currently going ot do 41 epochs
# At minibatch 15100, batch loss 0.012629, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.016952, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.030388, batch error rate 1.000000%
# At minibatch 15400, batch loss 0.008129, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.024612, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.020900% currently going ot do 41 epochs
# At minibatch 15600, batch loss 0.028008, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.033254, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.010042, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.036253, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.013183, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.018900% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.036695, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.031282, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.028708, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.011101, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.022157, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.020400% currently going ot do 49 epochs
# At minibatch 16600, batch loss 0.011948, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.019996, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.030389, batch error rate 1.000000%
# At minibatch 16900, batch loss 0.029518, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.021633, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.021200% currently going ot do 49 epochs
# At minibatch 17100, batch loss 0.022018, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.019351, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.015590, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.028491, batch error rate 1.000000%
# At minibatch 17500, batch loss 0.027259, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.020200% currently going ot do 49 epochs
# At minibatch 17600, batch loss 0.017890, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.011864, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.035616, batch error rate 1.000000%
# At minibatch 17900, batch loss 0.025476, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.017478, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.019500% currently going ot do 49 epochs
# At minibatch 18100, batch loss 0.023876, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.025365, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.030950, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.042201, batch error rate 1.000000%
# At minibatch 18500, batch loss 0.027816, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.019800% currently going ot do 49 epochs
# At minibatch 18600, batch loss 0.037409, batch error rate 2.000000%
# At minibatch 18700, batch loss 0.016369, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.023174, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.024949, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.012681, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.018800% currently going ot do 58 epochs
# At minibatch 19100, batch loss 0.018894, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.027185, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.032420, batch error rate 1.000000%
# At minibatch 19400, batch loss 0.025254, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.009849, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.019200% currently going ot do 58 epochs
# At minibatch 19600, batch loss 0.015793, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.016806, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.008821, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.018232, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.020802, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.019700% currently going ot do 58 epochs
# At minibatch 20100, batch loss 0.027345, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.014548, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.018853, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.017210, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.028491, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.018400% currently going ot do 62 epochs
# At minibatch 20600, batch loss 0.030729, batch error rate 1.000000%
# At minibatch 20700, batch loss 0.017252, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.024673, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.009880, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.013121, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.019200% currently going ot do 62 epochs
# At minibatch 21100, batch loss 0.007342, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.016815, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.013892, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.012210, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.013538, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.019200% currently going ot do 62 epochs
# At minibatch 21600, batch loss 0.020086, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.027004, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.039024, batch error rate 1.000000%
# At minibatch 21900, batch loss 0.018742, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.012937, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.018100% currently going ot do 67 epochs
# At minibatch 22100, batch loss 0.024635, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.024141, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.014185, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.013528, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.036043, batch error rate 1.000000%
# After epoch 45: valid_err_rate: 0.019000% currently going ot do 67 epochs
# At minibatch 22600, batch loss 0.016715, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.013498, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.032801, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.024153, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.028426, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.020100% currently going ot do 67 epochs
# At minibatch 23100, batch loss 0.030189, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.011524, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.039394, batch error rate 2.000000%
# At minibatch 23400, batch loss 0.035997, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.019590, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.018300% currently going ot do 67 epochs
# At minibatch 23600, batch loss 0.011203, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.022064, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.026516, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.016147, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.021750, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.018900% currently going ot do 67 epochs
# At minibatch 24100, batch loss 0.013016, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.012597, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.014097, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.022243, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.050167, batch error rate 2.000000%
# After epoch 49: valid_err_rate: 0.019300% currently going ot do 67 epochs
# At minibatch 24600, batch loss 0.021842, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.036952, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.011822, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.021501, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.011163, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.018600% currently going ot do 67 epochs
# At minibatch 25100, batch loss 0.019946, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.023522, batch error rate 1.000000%
# At minibatch 25300, batch loss 0.031478, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.019488, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.016297, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.020400% currently going ot do 67 epochs
# At minibatch 25600, batch loss 0.025031, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.017589, batch error rate 1.000000%
# At minibatch 25800, batch loss 0.035127, batch error rate 1.000000%
# At minibatch 25900, batch loss 0.013831, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.037647, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.019200% currently going ot do 67 epochs
# At minibatch 26100, batch loss 0.019075, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.009012, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.032278, batch error rate 1.000000%
# At minibatch 26400, batch loss 0.016626, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.011513, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.018600% currently going ot do 67 epochs
# At minibatch 26600, batch loss 0.016602, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.015168, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.016149, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.020389, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.023937, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.018300% currently going ot do 67 epochs
# At minibatch 27100, batch loss 0.017052, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.013690, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.011757, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.021785, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.020971, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.019200% currently going ot do 67 epochs
# At minibatch 27600, batch loss 0.011242, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.022160, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.020780, batch error rate 1.000000%
# At minibatch 27900, batch loss 0.017884, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.015251, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.018500% currently going ot do 67 epochs
# At minibatch 28100, batch loss 0.034980, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.023802, batch error rate 1.000000%
# At minibatch 28300, batch loss 0.011307, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.010577, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.027551, batch error rate 1.000000%
# After epoch 57: valid_err_rate: 0.018000% currently going ot do 86 epochs
# At minibatch 28600, batch loss 0.026267, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.012717, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.027486, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.023497, batch error rate 1.000000%
# At minibatch 29000, batch loss 0.038081, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.019700% currently going ot do 86 epochs
# At minibatch 29100, batch loss 0.012512, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.015635, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.019557, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.012773, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.014188, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.018800% currently going ot do 86 epochs
# At minibatch 29600, batch loss 0.029660, batch error rate 1.000000%
# At minibatch 29700, batch loss 0.015391, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.011034, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.020838, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.020009, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.018800% currently going ot do 86 epochs
# At minibatch 30100, batch loss 0.016255, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.035760, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.015491, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.012665, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.016931, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.019000% currently going ot do 86 epochs
# At minibatch 30600, batch loss 0.053722, batch error rate 2.000000%
# At minibatch 30700, batch loss 0.019856, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.037837, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.054929, batch error rate 2.000000%
# At minibatch 31000, batch loss 0.014172, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.018700% currently going ot do 86 epochs
# At minibatch 31100, batch loss 0.011418, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.011209, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.027771, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.019824, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.033185, batch error rate 1.000000%
# After epoch 63: valid_err_rate: 0.018400% currently going ot do 86 epochs
# At minibatch 31600, batch loss 0.028754, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.008498, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.013925, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.010108, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.011484, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.018200% currently going ot do 86 epochs
# At minibatch 32100, batch loss 0.009226, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.013307, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.014998, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.023902, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.021086, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.017900% currently going ot do 98 epochs
# At minibatch 32600, batch loss 0.017187, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.014278, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.006913, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.006929, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.022329, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.018300% currently going ot do 98 epochs
# At minibatch 33100, batch loss 0.013597, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.014636, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.021431, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.012884, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.013790, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.017200% currently going ot do 101 epochs
# At minibatch 33600, batch loss 0.020163, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.037428, batch error rate 1.000000%
# At minibatch 33800, batch loss 0.020809, batch error rate 1.000000%
# At minibatch 33900, batch loss 0.012032, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.028741, batch error rate 1.000000%
# After epoch 68: valid_err_rate: 0.019400% currently going ot do 101 epochs
# At minibatch 34100, batch loss 0.028916, batch error rate 1.000000%
# At minibatch 34200, batch loss 0.019753, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.016335, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.012532, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.021205, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.018700% currently going ot do 101 epochs
# At minibatch 34600, batch loss 0.012870, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.013147, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.010049, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.009012, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.021465, batch error rate 1.000000%
# After epoch 70: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 35100, batch loss 0.009577, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.019856, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.021233, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.016744, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.025564, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.018900% currently going ot do 101 epochs
# At minibatch 35600, batch loss 0.017618, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.019719, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.032682, batch error rate 1.000000%
# At minibatch 35900, batch loss 0.020560, batch error rate 1.000000%
# At minibatch 36000, batch loss 0.016383, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.018200% currently going ot do 101 epochs
# At minibatch 36100, batch loss 0.019918, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.011398, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.015632, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.012502, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.010633, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.019200% currently going ot do 101 epochs
# At minibatch 36600, batch loss 0.015259, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.014908, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.008467, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.012093, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.038116, batch error rate 1.000000%
# After epoch 74: valid_err_rate: 0.018700% currently going ot do 101 epochs
# At minibatch 37100, batch loss 0.013199, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.020022, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.027117, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.018792, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.018456, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.018400% currently going ot do 101 epochs
# At minibatch 37600, batch loss 0.028312, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.020313, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.021191, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.021093, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.016001, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 38100, batch loss 0.020772, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.022954, batch error rate 1.000000%
# At minibatch 38300, batch loss 0.023737, batch error rate 1.000000%
# At minibatch 38400, batch loss 0.011749, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.019503, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.017500% currently going ot do 101 epochs
# At minibatch 38600, batch loss 0.026647, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.010519, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.007329, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.012962, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.007727, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.018000% currently going ot do 101 epochs
# At minibatch 39100, batch loss 0.016160, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.015032, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.019359, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.033059, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.016865, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 39600, batch loss 0.039321, batch error rate 2.000000%
# At minibatch 39700, batch loss 0.008847, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.016713, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.021755, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.028868, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.016300% currently going ot do 121 epochs
# At minibatch 40100, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.018886, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.015629, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.029071, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.017644, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.017500% currently going ot do 121 epochs
# At minibatch 40600, batch loss 0.017967, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.010441, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.031549, batch error rate 1.000000%
# At minibatch 40900, batch loss 0.017871, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.012357, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.016500% currently going ot do 121 epochs
# At minibatch 41100, batch loss 0.020174, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.031512, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.013897, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.013238, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.007627, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.019400% currently going ot do 121 epochs
# At minibatch 41600, batch loss 0.010112, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.023764, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.018137, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.018109, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.012156, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.019000% currently going ot do 121 epochs
# At minibatch 42100, batch loss 0.009177, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.016395, batch error rate 1.000000%
# At minibatch 42300, batch loss 0.007600, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.022446, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.011767, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.018400% currently going ot do 121 epochs
# At minibatch 42600, batch loss 0.028497, batch error rate 1.000000%
# At minibatch 42700, batch loss 0.008029, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.019868, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.019324, batch error rate 0.000000%
# At minibatch 43000, batch loss 0.046210, batch error rate 1.000000%
# After epoch 86: valid_err_rate: 0.019200% currently going ot do 121 epochs
# At minibatch 43100, batch loss 0.012345, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.015968, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.039137, batch error rate 1.000000%
# At minibatch 43400, batch loss 0.017781, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.014449, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 43600, batch loss 0.017025, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.013035, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.010269, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.015681, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 44100, batch loss 0.042911, batch error rate 1.000000%
# At minibatch 44200, batch loss 0.022664, batch error rate 1.000000%
# At minibatch 44300, batch loss 0.027462, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.032448, batch error rate 1.000000%
# At minibatch 44500, batch loss 0.020443, batch error rate 1.000000%
# After epoch 89: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 44600, batch loss 0.016332, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.014254, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.013029, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.012116, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.015315, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.017500% currently going ot do 121 epochs
# At minibatch 45100, batch loss 0.016320, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.020971, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.019624, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.016326, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.018238, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.019600% currently going ot do 121 epochs
# At minibatch 45600, batch loss 0.009554, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.020640, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.025815, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.010225, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.012594, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.017200% currently going ot do 121 epochs
# At minibatch 46100, batch loss 0.014934, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.024804, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.009738, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.021447, batch error rate 1.000000%
# At minibatch 46500, batch loss 0.011121, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.018500% currently going ot do 121 epochs
# At minibatch 46600, batch loss 0.014700, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.015326, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.017151, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.020063, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.009515, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.018300% currently going ot do 121 epochs
# At minibatch 47100, batch loss 0.022973, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.016892, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.026333, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.018653, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.021400, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 47600, batch loss 0.011592, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.012700, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.020599, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.015280, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.034231, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.017300% currently going ot do 121 epochs
# At minibatch 48100, batch loss 0.011092, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.009717, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.028589, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.021318, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.019138, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.017700% currently going ot do 121 epochs
# At minibatch 48600, batch loss 0.024113, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.006874, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.021189, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.009018, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.027520, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.018900% currently going ot do 121 epochs
# At minibatch 49100, batch loss 0.013283, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.019252, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.023177, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.023980, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.016554, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.018700% currently going ot do 121 epochs
# At minibatch 49600, batch loss 0.011228, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.021124, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.021918, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.021672, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.016453, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 50100, batch loss 0.013830, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.011159, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.014902, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.012468, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.012518, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.017400% currently going ot do 121 epochs
# At minibatch 50600, batch loss 0.013041, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.036260, batch error rate 2.000000%
# At minibatch 50800, batch loss 0.027137, batch error rate 1.000000%
# At minibatch 50900, batch loss 0.012278, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.007474, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.017200% currently going ot do 121 epochs
# At minibatch 51100, batch loss 0.013243, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.019252, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.026720, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.011840, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.030166, batch error rate 1.000000%
# After epoch 103: valid_err_rate: 0.018100% currently going ot do 121 epochs
# At minibatch 51600, batch loss 0.014137, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.019039, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.018138, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.014336, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.011331, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.017400% currently going ot do 121 epochs
# At minibatch 52100, batch loss 0.024577, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.011339, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.014918, batch error rate 0.000000%
# At minibatch 52400, batch loss 0.024967, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.019673, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 52600, batch loss 0.018649, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.027665, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.020995, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.007034, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.009823, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.016600% currently going ot do 121 epochs
# At minibatch 53100, batch loss 0.009422, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.010772, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.025245, batch error rate 1.000000%
# At minibatch 53400, batch loss 0.013340, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.022997, batch error rate 1.000000%
# After epoch 107: valid_err_rate: 0.018700% currently going ot do 121 epochs
# At minibatch 53600, batch loss 0.009473, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.012321, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.008953, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.012913, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.028329, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.019300% currently going ot do 121 epochs
# At minibatch 54100, batch loss 0.015847, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.005305, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.041033, batch error rate 1.000000%
# At minibatch 54400, batch loss 0.013919, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.021071, batch error rate 1.000000%
# After epoch 109: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 54600, batch loss 0.020151, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.031970, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.016032, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.017815, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.019259, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.018300% currently going ot do 121 epochs
# At minibatch 55100, batch loss 0.011327, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.020200, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.019332, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.028087, batch error rate 1.000000%
# At minibatch 55500, batch loss 0.011845, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 55600, batch loss 0.020769, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.012160, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.013792, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.022415, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.016967, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 56100, batch loss 0.034665, batch error rate 1.000000%
# At minibatch 56200, batch loss 0.038785, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.006469, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.009274, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.008775, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 56600, batch loss 0.017385, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.007844, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.006447, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.025327, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.022001, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 57100, batch loss 0.020235, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.019268, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.026652, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.018541, batch error rate 1.000000%
# At minibatch 57500, batch loss 0.013917, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.017900% currently going ot do 121 epochs
# At minibatch 57600, batch loss 0.026536, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.012815, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.022720, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.019683, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.014940, batch error rate 0.000000%
# After epoch 116: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 58100, batch loss 0.016128, batch error rate 0.000000%
# At minibatch 58200, batch loss 0.035083, batch error rate 0.000000%
# At minibatch 58300, batch loss 0.022390, batch error rate 0.000000%
# At minibatch 58400, batch loss 0.022168, batch error rate 0.000000%
# At minibatch 58500, batch loss 0.022470, batch error rate 1.000000%
# After epoch 117: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 58600, batch loss 0.006153, batch error rate 0.000000%
# At minibatch 58700, batch loss 0.013314, batch error rate 0.000000%
# At minibatch 58800, batch loss 0.009477, batch error rate 0.000000%
# At minibatch 58900, batch loss 0.025113, batch error rate 0.000000%
# At minibatch 59000, batch loss 0.016335, batch error rate 0.000000%
# After epoch 118: valid_err_rate: 0.016800% currently going ot do 121 epochs
# At minibatch 59100, batch loss 0.010722, batch error rate 0.000000%
# At minibatch 59200, batch loss 0.031408, batch error rate 1.000000%
# At minibatch 59300, batch loss 0.022215, batch error rate 0.000000%
# At minibatch 59400, batch loss 0.016463, batch error rate 0.000000%
# At minibatch 59500, batch loss 0.021183, batch error rate 0.000000%
# After epoch 119: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 59600, batch loss 0.014341, batch error rate 0.000000%
# At minibatch 59700, batch loss 0.008557, batch error rate 0.000000%
# At minibatch 59800, batch loss 0.022984, batch error rate 0.000000%
# At minibatch 59900, batch loss 0.016729, batch error rate 0.000000%
# At minibatch 60000, batch loss 0.021550, batch error rate 0.000000%
# After epoch 120: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 60100, batch loss 0.018297, batch error rate 1.000000%
# At minibatch 60200, batch loss 0.015829, batch error rate 0.000000%
# At minibatch 60300, batch loss 0.017416, batch error rate 0.000000%
# At minibatch 60400, batch loss 0.021518, batch error rate 0.000000%
# At minibatch 60500, batch loss 0.012580, batch error rate 0.000000%
# After epoch 121: valid_err_rate: 0.017700% currently going ot do 121 epochs
# Finished with 121 epochs (minibatch 60500), with best valid error rate 0.016300

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0188

# %%
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_rate = 1e-3,
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg2())
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 0.592341, batch error rate 19.000000%
# At minibatch 200, batch loss 0.338097, batch error rate 16.000000%
# At minibatch 300, batch loss 0.241671, batch error rate 10.000000%
# At minibatch 400, batch loss 0.361459, batch error rate 9.000000%
# At minibatch 500, batch loss 0.194876, batch error rate 3.000000%
# After epoch 1: valid_err_rate: 0.065900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.206523, batch error rate 7.000000%
# At minibatch 700, batch loss 0.135839, batch error rate 3.000000%
# At minibatch 800, batch loss 0.154278, batch error rate 3.000000%
# At minibatch 900, batch loss 0.155688, batch error rate 9.000000%
# At minibatch 1000, batch loss 0.156920, batch error rate 6.000000%
# After epoch 2: valid_err_rate: 0.048500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.166709, batch error rate 7.000000%
# At minibatch 1200, batch loss 0.093855, batch error rate 3.000000%
# At minibatch 1300, batch loss 0.143351, batch error rate 5.000000%
# At minibatch 1400, batch loss 0.106799, batch error rate 3.000000%
# At minibatch 1500, batch loss 0.114536, batch error rate 3.000000%
# After epoch 3: valid_err_rate: 0.037700% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.054939, batch error rate 1.000000%
# At minibatch 1700, batch loss 0.072154, batch error rate 2.000000%
# At minibatch 1800, batch loss 0.119948, batch error rate 3.000000%
# At minibatch 1900, batch loss 0.095549, batch error rate 2.000000%
# At minibatch 2000, batch loss 0.120573, batch error rate 3.000000%
# After epoch 4: valid_err_rate: 0.036900% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.063877, batch error rate 2.000000%
# At minibatch 2200, batch loss 0.075898, batch error rate 2.000000%
# At minibatch 2300, batch loss 0.135982, batch error rate 4.000000%
# At minibatch 2400, batch loss 0.073894, batch error rate 2.000000%
# At minibatch 2500, batch loss 0.222021, batch error rate 7.000000%
# After epoch 5: valid_err_rate: 0.042900% currently going ot do 7 epochs
# At minibatch 2600, batch loss 0.093273, batch error rate 1.000000%
# At minibatch 2700, batch loss 0.044290, batch error rate 1.000000%
# At minibatch 2800, batch loss 0.070925, batch error rate 3.000000%
# At minibatch 2900, batch loss 0.070381, batch error rate 3.000000%
# At minibatch 3000, batch loss 0.031285, batch error rate 0.000000%
# After epoch 6: valid_err_rate: 0.030200% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.072525, batch error rate 2.000000%
# At minibatch 3200, batch loss 0.048924, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.060785, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.032117, batch error rate 0.000000%
# At minibatch 3500, batch loss 0.063964, batch error rate 3.000000%
# After epoch 7: valid_err_rate: 0.030900% currently going ot do 10 epochs
# At minibatch 3600, batch loss 0.059821, batch error rate 1.000000%
# At minibatch 3700, batch loss 0.035903, batch error rate 0.000000%
# At minibatch 3800, batch loss 0.096982, batch error rate 2.000000%
# At minibatch 3900, batch loss 0.074352, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.087971, batch error rate 4.000000%
# After epoch 8: valid_err_rate: 0.031000% currently going ot do 10 epochs
# At minibatch 4100, batch loss 0.028727, batch error rate 0.000000%
# At minibatch 4200, batch loss 0.033717, batch error rate 0.000000%
# At minibatch 4300, batch loss 0.044646, batch error rate 1.000000%
# At minibatch 4400, batch loss 0.025924, batch error rate 0.000000%
# At minibatch 4500, batch loss 0.065023, batch error rate 2.000000%
# After epoch 9: valid_err_rate: 0.028500% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.090117, batch error rate 3.000000%
# At minibatch 4700, batch loss 0.040165, batch error rate 1.000000%
# At minibatch 4800, batch loss 0.069216, batch error rate 2.000000%
# At minibatch 4900, batch loss 0.046674, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.070758, batch error rate 1.000000%
# After epoch 10: valid_err_rate: 0.027900% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.043479, batch error rate 1.000000%
# At minibatch 5200, batch loss 0.037451, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.043286, batch error rate 2.000000%
# At minibatch 5400, batch loss 0.025197, batch error rate 0.000000%
# At minibatch 5500, batch loss 0.024973, batch error rate 0.000000%
# After epoch 11: valid_err_rate: 0.026200% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.028929, batch error rate 1.000000%
# At minibatch 5700, batch loss 0.026693, batch error rate 0.000000%
# At minibatch 5800, batch loss 0.025829, batch error rate 1.000000%
# At minibatch 5900, batch loss 0.024291, batch error rate 0.000000%
# At minibatch 6000, batch loss 0.017087, batch error rate 0.000000%
# After epoch 12: valid_err_rate: 0.027400% currently going ot do 17 epochs
# At minibatch 6100, batch loss 0.024360, batch error rate 1.000000%
# At minibatch 6200, batch loss 0.031309, batch error rate 0.000000%
# At minibatch 6300, batch loss 0.055511, batch error rate 1.000000%
# At minibatch 6400, batch loss 0.034540, batch error rate 1.000000%
# At minibatch 6500, batch loss 0.013452, batch error rate 0.000000%
# After epoch 13: valid_err_rate: 0.025500% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.057176, batch error rate 3.000000%
# At minibatch 6700, batch loss 0.035482, batch error rate 1.000000%
# At minibatch 6800, batch loss 0.029238, batch error rate 0.000000%
# At minibatch 6900, batch loss 0.035776, batch error rate 2.000000%
# At minibatch 7000, batch loss 0.042856, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.025700% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.032338, batch error rate 1.000000%
# At minibatch 7200, batch loss 0.010144, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.010096, batch error rate 0.000000%
# At minibatch 7400, batch loss 0.032611, batch error rate 0.000000%
# At minibatch 7500, batch loss 0.071817, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.027900% currently going ot do 20 epochs
# At minibatch 7600, batch loss 0.012912, batch error rate 0.000000%
# At minibatch 7700, batch loss 0.026597, batch error rate 0.000000%
# At minibatch 7800, batch loss 0.026687, batch error rate 0.000000%
# At minibatch 7900, batch loss 0.052471, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.033111, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.023900% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.054046, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.010305, batch error rate 0.000000%
# At minibatch 8300, batch loss 0.011186, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.021488, batch error rate 0.000000%
# At minibatch 8500, batch loss 0.021601, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.025200% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.043333, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.027089, batch error rate 0.000000%
# At minibatch 8800, batch loss 0.037733, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.009994, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.024277, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.024900% currently going ot do 25 epochs
# At minibatch 9100, batch loss 0.026348, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.029144, batch error rate 0.000000%
# At minibatch 9300, batch loss 0.010447, batch error rate 0.000000%
# At minibatch 9400, batch loss 0.022291, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.051227, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.023600% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.013283, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.014674, batch error rate 0.000000%
# At minibatch 9800, batch loss 0.025400, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.013955, batch error rate 0.000000%
# At minibatch 10000, batch loss 0.018055, batch error rate 0.000000%
# After epoch 20: valid_err_rate: 0.023700% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.012290, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.005169, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.036621, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.029872, batch error rate 1.000000%
# At minibatch 10500, batch loss 0.005388, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 0.023600% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.025262, batch error rate 1.000000%
# At minibatch 10700, batch loss 0.018800, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.033351, batch error rate 2.000000%
# At minibatch 10900, batch loss 0.035565, batch error rate 1.000000%
# At minibatch 11000, batch loss 0.012361, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.022000% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.023802, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.020548, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.041374, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.021627, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.032602, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.022400% currently going ot do 34 epochs
# At minibatch 11600, batch loss 0.013109, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.028170, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.031025, batch error rate 1.000000%
# At minibatch 11900, batch loss 0.012525, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.018260, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.023200% currently going ot do 34 epochs
# At minibatch 12100, batch loss 0.012411, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.028352, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.010967, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.015104, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.028598, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.022700% currently going ot do 34 epochs
# At minibatch 12600, batch loss 0.023107, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.022289, batch error rate 0.000000%
# At minibatch 12800, batch loss 0.018714, batch error rate 0.000000%
# At minibatch 12900, batch loss 0.040890, batch error rate 1.000000%
# At minibatch 13000, batch loss 0.023956, batch error rate 0.000000%
# After epoch 26: valid_err_rate: 0.023100% currently going ot do 34 epochs
# At minibatch 13100, batch loss 0.022724, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.007896, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.015359, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.008507, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.024053, batch error rate 1.000000%
# After epoch 27: valid_err_rate: 0.024200% currently going ot do 34 epochs
# At minibatch 13600, batch loss 0.009193, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.029737, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.015717, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.019410, batch error rate 0.000000%
# At minibatch 14000, batch loss 0.027388, batch error rate 1.000000%
# After epoch 28: valid_err_rate: 0.021900% currently going ot do 43 epochs
# At minibatch 14100, batch loss 0.015061, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.047203, batch error rate 2.000000%
# At minibatch 14300, batch loss 0.017627, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.020729, batch error rate 1.000000%
# At minibatch 14500, batch loss 0.023798, batch error rate 0.000000%
# After epoch 29: valid_err_rate: 0.022200% currently going ot do 43 epochs
# At minibatch 14600, batch loss 0.018002, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.024128, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.025115, batch error rate 1.000000%
# At minibatch 14900, batch loss 0.010526, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.022829, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.021700% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.019290, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.032954, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.016162, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.036118, batch error rate 1.000000%
# At minibatch 15500, batch loss 0.013413, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.021800% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.032365, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.016283, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.015651, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.016414, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.015635, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.022600% currently going ot do 46 epochs
# At minibatch 16100, batch loss 0.023420, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.018850, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.032295, batch error rate 1.000000%
# At minibatch 16400, batch loss 0.015788, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.029765, batch error rate 1.000000%
# After epoch 33: valid_err_rate: 0.021300% currently going ot do 50 epochs
# At minibatch 16600, batch loss 0.021130, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.018106, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.013015, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.018952, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.018165, batch error rate 1.000000%
# After epoch 34: valid_err_rate: 0.021800% currently going ot do 50 epochs
# At minibatch 17100, batch loss 0.016710, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.026863, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.023305, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.015334, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.008297, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.021100% currently going ot do 53 epochs
# At minibatch 17600, batch loss 0.015576, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.010317, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.045464, batch error rate 1.000000%
# At minibatch 17900, batch loss 0.030449, batch error rate 1.000000%
# At minibatch 18000, batch loss 0.033662, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.022500% currently going ot do 53 epochs
# At minibatch 18100, batch loss 0.023036, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.015839, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.023620, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.028213, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.029195, batch error rate 0.000000%
# After epoch 37: valid_err_rate: 0.023900% currently going ot do 53 epochs
# At minibatch 18600, batch loss 0.017844, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.013317, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.021248, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.025224, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.005777, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.021400% currently going ot do 53 epochs
# At minibatch 19100, batch loss 0.017834, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.024940, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.012936, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.024685, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.026063, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.020600% currently going ot do 59 epochs
# At minibatch 19600, batch loss 0.021737, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.009788, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.040125, batch error rate 1.000000%
# At minibatch 19900, batch loss 0.013437, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.009988, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.021200% currently going ot do 59 epochs
# At minibatch 20100, batch loss 0.021868, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.016238, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.018777, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.026492, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.036085, batch error rate 1.000000%
# After epoch 41: valid_err_rate: 0.021700% currently going ot do 59 epochs
# At minibatch 20600, batch loss 0.037136, batch error rate 1.000000%
# At minibatch 20700, batch loss 0.013921, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.014887, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.020390, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.021432, batch error rate 1.000000%
# After epoch 42: valid_err_rate: 0.020300% currently going ot do 64 epochs
# At minibatch 21100, batch loss 0.013172, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.021794, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.023619, batch error rate 1.000000%
# At minibatch 21400, batch loss 0.043651, batch error rate 1.000000%
# At minibatch 21500, batch loss 0.013103, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.019800% currently going ot do 65 epochs
# At minibatch 21600, batch loss 0.040917, batch error rate 1.000000%
# At minibatch 21700, batch loss 0.037647, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.011432, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.026637, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.014262, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.020500% currently going ot do 65 epochs
# At minibatch 22100, batch loss 0.015517, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.008009, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.015802, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.020618, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.020190, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.022200% currently going ot do 65 epochs
# At minibatch 22600, batch loss 0.017604, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.013375, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.019802, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.021172, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.029519, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.020800% currently going ot do 65 epochs
# At minibatch 23100, batch loss 0.015355, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.025422, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.013209, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.006868, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.033669, batch error rate 1.000000%
# After epoch 47: valid_err_rate: 0.021200% currently going ot do 65 epochs
# At minibatch 23600, batch loss 0.023015, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.033841, batch error rate 1.000000%
# At minibatch 23800, batch loss 0.011823, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.019153, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.019279, batch error rate 1.000000%
# After epoch 48: valid_err_rate: 0.019800% currently going ot do 65 epochs
# At minibatch 24100, batch loss 0.013296, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.013609, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.023115, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.017519, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.018613, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.021500% currently going ot do 65 epochs
# At minibatch 24600, batch loss 0.011677, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.018447, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.020318, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.023213, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.028393, batch error rate 1.000000%
# After epoch 50: valid_err_rate: 0.020400% currently going ot do 65 epochs
# At minibatch 25100, batch loss 0.010378, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.031801, batch error rate 1.000000%
# At minibatch 25300, batch loss 0.010134, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.032505, batch error rate 1.000000%
# At minibatch 25500, batch loss 0.018407, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.019900% currently going ot do 65 epochs
# At minibatch 25600, batch loss 0.020027, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.025969, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.016495, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.012429, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.012350, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.020100% currently going ot do 65 epochs
# At minibatch 26100, batch loss 0.015420, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.016724, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.032496, batch error rate 1.000000%
# At minibatch 26400, batch loss 0.014359, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.017553, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.019800% currently going ot do 65 epochs
# At minibatch 26600, batch loss 0.031117, batch error rate 1.000000%
# At minibatch 26700, batch loss 0.018805, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.020425, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.019265, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.020250, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.020300% currently going ot do 65 epochs
# At minibatch 27100, batch loss 0.066254, batch error rate 2.000000%
# At minibatch 27200, batch loss 0.029865, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.014429, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.015624, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.014972, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.020400% currently going ot do 65 epochs
# At minibatch 27600, batch loss 0.007919, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.035749, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.015797, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.022468, batch error rate 1.000000%
# At minibatch 28000, batch loss 0.018605, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.019400% currently going ot do 85 epochs
# At minibatch 28100, batch loss 0.025192, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.015640, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.026896, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.033909, batch error rate 2.000000%
# At minibatch 28500, batch loss 0.027993, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.018700% currently going ot do 86 epochs
# At minibatch 28600, batch loss 0.013627, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.012347, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.028386, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.045238, batch error rate 3.000000%
# At minibatch 29000, batch loss 0.007875, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.020700% currently going ot do 86 epochs
# At minibatch 29100, batch loss 0.025503, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.026995, batch error rate 1.000000%
# At minibatch 29300, batch loss 0.015127, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.008140, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.022511, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.020400% currently going ot do 86 epochs
# At minibatch 29600, batch loss 0.016848, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.017694, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.013041, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.024078, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.013245, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.019800% currently going ot do 86 epochs
# At minibatch 30100, batch loss 0.022156, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.009944, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.022918, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.021599, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.016222, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.019500% currently going ot do 86 epochs
# At minibatch 30600, batch loss 0.015816, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.016842, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.021569, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.023401, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.017292, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.019100% currently going ot do 86 epochs
# At minibatch 31100, batch loss 0.012094, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.029285, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.018206, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.018431, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.024083, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.019100% currently going ot do 86 epochs
# At minibatch 31600, batch loss 0.015478, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.013691, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.007053, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.023999, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.013003, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.019800% currently going ot do 86 epochs
# At minibatch 32100, batch loss 0.016768, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.013512, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.014452, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.007631, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.013071, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.019000% currently going ot do 86 epochs
# At minibatch 32600, batch loss 0.013303, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.014733, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.016628, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.027172, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.026350, batch error rate 1.000000%
# After epoch 66: valid_err_rate: 0.020300% currently going ot do 86 epochs
# At minibatch 33100, batch loss 0.017539, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.005615, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.024187, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.018115, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.019659, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.019100% currently going ot do 86 epochs
# At minibatch 33600, batch loss 0.019115, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.018449, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.011318, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.018046, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.024776, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.019800% currently going ot do 86 epochs
# At minibatch 34100, batch loss 0.026297, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.029831, batch error rate 1.000000%
# At minibatch 34300, batch loss 0.019973, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.022119, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.025787, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.019300% currently going ot do 86 epochs
# At minibatch 34600, batch loss 0.013490, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.007435, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.012688, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.026378, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.027337, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.018500% currently going ot do 106 epochs
# At minibatch 35100, batch loss 0.012273, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.008542, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.013425, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.018926, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.017055, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.019000% currently going ot do 106 epochs
# At minibatch 35600, batch loss 0.027185, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.015285, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.012592, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.022653, batch error rate 1.000000%
# At minibatch 36000, batch loss 0.014146, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.019100% currently going ot do 106 epochs
# At minibatch 36100, batch loss 0.008125, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.019668, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.019424, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.020075, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.016595, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.018700% currently going ot do 106 epochs
# At minibatch 36600, batch loss 0.031966, batch error rate 1.000000%
# At minibatch 36700, batch loss 0.018875, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.008451, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.022901, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.009014, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.018800% currently going ot do 106 epochs
# At minibatch 37100, batch loss 0.010877, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.017170, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.011447, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.014517, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.025758, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.018600% currently going ot do 106 epochs
# At minibatch 37600, batch loss 0.014125, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.005955, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.006555, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.021548, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.006834, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.018800% currently going ot do 106 epochs
# At minibatch 38100, batch loss 0.006519, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.021301, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.009467, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.007717, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.014202, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.019200% currently going ot do 106 epochs
# At minibatch 38600, batch loss 0.017766, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.029542, batch error rate 1.000000%
# At minibatch 38800, batch loss 0.012404, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.017937, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.039829, batch error rate 2.000000%
# After epoch 78: valid_err_rate: 0.021000% currently going ot do 106 epochs
# At minibatch 39100, batch loss 0.012437, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.010358, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.033356, batch error rate 1.000000%
# At minibatch 39400, batch loss 0.015470, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.035215, batch error rate 1.000000%
# After epoch 79: valid_err_rate: 0.019300% currently going ot do 106 epochs
# At minibatch 39600, batch loss 0.007779, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.012763, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.018003, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.008597, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.027872, batch error rate 1.000000%
# After epoch 80: valid_err_rate: 0.018400% currently going ot do 121 epochs
# At minibatch 40100, batch loss 0.015597, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.011354, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.014521, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.023309, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.015057, batch error rate 1.000000%
# After epoch 81: valid_err_rate: 0.019000% currently going ot do 121 epochs
# At minibatch 40600, batch loss 0.017920, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.020567, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.017661, batch error rate 0.000000%
# At minibatch 40900, batch loss 0.015096, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.027741, batch error rate 1.000000%
# After epoch 82: valid_err_rate: 0.019400% currently going ot do 121 epochs
# At minibatch 41100, batch loss 0.021729, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.012198, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.018916, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.031414, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.018262, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.019800% currently going ot do 121 epochs
# At minibatch 41600, batch loss 0.029112, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.010735, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.016470, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.023461, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.016141, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.018200% currently going ot do 127 epochs
# At minibatch 42100, batch loss 0.019772, batch error rate 1.000000%
# At minibatch 42200, batch loss 0.016406, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.025733, batch error rate 1.000000%
# At minibatch 42400, batch loss 0.018040, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.009746, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.019400% currently going ot do 127 epochs
# At minibatch 42600, batch loss 0.023393, batch error rate 0.000000%
# At minibatch 42700, batch loss 0.013790, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.025219, batch error rate 1.000000%
# At minibatch 42900, batch loss 0.023780, batch error rate 1.000000%
# At minibatch 43000, batch loss 0.011634, batch error rate 0.000000%
# After epoch 86: valid_err_rate: 0.019200% currently going ot do 127 epochs
# At minibatch 43100, batch loss 0.035272, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.006173, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.014323, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.019624, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.013297, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.018100% currently going ot do 131 epochs
# At minibatch 43600, batch loss 0.010922, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.005786, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.010934, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.011829, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.010911, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.019200% currently going ot do 131 epochs
# At minibatch 44100, batch loss 0.024103, batch error rate 1.000000%
# At minibatch 44200, batch loss 0.020356, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.018894, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.017309, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.010472, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.019500% currently going ot do 131 epochs
# At minibatch 44600, batch loss 0.013393, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.011131, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.019012, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.012930, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.016447, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.018500% currently going ot do 131 epochs
# At minibatch 45100, batch loss 0.015115, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.020859, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.028522, batch error rate 1.000000%
# At minibatch 45400, batch loss 0.019113, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.023123, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.019400% currently going ot do 131 epochs
# At minibatch 45600, batch loss 0.012878, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.021962, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.011976, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.017267, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.023886, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.019900% currently going ot do 131 epochs
# At minibatch 46100, batch loss 0.013846, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.017151, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.011082, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.012761, batch error rate 0.000000%
# At minibatch 46500, batch loss 0.012749, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.019400% currently going ot do 131 epochs
# At minibatch 46600, batch loss 0.010946, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.016855, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.012980, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.013553, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.016536, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.018200% currently going ot do 131 epochs
# At minibatch 47100, batch loss 0.014040, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.023820, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.014145, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.008465, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.015778, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.019100% currently going ot do 131 epochs
# At minibatch 47600, batch loss 0.021299, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.021778, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.016643, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.017223, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.016772, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.019300% currently going ot do 131 epochs
# At minibatch 48100, batch loss 0.031395, batch error rate 1.000000%
# At minibatch 48200, batch loss 0.018351, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.034923, batch error rate 1.000000%
# At minibatch 48400, batch loss 0.020205, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.018726, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.019000% currently going ot do 131 epochs
# At minibatch 48600, batch loss 0.009477, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.005867, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.008320, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.017584, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.023305, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.018500% currently going ot do 131 epochs
# At minibatch 49100, batch loss 0.015109, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.025826, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.013392, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.011872, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.019800, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.018300% currently going ot do 131 epochs
# At minibatch 49600, batch loss 0.016004, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.020528, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.013038, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.005134, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.028517, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.019000% currently going ot do 131 epochs
# At minibatch 50100, batch loss 0.016793, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.028661, batch error rate 1.000000%
# At minibatch 50300, batch loss 0.009608, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.031601, batch error rate 1.000000%
# At minibatch 50500, batch loss 0.019984, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.018600% currently going ot do 131 epochs
# At minibatch 50600, batch loss 0.014143, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.019451, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.012602, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.022715, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.015745, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.018600% currently going ot do 131 epochs
# At minibatch 51100, batch loss 0.011472, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.007652, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.016622, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.011724, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.018400, batch error rate 1.000000%
# After epoch 103: valid_err_rate: 0.019000% currently going ot do 131 epochs
# At minibatch 51600, batch loss 0.036358, batch error rate 1.000000%
# At minibatch 51700, batch loss 0.010638, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.022002, batch error rate 1.000000%
# At minibatch 51900, batch loss 0.014082, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.023340, batch error rate 1.000000%
# After epoch 104: valid_err_rate: 0.017900% currently going ot do 157 epochs
# At minibatch 52100, batch loss 0.019417, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.015934, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.011305, batch error rate 0.000000%
# At minibatch 52400, batch loss 0.020254, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.026277, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.018700% currently going ot do 157 epochs
# At minibatch 52600, batch loss 0.024526, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.013716, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.010946, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.006530, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.014713, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.018800% currently going ot do 157 epochs
# At minibatch 53100, batch loss 0.024791, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.007820, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.009867, batch error rate 0.000000%
# At minibatch 53400, batch loss 0.014282, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.016271, batch error rate 1.000000%
# After epoch 107: valid_err_rate: 0.019400% currently going ot do 157 epochs
# At minibatch 53600, batch loss 0.018262, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.014083, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.012093, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.015495, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.008383, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.018000% currently going ot do 157 epochs
# At minibatch 54100, batch loss 0.014781, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.008455, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.025378, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.010610, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.012305, batch error rate 0.000000%
# After epoch 109: valid_err_rate: 0.019200% currently going ot do 157 epochs
# At minibatch 54600, batch loss 0.016691, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.022785, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.025745, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.016943, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.009348, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.018400% currently going ot do 157 epochs
# At minibatch 55100, batch loss 0.026996, batch error rate 1.000000%
# At minibatch 55200, batch loss 0.024327, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.014325, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.018287, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.016841, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.017700% currently going ot do 167 epochs
# At minibatch 55600, batch loss 0.030145, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.013160, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.029685, batch error rate 1.000000%
# At minibatch 55900, batch loss 0.016199, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.008684, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.018700% currently going ot do 167 epochs
# At minibatch 56100, batch loss 0.036271, batch error rate 1.000000%
# At minibatch 56200, batch loss 0.010696, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.021561, batch error rate 1.000000%
# At minibatch 56400, batch loss 0.017510, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.008835, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.017800% currently going ot do 167 epochs
# At minibatch 56600, batch loss 0.014365, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.017655, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.031915, batch error rate 1.000000%
# At minibatch 56900, batch loss 0.014087, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.019246, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.018500% currently going ot do 167 epochs
# At minibatch 57100, batch loss 0.027351, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.007294, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.014979, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.013735, batch error rate 0.000000%
# At minibatch 57500, batch loss 0.016532, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.018700% currently going ot do 167 epochs
# At minibatch 57600, batch loss 0.011583, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.016549, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.010165, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.008531, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.021199, batch error rate 0.000000%
# ...
# After epoch 151: valid_err_rate: 0.018300% currently going ot do 188 epochs
# At minibatch 75600, batch loss 0.021402, batch error rate 0.000000%
# At minibatch 75700, batch loss 0.010174, batch error rate 0.000000%
# At minibatch 75800, batch loss 0.015498, batch error rate 0.000000%
# At minibatch 75900, batch loss 0.021728, batch error rate 0.000000%
# At minibatch 76000, batch loss 0.010173, batch error rate 0.000000%
# After epoch 152: valid_err_rate: 0.018100% currently going ot do 188 epochs
# At minibatch 76100, batch loss 0.011691, batch error rate 0.000000%
# At minibatch 76200, batch loss 0.015372, batch error rate 0.000000%
# At minibatch 76300, batch loss 0.020028, batch error rate 1.000000%
# At minibatch 76400, batch loss 0.024083, batch error rate 0.000000%
# At minibatch 76500, batch loss 0.014716, batch error rate 0.000000%
# After epoch 153: valid_err_rate: 0.018600% currently going ot do 188 epochs
# At minibatch 76600, batch loss 0.014283, batch error rate 0.000000%
# At minibatch 76700, batch loss 0.012823, batch error rate 0.000000%
# At minibatch 76800, batch loss 0.016209, batch error rate 0.000000%
# At minibatch 76900, batch loss 0.014851, batch error rate 0.000000%
# At minibatch 77000, batch loss 0.006476, batch error rate 0.000000%
# After epoch 154: valid_err_rate: 0.018100% currently going ot do 188 epochs
# At minibatch 77100, batch loss 0.007525, batch error rate 0.000000%
# At minibatch 77200, batch loss 0.016658, batch error rate 0.000000%
# At minibatch 77300, batch loss 0.012083, batch error rate 0.000000%
# At minibatch 77400, batch loss 0.013910, batch error rate 0.000000%
# At minibatch 77500, batch loss 0.005150, batch error rate 0.000000%
# After epoch 155: valid_err_rate: 0.018300% currently going ot do 188 epochs
# At minibatch 77600, batch loss 0.005747, batch error rate 0.000000%
# At minibatch 77700, batch loss 0.023062, batch error rate 0.000000%
# At minibatch 77800, batch loss 0.009655, batch error rate 0.000000%
# At minibatch 77900, batch loss 0.010549, batch error rate 0.000000%
# At minibatch 78000, batch loss 0.029313, batch error rate 1.000000%
# After epoch 156: valid_err_rate: 0.018800% currently going ot do 188 epochs
# At minibatch 78100, batch loss 0.012426, batch error rate 0.000000%
# At minibatch 78200, batch loss 0.012298, batch error rate 0.000000%
# At minibatch 78300, batch loss 0.016901, batch error rate 0.000000%
# At minibatch 78400, batch loss 0.013698, batch error rate 0.000000%
# At minibatch 78500, batch loss 0.013395, batch error rate 0.000000%
# After epoch 157: valid_err_rate: 0.018400% currently going ot do 188 epochs
# At minibatch 78600, batch loss 0.016545, batch error rate 0.000000%
# At minibatch 78700, batch loss 0.010058, batch error rate 0.000000%
# At minibatch 78800, batch loss 0.027832, batch error rate 0.000000%
# At minibatch 78900, batch loss 0.011645, batch error rate 0.000000%
# At minibatch 79000, batch loss 0.014258, batch error rate 0.000000%
# After epoch 158: valid_err_rate: 0.017600% currently going ot do 188 epochs
# At minibatch 79100, batch loss 0.011760, batch error rate 0.000000%
# At minibatch 79200, batch loss 0.013860, batch error rate 0.000000%
# At minibatch 79300, batch loss 0.015639, batch error rate 0.000000%
# At minibatch 79400, batch loss 0.022955, batch error rate 0.000000%
# At minibatch 79500, batch loss 0.008647, batch error rate 0.000000%
# After epoch 159: valid_err_rate: 0.017800% currently going ot do 188 epochs
# At minibatch 79600, batch loss 0.011767, batch error rate 0.000000%
# At minibatch 79700, batch loss 0.019818, batch error rate 0.000000%
# At minibatch 79800, batch loss 0.009553, batch error rate 0.000000%
# At minibatch 79900, batch loss 0.018441, batch error rate 0.000000%
# At minibatch 80000, batch loss 0.020330, batch error rate 0.000000%
# After epoch 160: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 80100, batch loss 0.017629, batch error rate 0.000000%
# At minibatch 80200, batch loss 0.014573, batch error rate 0.000000%
# At minibatch 80300, batch loss 0.017524, batch error rate 0.000000%
# At minibatch 80400, batch loss 0.010231, batch error rate 0.000000%
# At minibatch 80500, batch loss 0.015829, batch error rate 0.000000%
# After epoch 161: valid_err_rate: 0.018500% currently going ot do 188 epochs
# At minibatch 80600, batch loss 0.020397, batch error rate 0.000000%
# At minibatch 80700, batch loss 0.013136, batch error rate 0.000000%
# At minibatch 80800, batch loss 0.012082, batch error rate 0.000000%
# At minibatch 80900, batch loss 0.014751, batch error rate 0.000000%
# At minibatch 81000, batch loss 0.014228, batch error rate 0.000000%
# After epoch 162: valid_err_rate: 0.018200% currently going ot do 188 epochs
# At minibatch 81100, batch loss 0.009582, batch error rate 0.000000%
# At minibatch 81200, batch loss 0.024574, batch error rate 0.000000%
# At minibatch 81300, batch loss 0.013922, batch error rate 0.000000%
# At minibatch 81400, batch loss 0.012415, batch error rate 0.000000%
# At minibatch 81500, batch loss 0.013468, batch error rate 0.000000%
# After epoch 163: valid_err_rate: 0.018400% currently going ot do 188 epochs
# At minibatch 81600, batch loss 0.006534, batch error rate 0.000000%
# At minibatch 81700, batch loss 0.017840, batch error rate 0.000000%
# At minibatch 81800, batch loss 0.015613, batch error rate 0.000000%
# At minibatch 81900, batch loss 0.012473, batch error rate 0.000000%
# At minibatch 82000, batch loss 0.011444, batch error rate 0.000000%
# After epoch 164: valid_err_rate: 0.018100% currently going ot do 188 epochs
# At minibatch 82100, batch loss 0.011336, batch error rate 0.000000%
# At minibatch 82200, batch loss 0.020983, batch error rate 0.000000%
# At minibatch 82300, batch loss 0.014824, batch error rate 0.000000%
# At minibatch 82400, batch loss 0.021266, batch error rate 1.000000%
# At minibatch 82500, batch loss 0.011508, batch error rate 0.000000%
# After epoch 165: valid_err_rate: 0.017900% currently going ot do 188 epochs
# At minibatch 82600, batch loss 0.010061, batch error rate 0.000000%
# At minibatch 82700, batch loss 0.010896, batch error rate 0.000000%
# At minibatch 82800, batch loss 0.013859, batch error rate 0.000000%
# At minibatch 82900, batch loss 0.033108, batch error rate 2.000000%
# At minibatch 83000, batch loss 0.012163, batch error rate 0.000000%
# After epoch 166: valid_err_rate: 0.017500% currently going ot do 188 epochs
# At minibatch 83100, batch loss 0.009912, batch error rate 0.000000%
# At minibatch 83200, batch loss 0.012271, batch error rate 0.000000%
# At minibatch 83300, batch loss 0.012609, batch error rate 0.000000%
# At minibatch 83400, batch loss 0.011300, batch error rate 0.000000%
# At minibatch 83500, batch loss 0.009301, batch error rate 0.000000%
# After epoch 167: valid_err_rate: 0.018600% currently going ot do 188 epochs
# At minibatch 83600, batch loss 0.020054, batch error rate 0.000000%
# At minibatch 83700, batch loss 0.020467, batch error rate 0.000000%
# At minibatch 83800, batch loss 0.017208, batch error rate 0.000000%
# At minibatch 83900, batch loss 0.016001, batch error rate 0.000000%
# At minibatch 84000, batch loss 0.029695, batch error rate 1.000000%
# After epoch 168: valid_err_rate: 0.017900% currently going ot do 188 epochs
# At minibatch 84100, batch loss 0.032648, batch error rate 0.000000%
# At minibatch 84200, batch loss 0.015031, batch error rate 0.000000%
# At minibatch 84300, batch loss 0.016074, batch error rate 0.000000%
# At minibatch 84400, batch loss 0.017365, batch error rate 0.000000%
# At minibatch 84500, batch loss 0.019412, batch error rate 0.000000%
# After epoch 169: valid_err_rate: 0.018400% currently going ot do 188 epochs
# At minibatch 84600, batch loss 0.011762, batch error rate 0.000000%
# At minibatch 84700, batch loss 0.018042, batch error rate 0.000000%
# At minibatch 84800, batch loss 0.018226, batch error rate 0.000000%
# At minibatch 84900, batch loss 0.013920, batch error rate 0.000000%
# At minibatch 85000, batch loss 0.010711, batch error rate 0.000000%
# After epoch 170: valid_err_rate: 0.018100% currently going ot do 188 epochs
# At minibatch 85100, batch loss 0.020348, batch error rate 0.000000%
# At minibatch 85200, batch loss 0.023475, batch error rate 0.000000%
# At minibatch 85300, batch loss 0.010181, batch error rate 0.000000%
# At minibatch 85400, batch loss 0.014517, batch error rate 0.000000%
# At minibatch 85500, batch loss 0.009999, batch error rate 0.000000%
# After epoch 171: valid_err_rate: 0.017800% currently going ot do 188 epochs
# At minibatch 85600, batch loss 0.012347, batch error rate 0.000000%
# At minibatch 85700, batch loss 0.015601, batch error rate 0.000000%
# At minibatch 85800, batch loss 0.022653, batch error rate 1.000000%
# At minibatch 85900, batch loss 0.011697, batch error rate 0.000000%
# At minibatch 86000, batch loss 0.031572, batch error rate 0.000000%
# After epoch 172: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 86100, batch loss 0.011829, batch error rate 0.000000%
# At minibatch 86200, batch loss 0.015262, batch error rate 0.000000%
# At minibatch 86300, batch loss 0.012972, batch error rate 0.000000%
# At minibatch 86400, batch loss 0.004991, batch error rate 0.000000%
# At minibatch 86500, batch loss 0.020039, batch error rate 0.000000%
# After epoch 173: valid_err_rate: 0.018700% currently going ot do 188 epochs
# At minibatch 86600, batch loss 0.026066, batch error rate 0.000000%
# At minibatch 86700, batch loss 0.007534, batch error rate 0.000000%
# At minibatch 86800, batch loss 0.010586, batch error rate 0.000000%
# At minibatch 86900, batch loss 0.010147, batch error rate 0.000000%
# At minibatch 87000, batch loss 0.012818, batch error rate 0.000000%
# After epoch 174: valid_err_rate: 0.018400% currently going ot do 188 epochs
# At minibatch 87100, batch loss 0.008760, batch error rate 0.000000%
# At minibatch 87200, batch loss 0.016611, batch error rate 0.000000%
# At minibatch 87300, batch loss 0.019804, batch error rate 0.000000%
# At minibatch 87400, batch loss 0.015654, batch error rate 0.000000%
# At minibatch 87500, batch loss 0.016328, batch error rate 0.000000%
# After epoch 175: valid_err_rate: 0.018000% currently going ot do 188 epochs
# At minibatch 87600, batch loss 0.011084, batch error rate 0.000000%
# At minibatch 87700, batch loss 0.010569, batch error rate 0.000000%
# At minibatch 87800, batch loss 0.017426, batch error rate 0.000000%
# At minibatch 87900, batch loss 0.012427, batch error rate 0.000000%
# At minibatch 88000, batch loss 0.021160, batch error rate 1.000000%
# After epoch 176: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 88100, batch loss 0.010114, batch error rate 0.000000%
# At minibatch 88200, batch loss 0.013856, batch error rate 0.000000%
# At minibatch 88300, batch loss 0.022021, batch error rate 0.000000%
# At minibatch 88400, batch loss 0.017277, batch error rate 0.000000%
# At minibatch 88500, batch loss 0.013134, batch error rate 0.000000%
# After epoch 177: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 88600, batch loss 0.013674, batch error rate 0.000000%
# At minibatch 88700, batch loss 0.015252, batch error rate 0.000000%
# At minibatch 88800, batch loss 0.006137, batch error rate 0.000000%
# At minibatch 88900, batch loss 0.006919, batch error rate 0.000000%
# At minibatch 89000, batch loss 0.011235, batch error rate 0.000000%
# After epoch 178: valid_err_rate: 0.017800% currently going ot do 188 epochs
# At minibatch 89100, batch loss 0.011732, batch error rate 0.000000%
# At minibatch 89200, batch loss 0.019634, batch error rate 0.000000%
# At minibatch 89300, batch loss 0.018110, batch error rate 0.000000%
# At minibatch 89400, batch loss 0.021223, batch error rate 0.000000%
# At minibatch 89500, batch loss 0.024806, batch error rate 0.000000%
# After epoch 179: valid_err_rate: 0.019000% currently going ot do 188 epochs
# At minibatch 89600, batch loss 0.009797, batch error rate 0.000000%
# At minibatch 89700, batch loss 0.014775, batch error rate 0.000000%
# At minibatch 89800, batch loss 0.016558, batch error rate 0.000000%
# At minibatch 89900, batch loss 0.013250, batch error rate 0.000000%
# At minibatch 90000, batch loss 0.014183, batch error rate 0.000000%
# After epoch 180: valid_err_rate: 0.018000% currently going ot do 188 epochs
# At minibatch 90100, batch loss 0.020269, batch error rate 0.000000%
# At minibatch 90200, batch loss 0.013883, batch error rate 0.000000%
# At minibatch 90300, batch loss 0.014230, batch error rate 0.000000%
# At minibatch 90400, batch loss 0.007464, batch error rate 0.000000%
# At minibatch 90500, batch loss 0.011552, batch error rate 0.000000%
# After epoch 181: valid_err_rate: 0.018000% currently going ot do 188 epochs
# At minibatch 90600, batch loss 0.024793, batch error rate 1.000000%
# At minibatch 90700, batch loss 0.012699, batch error rate 0.000000%
# At minibatch 90800, batch loss 0.009505, batch error rate 0.000000%
# At minibatch 90900, batch loss 0.013094, batch error rate 0.000000%
# At minibatch 91000, batch loss 0.010690, batch error rate 0.000000%
# After epoch 182: valid_err_rate: 0.018300% currently going ot do 188 epochs
# At minibatch 91100, batch loss 0.007604, batch error rate 0.000000%
# At minibatch 91200, batch loss 0.012125, batch error rate 0.000000%
# At minibatch 91300, batch loss 0.006891, batch error rate 0.000000%
# At minibatch 91400, batch loss 0.014180, batch error rate 0.000000%
# At minibatch 91500, batch loss 0.012672, batch error rate 0.000000%
# After epoch 183: valid_err_rate: 0.018500% currently going ot do 188 epochs
# At minibatch 91600, batch loss 0.015801, batch error rate 0.000000%
# At minibatch 91700, batch loss 0.018786, batch error rate 0.000000%
# At minibatch 91800, batch loss 0.014629, batch error rate 0.000000%
# At minibatch 91900, batch loss 0.025417, batch error rate 0.000000%
# At minibatch 92000, batch loss 0.009520, batch error rate 0.000000%
# After epoch 184: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 92100, batch loss 0.015237, batch error rate 0.000000%
# At minibatch 92200, batch loss 0.014734, batch error rate 0.000000%
# At minibatch 92300, batch loss 0.011956, batch error rate 0.000000%
# At minibatch 92400, batch loss 0.016444, batch error rate 0.000000%
# At minibatch 92500, batch loss 0.009905, batch error rate 0.000000%
# After epoch 185: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 92600, batch loss 0.005972, batch error rate 0.000000%
# At minibatch 92700, batch loss 0.005578, batch error rate 0.000000%
# At minibatch 92800, batch loss 0.013618, batch error rate 0.000000%
# At minibatch 92900, batch loss 0.022337, batch error rate 0.000000%
# At minibatch 93000, batch loss 0.008867, batch error rate 0.000000%
# After epoch 186: valid_err_rate: 0.018600% currently going ot do 188 epochs
# At minibatch 93100, batch loss 0.011791, batch error rate 0.000000%
# At minibatch 93200, batch loss 0.015570, batch error rate 0.000000%
# At minibatch 93300, batch loss 0.008850, batch error rate 0.000000%
# At minibatch 93400, batch loss 0.022442, batch error rate 1.000000%
# At minibatch 93500, batch loss 0.006051, batch error rate 0.000000%
# After epoch 187: valid_err_rate: 0.018100% currently going ot do 188 epochs
# At minibatch 93600, batch loss 0.007613, batch error rate 0.000000%
# At minibatch 93700, batch loss 0.019556, batch error rate 1.000000%
# At minibatch 93800, batch loss 0.020811, batch error rate 0.000000%
# At minibatch 93900, batch loss 0.008754, batch error rate 0.000000%
# At minibatch 94000, batch loss 0.009689, batch error rate 0.000000%
# After epoch 188: valid_err_rate: 0.017700% currently going ot do 188 epochs
# At minibatch 94100, batch loss 0.005719, batch error rate 0.000000%
# At minibatch 94200, batch loss 0.018500, batch error rate 0.000000%
# At minibatch 94300, batch loss 0.012432, batch error rate 0.000000%
# At minibatch 94400, batch loss 0.014214, batch error rate 0.000000%
# At minibatch 94500, batch loss 0.010945, batch error rate 0.000000%
# After epoch 189: valid_err_rate: 0.017500% currently going ot do 188 epochs
# Finished with 189 epochs (minibatch 94500), with best valid error rate 0.017000

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0175

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
weight_init = IsotropicGaussian(std=0.05, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 10, weight_init = weight_init, dropout = 0.5),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 1000,
    regularization_rate = 0.0,
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg3())

net1 = net
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 2.235817, batch error rate 82.000000%
# At minibatch 200, batch loss 2.294521, batch error rate 90.000000%
# At minibatch 300, batch loss 2.251549, batch error rate 86.000000%
# At minibatch 400, batch loss 2.111785, batch error rate 71.000000%
# At minibatch 500, batch loss 2.155147, batch error rate 67.000000%
# After epoch 1: valid_err_rate: 0.463200% currently going ot do 1000 epochs
# At minibatch 600, batch loss 2.002360, batch error rate 70.000000%
# At minibatch 700, batch loss 2.047866, batch error rate 54.000000%
# At minibatch 800, batch loss 2.006921, batch error rate 65.000000%
# At minibatch 900, batch loss 1.888745, batch error rate 55.000000%
# At minibatch 1000, batch loss 1.757187, batch error rate 52.000000%
# After epoch 2: valid_err_rate: 0.319900% currently going ot do 1000 epochs
# At minibatch 1100, batch loss 1.775835, batch error rate 50.000000%
# At minibatch 1200, batch loss 1.634271, batch error rate 54.000000%
# At minibatch 1300, batch loss 1.546748, batch error rate 60.000000%
# At minibatch 1400, batch loss 1.551481, batch error rate 39.000000%
# At minibatch 1500, batch loss 1.333248, batch error rate 43.000000%
# After epoch 3: valid_err_rate: 0.244000% currently going ot do 1000 epochs
# At minibatch 1600, batch loss 1.249351, batch error rate 43.000000%
# At minibatch 1700, batch loss 1.265222, batch error rate 43.000000%
# At minibatch 1800, batch loss 1.188906, batch error rate 48.000000%
# At minibatch 1900, batch loss 1.162097, batch error rate 36.000000%
# At minibatch 2000, batch loss 1.135175, batch error rate 40.000000%
# After epoch 4: valid_err_rate: 0.200300% currently going ot do 1000 epochs
# At minibatch 2100, batch loss 1.067825, batch error rate 35.000000%
# At minibatch 2200, batch loss 0.940923, batch error rate 28.000000%
# At minibatch 2300, batch loss 1.111717, batch error rate 38.000000%
# At minibatch 2400, batch loss 1.081097, batch error rate 33.000000%
# At minibatch 2500, batch loss 0.882646, batch error rate 25.000000%
# After epoch 5: valid_err_rate: 0.176400% currently going ot do 1000 epochs
# At minibatch 2600, batch loss 1.044032, batch error rate 34.000000%
# At minibatch 2700, batch loss 0.827932, batch error rate 29.000000%
# At minibatch 2800, batch loss 0.868337, batch error rate 25.000000%
# At minibatch 2900, batch loss 0.718232, batch error rate 21.000000%
# At minibatch 3000, batch loss 0.989190, batch error rate 30.000000%
# After epoch 6: valid_err_rate: 0.153700% currently going ot do 1000 epochs
# At minibatch 3100, batch loss 0.961773, batch error rate 29.000000%
# At minibatch 3200, batch loss 0.815247, batch error rate 26.000000%
# At minibatch 3300, batch loss 0.905069, batch error rate 25.000000%
# At minibatch 3400, batch loss 0.756129, batch error rate 23.000000%
# At minibatch 3500, batch loss 0.608044, batch error rate 22.000000%
# After epoch 7: valid_err_rate: 0.142400% currently going ot do 1000 epochs
# At minibatch 3600, batch loss 0.897505, batch error rate 32.000000%
# At minibatch 3700, batch loss 0.798290, batch error rate 24.000000%
# At minibatch 3800, batch loss 0.716721, batch error rate 25.000000%
# At minibatch 3900, batch loss 0.869519, batch error rate 25.000000%
# At minibatch 4000, batch loss 0.747260, batch error rate 28.000000%
# After epoch 8: valid_err_rate: 0.128100% currently going ot do 1000 epochs
# At minibatch 4100, batch loss 0.844556, batch error rate 27.000000%
# At minibatch 4200, batch loss 0.554070, batch error rate 18.000000%
# At minibatch 4300, batch loss 0.856600, batch error rate 31.000000%
# At minibatch 4400, batch loss 0.614469, batch error rate 16.000000%
# At minibatch 4500, batch loss 0.899168, batch error rate 25.000000%
# After epoch 9: valid_err_rate: 0.123600% currently going ot do 1000 epochs
# At minibatch 4600, batch loss 0.723767, batch error rate 24.000000%
# At minibatch 4700, batch loss 0.461538, batch error rate 10.000000%
# At minibatch 4800, batch loss 0.706409, batch error rate 24.000000%
# At minibatch 4900, batch loss 0.415702, batch error rate 9.000000%
# At minibatch 5000, batch loss 0.653676, batch error rate 17.000000%
# After epoch 10: valid_err_rate: 0.118800% currently going ot do 1000 epochs
# At minibatch 5100, batch loss 0.427468, batch error rate 11.000000%
# At minibatch 5200, batch loss 0.680496, batch error rate 22.000000%
# At minibatch 5300, batch loss 0.657046, batch error rate 21.000000%
# At minibatch 5400, batch loss 0.670351, batch error rate 15.000000%
# At minibatch 5500, batch loss 0.504936, batch error rate 15.000000%
# After epoch 11: valid_err_rate: 0.108800% currently going ot do 1000 epochs
# At minibatch 5600, batch loss 0.537214, batch error rate 19.000000%
# At minibatch 5700, batch loss 0.676649, batch error rate 20.000000%
# At minibatch 5800, batch loss 0.501712, batch error rate 15.000000%
# At minibatch 5900, batch loss 0.494493, batch error rate 17.000000%
# At minibatch 6000, batch loss 0.376188, batch error rate 10.000000%
# After epoch 12: valid_err_rate: 0.105800% currently going ot do 1000 epochs
# At minibatch 6100, batch loss 0.708154, batch error rate 22.000000%
# At minibatch 6200, batch loss 0.461529, batch error rate 12.000000%
# At minibatch 6300, batch loss 0.577426, batch error rate 14.000000%
# At minibatch 6400, batch loss 0.532130, batch error rate 15.000000%
# At minibatch 6500, batch loss 0.514356, batch error rate 18.000000%
# After epoch 13: valid_err_rate: 0.102200% currently going ot do 1000 epochs
# At minibatch 6600, batch loss 0.624483, batch error rate 17.000000%
# At minibatch 6700, batch loss 0.398858, batch error rate 15.000000%
# At minibatch 6800, batch loss 0.689186, batch error rate 21.000000%
# At minibatch 6900, batch loss 0.577702, batch error rate 17.000000%
# At minibatch 7000, batch loss 0.418711, batch error rate 13.000000%
# After epoch 14: valid_err_rate: 0.100200% currently going ot do 1000 epochs
# At minibatch 7100, batch loss 0.475081, batch error rate 14.000000%
# At minibatch 7200, batch loss 0.403719, batch error rate 14.000000%
# At minibatch 7300, batch loss 0.566585, batch error rate 18.000000%
# At minibatch 7400, batch loss 0.585716, batch error rate 21.000000%
# At minibatch 7500, batch loss 0.523589, batch error rate 12.000000%
# After epoch 15: valid_err_rate: 0.096500% currently going ot do 1000 epochs
# At minibatch 7600, batch loss 0.393910, batch error rate 13.000000%
# At minibatch 7700, batch loss 0.496815, batch error rate 12.000000%
# At minibatch 7800, batch loss 0.510380, batch error rate 18.000000%
# At minibatch 7900, batch loss 0.336364, batch error rate 13.000000%
# At minibatch 8000, batch loss 0.339398, batch error rate 16.000000%
# After epoch 16: valid_err_rate: 0.093700% currently going ot do 1000 epochs
# At minibatch 8100, batch loss 0.523708, batch error rate 22.000000%
# At minibatch 8200, batch loss 0.567320, batch error rate 14.000000%
# At minibatch 8300, batch loss 0.558494, batch error rate 17.000000%
# At minibatch 8400, batch loss 0.450535, batch error rate 13.000000%
# At minibatch 8500, batch loss 0.431663, batch error rate 10.000000%
# After epoch 17: valid_err_rate: 0.092900% currently going ot do 1000 epochs
# At minibatch 8600, batch loss 0.617229, batch error rate 20.000000%
# At minibatch 8700, batch loss 0.546450, batch error rate 15.000000%
# At minibatch 8800, batch loss 0.396106, batch error rate 11.000000%
# At minibatch 8900, batch loss 0.441073, batch error rate 10.000000%
# At minibatch 9000, batch loss 0.379315, batch error rate 13.000000%
# After epoch 18: valid_err_rate: 0.090800% currently going ot do 1000 epochs
# At minibatch 9100, batch loss 0.645373, batch error rate 18.000000%
# At minibatch 9200, batch loss 0.569347, batch error rate 17.000000%
# At minibatch 9300, batch loss 0.668335, batch error rate 19.000000%
# At minibatch 9400, batch loss 0.610685, batch error rate 18.000000%
# At minibatch 9500, batch loss 0.390254, batch error rate 11.000000%
# After epoch 19: valid_err_rate: 0.089300% currently going ot do 1000 epochs
# At minibatch 9600, batch loss 0.401707, batch error rate 12.000000%
# At minibatch 9700, batch loss 0.242015, batch error rate 4.000000%
# At minibatch 9800, batch loss 0.396116, batch error rate 13.000000%
# At minibatch 9900, batch loss 0.676167, batch error rate 26.000000%
# At minibatch 10000, batch loss 0.412657, batch error rate 13.000000%
# After epoch 20: valid_err_rate: 0.085500% currently going ot do 1000 epochs
# At minibatch 10100, batch loss 0.516918, batch error rate 14.000000%
# At minibatch 10200, batch loss 0.240295, batch error rate 6.000000%
# At minibatch 10300, batch loss 0.326214, batch error rate 12.000000%
# At minibatch 10400, batch loss 0.376142, batch error rate 11.000000%
# At minibatch 10500, batch loss 0.585585, batch error rate 18.000000%
# After epoch 21: valid_err_rate: 0.083500% currently going ot do 1000 epochs
# At minibatch 10600, batch loss 0.210448, batch error rate 6.000000%
# At minibatch 10700, batch loss 0.339790, batch error rate 12.000000%
# At minibatch 10800, batch loss 0.465552, batch error rate 16.000000%
# At minibatch 10900, batch loss 0.516950, batch error rate 17.000000%
# At minibatch 11000, batch loss 0.489140, batch error rate 11.000000%
# After epoch 22: valid_err_rate: 0.083100% currently going ot do 1000 epochs
# At minibatch 11100, batch loss 0.472753, batch error rate 13.000000%
# At minibatch 11200, batch loss 0.414253, batch error rate 14.000000%
# At minibatch 11300, batch loss 0.241248, batch error rate 5.000000%
# At minibatch 11400, batch loss 0.385960, batch error rate 10.000000%
# At minibatch 11500, batch loss 0.463535, batch error rate 15.000000%
# After epoch 23: valid_err_rate: 0.083700% currently going ot do 1000 epochs
# At minibatch 11600, batch loss 0.416180, batch error rate 15.000000%
# At minibatch 11700, batch loss 0.460805, batch error rate 15.000000%
# At minibatch 11800, batch loss 0.540040, batch error rate 21.000000%
# At minibatch 11900, batch loss 0.222896, batch error rate 8.000000%
# At minibatch 12000, batch loss 0.384657, batch error rate 14.000000%
# After epoch 24: valid_err_rate: 0.080900% currently going ot do 1000 epochs
# At minibatch 12100, batch loss 0.441354, batch error rate 11.000000%
# At minibatch 12200, batch loss 0.506022, batch error rate 14.000000%
# At minibatch 12300, batch loss 0.313779, batch error rate 11.000000%
# At minibatch 12400, batch loss 0.341486, batch error rate 11.000000%
# At minibatch 12500, batch loss 0.407734, batch error rate 13.000000%
# After epoch 25: valid_err_rate: 0.080000% currently going ot do 1000 epochs
# At minibatch 12600, batch loss 0.388930, batch error rate 11.000000%
# At minibatch 12700, batch loss 0.429530, batch error rate 12.000000%
# At minibatch 12800, batch loss 0.360725, batch error rate 12.000000%
# At minibatch 12900, batch loss 0.468388, batch error rate 15.000000%
# At minibatch 13000, batch loss 0.356854, batch error rate 9.000000%
# After epoch 26: valid_err_rate: 0.079400% currently going ot do 1000 epochs
# At minibatch 13100, batch loss 0.283167, batch error rate 8.000000%
# At minibatch 13200, batch loss 0.437266, batch error rate 15.000000%
# At minibatch 13300, batch loss 0.295152, batch error rate 8.000000%
# At minibatch 13400, batch loss 0.260422, batch error rate 7.000000%
# At minibatch 13500, batch loss 0.405240, batch error rate 16.000000%
# After epoch 27: valid_err_rate: 0.077600% currently going ot do 1000 epochs
# At minibatch 13600, batch loss 0.313993, batch error rate 10.000000%
# At minibatch 13700, batch loss 0.427275, batch error rate 13.000000%
# At minibatch 13800, batch loss 0.494703, batch error rate 8.000000%
# At minibatch 13900, batch loss 0.455096, batch error rate 17.000000%
# At minibatch 14000, batch loss 0.468959, batch error rate 10.000000%
# After epoch 28: valid_err_rate: 0.076400% currently going ot do 1000 epochs
# At minibatch 14100, batch loss 0.369292, batch error rate 9.000000%
# At minibatch 14200, batch loss 0.498054, batch error rate 18.000000%
# At minibatch 14300, batch loss 0.452762, batch error rate 12.000000%
# At minibatch 14400, batch loss 0.417772, batch error rate 11.000000%
# At minibatch 14500, batch loss 0.321177, batch error rate 11.000000%
# After epoch 29: valid_err_rate: 0.076500% currently going ot do 1000 epochs
# At minibatch 14600, batch loss 0.291635, batch error rate 7.000000%
# At minibatch 14700, batch loss 0.362613, batch error rate 9.000000%
# At minibatch 14800, batch loss 0.479273, batch error rate 16.000000%
# At minibatch 14900, batch loss 0.418227, batch error rate 12.000000%
# At minibatch 15000, batch loss 0.328125, batch error rate 9.000000%
# After epoch 30: valid_err_rate: 0.075900% currently going ot do 1000 epochs
# At minibatch 15100, batch loss 0.295964, batch error rate 10.000000%
# At minibatch 15200, batch loss 0.489764, batch error rate 16.000000%
# At minibatch 15300, batch loss 0.230526, batch error rate 7.000000%
# At minibatch 15400, batch loss 0.389559, batch error rate 11.000000%
# At minibatch 15500, batch loss 0.658352, batch error rate 20.000000%
# After epoch 31: valid_err_rate: 0.074000% currently going ot do 1000 epochs
# At minibatch 15600, batch loss 0.387300, batch error rate 10.000000%
# At minibatch 15700, batch loss 0.446981, batch error rate 12.000000%
# At minibatch 15800, batch loss 0.363763, batch error rate 14.000000%
# At minibatch 15900, batch loss 0.368959, batch error rate 13.000000%
# At minibatch 16000, batch loss 0.358122, batch error rate 10.000000%
# After epoch 32: valid_err_rate: 0.073100% currently going ot do 1000 epochs
# At minibatch 16100, batch loss 0.577266, batch error rate 17.000000%
# At minibatch 16200, batch loss 0.304214, batch error rate 10.000000%
# At minibatch 16300, batch loss 0.517719, batch error rate 13.000000%
# At minibatch 16400, batch loss 0.430922, batch error rate 10.000000%
# At minibatch 16500, batch loss 0.366147, batch error rate 12.000000%
# After epoch 33: valid_err_rate: 0.071700% currently going ot do 1000 epochs
# At minibatch 16600, batch loss 0.319238, batch error rate 10.000000%
# At minibatch 16700, batch loss 0.368350, batch error rate 10.000000%
# At minibatch 16800, batch loss 0.446879, batch error rate 13.000000%
# At minibatch 16900, batch loss 0.221826, batch error rate 6.000000%
# At minibatch 17000, batch loss 0.275388, batch error rate 10.000000%
# After epoch 34: valid_err_rate: 0.071400% currently going ot do 1000 epochs
# At minibatch 17100, batch loss 0.398295, batch error rate 12.000000%
# At minibatch 17200, batch loss 0.256132, batch error rate 8.000000%
# At minibatch 17300, batch loss 0.318684, batch error rate 10.000000%
# At minibatch 17400, batch loss 0.246642, batch error rate 9.000000%
# At minibatch 17500, batch loss 0.200926, batch error rate 4.000000%
# After epoch 35: valid_err_rate: 0.070400% currently going ot do 1000 epochs
# At minibatch 17600, batch loss 0.455753, batch error rate 15.000000%
# At minibatch 17700, batch loss 0.350217, batch error rate 10.000000%
# At minibatch 17800, batch loss 0.383104, batch error rate 13.000000%
# At minibatch 17900, batch loss 0.523779, batch error rate 17.000000%
# At minibatch 18000, batch loss 0.316398, batch error rate 12.000000%
# After epoch 36: valid_err_rate: 0.070300% currently going ot do 1000 epochs
# At minibatch 18100, batch loss 0.328930, batch error rate 9.000000%
# At minibatch 18200, batch loss 0.363470, batch error rate 10.000000%
# At minibatch 18300, batch loss 0.312494, batch error rate 9.000000%
# At minibatch 18400, batch loss 0.462380, batch error rate 10.000000%
# At minibatch 18500, batch loss 0.536403, batch error rate 14.000000%
# After epoch 37: valid_err_rate: 0.068600% currently going ot do 1000 epochs
# At minibatch 18600, batch loss 0.378425, batch error rate 7.000000%
# At minibatch 18700, batch loss 0.189987, batch error rate 3.000000%
# At minibatch 18800, batch loss 0.321550, batch error rate 8.000000%
# At minibatch 18900, batch loss 0.337998, batch error rate 11.000000%
# At minibatch 19000, batch loss 0.358402, batch error rate 11.000000%
# After epoch 38: valid_err_rate: 0.068500% currently going ot do 1000 epochs
# At minibatch 19100, batch loss 0.395836, batch error rate 16.000000%
# At minibatch 19200, batch loss 0.267643, batch error rate 8.000000%
# At minibatch 19300, batch loss 0.316093, batch error rate 9.000000%
# At minibatch 19400, batch loss 0.327591, batch error rate 11.000000%
# At minibatch 19500, batch loss 0.205481, batch error rate 6.000000%
# After epoch 39: valid_err_rate: 0.066800% currently going ot do 1000 epochs
# At minibatch 19600, batch loss 0.319869, batch error rate 7.000000%
# At minibatch 19700, batch loss 0.298897, batch error rate 9.000000%
# At minibatch 19800, batch loss 0.250121, batch error rate 8.000000%
# At minibatch 19900, batch loss 0.373610, batch error rate 10.000000%
# At minibatch 20000, batch loss 0.219878, batch error rate 5.000000%
# After epoch 40: valid_err_rate: 0.066200% currently going ot do 1000 epochs
# At minibatch 20100, batch loss 0.366717, batch error rate 12.000000%
# At minibatch 20200, batch loss 0.398857, batch error rate 15.000000%
# At minibatch 20300, batch loss 0.341417, batch error rate 8.000000%
# At minibatch 20400, batch loss 0.268952, batch error rate 4.000000%
# At minibatch 20500, batch loss 0.236134, batch error rate 7.000000%
# After epoch 41: valid_err_rate: 0.065500% currently going ot do 1000 epochs
# At minibatch 20600, batch loss 0.239767, batch error rate 7.000000%
# At minibatch 20700, batch loss 0.222409, batch error rate 4.000000%
# At minibatch 20800, batch loss 0.233679, batch error rate 6.000000%
# At minibatch 20900, batch loss 0.266138, batch error rate 10.000000%
# At minibatch 21000, batch loss 0.292679, batch error rate 10.000000%
# After epoch 42: valid_err_rate: 0.064500% currently going ot do 1000 epochs
# At minibatch 21100, batch loss 0.306881, batch error rate 10.000000%
# At minibatch 21200, batch loss 0.270720, batch error rate 9.000000%
# At minibatch 21300, batch loss 0.419989, batch error rate 11.000000%
# At minibatch 21400, batch loss 0.301569, batch error rate 8.000000%
# At minibatch 21500, batch loss 0.442012, batch error rate 13.000000%
# After epoch 43: valid_err_rate: 0.064300% currently going ot do 1000 epochs
# At minibatch 21600, batch loss 0.389589, batch error rate 9.000000%
# At minibatch 21700, batch loss 0.331693, batch error rate 7.000000%
# At minibatch 21800, batch loss 0.579900, batch error rate 17.000000%
# At minibatch 21900, batch loss 0.317964, batch error rate 10.000000%
# At minibatch 22000, batch loss 0.308145, batch error rate 9.000000%
# After epoch 44: valid_err_rate: 0.063800% currently going ot do 1000 epochs
# At minibatch 22100, batch loss 0.277094, batch error rate 6.000000%
# At minibatch 22200, batch loss 0.310184, batch error rate 14.000000%
# At minibatch 22300, batch loss 0.338284, batch error rate 8.000000%
# At minibatch 22400, batch loss 0.461157, batch error rate 17.000000%
# At minibatch 22500, batch loss 0.291008, batch error rate 12.000000%
# After epoch 45: valid_err_rate: 0.062700% currently going ot do 1000 epochs
# At minibatch 22600, batch loss 0.352223, batch error rate 9.000000%
# At minibatch 22700, batch loss 0.345340, batch error rate 10.000000%
# At minibatch 22800, batch loss 0.383757, batch error rate 12.000000%
# At minibatch 22900, batch loss 0.377302, batch error rate 9.000000%
# At minibatch 23000, batch loss 0.269013, batch error rate 9.000000%
# After epoch 46: valid_err_rate: 0.061300% currently going ot do 1000 epochs
# At minibatch 23100, batch loss 0.254267, batch error rate 8.000000%
# At minibatch 23200, batch loss 0.363695, batch error rate 12.000000%
# At minibatch 23300, batch loss 0.288078, batch error rate 6.000000%
# At minibatch 23400, batch loss 0.261070, batch error rate 7.000000%
# At minibatch 23500, batch loss 0.256202, batch error rate 6.000000%
# After epoch 47: valid_err_rate: 0.062200% currently going ot do 1000 epochs
# At minibatch 23600, batch loss 0.295974, batch error rate 10.000000%
# At minibatch 23700, batch loss 0.300914, batch error rate 7.000000%
# At minibatch 23800, batch loss 0.322655, batch error rate 8.000000%
# At minibatch 23900, batch loss 0.239085, batch error rate 7.000000%
# At minibatch 24000, batch loss 0.398047, batch error rate 12.000000%
# After epoch 48: valid_err_rate: 0.062100% currently going ot do 1000 epochs
# At minibatch 24100, batch loss 0.222802, batch error rate 5.000000%
# At minibatch 24200, batch loss 0.237183, batch error rate 8.000000%
# At minibatch 24300, batch loss 0.415164, batch error rate 14.000000%
# At minibatch 24400, batch loss 0.212922, batch error rate 5.000000%
# At minibatch 24500, batch loss 0.290036, batch error rate 11.000000%
# After epoch 49: valid_err_rate: 0.061500% currently going ot do 1000 epochs
# At minibatch 24600, batch loss 0.345626, batch error rate 11.000000%
# At minibatch 24700, batch loss 0.275577, batch error rate 9.000000%
# At minibatch 24800, batch loss 0.261952, batch error rate 6.000000%
# At minibatch 24900, batch loss 0.253867, batch error rate 5.000000%
# At minibatch 25000, batch loss 0.191612, batch error rate 6.000000%
# After epoch 50: valid_err_rate: 0.060700% currently going ot do 1000 epochs
# At minibatch 25100, batch loss 0.300845, batch error rate 10.000000%
# At minibatch 25200, batch loss 0.395443, batch error rate 16.000000%
# At minibatch 25300, batch loss 0.258885, batch error rate 5.000000%
# At minibatch 25400, batch loss 0.259975, batch error rate 7.000000%
# At minibatch 25500, batch loss 0.230105, batch error rate 4.000000%
# After epoch 51: valid_err_rate: 0.059100% currently going ot do 1000 epochs
# At minibatch 25600, batch loss 0.269414, batch error rate 9.000000%
# At minibatch 25700, batch loss 0.244792, batch error rate 7.000000%
# At minibatch 25800, batch loss 0.324845, batch error rate 12.000000%
# At minibatch 25900, batch loss 0.559348, batch error rate 16.000000%
# At minibatch 26000, batch loss 0.408640, batch error rate 14.000000%
# After epoch 52: valid_err_rate: 0.058500% currently going ot do 1000 epochs
# At minibatch 26100, batch loss 0.281324, batch error rate 9.000000%
# At minibatch 26200, batch loss 0.317132, batch error rate 7.000000%
# At minibatch 26300, batch loss 0.319728, batch error rate 10.000000%
# At minibatch 26400, batch loss 0.249979, batch error rate 6.000000%
# At minibatch 26500, batch loss 0.347962, batch error rate 12.000000%
# After epoch 53: valid_err_rate: 0.058300% currently going ot do 1000 epochs
# At minibatch 26600, batch loss 0.213730, batch error rate 8.000000%
# At minibatch 26700, batch loss 0.277049, batch error rate 9.000000%
# At minibatch 26800, batch loss 0.345687, batch error rate 11.000000%
# At minibatch 26900, batch loss 0.287793, batch error rate 7.000000%
# At minibatch 27000, batch loss 0.500259, batch error rate 13.000000%
# After epoch 54: valid_err_rate: 0.057400% currently going ot do 1000 epochs
# At minibatch 27100, batch loss 0.373404, batch error rate 11.000000%
# At minibatch 27200, batch loss 0.151442, batch error rate 7.000000%
# At minibatch 27300, batch loss 0.311342, batch error rate 12.000000%
# At minibatch 27400, batch loss 0.206575, batch error rate 8.000000%
# At minibatch 27500, batch loss 0.306593, batch error rate 9.000000%
# After epoch 55: valid_err_rate: 0.057700% currently going ot do 1000 epochs
# At minibatch 27600, batch loss 0.292482, batch error rate 7.000000%
# At minibatch 27700, batch loss 0.470631, batch error rate 11.000000%
# At minibatch 27800, batch loss 0.286349, batch error rate 11.000000%
# At minibatch 27900, batch loss 0.232943, batch error rate 6.000000%
# At minibatch 28000, batch loss 0.227717, batch error rate 6.000000%
# After epoch 56: valid_err_rate: 0.056900% currently going ot do 1000 epochs
# At minibatch 28100, batch loss 0.274572, batch error rate 10.000000%
# At minibatch 28200, batch loss 0.280427, batch error rate 11.000000%
# At minibatch 28300, batch loss 0.267927, batch error rate 5.000000%
# At minibatch 28400, batch loss 0.348067, batch error rate 11.000000%
# At minibatch 28500, batch loss 0.291349, batch error rate 9.000000%
# After epoch 57: valid_err_rate: 0.055700% currently going ot do 1000 epochs
# At minibatch 28600, batch loss 0.279934, batch error rate 8.000000%
# At minibatch 28700, batch loss 0.296466, batch error rate 7.000000%
# At minibatch 28800, batch loss 0.310967, batch error rate 11.000000%
# At minibatch 28900, batch loss 0.218921, batch error rate 6.000000%
# At minibatch 29000, batch loss 0.293812, batch error rate 7.000000%
# After epoch 58: valid_err_rate: 0.055000% currently going ot do 1000 epochs
# At minibatch 29100, batch loss 0.229896, batch error rate 7.000000%
# At minibatch 29200, batch loss 0.384017, batch error rate 11.000000%
# At minibatch 29300, batch loss 0.301200, batch error rate 10.000000%
# At minibatch 29400, batch loss 0.185281, batch error rate 6.000000%
# At minibatch 29500, batch loss 0.234413, batch error rate 10.000000%
# After epoch 59: valid_err_rate: 0.054600% currently going ot do 1000 epochs
# At minibatch 29600, batch loss 0.234721, batch error rate 7.000000%
# At minibatch 29700, batch loss 0.226258, batch error rate 9.000000%
# At minibatch 29800, batch loss 0.246686, batch error rate 9.000000%
# At minibatch 29900, batch loss 0.132461, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.272500, batch error rate 7.000000%
# After epoch 60: valid_err_rate: 0.054000% currently going ot do 1000 epochs
# At minibatch 30100, batch loss 0.213014, batch error rate 5.000000%
# At minibatch 30200, batch loss 0.271108, batch error rate 12.000000%
# At minibatch 30300, batch loss 0.339026, batch error rate 13.000000%
# At minibatch 30400, batch loss 0.454613, batch error rate 14.000000%
# At minibatch 30500, batch loss 0.197957, batch error rate 6.000000%
# After epoch 61: valid_err_rate: 0.054300% currently going ot do 1000 epochs
# At minibatch 30600, batch loss 0.215242, batch error rate 7.000000%
# At minibatch 30700, batch loss 0.141234, batch error rate 7.000000%
# At minibatch 30800, batch loss 0.208712, batch error rate 7.000000%
# At minibatch 30900, batch loss 0.371055, batch error rate 8.000000%
# At minibatch 31000, batch loss 0.399071, batch error rate 10.000000%
# After epoch 62: valid_err_rate: 0.053900% currently going ot do 1000 epochs
# At minibatch 31100, batch loss 0.322649, batch error rate 10.000000%
# At minibatch 31200, batch loss 0.408659, batch error rate 18.000000%
# At minibatch 31300, batch loss 0.265398, batch error rate 10.000000%
# At minibatch 31400, batch loss 0.174028, batch error rate 5.000000%
# At minibatch 31500, batch loss 0.150359, batch error rate 3.000000%
# After epoch 63: valid_err_rate: 0.052700% currently going ot do 1000 epochs
# At minibatch 31600, batch loss 0.171112, batch error rate 5.000000%
# At minibatch 31700, batch loss 0.335324, batch error rate 11.000000%
# At minibatch 31800, batch loss 0.262073, batch error rate 8.000000%
# At minibatch 31900, batch loss 0.382791, batch error rate 12.000000%
# At minibatch 32000, batch loss 0.443316, batch error rate 13.000000%
# After epoch 64: valid_err_rate: 0.052500% currently going ot do 1000 epochs
# At minibatch 32100, batch loss 0.266470, batch error rate 9.000000%
# At minibatch 32200, batch loss 0.224096, batch error rate 5.000000%
# At minibatch 32300, batch loss 0.111114, batch error rate 4.000000%
# At minibatch 32400, batch loss 0.224815, batch error rate 8.000000%
# At minibatch 32500, batch loss 0.480833, batch error rate 13.000000%
# After epoch 65: valid_err_rate: 0.051600% currently going ot do 1000 epochs
# At minibatch 32600, batch loss 0.272197, batch error rate 9.000000%
# At minibatch 32700, batch loss 0.140284, batch error rate 2.000000%
# At minibatch 32800, batch loss 0.270826, batch error rate 9.000000%
# At minibatch 32900, batch loss 0.148287, batch error rate 4.000000%
# At minibatch 33000, batch loss 0.199134, batch error rate 4.000000%
# After epoch 66: valid_err_rate: 0.051300% currently going ot do 1000 epochs
# At minibatch 33100, batch loss 0.341513, batch error rate 11.000000%
# At minibatch 33200, batch loss 0.456471, batch error rate 13.000000%
# At minibatch 33300, batch loss 0.252814, batch error rate 8.000000%
# At minibatch 33400, batch loss 0.341985, batch error rate 11.000000%
# At minibatch 33500, batch loss 0.259971, batch error rate 8.000000%
# After epoch 67: valid_err_rate: 0.051200% currently going ot do 1000 epochs
# At minibatch 33600, batch loss 0.320642, batch error rate 13.000000%
# At minibatch 33700, batch loss 0.427276, batch error rate 14.000000%
# At minibatch 33800, batch loss 0.180759, batch error rate 7.000000%
# At minibatch 33900, batch loss 0.237529, batch error rate 7.000000%
# At minibatch 34000, batch loss 0.141208, batch error rate 4.000000%
# After epoch 68: valid_err_rate: 0.050400% currently going ot do 1000 epochs
# At minibatch 34100, batch loss 0.308362, batch error rate 7.000000%
# At minibatch 34200, batch loss 0.199683, batch error rate 6.000000%
# At minibatch 34300, batch loss 0.200875, batch error rate 7.000000%
# At minibatch 34400, batch loss 0.236177, batch error rate 7.000000%
# At minibatch 34500, batch loss 0.217623, batch error rate 7.000000%
# After epoch 69: valid_err_rate: 0.049100% currently going ot do 1000 epochs
# At minibatch 34600, batch loss 0.425201, batch error rate 14.000000%
# At minibatch 34700, batch loss 0.335384, batch error rate 10.000000%
# At minibatch 34800, batch loss 0.182609, batch error rate 6.000000%
# At minibatch 34900, batch loss 0.150549, batch error rate 5.000000%
# At minibatch 35000, batch loss 0.172531, batch error rate 2.000000%
# After epoch 70: valid_err_rate: 0.049500% currently going ot do 1000 epochs
# At minibatch 35100, batch loss 0.213818, batch error rate 7.000000%
# At minibatch 35200, batch loss 0.197242, batch error rate 5.000000%
# At minibatch 35300, batch loss 0.204034, batch error rate 7.000000%
# At minibatch 35400, batch loss 0.264347, batch error rate 8.000000%
# At minibatch 35500, batch loss 0.289896, batch error rate 9.000000%
# After epoch 71: valid_err_rate: 0.050400% currently going ot do 1000 epochs
# At minibatch 35600, batch loss 0.274630, batch error rate 10.000000%
# At minibatch 35700, batch loss 0.303769, batch error rate 9.000000%
# At minibatch 35800, batch loss 0.491301, batch error rate 13.000000%
# At minibatch 35900, batch loss 0.218600, batch error rate 6.000000%
# At minibatch 36000, batch loss 0.306261, batch error rate 12.000000%
# After epoch 72: valid_err_rate: 0.050100% currently going ot do 1000 epochs
# At minibatch 36100, batch loss 0.366450, batch error rate 12.000000%
# At minibatch 36200, batch loss 0.134299, batch error rate 6.000000%
# At minibatch 36300, batch loss 0.323556, batch error rate 9.000000%
# At minibatch 36400, batch loss 0.265406, batch error rate 8.000000%
# At minibatch 36500, batch loss 0.310569, batch error rate 10.000000%
# After epoch 73: valid_err_rate: 0.048400% currently going ot do 1000 epochs
# At minibatch 36600, batch loss 0.309582, batch error rate 6.000000%
# At minibatch 36700, batch loss 0.455341, batch error rate 12.000000%
# At minibatch 36800, batch loss 0.258049, batch error rate 8.000000%
# At minibatch 36900, batch loss 0.205353, batch error rate 7.000000%
# At minibatch 37000, batch loss 0.294050, batch error rate 7.000000%
# After epoch 74: valid_err_rate: 0.049600% currently going ot do 1000 epochs
# At minibatch 37100, batch loss 0.113024, batch error rate 2.000000%
# At minibatch 37200, batch loss 0.173617, batch error rate 6.000000%
# At minibatch 37300, batch loss 0.147669, batch error rate 5.000000%
# At minibatch 37400, batch loss 0.279377, batch error rate 5.000000%
# At minibatch 37500, batch loss 0.181633, batch error rate 4.000000%
# After epoch 75: valid_err_rate: 0.048400% currently going ot do 1000 epochs
# At minibatch 37600, batch loss 0.138915, batch error rate 5.000000%
# At minibatch 37700, batch loss 0.268938, batch error rate 9.000000%
# At minibatch 37800, batch loss 0.363489, batch error rate 15.000000%
# At minibatch 37900, batch loss 0.227769, batch error rate 8.000000%
# At minibatch 38000, batch loss 0.323494, batch error rate 7.000000%
# After epoch 76: valid_err_rate: 0.048800% currently going ot do 1000 epochs
# At minibatch 38100, batch loss 0.233378, batch error rate 6.000000%
# At minibatch 38200, batch loss 0.116415, batch error rate 4.000000%
# At minibatch 38300, batch loss 0.349314, batch error rate 10.000000%
# At minibatch 38400, batch loss 0.389361, batch error rate 10.000000%
# At minibatch 38500, batch loss 0.294449, batch error rate 10.000000%
# After epoch 77: valid_err_rate: 0.047100% currently going ot do 1000 epochs
# At minibatch 38600, batch loss 0.258291, batch error rate 4.000000%
# At minibatch 38700, batch loss 0.145889, batch error rate 8.000000%
# At minibatch 38800, batch loss 0.322866, batch error rate 11.000000%
# At minibatch 38900, batch loss 0.294030, batch error rate 11.000000%
# At minibatch 39000, batch loss 0.261532, batch error rate 7.000000%
# After epoch 78: valid_err_rate: 0.048200% currently going ot do 1000 epochs
# At minibatch 39100, batch loss 0.190175, batch error rate 6.000000%
# At minibatch 39200, batch loss 0.256629, batch error rate 6.000000%
# At minibatch 39300, batch loss 0.180680, batch error rate 5.000000%
# At minibatch 39400, batch loss 0.173991, batch error rate 4.000000%
# At minibatch 39500, batch loss 0.190900, batch error rate 5.000000%
# After epoch 79: valid_err_rate: 0.048100% currently going ot do 1000 epochs
# At minibatch 39600, batch loss 0.384468, batch error rate 9.000000%
# At minibatch 39700, batch loss 0.269269, batch error rate 7.000000%
# At minibatch 39800, batch loss 0.304239, batch error rate 9.000000%
# At minibatch 39900, batch loss 0.146549, batch error rate 6.000000%
# At minibatch 40000, batch loss 0.287961, batch error rate 9.000000%
# After epoch 80: valid_err_rate: 0.047400% currently going ot do 1000 epochs
# At minibatch 40100, batch loss 0.199129, batch error rate 6.000000%
# At minibatch 40200, batch loss 0.248047, batch error rate 8.000000%
# At minibatch 40300, batch loss 0.172855, batch error rate 5.000000%
# At minibatch 40400, batch loss 0.202255, batch error rate 7.000000%
# At minibatch 40500, batch loss 0.298479, batch error rate 10.000000%
# After epoch 81: valid_err_rate: 0.047200% currently going ot do 1000 epochs
# At minibatch 40600, batch loss 0.167177, batch error rate 4.000000%
# At minibatch 40700, batch loss 0.249936, batch error rate 9.000000%
# At minibatch 40800, batch loss 0.148661, batch error rate 4.000000%
# At minibatch 40900, batch loss 0.253033, batch error rate 10.000000%
# At minibatch 41000, batch loss 0.219865, batch error rate 7.000000%
# After epoch 82: valid_err_rate: 0.046900% currently going ot do 1000 epochs
# At minibatch 41100, batch loss 0.267007, batch error rate 5.000000%
# At minibatch 41200, batch loss 0.362219, batch error rate 10.000000%
# At minibatch 41300, batch loss 0.277224, batch error rate 11.000000%
# At minibatch 41400, batch loss 0.170603, batch error rate 7.000000%
# At minibatch 41500, batch loss 0.269110, batch error rate 5.000000%
# After epoch 83: valid_err_rate: 0.045400% currently going ot do 1000 epochs
# At minibatch 41600, batch loss 0.151217, batch error rate 4.000000%
# At minibatch 41700, batch loss 0.410862, batch error rate 12.000000%
# At minibatch 41800, batch loss 0.217938, batch error rate 6.000000%
# At minibatch 41900, batch loss 0.181645, batch error rate 4.000000%
# At minibatch 42000, batch loss 0.224754, batch error rate 7.000000%
# After epoch 84: valid_err_rate: 0.045100% currently going ot do 1000 epochs
# At minibatch 42100, batch loss 0.149603, batch error rate 5.000000%
# At minibatch 42200, batch loss 0.386242, batch error rate 13.000000%
# At minibatch 42300, batch loss 0.200432, batch error rate 4.000000%
# At minibatch 42400, batch loss 0.231494, batch error rate 5.000000%
# At minibatch 42500, batch loss 0.130734, batch error rate 5.000000%
# After epoch 85: valid_err_rate: 0.044800% currently going ot do 1000 epochs
# At minibatch 42600, batch loss 0.250404, batch error rate 10.000000%
# At minibatch 42700, batch loss 0.245404, batch error rate 7.000000%
# At minibatch 42800, batch loss 0.196861, batch error rate 4.000000%
# At minibatch 42900, batch loss 0.316863, batch error rate 7.000000%
# At minibatch 43000, batch loss 0.265026, batch error rate 10.000000%
# After epoch 86: valid_err_rate: 0.045300% currently going ot do 1000 epochs
# At minibatch 43100, batch loss 0.338322, batch error rate 10.000000%
# At minibatch 43200, batch loss 0.286854, batch error rate 9.000000%
# At minibatch 43300, batch loss 0.283585, batch error rate 7.000000%
# At minibatch 43400, batch loss 0.147894, batch error rate 3.000000%
# At minibatch 43500, batch loss 0.173216, batch error rate 6.000000%
# After epoch 87: valid_err_rate: 0.045500% currently going ot do 1000 epochs
# At minibatch 43600, batch loss 0.293576, batch error rate 10.000000%
# At minibatch 43700, batch loss 0.208900, batch error rate 4.000000%
# At minibatch 43800, batch loss 0.203698, batch error rate 10.000000%
# At minibatch 43900, batch loss 0.339534, batch error rate 9.000000%
# At minibatch 44000, batch loss 0.352749, batch error rate 13.000000%
# After epoch 88: valid_err_rate: 0.044300% currently going ot do 1000 epochs
# At minibatch 44100, batch loss 0.283069, batch error rate 7.000000%
# At minibatch 44200, batch loss 0.248374, batch error rate 7.000000%
# At minibatch 44300, batch loss 0.172639, batch error rate 5.000000%
# At minibatch 44400, batch loss 0.303847, batch error rate 7.000000%
# At minibatch 44500, batch loss 0.231370, batch error rate 7.000000%
# After epoch 89: valid_err_rate: 0.044700% currently going ot do 1000 epochs
# At minibatch 44600, batch loss 0.203268, batch error rate 5.000000%
# At minibatch 44700, batch loss 0.246480, batch error rate 6.000000%
# At minibatch 44800, batch loss 0.291408, batch error rate 7.000000%
# At minibatch 44900, batch loss 0.140349, batch error rate 2.000000%
# At minibatch 45000, batch loss 0.198453, batch error rate 6.000000%
# After epoch 90: valid_err_rate: 0.044100% currently going ot do 1000 epochs
# At minibatch 45100, batch loss 0.200730, batch error rate 5.000000%
# At minibatch 45200, batch loss 0.154820, batch error rate 4.000000%
# At minibatch 45300, batch loss 0.197840, batch error rate 4.000000%
# At minibatch 45400, batch loss 0.230994, batch error rate 5.000000%
# At minibatch 45500, batch loss 0.271522, batch error rate 6.000000%
# After epoch 91: valid_err_rate: 0.042500% currently going ot do 1000 epochs
# At minibatch 45600, batch loss 0.112679, batch error rate 3.000000%
# At minibatch 45700, batch loss 0.321535, batch error rate 11.000000%
# At minibatch 45800, batch loss 0.244316, batch error rate 6.000000%
# At minibatch 45900, batch loss 0.283345, batch error rate 11.000000%
# At minibatch 46000, batch loss 0.171269, batch error rate 4.000000%
# After epoch 92: valid_err_rate: 0.042700% currently going ot do 1000 epochs
# At minibatch 46100, batch loss 0.433402, batch error rate 11.000000%
# At minibatch 46200, batch loss 0.300429, batch error rate 10.000000%
# At minibatch 46300, batch loss 0.275340, batch error rate 7.000000%
# At minibatch 46400, batch loss 0.105748, batch error rate 2.000000%
# At minibatch 46500, batch loss 0.281880, batch error rate 9.000000%
# After epoch 93: valid_err_rate: 0.043600% currently going ot do 1000 epochs
# At minibatch 46600, batch loss 0.197729, batch error rate 6.000000%
# At minibatch 46700, batch loss 0.287748, batch error rate 10.000000%
# At minibatch 46800, batch loss 0.115959, batch error rate 3.000000%
# At minibatch 46900, batch loss 0.290567, batch error rate 7.000000%
# At minibatch 47000, batch loss 0.254685, batch error rate 5.000000%
# After epoch 94: valid_err_rate: 0.042700% currently going ot do 1000 epochs
# At minibatch 47100, batch loss 0.229990, batch error rate 8.000000%
# At minibatch 47200, batch loss 0.189118, batch error rate 4.000000%
# At minibatch 47300, batch loss 0.297422, batch error rate 9.000000%
# At minibatch 47400, batch loss 0.103141, batch error rate 1.000000%
# At minibatch 47500, batch loss 0.145694, batch error rate 5.000000%
# After epoch 95: valid_err_rate: 0.042000% currently going ot do 1000 epochs
# At minibatch 47600, batch loss 0.269040, batch error rate 9.000000%
# At minibatch 47700, batch loss 0.282182, batch error rate 8.000000%
# At minibatch 47800, batch loss 0.161719, batch error rate 6.000000%
# At minibatch 47900, batch loss 0.241985, batch error rate 9.000000%
# At minibatch 48000, batch loss 0.119634, batch error rate 2.000000%
# After epoch 96: valid_err_rate: 0.041500% currently going ot do 1000 epochs
# At minibatch 48100, batch loss 0.258005, batch error rate 9.000000%
# At minibatch 48200, batch loss 0.279338, batch error rate 8.000000%
# At minibatch 48300, batch loss 0.199271, batch error rate 4.000000%
# At minibatch 48400, batch loss 0.183977, batch error rate 5.000000%
# At minibatch 48500, batch loss 0.222275, batch error rate 6.000000%
# After epoch 97: valid_err_rate: 0.042400% currently going ot do 1000 epochs
# At minibatch 48600, batch loss 0.214653, batch error rate 6.000000%
# At minibatch 48700, batch loss 0.231054, batch error rate 7.000000%
# At minibatch 48800, batch loss 0.258020, batch error rate 7.000000%
# At minibatch 48900, batch loss 0.164369, batch error rate 4.000000%
# At minibatch 49000, batch loss 0.271704, batch error rate 8.000000%
# After epoch 98: valid_err_rate: 0.042300% currently going ot do 1000 epochs
# At minibatch 49100, batch loss 0.130665, batch error rate 6.000000%
# At minibatch 49200, batch loss 0.271853, batch error rate 7.000000%
# At minibatch 49300, batch loss 0.161533, batch error rate 3.000000%
# At minibatch 49400, batch loss 0.233148, batch error rate 8.000000%
# At minibatch 49500, batch loss 0.198137, batch error rate 6.000000%
# After epoch 99: valid_err_rate: 0.041900% currently going ot do 1000 epochs
# At minibatch 49600, batch loss 0.230791, batch error rate 7.000000%
# At minibatch 49700, batch loss 0.297495, batch error rate 7.000000%
# At minibatch 49800, batch loss 0.278902, batch error rate 10.000000%
# At minibatch 49900, batch loss 0.221875, batch error rate 4.000000%
# At minibatch 50000, batch loss 0.218844, batch error rate 6.000000%
# After epoch 100: valid_err_rate: 0.041500% currently going ot do 1000 epochs
# At minibatch 50100, batch loss 0.114176, batch error rate 4.000000%
# At minibatch 50200, batch loss 0.175970, batch error rate 6.000000%
# At minibatch 50300, batch loss 0.353802, batch error rate 10.000000%
# At minibatch 50400, batch loss 0.202094, batch error rate 7.000000%
# At minibatch 50500, batch loss 0.174109, batch error rate 5.000000%
# After epoch 101: valid_err_rate: 0.041500% currently going ot do 1000 epochs
# At minibatch 50600, batch loss 0.120485, batch error rate 3.000000%
# At minibatch 50700, batch loss 0.270387, batch error rate 8.000000%
# At minibatch 50800, batch loss 0.218696, batch error rate 5.000000%
# At minibatch 50900, batch loss 0.131540, batch error rate 5.000000%
# At minibatch 51000, batch loss 0.148257, batch error rate 4.000000%
# After epoch 102: valid_err_rate: 0.041200% currently going ot do 1000 epochs
# At minibatch 51100, batch loss 0.153580, batch error rate 4.000000%
# At minibatch 51200, batch loss 0.199779, batch error rate 8.000000%
# At minibatch 51300, batch loss 0.152147, batch error rate 3.000000%
# At minibatch 51400, batch loss 0.182184, batch error rate 5.000000%
# At minibatch 51500, batch loss 0.170482, batch error rate 4.000000%
# After epoch 103: valid_err_rate: 0.040500% currently going ot do 1000 epochs
# At minibatch 51600, batch loss 0.082528, batch error rate 2.000000%
# At minibatch 51700, batch loss 0.178934, batch error rate 5.000000%
# At minibatch 51800, batch loss 0.164838, batch error rate 6.000000%
# At minibatch 51900, batch loss 0.359083, batch error rate 13.000000%
# At minibatch 52000, batch loss 0.134022, batch error rate 2.000000%
# After epoch 104: valid_err_rate: 0.041000% currently going ot do 1000 epochs
# At minibatch 52100, batch loss 0.328176, batch error rate 13.000000%
# At minibatch 52200, batch loss 0.175551, batch error rate 6.000000%
# At minibatch 52300, batch loss 0.200972, batch error rate 8.000000%
# At minibatch 52400, batch loss 0.167927, batch error rate 5.000000%
# At minibatch 52500, batch loss 0.281581, batch error rate 8.000000%
# After epoch 105: valid_err_rate: 0.040900% currently going ot do 1000 epochs
# At minibatch 52600, batch loss 0.288522, batch error rate 8.000000%
# At minibatch 52700, batch loss 0.127024, batch error rate 5.000000%
# At minibatch 52800, batch loss 0.245412, batch error rate 10.000000%
# At minibatch 52900, batch loss 0.231158, batch error rate 9.000000%
# At minibatch 53000, batch loss 0.214410, batch error rate 9.000000%
# After epoch 106: valid_err_rate: 0.040300% currently going ot do 1000 epochs
# At minibatch 53100, batch loss 0.197124, batch error rate 6.000000%
# At minibatch 53200, batch loss 0.198393, batch error rate 5.000000%
# At minibatch 53300, batch loss 0.135326, batch error rate 3.000000%
# At minibatch 53400, batch loss 0.200282, batch error rate 8.000000%
# At minibatch 53500, batch loss 0.126378, batch error rate 3.000000%
# After epoch 107: valid_err_rate: 0.040900% currently going ot do 1000 epochs
# At minibatch 53600, batch loss 0.164517, batch error rate 5.000000%
# At minibatch 53700, batch loss 0.372728, batch error rate 13.000000%
# At minibatch 53800, batch loss 0.133950, batch error rate 3.000000%
# At minibatch 53900, batch loss 0.249854, batch error rate 7.000000%
# At minibatch 54000, batch loss 0.295487, batch error rate 9.000000%
# After epoch 108: valid_err_rate: 0.040500% currently going ot do 1000 epochs
# At minibatch 54100, batch loss 0.187587, batch error rate 4.000000%
# At minibatch 54200, batch loss 0.231868, batch error rate 7.000000%
# At minibatch 54300, batch loss 0.323344, batch error rate 7.000000%
# At minibatch 54400, batch loss 0.243860, batch error rate 8.000000%
# At minibatch 54500, batch loss 0.241226, batch error rate 7.000000%
# After epoch 109: valid_err_rate: 0.039800% currently going ot do 1000 epochs
# At minibatch 54600, batch loss 0.161346, batch error rate 4.000000%
# At minibatch 54700, batch loss 0.170777, batch error rate 5.000000%
# At minibatch 54800, batch loss 0.204963, batch error rate 6.000000%
# At minibatch 54900, batch loss 0.390423, batch error rate 11.000000%
# At minibatch 55000, batch loss 0.204495, batch error rate 6.000000%
# After epoch 110: valid_err_rate: 0.040000% currently going ot do 1000 epochs
# At minibatch 55100, batch loss 0.123674, batch error rate 4.000000%
# At minibatch 55200, batch loss 0.161371, batch error rate 4.000000%
# At minibatch 55300, batch loss 0.124990, batch error rate 2.000000%
# At minibatch 55400, batch loss 0.246381, batch error rate 10.000000%
# At minibatch 55500, batch loss 0.242968, batch error rate 5.000000%
# After epoch 111: valid_err_rate: 0.040100% currently going ot do 1000 epochs
# At minibatch 55600, batch loss 0.171968, batch error rate 5.000000%
# At minibatch 55700, batch loss 0.135733, batch error rate 3.000000%
# At minibatch 55800, batch loss 0.309020, batch error rate 7.000000%
# At minibatch 55900, batch loss 0.223142, batch error rate 7.000000%
# At minibatch 56000, batch loss 0.239012, batch error rate 3.000000%
# After epoch 112: valid_err_rate: 0.039400% currently going ot do 1000 epochs
# At minibatch 56100, batch loss 0.200671, batch error rate 6.000000%
# At minibatch 56200, batch loss 0.208220, batch error rate 9.000000%
# At minibatch 56300, batch loss 0.209028, batch error rate 6.000000%
# At minibatch 56400, batch loss 0.130157, batch error rate 4.000000%
# At minibatch 56500, batch loss 0.303562, batch error rate 8.000000%
# After epoch 113: valid_err_rate: 0.040300% currently going ot do 1000 epochs
# At minibatch 56600, batch loss 0.116548, batch error rate 3.000000%
# At minibatch 56700, batch loss 0.156162, batch error rate 5.000000%
# At minibatch 56800, batch loss 0.276650, batch error rate 8.000000%
# At minibatch 56900, batch loss 0.147069, batch error rate 5.000000%
# At minibatch 57000, batch loss 0.098323, batch error rate 3.000000%
# After epoch 114: valid_err_rate: 0.039900% currently going ot do 1000 epochs
# At minibatch 57100, batch loss 0.378217, batch error rate 9.000000%
# At minibatch 57200, batch loss 0.423511, batch error rate 12.000000%
# At minibatch 57300, batch loss 0.226000, batch error rate 9.000000%
# At minibatch 57400, batch loss 0.098376, batch error rate 2.000000%
# ...
# At minibatch 481300, batch loss 0.112913, batch error rate 4.000000%
# At minibatch 481400, batch loss 0.192637, batch error rate 5.000000%
# At minibatch 481500, batch loss 0.114169, batch error rate 5.000000%
# After epoch 963: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 481600, batch loss 0.103309, batch error rate 2.000000%
# At minibatch 481700, batch loss 0.217155, batch error rate 7.000000%
# At minibatch 481800, batch loss 0.138523, batch error rate 5.000000%
# At minibatch 481900, batch loss 0.178394, batch error rate 4.000000%
# At minibatch 482000, batch loss 0.221941, batch error rate 8.000000%
# After epoch 964: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 482100, batch loss 0.198287, batch error rate 6.000000%
# At minibatch 482200, batch loss 0.222753, batch error rate 7.000000%
# At minibatch 482300, batch loss 0.180274, batch error rate 7.000000%
# At minibatch 482400, batch loss 0.148820, batch error rate 6.000000%
# At minibatch 482500, batch loss 0.190226, batch error rate 7.000000%
# After epoch 965: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 482600, batch loss 0.193038, batch error rate 6.000000%
# At minibatch 482700, batch loss 0.081067, batch error rate 3.000000%
# At minibatch 482800, batch loss 0.088261, batch error rate 1.000000%
# At minibatch 482900, batch loss 0.122200, batch error rate 2.000000%
# At minibatch 483000, batch loss 0.263355, batch error rate 5.000000%
# After epoch 966: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 483100, batch loss 0.146466, batch error rate 10.000000%
# At minibatch 483200, batch loss 0.070391, batch error rate 2.000000%
# At minibatch 483300, batch loss 0.081355, batch error rate 1.000000%
# At minibatch 483400, batch loss 0.143762, batch error rate 6.000000%
# At minibatch 483500, batch loss 0.158599, batch error rate 3.000000%
# After epoch 967: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 483600, batch loss 0.193798, batch error rate 5.000000%
# At minibatch 483700, batch loss 0.074731, batch error rate 4.000000%
# At minibatch 483800, batch loss 0.084788, batch error rate 4.000000%
# At minibatch 483900, batch loss 0.128969, batch error rate 5.000000%
# At minibatch 484000, batch loss 0.126587, batch error rate 4.000000%
# After epoch 968: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 484100, batch loss 0.127833, batch error rate 4.000000%
# At minibatch 484200, batch loss 0.239568, batch error rate 6.000000%
# At minibatch 484300, batch loss 0.126854, batch error rate 2.000000%
# At minibatch 484400, batch loss 0.133291, batch error rate 4.000000%
# At minibatch 484500, batch loss 0.067790, batch error rate 2.000000%
# After epoch 969: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 484600, batch loss 0.152926, batch error rate 5.000000%
# At minibatch 484700, batch loss 0.200238, batch error rate 6.000000%
# At minibatch 484800, batch loss 0.127604, batch error rate 2.000000%
# At minibatch 484900, batch loss 0.133581, batch error rate 5.000000%
# At minibatch 485000, batch loss 0.158997, batch error rate 5.000000%
# After epoch 970: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 485100, batch loss 0.149879, batch error rate 7.000000%
# At minibatch 485200, batch loss 0.138123, batch error rate 3.000000%
# At minibatch 485300, batch loss 0.121516, batch error rate 4.000000%
# At minibatch 485400, batch loss 0.078977, batch error rate 2.000000%
# At minibatch 485500, batch loss 0.125426, batch error rate 5.000000%
# After epoch 971: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 485600, batch loss 0.135823, batch error rate 5.000000%
# At minibatch 485700, batch loss 0.151629, batch error rate 6.000000%
# At minibatch 485800, batch loss 0.174914, batch error rate 4.000000%
# At minibatch 485900, batch loss 0.067475, batch error rate 1.000000%
# At minibatch 486000, batch loss 0.185983, batch error rate 7.000000%
# After epoch 972: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 486100, batch loss 0.322503, batch error rate 11.000000%
# At minibatch 486200, batch loss 0.233829, batch error rate 7.000000%
# At minibatch 486300, batch loss 0.134338, batch error rate 3.000000%
# At minibatch 486400, batch loss 0.058835, batch error rate 1.000000%
# At minibatch 486500, batch loss 0.187247, batch error rate 4.000000%
# After epoch 973: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 486600, batch loss 0.130321, batch error rate 5.000000%
# At minibatch 486700, batch loss 0.142735, batch error rate 6.000000%
# At minibatch 486800, batch loss 0.069382, batch error rate 4.000000%
# At minibatch 486900, batch loss 0.083855, batch error rate 3.000000%
# At minibatch 487000, batch loss 0.293058, batch error rate 7.000000%
# After epoch 974: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 487100, batch loss 0.079091, batch error rate 2.000000%
# At minibatch 487200, batch loss 0.176647, batch error rate 4.000000%
# At minibatch 487300, batch loss 0.135457, batch error rate 4.000000%
# At minibatch 487400, batch loss 0.102764, batch error rate 3.000000%
# At minibatch 487500, batch loss 0.104419, batch error rate 4.000000%
# After epoch 975: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 487600, batch loss 0.148666, batch error rate 5.000000%
# At minibatch 487700, batch loss 0.061412, batch error rate 1.000000%
# At minibatch 487800, batch loss 0.101069, batch error rate 4.000000%
# At minibatch 487900, batch loss 0.149287, batch error rate 5.000000%
# At minibatch 488000, batch loss 0.106387, batch error rate 3.000000%
# After epoch 976: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 488100, batch loss 0.318729, batch error rate 8.000000%
# At minibatch 488200, batch loss 0.101758, batch error rate 3.000000%
# At minibatch 488300, batch loss 0.160419, batch error rate 5.000000%
# At minibatch 488400, batch loss 0.056208, batch error rate 2.000000%
# At minibatch 488500, batch loss 0.136708, batch error rate 5.000000%
# After epoch 977: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 488600, batch loss 0.139837, batch error rate 4.000000%
# At minibatch 488700, batch loss 0.130321, batch error rate 2.000000%
# At minibatch 488800, batch loss 0.182462, batch error rate 5.000000%
# At minibatch 488900, batch loss 0.073000, batch error rate 2.000000%
# At minibatch 489000, batch loss 0.072905, batch error rate 2.000000%
# After epoch 978: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 489100, batch loss 0.190275, batch error rate 8.000000%
# At minibatch 489200, batch loss 0.071389, batch error rate 1.000000%
# At minibatch 489300, batch loss 0.167460, batch error rate 6.000000%
# At minibatch 489400, batch loss 0.190342, batch error rate 7.000000%
# At minibatch 489500, batch loss 0.110176, batch error rate 3.000000%
# After epoch 979: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 489600, batch loss 0.198620, batch error rate 6.000000%
# At minibatch 489700, batch loss 0.121988, batch error rate 5.000000%
# At minibatch 489800, batch loss 0.090940, batch error rate 2.000000%
# At minibatch 489900, batch loss 0.165718, batch error rate 6.000000%
# At minibatch 490000, batch loss 0.082250, batch error rate 2.000000%
# After epoch 980: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 490100, batch loss 0.204706, batch error rate 5.000000%
# At minibatch 490200, batch loss 0.095500, batch error rate 4.000000%
# At minibatch 490300, batch loss 0.105165, batch error rate 2.000000%
# At minibatch 490400, batch loss 0.162170, batch error rate 7.000000%
# At minibatch 490500, batch loss 0.124955, batch error rate 3.000000%
# After epoch 981: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 490600, batch loss 0.080555, batch error rate 5.000000%
# At minibatch 490700, batch loss 0.111310, batch error rate 2.000000%
# At minibatch 490800, batch loss 0.100733, batch error rate 5.000000%
# At minibatch 490900, batch loss 0.111973, batch error rate 3.000000%
# At minibatch 491000, batch loss 0.097928, batch error rate 3.000000%
# After epoch 982: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 491100, batch loss 0.189548, batch error rate 7.000000%
# At minibatch 491200, batch loss 0.211664, batch error rate 6.000000%
# At minibatch 491300, batch loss 0.149746, batch error rate 4.000000%
# At minibatch 491400, batch loss 0.266041, batch error rate 9.000000%
# At minibatch 491500, batch loss 0.241555, batch error rate 4.000000%
# After epoch 983: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 491600, batch loss 0.146783, batch error rate 4.000000%
# At minibatch 491700, batch loss 0.107492, batch error rate 4.000000%
# At minibatch 491800, batch loss 0.140116, batch error rate 3.000000%
# At minibatch 491900, batch loss 0.142626, batch error rate 3.000000%
# At minibatch 492000, batch loss 0.105787, batch error rate 3.000000%
# After epoch 984: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 492100, batch loss 0.150969, batch error rate 6.000000%
# At minibatch 492200, batch loss 0.258453, batch error rate 6.000000%
# At minibatch 492300, batch loss 0.342829, batch error rate 13.000000%
# At minibatch 492400, batch loss 0.137922, batch error rate 4.000000%
# At minibatch 492500, batch loss 0.106639, batch error rate 5.000000%
# After epoch 985: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 492600, batch loss 0.223417, batch error rate 4.000000%
# At minibatch 492700, batch loss 0.062027, batch error rate 3.000000%
# At minibatch 492800, batch loss 0.138585, batch error rate 4.000000%
# At minibatch 492900, batch loss 0.150286, batch error rate 4.000000%
# At minibatch 493000, batch loss 0.128580, batch error rate 4.000000%
# After epoch 986: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 493100, batch loss 0.268665, batch error rate 9.000000%
# At minibatch 493200, batch loss 0.293615, batch error rate 8.000000%
# At minibatch 493300, batch loss 0.120065, batch error rate 3.000000%
# At minibatch 493400, batch loss 0.186386, batch error rate 5.000000%
# At minibatch 493500, batch loss 0.350306, batch error rate 7.000000%
# After epoch 987: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 493600, batch loss 0.125695, batch error rate 3.000000%
# At minibatch 493700, batch loss 0.153763, batch error rate 6.000000%
# At minibatch 493800, batch loss 0.072768, batch error rate 2.000000%
# At minibatch 493900, batch loss 0.174688, batch error rate 4.000000%
# At minibatch 494000, batch loss 0.195702, batch error rate 5.000000%
# After epoch 988: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 494100, batch loss 0.211242, batch error rate 5.000000%
# At minibatch 494200, batch loss 0.077071, batch error rate 2.000000%
# At minibatch 494300, batch loss 0.110149, batch error rate 5.000000%
# At minibatch 494400, batch loss 0.200628, batch error rate 7.000000%
# At minibatch 494500, batch loss 0.096060, batch error rate 3.000000%
# After epoch 989: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 494600, batch loss 0.098048, batch error rate 4.000000%
# At minibatch 494700, batch loss 0.185233, batch error rate 6.000000%
# At minibatch 494800, batch loss 0.102152, batch error rate 2.000000%
# At minibatch 494900, batch loss 0.259958, batch error rate 5.000000%
# At minibatch 495000, batch loss 0.279646, batch error rate 7.000000%
# After epoch 990: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 495100, batch loss 0.118489, batch error rate 4.000000%
# At minibatch 495200, batch loss 0.196601, batch error rate 5.000000%
# At minibatch 495300, batch loss 0.188286, batch error rate 6.000000%
# At minibatch 495400, batch loss 0.124715, batch error rate 4.000000%
# At minibatch 495500, batch loss 0.135611, batch error rate 4.000000%
# After epoch 991: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 495600, batch loss 0.086525, batch error rate 2.000000%
# At minibatch 495700, batch loss 0.243795, batch error rate 7.000000%
# At minibatch 495800, batch loss 0.182611, batch error rate 4.000000%
# At minibatch 495900, batch loss 0.154749, batch error rate 5.000000%
# At minibatch 496000, batch loss 0.152530, batch error rate 3.000000%
# After epoch 992: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 496100, batch loss 0.072164, batch error rate 1.000000%
# At minibatch 496200, batch loss 0.149390, batch error rate 6.000000%
# At minibatch 496300, batch loss 0.082813, batch error rate 4.000000%
# At minibatch 496400, batch loss 0.142833, batch error rate 3.000000%
# At minibatch 496500, batch loss 0.074622, batch error rate 3.000000%
# After epoch 993: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 496600, batch loss 0.099948, batch error rate 3.000000%
# At minibatch 496700, batch loss 0.083398, batch error rate 3.000000%
# At minibatch 496800, batch loss 0.189087, batch error rate 7.000000%
# At minibatch 496900, batch loss 0.150052, batch error rate 4.000000%
# At minibatch 497000, batch loss 0.127753, batch error rate 3.000000%
# After epoch 994: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 497100, batch loss 0.091511, batch error rate 4.000000%
# At minibatch 497200, batch loss 0.124192, batch error rate 3.000000%
# At minibatch 497300, batch loss 0.098022, batch error rate 3.000000%
# At minibatch 497400, batch loss 0.127463, batch error rate 3.000000%
# At minibatch 497500, batch loss 0.111271, batch error rate 4.000000%
# After epoch 995: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 497600, batch loss 0.189135, batch error rate 5.000000%
# At minibatch 497700, batch loss 0.259395, batch error rate 7.000000%
# At minibatch 497800, batch loss 0.095448, batch error rate 3.000000%
# At minibatch 497900, batch loss 0.211188, batch error rate 6.000000%
# At minibatch 498000, batch loss 0.147719, batch error rate 6.000000%
# After epoch 996: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 498100, batch loss 0.285635, batch error rate 8.000000%
# At minibatch 498200, batch loss 0.111419, batch error rate 2.000000%
# At minibatch 498300, batch loss 0.149310, batch error rate 5.000000%
# At minibatch 498400, batch loss 0.086335, batch error rate 3.000000%
# At minibatch 498500, batch loss 0.083094, batch error rate 3.000000%
# After epoch 997: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 498600, batch loss 0.296644, batch error rate 9.000000%
# At minibatch 498700, batch loss 0.252460, batch error rate 9.000000%
# At minibatch 498800, batch loss 0.305180, batch error rate 7.000000%
# At minibatch 498900, batch loss 0.216755, batch error rate 5.000000%
# At minibatch 499000, batch loss 0.229764, batch error rate 8.000000%
# After epoch 998: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 499100, batch loss 0.153298, batch error rate 5.000000%
# At minibatch 499200, batch loss 0.103498, batch error rate 4.000000%
# At minibatch 499300, batch loss 0.056691, batch error rate 1.000000%
# At minibatch 499400, batch loss 0.100223, batch error rate 2.000000%
# At minibatch 499500, batch loss 0.149328, batch error rate 6.000000%
# After epoch 999: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# At minibatch 499600, batch loss 0.062765, batch error rate 0.000000%
# At minibatch 499700, batch loss 0.138481, batch error rate 4.000000%
# At minibatch 499800, batch loss 0.108127, batch error rate 2.000000%
# At minibatch 499900, batch loss 0.125007, batch error rate 4.000000%
# At minibatch 500000, batch loss 0.145314, batch error rate 6.000000%
# After epoch 1000: valid_err_rate: 0.029900% currently going ot do 1000 epochs
# Finished with 1000 epochs (minibatch 500000), with best valid error rate 0.029800

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0333

# %%
weight_init = IsotropicGaussian(std=0.05, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 10, weight_init = weight_init, dropout = 0.5),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 2000,
    regularization_rate = 10e-3,
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg3())

net2 = net

compute_error_rate(net2, mnist_test_stream)
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 1.907856, batch error rate 59.000000%
# At minibatch 200, batch loss 1.392057, batch error rate 45.000000%
# At minibatch 300, batch loss 1.326791, batch error rate 44.000000%
# At minibatch 400, batch loss 0.938276, batch error rate 33.000000%
# At minibatch 500, batch loss 0.638601, batch error rate 15.000000%
# After epoch 1: valid_err_rate: 0.148100% currently going ot do 2000 epochs
# At minibatch 600, batch loss 0.559347, batch error rate 13.000000%
# At minibatch 700, batch loss 0.546448, batch error rate 13.000000%
# At minibatch 800, batch loss 0.744539, batch error rate 23.000000%
# At minibatch 900, batch loss 0.514670, batch error rate 18.000000%
# At minibatch 1000, batch loss 0.807940, batch error rate 23.000000%
# After epoch 2: valid_err_rate: 0.122100% currently going ot do 2000 epochs
# At minibatch 1100, batch loss 0.533729, batch error rate 13.000000%
# At minibatch 1200, batch loss 0.532857, batch error rate 17.000000%
# At minibatch 1300, batch loss 0.640259, batch error rate 20.000000%
# At minibatch 1400, batch loss 0.446472, batch error rate 14.000000%
# At minibatch 1500, batch loss 0.502548, batch error rate 14.000000%
# After epoch 3: valid_err_rate: 0.122000% currently going ot do 2000 epochs
# At minibatch 1600, batch loss 0.590832, batch error rate 16.000000%
# At minibatch 1700, batch loss 0.569628, batch error rate 17.000000%
# At minibatch 1800, batch loss 0.373323, batch error rate 12.000000%
# At minibatch 1900, batch loss 0.518585, batch error rate 12.000000%
# At minibatch 2000, batch loss 0.631850, batch error rate 18.000000%
# After epoch 4: valid_err_rate: 0.096000% currently going ot do 2000 epochs
# At minibatch 2100, batch loss 0.640205, batch error rate 19.000000%
# At minibatch 2200, batch loss 0.555640, batch error rate 15.000000%
# At minibatch 2300, batch loss 0.630118, batch error rate 21.000000%
# At minibatch 2400, batch loss 0.493910, batch error rate 16.000000%
# At minibatch 2500, batch loss 0.557486, batch error rate 18.000000%
# After epoch 5: valid_err_rate: 0.099400% currently going ot do 2000 epochs
# At minibatch 2600, batch loss 0.697366, batch error rate 17.000000%
# At minibatch 2700, batch loss 0.513065, batch error rate 15.000000%
# At minibatch 2800, batch loss 0.537382, batch error rate 14.000000%
# At minibatch 2900, batch loss 0.408841, batch error rate 12.000000%
# At minibatch 3000, batch loss 0.428661, batch error rate 14.000000%
# After epoch 6: valid_err_rate: 0.098100% currently going ot do 2000 epochs
# At minibatch 3100, batch loss 0.392447, batch error rate 10.000000%
# At minibatch 3200, batch loss 0.285278, batch error rate 5.000000%
# At minibatch 3300, batch loss 0.539406, batch error rate 17.000000%
# At minibatch 3400, batch loss 0.565186, batch error rate 15.000000%
# At minibatch 3500, batch loss 0.460941, batch error rate 13.000000%
# After epoch 7: valid_err_rate: 0.091600% currently going ot do 2000 epochs
# At minibatch 3600, batch loss 0.513352, batch error rate 14.000000%
# At minibatch 3700, batch loss 0.453373, batch error rate 13.000000%
# At minibatch 3800, batch loss 0.618725, batch error rate 20.000000%
# At minibatch 3900, batch loss 0.342676, batch error rate 10.000000%
# At minibatch 4000, batch loss 0.568487, batch error rate 17.000000%
# After epoch 8: valid_err_rate: 0.096000% currently going ot do 2000 epochs
# At minibatch 4100, batch loss 0.377672, batch error rate 10.000000%
# At minibatch 4200, batch loss 0.493649, batch error rate 14.000000%
# At minibatch 4300, batch loss 0.370265, batch error rate 11.000000%
# At minibatch 4400, batch loss 0.461286, batch error rate 10.000000%
# At minibatch 4500, batch loss 0.449677, batch error rate 17.000000%
# After epoch 9: valid_err_rate: 0.092500% currently going ot do 2000 epochs
# At minibatch 4600, batch loss 0.429729, batch error rate 15.000000%
# At minibatch 4700, batch loss 0.281081, batch error rate 6.000000%
# At minibatch 4800, batch loss 0.731722, batch error rate 21.000000%
# At minibatch 4900, batch loss 0.384874, batch error rate 10.000000%
# At minibatch 5000, batch loss 0.543558, batch error rate 19.000000%
# After epoch 10: valid_err_rate: 0.088000% currently going ot do 2000 epochs
# At minibatch 5100, batch loss 0.439057, batch error rate 13.000000%
# At minibatch 5200, batch loss 0.454469, batch error rate 13.000000%
# At minibatch 5300, batch loss 0.504895, batch error rate 14.000000%
# At minibatch 5400, batch loss 0.459479, batch error rate 13.000000%
# At minibatch 5500, batch loss 0.490950, batch error rate 16.000000%
# After epoch 11: valid_err_rate: 0.091600% currently going ot do 2000 epochs
# At minibatch 5600, batch loss 0.366151, batch error rate 13.000000%
# At minibatch 5700, batch loss 0.299545, batch error rate 7.000000%
# At minibatch 5800, batch loss 0.364205, batch error rate 9.000000%
# At minibatch 5900, batch loss 0.445163, batch error rate 13.000000%
# At minibatch 6000, batch loss 0.668734, batch error rate 19.000000%
# After epoch 12: valid_err_rate: 0.090700% currently going ot do 2000 epochs
# At minibatch 6100, batch loss 0.383524, batch error rate 8.000000%
# At minibatch 6200, batch loss 0.405210, batch error rate 10.000000%
# At minibatch 6300, batch loss 0.547498, batch error rate 15.000000%
# At minibatch 6400, batch loss 0.472246, batch error rate 13.000000%
# At minibatch 6500, batch loss 0.397507, batch error rate 12.000000%
# After epoch 13: valid_err_rate: 0.083000% currently going ot do 2000 epochs
# At minibatch 6600, batch loss 0.306510, batch error rate 7.000000%
# At minibatch 6700, batch loss 0.346395, batch error rate 12.000000%
# At minibatch 6800, batch loss 0.314341, batch error rate 8.000000%
# At minibatch 6900, batch loss 0.329559, batch error rate 6.000000%
# At minibatch 7000, batch loss 0.367852, batch error rate 12.000000%
# After epoch 14: valid_err_rate: 0.104600% currently going ot do 2000 epochs
# At minibatch 7100, batch loss 0.608322, batch error rate 16.000000%
# At minibatch 7200, batch loss 0.375641, batch error rate 12.000000%
# At minibatch 7300, batch loss 0.445118, batch error rate 15.000000%
# At minibatch 7400, batch loss 0.330882, batch error rate 9.000000%
# At minibatch 7500, batch loss 0.461691, batch error rate 11.000000%
# After epoch 15: valid_err_rate: 0.083000% currently going ot do 2000 epochs
# At minibatch 7600, batch loss 0.405825, batch error rate 11.000000%
# At minibatch 7700, batch loss 0.306302, batch error rate 7.000000%
# At minibatch 7800, batch loss 0.340874, batch error rate 7.000000%
# At minibatch 7900, batch loss 0.345291, batch error rate 9.000000%
# At minibatch 8000, batch loss 0.481639, batch error rate 12.000000%
# After epoch 16: valid_err_rate: 0.096900% currently going ot do 2000 epochs
# At minibatch 8100, batch loss 0.358002, batch error rate 11.000000%
# At minibatch 8200, batch loss 0.413746, batch error rate 11.000000%
# At minibatch 8300, batch loss 0.521401, batch error rate 19.000000%
# At minibatch 8400, batch loss 0.428791, batch error rate 17.000000%
# At minibatch 8500, batch loss 0.396507, batch error rate 14.000000%
# After epoch 17: valid_err_rate: 0.080200% currently going ot do 2000 epochs
# At minibatch 8600, batch loss 0.300790, batch error rate 7.000000%
# At minibatch 8700, batch loss 0.405446, batch error rate 11.000000%
# At minibatch 8800, batch loss 0.340995, batch error rate 11.000000%
# At minibatch 8900, batch loss 0.297404, batch error rate 3.000000%
# At minibatch 9000, batch loss 0.317358, batch error rate 9.000000%
# After epoch 18: valid_err_rate: 0.079200% currently going ot do 2000 epochs
# At minibatch 9100, batch loss 0.344449, batch error rate 13.000000%
# At minibatch 9200, batch loss 0.407066, batch error rate 12.000000%
# At minibatch 9300, batch loss 0.324464, batch error rate 13.000000%
# At minibatch 9400, batch loss 0.579192, batch error rate 17.000000%
# At minibatch 9500, batch loss 0.405554, batch error rate 14.000000%
# After epoch 19: valid_err_rate: 0.081100% currently going ot do 2000 epochs
# At minibatch 9600, batch loss 0.617804, batch error rate 26.000000%
# At minibatch 9700, batch loss 0.324276, batch error rate 9.000000%
# At minibatch 9800, batch loss 0.357905, batch error rate 11.000000%
# At minibatch 9900, batch loss 0.485347, batch error rate 15.000000%
# At minibatch 10000, batch loss 0.450092, batch error rate 14.000000%
# After epoch 20: valid_err_rate: 0.079500% currently going ot do 2000 epochs
# At minibatch 10100, batch loss 0.459606, batch error rate 19.000000%
# At minibatch 10200, batch loss 0.250594, batch error rate 8.000000%
# At minibatch 10300, batch loss 0.498776, batch error rate 14.000000%
# At minibatch 10400, batch loss 0.433163, batch error rate 12.000000%
# At minibatch 10500, batch loss 0.501949, batch error rate 13.000000%
# After epoch 21: valid_err_rate: 0.084400% currently going ot do 2000 epochs
# At minibatch 10600, batch loss 0.446394, batch error rate 13.000000%
# At minibatch 10700, batch loss 0.333037, batch error rate 8.000000%
# At minibatch 10800, batch loss 0.537569, batch error rate 19.000000%
# At minibatch 10900, batch loss 0.426352, batch error rate 12.000000%
# At minibatch 11000, batch loss 0.424629, batch error rate 12.000000%
# After epoch 22: valid_err_rate: 0.085100% currently going ot do 2000 epochs
# At minibatch 11100, batch loss 0.378602, batch error rate 9.000000%
# At minibatch 11200, batch loss 0.443644, batch error rate 9.000000%
# At minibatch 11300, batch loss 0.317653, batch error rate 9.000000%
# At minibatch 11400, batch loss 0.480024, batch error rate 16.000000%
# At minibatch 11500, batch loss 0.564873, batch error rate 15.000000%
# After epoch 23: valid_err_rate: 0.086300% currently going ot do 2000 epochs
# At minibatch 11600, batch loss 0.362242, batch error rate 10.000000%
# At minibatch 11700, batch loss 0.316088, batch error rate 11.000000%
# At minibatch 11800, batch loss 0.407912, batch error rate 13.000000%
# At minibatch 11900, batch loss 0.420254, batch error rate 10.000000%
# At minibatch 12000, batch loss 0.442033, batch error rate 13.000000%
# After epoch 24: valid_err_rate: 0.087700% currently going ot do 2000 epochs
# At minibatch 12100, batch loss 0.359533, batch error rate 10.000000%
# At minibatch 12200, batch loss 0.339523, batch error rate 9.000000%
# At minibatch 12300, batch loss 0.279439, batch error rate 7.000000%
# At minibatch 12400, batch loss 0.346354, batch error rate 6.000000%
# At minibatch 12500, batch loss 0.330222, batch error rate 6.000000%
# After epoch 25: valid_err_rate: 0.081000% currently going ot do 2000 epochs
# At minibatch 12600, batch loss 0.564737, batch error rate 17.000000%
# At minibatch 12700, batch loss 0.583135, batch error rate 17.000000%
# At minibatch 12800, batch loss 0.507143, batch error rate 14.000000%
# At minibatch 12900, batch loss 0.314670, batch error rate 7.000000%
# At minibatch 13000, batch loss 0.343219, batch error rate 7.000000%
# After epoch 26: valid_err_rate: 0.097800% currently going ot do 2000 epochs
# At minibatch 13100, batch loss 0.285326, batch error rate 8.000000%
# At minibatch 13200, batch loss 0.427841, batch error rate 11.000000%
# At minibatch 13300, batch loss 0.470609, batch error rate 10.000000%
# At minibatch 13400, batch loss 0.319090, batch error rate 12.000000%
# At minibatch 13500, batch loss 0.459653, batch error rate 15.000000%
# After epoch 27: valid_err_rate: 0.075000% currently going ot do 2000 epochs
# At minibatch 13600, batch loss 0.342458, batch error rate 7.000000%
# At minibatch 13700, batch loss 0.431420, batch error rate 13.000000%
# At minibatch 13800, batch loss 0.255133, batch error rate 6.000000%
# At minibatch 13900, batch loss 0.443574, batch error rate 16.000000%
# At minibatch 14000, batch loss 0.456331, batch error rate 15.000000%
# After epoch 28: valid_err_rate: 0.081400% currently going ot do 2000 epochs
# At minibatch 14100, batch loss 0.393965, batch error rate 7.000000%
# At minibatch 14200, batch loss 0.338569, batch error rate 10.000000%
# At minibatch 14300, batch loss 0.366027, batch error rate 11.000000%
# At minibatch 14400, batch loss 0.416065, batch error rate 14.000000%
# At minibatch 14500, batch loss 0.432935, batch error rate 15.000000%
# After epoch 29: valid_err_rate: 0.075400% currently going ot do 2000 epochs
# At minibatch 14600, batch loss 0.302617, batch error rate 4.000000%
# At minibatch 14700, batch loss 0.213737, batch error rate 6.000000%
# At minibatch 14800, batch loss 0.480211, batch error rate 14.000000%
# At minibatch 14900, batch loss 0.198958, batch error rate 2.000000%
# At minibatch 15000, batch loss 0.422139, batch error rate 14.000000%
# After epoch 30: valid_err_rate: 0.076200% currently going ot do 2000 epochs
# At minibatch 15100, batch loss 0.399658, batch error rate 11.000000%
# At minibatch 15200, batch loss 0.476923, batch error rate 13.000000%
# At minibatch 15300, batch loss 0.338255, batch error rate 7.000000%
# At minibatch 15400, batch loss 0.374117, batch error rate 11.000000%
# At minibatch 15500, batch loss 0.396590, batch error rate 11.000000%
# After epoch 31: valid_err_rate: 0.074900% currently going ot do 2000 epochs
# At minibatch 15600, batch loss 0.354669, batch error rate 10.000000%
# At minibatch 15700, batch loss 0.497685, batch error rate 14.000000%
# At minibatch 15800, batch loss 0.445503, batch error rate 9.000000%
# At minibatch 15900, batch loss 0.372624, batch error rate 12.000000%
# At minibatch 16000, batch loss 0.431585, batch error rate 12.000000%
# After epoch 32: valid_err_rate: 0.079500% currently going ot do 2000 epochs
# At minibatch 16100, batch loss 0.303509, batch error rate 10.000000%
# At minibatch 16200, batch loss 0.428026, batch error rate 13.000000%
# At minibatch 16300, batch loss 0.403089, batch error rate 12.000000%
# At minibatch 16400, batch loss 0.345573, batch error rate 8.000000%
# At minibatch 16500, batch loss 0.442235, batch error rate 11.000000%
# After epoch 33: valid_err_rate: 0.075900% currently going ot do 2000 epochs
# At minibatch 16600, batch loss 0.489863, batch error rate 13.000000%
# At minibatch 16700, batch loss 0.344808, batch error rate 13.000000%
# At minibatch 16800, batch loss 0.409464, batch error rate 11.000000%
# At minibatch 16900, batch loss 0.338797, batch error rate 9.000000%
# At minibatch 17000, batch loss 0.463373, batch error rate 12.000000%
# After epoch 34: valid_err_rate: 0.082500% currently going ot do 2000 epochs
# At minibatch 17100, batch loss 0.308767, batch error rate 6.000000%
# At minibatch 17200, batch loss 0.564181, batch error rate 22.000000%
# At minibatch 17300, batch loss 0.335177, batch error rate 7.000000%
# At minibatch 17400, batch loss 0.390653, batch error rate 12.000000%
# At minibatch 17500, batch loss 0.491879, batch error rate 14.000000%
# After epoch 35: valid_err_rate: 0.075100% currently going ot do 2000 epochs
# At minibatch 17600, batch loss 0.337973, batch error rate 9.000000%
# At minibatch 17700, batch loss 0.416462, batch error rate 11.000000%
# At minibatch 17800, batch loss 0.442595, batch error rate 12.000000%
# At minibatch 17900, batch loss 0.426569, batch error rate 12.000000%
# At minibatch 18000, batch loss 0.267195, batch error rate 8.000000%
# After epoch 36: valid_err_rate: 0.075000% currently going ot do 2000 epochs
# At minibatch 18100, batch loss 0.329758, batch error rate 9.000000%
# At minibatch 18200, batch loss 0.420279, batch error rate 10.000000%
# At minibatch 18300, batch loss 0.315095, batch error rate 5.000000%
# At minibatch 18400, batch loss 0.369428, batch error rate 9.000000%
# At minibatch 18500, batch loss 0.401977, batch error rate 10.000000%
# After epoch 37: valid_err_rate: 0.075400% currently going ot do 2000 epochs
# At minibatch 18600, batch loss 0.359896, batch error rate 11.000000%
# At minibatch 18700, batch loss 0.278508, batch error rate 8.000000%
# At minibatch 18800, batch loss 0.406153, batch error rate 11.000000%
# At minibatch 18900, batch loss 0.368126, batch error rate 13.000000%
# At minibatch 19000, batch loss 0.385085, batch error rate 7.000000%
# After epoch 38: valid_err_rate: 0.073400% currently going ot do 2000 epochs
# At minibatch 19100, batch loss 0.453195, batch error rate 14.000000%
# At minibatch 19200, batch loss 0.389931, batch error rate 14.000000%
# At minibatch 19300, batch loss 0.408120, batch error rate 11.000000%
# At minibatch 19400, batch loss 0.353592, batch error rate 11.000000%
# At minibatch 19500, batch loss 0.595669, batch error rate 20.000000%
# After epoch 39: valid_err_rate: 0.075200% currently going ot do 2000 epochs
# At minibatch 19600, batch loss 0.319266, batch error rate 3.000000%
# At minibatch 19700, batch loss 0.390307, batch error rate 11.000000%
# At minibatch 19800, batch loss 0.386486, batch error rate 12.000000%
# At minibatch 19900, batch loss 0.315611, batch error rate 8.000000%
# At minibatch 20000, batch loss 0.407828, batch error rate 12.000000%
# After epoch 40: valid_err_rate: 0.073500% currently going ot do 2000 epochs
# At minibatch 20100, batch loss 0.312633, batch error rate 10.000000%
# At minibatch 20200, batch loss 0.332266, batch error rate 12.000000%
# At minibatch 20300, batch loss 0.392740, batch error rate 15.000000%
# At minibatch 20400, batch loss 0.371127, batch error rate 6.000000%
# At minibatch 20500, batch loss 0.275448, batch error rate 7.000000%
# After epoch 41: valid_err_rate: 0.072700% currently going ot do 2000 epochs
# At minibatch 20600, batch loss 0.416446, batch error rate 13.000000%
# At minibatch 20700, batch loss 0.594184, batch error rate 16.000000%
# At minibatch 20800, batch loss 0.446701, batch error rate 19.000000%
# At minibatch 20900, batch loss 0.355338, batch error rate 9.000000%
# At minibatch 21000, batch loss 0.400296, batch error rate 9.000000%
# After epoch 42: valid_err_rate: 0.074700% currently going ot do 2000 epochs
# At minibatch 21100, batch loss 0.325198, batch error rate 8.000000%
# At minibatch 21200, batch loss 0.440437, batch error rate 12.000000%
# At minibatch 21300, batch loss 0.293635, batch error rate 5.000000%
# At minibatch 21400, batch loss 0.342989, batch error rate 13.000000%
# At minibatch 21500, batch loss 0.286884, batch error rate 8.000000%
# After epoch 43: valid_err_rate: 0.072000% currently going ot do 2000 epochs
# At minibatch 21600, batch loss 0.282798, batch error rate 7.000000%
# At minibatch 21700, batch loss 0.349231, batch error rate 9.000000%
# At minibatch 21800, batch loss 0.444672, batch error rate 8.000000%
# At minibatch 21900, batch loss 0.408443, batch error rate 10.000000%
# At minibatch 22000, batch loss 0.374021, batch error rate 10.000000%
# After epoch 44: valid_err_rate: 0.079300% currently going ot do 2000 epochs
# At minibatch 22100, batch loss 0.480092, batch error rate 17.000000%
# At minibatch 22200, batch loss 0.251690, batch error rate 5.000000%
# At minibatch 22300, batch loss 0.454964, batch error rate 14.000000%
# At minibatch 22400, batch loss 0.273927, batch error rate 6.000000%
# At minibatch 22500, batch loss 0.276013, batch error rate 7.000000%
# After epoch 45: valid_err_rate: 0.075500% currently going ot do 2000 epochs
# At minibatch 22600, batch loss 0.218737, batch error rate 4.000000%
# At minibatch 22700, batch loss 0.315334, batch error rate 6.000000%
# At minibatch 22800, batch loss 0.279683, batch error rate 6.000000%
# At minibatch 22900, batch loss 0.357927, batch error rate 12.000000%
# At minibatch 23000, batch loss 0.390786, batch error rate 12.000000%
# After epoch 46: valid_err_rate: 0.075900% currently going ot do 2000 epochs
# At minibatch 23100, batch loss 0.359642, batch error rate 8.000000%
# At minibatch 23200, batch loss 0.397850, batch error rate 9.000000%
# At minibatch 23300, batch loss 0.557124, batch error rate 17.000000%
# At minibatch 23400, batch loss 0.315130, batch error rate 8.000000%
# At minibatch 23500, batch loss 0.386174, batch error rate 10.000000%
# After epoch 47: valid_err_rate: 0.072700% currently going ot do 2000 epochs
# At minibatch 23600, batch loss 0.285559, batch error rate 8.000000%
# At minibatch 23700, batch loss 0.357873, batch error rate 12.000000%
# At minibatch 23800, batch loss 0.252493, batch error rate 6.000000%
# At minibatch 23900, batch loss 0.300765, batch error rate 9.000000%
# At minibatch 24000, batch loss 0.389158, batch error rate 12.000000%
# After epoch 48: valid_err_rate: 0.076200% currently going ot do 2000 epochs
# At minibatch 24100, batch loss 0.372627, batch error rate 9.000000%
# At minibatch 24200, batch loss 0.571162, batch error rate 14.000000%
# At minibatch 24300, batch loss 0.475892, batch error rate 12.000000%
# At minibatch 24400, batch loss 0.376468, batch error rate 8.000000%
# At minibatch 24500, batch loss 0.364830, batch error rate 7.000000%
# After epoch 49: valid_err_rate: 0.072900% currently going ot do 2000 epochs
# At minibatch 24600, batch loss 0.442790, batch error rate 9.000000%
# At minibatch 24700, batch loss 0.335822, batch error rate 5.000000%
# At minibatch 24800, batch loss 0.412621, batch error rate 12.000000%
# At minibatch 24900, batch loss 0.341682, batch error rate 8.000000%
# At minibatch 25000, batch loss 0.529254, batch error rate 19.000000%
# After epoch 50: valid_err_rate: 0.072200% currently going ot do 2000 epochs
# At minibatch 25100, batch loss 0.469266, batch error rate 14.000000%
# At minibatch 25200, batch loss 0.290984, batch error rate 6.000000%
# At minibatch 25300, batch loss 0.453796, batch error rate 15.000000%
# At minibatch 25400, batch loss 0.317587, batch error rate 7.000000%
# At minibatch 25500, batch loss 0.361572, batch error rate 9.000000%
# After epoch 51: valid_err_rate: 0.071500% currently going ot do 2000 epochs
# At minibatch 25600, batch loss 0.344594, batch error rate 10.000000%
# At minibatch 25700, batch loss 0.280623, batch error rate 8.000000%
# At minibatch 25800, batch loss 0.396890, batch error rate 10.000000%
# At minibatch 25900, batch loss 0.457060, batch error rate 9.000000%
# At minibatch 26000, batch loss 0.364029, batch error rate 9.000000%
# After epoch 52: valid_err_rate: 0.072400% currently going ot do 2000 epochs
# At minibatch 26100, batch loss 0.282891, batch error rate 5.000000%
# At minibatch 26200, batch loss 0.357759, batch error rate 10.000000%
# At minibatch 26300, batch loss 0.309402, batch error rate 8.000000%
# At minibatch 26400, batch loss 0.314566, batch error rate 10.000000%
# At minibatch 26500, batch loss 0.421973, batch error rate 12.000000%
# After epoch 53: valid_err_rate: 0.070900% currently going ot do 2000 epochs
# At minibatch 26600, batch loss 0.300680, batch error rate 10.000000%
# At minibatch 26700, batch loss 0.271893, batch error rate 8.000000%
# At minibatch 26800, batch loss 0.327257, batch error rate 8.000000%
# At minibatch 26900, batch loss 0.373373, batch error rate 11.000000%
# At minibatch 27000, batch loss 0.362489, batch error rate 11.000000%
# After epoch 54: valid_err_rate: 0.069400% currently going ot do 2000 epochs
# At minibatch 27100, batch loss 0.342373, batch error rate 8.000000%
# At minibatch 27200, batch loss 0.428413, batch error rate 16.000000%
# At minibatch 27300, batch loss 0.266098, batch error rate 8.000000%
# At minibatch 27400, batch loss 0.351936, batch error rate 8.000000%
# At minibatch 27500, batch loss 0.443884, batch error rate 15.000000%
# After epoch 55: valid_err_rate: 0.075300% currently going ot do 2000 epochs
# At minibatch 27600, batch loss 0.289651, batch error rate 5.000000%
# At minibatch 27700, batch loss 0.386636, batch error rate 11.000000%
# At minibatch 27800, batch loss 0.356231, batch error rate 7.000000%
# At minibatch 27900, batch loss 0.434754, batch error rate 9.000000%
# At minibatch 28000, batch loss 0.377076, batch error rate 7.000000%
# After epoch 56: valid_err_rate: 0.070900% currently going ot do 2000 epochs
# At minibatch 28100, batch loss 0.647170, batch error rate 23.000000%
# At minibatch 28200, batch loss 0.425507, batch error rate 13.000000%
# At minibatch 28300, batch loss 0.422905, batch error rate 13.000000%
# At minibatch 28400, batch loss 0.357488, batch error rate 9.000000%
# At minibatch 28500, batch loss 0.290810, batch error rate 9.000000%
# After epoch 57: valid_err_rate: 0.072800% currently going ot do 2000 epochs
# At minibatch 28600, batch loss 0.325341, batch error rate 6.000000%
# At minibatch 28700, batch loss 0.468923, batch error rate 12.000000%
# At minibatch 28800, batch loss 0.473379, batch error rate 13.000000%
# At minibatch 28900, batch loss 0.414823, batch error rate 13.000000%
# At minibatch 29000, batch loss 0.514772, batch error rate 14.000000%
# After epoch 58: valid_err_rate: 0.071200% currently going ot do 2000 epochs
# At minibatch 29100, batch loss 0.339708, batch error rate 10.000000%
# At minibatch 29200, batch loss 0.424666, batch error rate 9.000000%
# At minibatch 29300, batch loss 0.315701, batch error rate 7.000000%
# At minibatch 29400, batch loss 0.413718, batch error rate 10.000000%
# At minibatch 29500, batch loss 0.349453, batch error rate 7.000000%
# After epoch 59: valid_err_rate: 0.071400% currently going ot do 2000 epochs
# At minibatch 29600, batch loss 0.385136, batch error rate 11.000000%
# At minibatch 29700, batch loss 0.339703, batch error rate 10.000000%
# At minibatch 29800, batch loss 0.439225, batch error rate 15.000000%
# At minibatch 29900, batch loss 0.408206, batch error rate 12.000000%
# At minibatch 30000, batch loss 0.463160, batch error rate 14.000000%
# After epoch 60: valid_err_rate: 0.072600% currently going ot do 2000 epochs
# At minibatch 30100, batch loss 0.266791, batch error rate 8.000000%
# At minibatch 30200, batch loss 0.242395, batch error rate 6.000000%
# At minibatch 30300, batch loss 0.335534, batch error rate 8.000000%
# At minibatch 30400, batch loss 0.247526, batch error rate 6.000000%
# At minibatch 30500, batch loss 0.324902, batch error rate 11.000000%
# After epoch 61: valid_err_rate: 0.072500% currently going ot do 2000 epochs
# At minibatch 30600, batch loss 0.526401, batch error rate 18.000000%
# At minibatch 30700, batch loss 0.362903, batch error rate 11.000000%
# At minibatch 30800, batch loss 0.263129, batch error rate 6.000000%
# At minibatch 30900, batch loss 0.505890, batch error rate 15.000000%
# At minibatch 31000, batch loss 0.372798, batch error rate 12.000000%
# After epoch 62: valid_err_rate: 0.074900% currently going ot do 2000 epochs
# At minibatch 31100, batch loss 0.271199, batch error rate 7.000000%
# At minibatch 31200, batch loss 0.278159, batch error rate 7.000000%
# At minibatch 31300, batch loss 0.452428, batch error rate 13.000000%
# At minibatch 31400, batch loss 0.387883, batch error rate 7.000000%
# At minibatch 31500, batch loss 0.429915, batch error rate 14.000000%
# After epoch 63: valid_err_rate: 0.071300% currently going ot do 2000 epochs
# At minibatch 31600, batch loss 0.252269, batch error rate 4.000000%
# At minibatch 31700, batch loss 0.455015, batch error rate 13.000000%
# At minibatch 31800, batch loss 0.390502, batch error rate 11.000000%
# At minibatch 31900, batch loss 0.370941, batch error rate 8.000000%
# At minibatch 32000, batch loss 0.288442, batch error rate 7.000000%
# After epoch 64: valid_err_rate: 0.071800% currently going ot do 2000 epochs
# At minibatch 32100, batch loss 0.337210, batch error rate 7.000000%
# At minibatch 32200, batch loss 0.357979, batch error rate 12.000000%
# At minibatch 32300, batch loss 0.425479, batch error rate 10.000000%
# At minibatch 32400, batch loss 0.353903, batch error rate 10.000000%
# At minibatch 32500, batch loss 0.268561, batch error rate 7.000000%
# After epoch 65: valid_err_rate: 0.076400% currently going ot do 2000 epochs
# At minibatch 32600, batch loss 0.390257, batch error rate 13.000000%
# At minibatch 32700, batch loss 0.338194, batch error rate 6.000000%
# At minibatch 32800, batch loss 0.415727, batch error rate 11.000000%
# At minibatch 32900, batch loss 0.300788, batch error rate 9.000000%
# At minibatch 33000, batch loss 0.391671, batch error rate 12.000000%
# After epoch 66: valid_err_rate: 0.072100% currently going ot do 2000 epochs
# At minibatch 33100, batch loss 0.269708, batch error rate 9.000000%
# At minibatch 33200, batch loss 0.275422, batch error rate 5.000000%
# At minibatch 33300, batch loss 0.272465, batch error rate 7.000000%
# At minibatch 33400, batch loss 0.409608, batch error rate 15.000000%
# At minibatch 33500, batch loss 0.599192, batch error rate 19.000000%
# After epoch 67: valid_err_rate: 0.073300% currently going ot do 2000 epochs
# At minibatch 33600, batch loss 0.356212, batch error rate 9.000000%
# At minibatch 33700, batch loss 0.354315, batch error rate 13.000000%
# At minibatch 33800, batch loss 0.339002, batch error rate 11.000000%
# At minibatch 33900, batch loss 0.424041, batch error rate 16.000000%
# At minibatch 34000, batch loss 0.466104, batch error rate 14.000000%
# After epoch 68: valid_err_rate: 0.071600% currently going ot do 2000 epochs
# At minibatch 34100, batch loss 0.416061, batch error rate 14.000000%
# At minibatch 34200, batch loss 0.287263, batch error rate 5.000000%
# At minibatch 34300, batch loss 0.339520, batch error rate 6.000000%
# At minibatch 34400, batch loss 0.331360, batch error rate 9.000000%
# At minibatch 34500, batch loss 0.354814, batch error rate 7.000000%
# After epoch 69: valid_err_rate: 0.069000% currently going ot do 2000 epochs
# At minibatch 34600, batch loss 0.236200, batch error rate 8.000000%
# At minibatch 34700, batch loss 0.482323, batch error rate 13.000000%
# At minibatch 34800, batch loss 0.426851, batch error rate 11.000000%
# At minibatch 34900, batch loss 0.291771, batch error rate 4.000000%
# At minibatch 35000, batch loss 0.329003, batch error rate 5.000000%
# After epoch 70: valid_err_rate: 0.070600% currently going ot do 2000 epochs
# At minibatch 35100, batch loss 0.305700, batch error rate 10.000000%
# At minibatch 35200, batch loss 0.316919, batch error rate 10.000000%
# At minibatch 35300, batch loss 0.316590, batch error rate 6.000000%
# At minibatch 35400, batch loss 0.372683, batch error rate 10.000000%
# At minibatch 35500, batch loss 0.375429, batch error rate 9.000000%
# After epoch 71: valid_err_rate: 0.071500% currently going ot do 2000 epochs
# At minibatch 35600, batch loss 0.281879, batch error rate 9.000000%
# At minibatch 35700, batch loss 0.359275, batch error rate 8.000000%
# At minibatch 35800, batch loss 0.277887, batch error rate 9.000000%
# At minibatch 35900, batch loss 0.297843, batch error rate 7.000000%
# At minibatch 36000, batch loss 0.351561, batch error rate 13.000000%
# After epoch 72: valid_err_rate: 0.069600% currently going ot do 2000 epochs
# At minibatch 36100, batch loss 0.255416, batch error rate 8.000000%
# At minibatch 36200, batch loss 0.282462, batch error rate 8.000000%
# At minibatch 36300, batch loss 0.496041, batch error rate 10.000000%
# At minibatch 36400, batch loss 0.262080, batch error rate 5.000000%
# At minibatch 36500, batch loss 0.362327, batch error rate 9.000000%
# After epoch 73: valid_err_rate: 0.069700% currently going ot do 2000 epochs
# At minibatch 36600, batch loss 0.369020, batch error rate 9.000000%
# At minibatch 36700, batch loss 0.279420, batch error rate 9.000000%
# At minibatch 36800, batch loss 0.367523, batch error rate 11.000000%
# At minibatch 36900, batch loss 0.321322, batch error rate 11.000000%
# At minibatch 37000, batch loss 0.291194, batch error rate 6.000000%
# After epoch 74: valid_err_rate: 0.072900% currently going ot do 2000 epochs
# At minibatch 37100, batch loss 0.354450, batch error rate 9.000000%
# At minibatch 37200, batch loss 0.335809, batch error rate 7.000000%
# At minibatch 37300, batch loss 0.384360, batch error rate 10.000000%
# At minibatch 37400, batch loss 0.317352, batch error rate 12.000000%
# At minibatch 37500, batch loss 0.386070, batch error rate 10.000000%
# After epoch 75: valid_err_rate: 0.068900% currently going ot do 2000 epochs
# At minibatch 37600, batch loss 0.306900, batch error rate 5.000000%
# At minibatch 37700, batch loss 0.326675, batch error rate 7.000000%
# At minibatch 37800, batch loss 0.386338, batch error rate 13.000000%
# At minibatch 37900, batch loss 0.317237, batch error rate 8.000000%
# At minibatch 38000, batch loss 0.321930, batch error rate 11.000000%
# After epoch 76: valid_err_rate: 0.071000% currently going ot do 2000 epochs
# At minibatch 38100, batch loss 0.337590, batch error rate 6.000000%
# At minibatch 38200, batch loss 0.498307, batch error rate 15.000000%
# At minibatch 38300, batch loss 0.322858, batch error rate 8.000000%
# At minibatch 38400, batch loss 0.386963, batch error rate 7.000000%
# At minibatch 38500, batch loss 0.350859, batch error rate 12.000000%
# After epoch 77: valid_err_rate: 0.069300% currently going ot do 2000 epochs
# At minibatch 38600, batch loss 0.326922, batch error rate 8.000000%
# At minibatch 38700, batch loss 0.491162, batch error rate 14.000000%
# At minibatch 38800, batch loss 0.327244, batch error rate 12.000000%
# At minibatch 38900, batch loss 0.405394, batch error rate 14.000000%
# At minibatch 39000, batch loss 0.256361, batch error rate 5.000000%
# After epoch 78: valid_err_rate: 0.070600% currently going ot do 2000 epochs
# At minibatch 39100, batch loss 0.343581, batch error rate 7.000000%
# At minibatch 39200, batch loss 0.338286, batch error rate 5.000000%
# At minibatch 39300, batch loss 0.270690, batch error rate 4.000000%
# At minibatch 39400, batch loss 0.239905, batch error rate 7.000000%
# At minibatch 39500, batch loss 0.371398, batch error rate 11.000000%
# After epoch 79: valid_err_rate: 0.069700% currently going ot do 2000 epochs
# At minibatch 39600, batch loss 0.166126, batch error rate 2.000000%
# At minibatch 39700, batch loss 0.394588, batch error rate 9.000000%
# At minibatch 39800, batch loss 0.424542, batch error rate 9.000000%
# At minibatch 39900, batch loss 0.444452, batch error rate 11.000000%
# At minibatch 40000, batch loss 0.268191, batch error rate 3.000000%
# After epoch 80: valid_err_rate: 0.073700% currently going ot do 2000 epochs
# At minibatch 40100, batch loss 0.440422, batch error rate 12.000000%
# At minibatch 40200, batch loss 0.315270, batch error rate 9.000000%
# At minibatch 40300, batch loss 0.441250, batch error rate 12.000000%
# At minibatch 40400, batch loss 0.381097, batch error rate 13.000000%
# At minibatch 40500, batch loss 0.249533, batch error rate 5.000000%
# After epoch 81: valid_err_rate: 0.070900% currently going ot do 2000 epochs
# At minibatch 40600, batch loss 0.373670, batch error rate 10.000000%
# At minibatch 40700, batch loss 0.381042, batch error rate 11.000000%
# At minibatch 40800, batch loss 0.312208, batch error rate 7.000000%
# At minibatch 40900, batch loss 0.455094, batch error rate 12.000000%
# At minibatch 41000, batch loss 0.306435, batch error rate 8.000000%
# After epoch 82: valid_err_rate: 0.069400% currently going ot do 2000 epochs
# At minibatch 41100, batch loss 0.337289, batch error rate 9.000000%
# At minibatch 41200, batch loss 0.382601, batch error rate 8.000000%
# At minibatch 41300, batch loss 0.377917, batch error rate 9.000000%
# At minibatch 41400, batch loss 0.344924, batch error rate 12.000000%
# At minibatch 41500, batch loss 0.311410, batch error rate 10.000000%
# After epoch 83: valid_err_rate: 0.072700% currently going ot do 2000 epochs
# At minibatch 41600, batch loss 0.341102, batch error rate 9.000000%
# At minibatch 41700, batch loss 0.411057, batch error rate 7.000000%
# At minibatch 41800, batch loss 0.360812, batch error rate 6.000000%
# At minibatch 41900, batch loss 0.369096, batch error rate 9.000000%
# At minibatch 42000, batch loss 0.265734, batch error rate 5.000000%
# After epoch 84: valid_err_rate: 0.069100% currently going ot do 2000 epochs
# At minibatch 42100, batch loss 0.378356, batch error rate 10.000000%
# At minibatch 42200, batch loss 0.240162, batch error rate 9.000000%
# At minibatch 42300, batch loss 0.246973, batch error rate 6.000000%
# At minibatch 42400, batch loss 0.428129, batch error rate 12.000000%
# At minibatch 42500, batch loss 0.309315, batch error rate 8.000000%
# After epoch 85: valid_err_rate: 0.068500% currently going ot do 2000 epochs
# At minibatch 42600, batch loss 0.324152, batch error rate 10.000000%
# At minibatch 42700, batch loss 0.212944, batch error rate 5.000000%
# At minibatch 42800, batch loss 0.399558, batch error rate 8.000000%
# At minibatch 42900, batch loss 0.348508, batch error rate 10.000000%
# At minibatch 43000, batch loss 0.559479, batch error rate 18.000000%
# After epoch 86: valid_err_rate: 0.069200% currently going ot do 2000 epochs
# At minibatch 43100, batch loss 0.245425, batch error rate 7.000000%
# At minibatch 43200, batch loss 0.394926, batch error rate 12.000000%
# At minibatch 43300, batch loss 0.360179, batch error rate 10.000000%
# At minibatch 43400, batch loss 0.359503, batch error rate 8.000000%
# At minibatch 43500, batch loss 0.419228, batch error rate 15.000000%
# After epoch 87: valid_err_rate: 0.070500% currently going ot do 2000 epochs
# At minibatch 43600, batch loss 0.321552, batch error rate 8.000000%
# At minibatch 43700, batch loss 0.310665, batch error rate 7.000000%
# At minibatch 43800, batch loss 0.435342, batch error rate 13.000000%
# At minibatch 43900, batch loss 0.260819, batch error rate 6.000000%
# At minibatch 44000, batch loss 0.543619, batch error rate 14.000000%
# After epoch 88: valid_err_rate: 0.066000% currently going ot do 2000 epochs
# At minibatch 44100, batch loss 0.333783, batch error rate 8.000000%
# At minibatch 44200, batch loss 0.296123, batch error rate 8.000000%
# At minibatch 44300, batch loss 0.353776, batch error rate 9.000000%
# At minibatch 44400, batch loss 0.434329, batch error rate 15.000000%
# At minibatch 44500, batch loss 0.282581, batch error rate 7.000000%
# After epoch 89: valid_err_rate: 0.069100% currently going ot do 2000 epochs
# At minibatch 44600, batch loss 0.280429, batch error rate 7.000000%
# At minibatch 44700, batch loss 0.246392, batch error rate 5.000000%
# At minibatch 44800, batch loss 0.347421, batch error rate 10.000000%
# At minibatch 44900, batch loss 0.283843, batch error rate 6.000000%
# At minibatch 45000, batch loss 0.251130, batch error rate 4.000000%
# After epoch 90: valid_err_rate: 0.067700% currently going ot do 2000 epochs
# At minibatch 45100, batch loss 0.382846, batch error rate 12.000000%
# At minibatch 45200, batch loss 0.409913, batch error rate 8.000000%
# At minibatch 45300, batch loss 0.263951, batch error rate 6.000000%
# At minibatch 45400, batch loss 0.319733, batch error rate 10.000000%
# At minibatch 45500, batch loss 0.359926, batch error rate 12.000000%
# After epoch 91: valid_err_rate: 0.071000% currently going ot do 2000 epochs
# At minibatch 45600, batch loss 0.349333, batch error rate 9.000000%
# At minibatch 45700, batch loss 0.348891, batch error rate 9.000000%
# At minibatch 45800, batch loss 0.377763, batch error rate 9.000000%
# At minibatch 45900, batch loss 0.373363, batch error rate 7.000000%
# At minibatch 46000, batch loss 0.375107, batch error rate 12.000000%
# After epoch 92: valid_err_rate: 0.068500% currently going ot do 2000 epochs
# At minibatch 46100, batch loss 0.357373, batch error rate 7.000000%
# At minibatch 46200, batch loss 0.311064, batch error rate 11.000000%
# At minibatch 46300, batch loss 0.368015, batch error rate 8.000000%
# At minibatch 46400, batch loss 0.340828, batch error rate 9.000000%
# At minibatch 46500, batch loss 0.356948, batch error rate 9.000000%
# After epoch 93: valid_err_rate: 0.070800% currently going ot do 2000 epochs
# At minibatch 46600, batch loss 0.380038, batch error rate 11.000000%
# At minibatch 46700, batch loss 0.363760, batch error rate 12.000000%
# At minibatch 46800, batch loss 0.307169, batch error rate 7.000000%
# At minibatch 46900, batch loss 0.420238, batch error rate 13.000000%
# At minibatch 47000, batch loss 0.379759, batch error rate 10.000000%
# After epoch 94: valid_err_rate: 0.068200% currently going ot do 2000 epochs
# At minibatch 47100, batch loss 0.523923, batch error rate 15.000000%
# At minibatch 47200, batch loss 0.471086, batch error rate 15.000000%
# At minibatch 47300, batch loss 0.272135, batch error rate 9.000000%
# At minibatch 47400, batch loss 0.414817, batch error rate 14.000000%
# At minibatch 47500, batch loss 0.316993, batch error rate 8.000000%
# After epoch 95: valid_err_rate: 0.069200% currently going ot do 2000 epochs
# At minibatch 47600, batch loss 0.347741, batch error rate 10.000000%
# At minibatch 47700, batch loss 0.266125, batch error rate 8.000000%
# At minibatch 47800, batch loss 0.189777, batch error rate 7.000000%
# At minibatch 47900, batch loss 0.322446, batch error rate 9.000000%
# At minibatch 48000, batch loss 0.292491, batch error rate 6.000000%
# After epoch 96: valid_err_rate: 0.070500% currently going ot do 2000 epochs
# At minibatch 48100, batch loss 0.405513, batch error rate 13.000000%
# At minibatch 48200, batch loss 0.352084, batch error rate 11.000000%
# At minibatch 48300, batch loss 0.567830, batch error rate 16.000000%
# At minibatch 48400, batch loss 0.287442, batch error rate 6.000000%
# At minibatch 48500, batch loss 0.337574, batch error rate 11.000000%
# After epoch 97: valid_err_rate: 0.068500% currently going ot do 2000 epochs
# At minibatch 48600, batch loss 0.362931, batch error rate 10.000000%
# At minibatch 48700, batch loss 0.302926, batch error rate 7.000000%
# At minibatch 48800, batch loss 0.381977, batch error rate 13.000000%
# At minibatch 48900, batch loss 0.332759, batch error rate 9.000000%
# At minibatch 49000, batch loss 0.417563, batch error rate 10.000000%
# After epoch 98: valid_err_rate: 0.066400% currently going ot do 2000 epochs
# At minibatch 49100, batch loss 0.196198, batch error rate 3.000000%
# At minibatch 49200, batch loss 0.361889, batch error rate 10.000000%
# At minibatch 49300, batch loss 0.301653, batch error rate 5.000000%
# At minibatch 49400, batch loss 0.416223, batch error rate 17.000000%
# At minibatch 49500, batch loss 0.333489, batch error rate 8.000000%
# After epoch 99: valid_err_rate: 0.070300% currently going ot do 2000 epochs
# At minibatch 49600, batch loss 0.245074, batch error rate 4.000000%
# At minibatch 49700, batch loss 0.310539, batch error rate 8.000000%
# At minibatch 49800, batch loss 0.316615, batch error rate 7.000000%
# At minibatch 49900, batch loss 0.322268, batch error rate 6.000000%
# At minibatch 50000, batch loss 0.222916, batch error rate 6.000000%
# After epoch 100: valid_err_rate: 0.067100% currently going ot do 2000 epochs
# At minibatch 50100, batch loss 0.378260, batch error rate 9.000000%
# At minibatch 50200, batch loss 0.281873, batch error rate 6.000000%
# At minibatch 50300, batch loss 0.433314, batch error rate 12.000000%
# At minibatch 50400, batch loss 0.318400, batch error rate 9.000000%
# At minibatch 50500, batch loss 0.380162, batch error rate 13.000000%
# After epoch 101: valid_err_rate: 0.068900% currently going ot do 2000 epochs
# At minibatch 50600, batch loss 0.365386, batch error rate 12.000000%
# At minibatch 50700, batch loss 0.287658, batch error rate 9.000000%
# At minibatch 50800, batch loss 0.420139, batch error rate 13.000000%
# At minibatch 50900, batch loss 0.235856, batch error rate 3.000000%
# At minibatch 51000, batch loss 0.358125, batch error rate 10.000000%
# After epoch 102: valid_err_rate: 0.070800% currently going ot do 2000 epochs
# At minibatch 51100, batch loss 0.174993, batch error rate 4.000000%
# At minibatch 51200, batch loss 0.414440, batch error rate 10.000000%
# At minibatch 51300, batch loss 0.411111, batch error rate 12.000000%
# At minibatch 51400, batch loss 0.400356, batch error rate 9.000000%
# At minibatch 51500, batch loss 0.406040, batch error rate 11.000000%
# After epoch 103: valid_err_rate: 0.067200% currently going ot do 2000 epochs
# At minibatch 51600, batch loss 0.375225, batch error rate 10.000000%
# At minibatch 51700, batch loss 0.404262, batch error rate 7.000000%
# At minibatch 51800, batch loss 0.312389, batch error rate 10.000000%
# At minibatch 51900, batch loss 0.440051, batch error rate 12.000000%
# At minibatch 52000, batch loss 0.310294, batch error rate 5.000000%
# After epoch 104: valid_err_rate: 0.066300% currently going ot do 2000 epochs
# At minibatch 52100, batch loss 0.425968, batch error rate 14.000000%
# At minibatch 52200, batch loss 0.370362, batch error rate 14.000000%
# At minibatch 52300, batch loss 0.322844, batch error rate 6.000000%
# At minibatch 52400, batch loss 0.491215, batch error rate 12.000000%
# At minibatch 52500, batch loss 0.303780, batch error rate 9.000000%
# After epoch 105: valid_err_rate: 0.070100% currently going ot do 2000 epochs
# At minibatch 52600, batch loss 0.335722, batch error rate 10.000000%
# At minibatch 52700, batch loss 0.296062, batch error rate 7.000000%
# At minibatch 52800, batch loss 0.373938, batch error rate 10.000000%
# At minibatch 52900, batch loss 0.251141, batch error rate 5.000000%
# At minibatch 53000, batch loss 0.329981, batch error rate 8.000000%
# After epoch 106: valid_err_rate: 0.065200% currently going ot do 2000 epochs
# At minibatch 53100, batch loss 0.195566, batch error rate 5.000000%
# At minibatch 53200, batch loss 0.366101, batch error rate 8.000000%
# At minibatch 53300, batch loss 0.255364, batch error rate 5.000000%
# At minibatch 53400, batch loss 0.435565, batch error rate 13.000000%
# At minibatch 53500, batch loss 0.300766, batch error rate 10.000000%
# After epoch 107: valid_err_rate: 0.066200% currently going ot do 2000 epochs
# At minibatch 53600, batch loss 0.390256, batch error rate 12.000000%
# At minibatch 53700, batch loss 0.398355, batch error rate 10.000000%
# At minibatch 53800, batch loss 0.288250, batch error rate 7.000000%
# At minibatch 53900, batch loss 0.355587, batch error rate 9.000000%
# At minibatch 54000, batch loss 0.206078, batch error rate 4.000000%
# After epoch 108: valid_err_rate: 0.071500% currently going ot do 2000 epochs
# At minibatch 54100, batch loss 0.336263, batch error rate 10.000000%
# At minibatch 54200, batch loss 0.343519, batch error rate 10.000000%
# At minibatch 54300, batch loss 0.518025, batch error rate 16.000000%
# At minibatch 54400, batch loss 0.347504, batch error rate 10.000000%
# At minibatch 54500, batch loss 0.298211, batch error rate 8.000000%
# After epoch 109: valid_err_rate: 0.067200% currently going ot do 2000 epochs
# At minibatch 54600, batch loss 0.388353, batch error rate 10.000000%
# At minibatch 54700, batch loss 0.289362, batch error rate 9.000000%
# At minibatch 54800, batch loss 0.373523, batch error rate 7.000000%
# At minibatch 54900, batch loss 0.272029, batch error rate 6.000000%
# At minibatch 55000, batch loss 0.404927, batch error rate 12.000000%
# After epoch 110: valid_err_rate: 0.067300% currently going ot do 2000 epochs
# At minibatch 55100, batch loss 0.308767, batch error rate 10.000000%
# At minibatch 55200, batch loss 0.247078, batch error rate 4.000000%
# At minibatch 55300, batch loss 0.397985, batch error rate 8.000000%
# At minibatch 55400, batch loss 0.375975, batch error rate 12.000000%
# At minibatch 55500, batch loss 0.242494, batch error rate 6.000000%
# After epoch 111: valid_err_rate: 0.066500% currently going ot do 2000 epochs
# At minibatch 55600, batch loss 0.322397, batch error rate 9.000000%
# At minibatch 55700, batch loss 0.336810, batch error rate 10.000000%
# At minibatch 55800, batch loss 0.304993, batch error rate 8.000000%
# At minibatch 55900, batch loss 0.288168, batch error rate 8.000000%
# At minibatch 56000, batch loss 0.281236, batch error rate 4.000000%
# After epoch 112: valid_err_rate: 0.066600% currently going ot do 2000 epochs
# At minibatch 56100, batch loss 0.204574, batch error rate 5.000000%
# At minibatch 56200, batch loss 0.242015, batch error rate 5.000000%
# At minibatch 56300, batch loss 0.250327, batch error rate 3.000000%
# At minibatch 56400, batch loss 0.297383, batch error rate 3.000000%
# At minibatch 56500, batch loss 0.436904, batch error rate 13.000000%
# After epoch 113: valid_err_rate: 0.066200% currently going ot do 2000 epochs
# At minibatch 56600, batch loss 0.273754, batch error rate 7.000000%
# At minibatch 56700, batch loss 0.426777, batch error rate 11.000000%
# At minibatch 56800, batch loss 0.252793, batch error rate 8.000000%
# At minibatch 56900, batch loss 0.396812, batch error rate 10.000000%
# At minibatch 57000, batch loss 0.408981, batch error rate 12.000000%
# After epoch 114: valid_err_rate: 0.064800% currently going ot do 2000 epochs
# At minibatch 57100, batch loss 0.302348, batch error rate 11.000000%
# At minibatch 57200, batch loss 0.438630, batch error rate 12.000000%
# At minibatch 57300, batch loss 0.459550, batch error rate 11.000000%
# ...
# At minibatch 607000, batch loss 0.435344, batch error rate 8.000000%
# After epoch 1214: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 607100, batch loss 0.275510, batch error rate 6.000000%
# At minibatch 607200, batch loss 0.160571, batch error rate 2.000000%
# At minibatch 607300, batch loss 0.222101, batch error rate 7.000000%
# At minibatch 607400, batch loss 0.276661, batch error rate 4.000000%
# At minibatch 607500, batch loss 0.275892, batch error rate 4.000000%
# After epoch 1215: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 607600, batch loss 0.231127, batch error rate 4.000000%
# At minibatch 607700, batch loss 0.297028, batch error rate 8.000000%
# At minibatch 607800, batch loss 0.390333, batch error rate 9.000000%
# At minibatch 607900, batch loss 0.278735, batch error rate 4.000000%
# At minibatch 608000, batch loss 0.289405, batch error rate 6.000000%
# After epoch 1216: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 608100, batch loss 0.314701, batch error rate 9.000000%
# At minibatch 608200, batch loss 0.268282, batch error rate 5.000000%
# At minibatch 608300, batch loss 0.358937, batch error rate 9.000000%
# At minibatch 608400, batch loss 0.320528, batch error rate 8.000000%
# At minibatch 608500, batch loss 0.341023, batch error rate 9.000000%
# After epoch 1217: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 608600, batch loss 0.387145, batch error rate 13.000000%
# At minibatch 608700, batch loss 0.254573, batch error rate 2.000000%
# At minibatch 608800, batch loss 0.254678, batch error rate 6.000000%
# At minibatch 608900, batch loss 0.214407, batch error rate 3.000000%
# At minibatch 609000, batch loss 0.236034, batch error rate 7.000000%
# After epoch 1218: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 609100, batch loss 0.269284, batch error rate 6.000000%
# At minibatch 609200, batch loss 0.328139, batch error rate 6.000000%
# At minibatch 609300, batch loss 0.473552, batch error rate 13.000000%
# At minibatch 609400, batch loss 0.197353, batch error rate 3.000000%
# At minibatch 609500, batch loss 0.193832, batch error rate 3.000000%
# After epoch 1219: valid_err_rate: 0.061100% currently going ot do 2000 epochs
# At minibatch 609600, batch loss 0.406790, batch error rate 12.000000%
# At minibatch 609700, batch loss 0.363572, batch error rate 12.000000%
# At minibatch 609800, batch loss 0.339576, batch error rate 8.000000%
# At minibatch 609900, batch loss 0.352225, batch error rate 9.000000%
# At minibatch 610000, batch loss 0.210217, batch error rate 4.000000%
# After epoch 1220: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 610100, batch loss 0.266776, batch error rate 5.000000%
# At minibatch 610200, batch loss 0.268771, batch error rate 5.000000%
# At minibatch 610300, batch loss 0.267932, batch error rate 5.000000%
# At minibatch 610400, batch loss 0.386213, batch error rate 11.000000%
# At minibatch 610500, batch loss 0.173647, batch error rate 2.000000%
# After epoch 1221: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 610600, batch loss 0.418810, batch error rate 10.000000%
# At minibatch 610700, batch loss 0.304780, batch error rate 6.000000%
# At minibatch 610800, batch loss 0.339087, batch error rate 8.000000%
# At minibatch 610900, batch loss 0.378658, batch error rate 9.000000%
# At minibatch 611000, batch loss 0.280447, batch error rate 4.000000%
# After epoch 1222: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 611100, batch loss 0.375573, batch error rate 11.000000%
# At minibatch 611200, batch loss 0.367450, batch error rate 10.000000%
# At minibatch 611300, batch loss 0.253616, batch error rate 7.000000%
# At minibatch 611400, batch loss 0.238034, batch error rate 5.000000%
# At minibatch 611500, batch loss 0.288995, batch error rate 8.000000%
# After epoch 1223: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 611600, batch loss 0.409433, batch error rate 13.000000%
# At minibatch 611700, batch loss 0.336917, batch error rate 9.000000%
# At minibatch 611800, batch loss 0.234219, batch error rate 7.000000%
# At minibatch 611900, batch loss 0.415161, batch error rate 13.000000%
# At minibatch 612000, batch loss 0.312592, batch error rate 6.000000%
# After epoch 1224: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 612100, batch loss 0.356680, batch error rate 10.000000%
# At minibatch 612200, batch loss 0.270810, batch error rate 10.000000%
# At minibatch 612300, batch loss 0.227607, batch error rate 4.000000%
# At minibatch 612400, batch loss 0.291773, batch error rate 11.000000%
# At minibatch 612500, batch loss 0.296338, batch error rate 9.000000%
# After epoch 1225: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 612600, batch loss 0.388917, batch error rate 10.000000%
# At minibatch 612700, batch loss 0.313942, batch error rate 9.000000%
# At minibatch 612800, batch loss 0.327547, batch error rate 9.000000%
# At minibatch 612900, batch loss 0.344467, batch error rate 11.000000%
# At minibatch 613000, batch loss 0.341379, batch error rate 9.000000%
# After epoch 1226: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 613100, batch loss 0.339418, batch error rate 9.000000%
# At minibatch 613200, batch loss 0.337585, batch error rate 9.000000%
# At minibatch 613300, batch loss 0.330073, batch error rate 9.000000%
# At minibatch 613400, batch loss 0.368426, batch error rate 9.000000%
# At minibatch 613500, batch loss 0.369638, batch error rate 11.000000%
# After epoch 1227: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 613600, batch loss 0.240711, batch error rate 6.000000%
# At minibatch 613700, batch loss 0.210976, batch error rate 2.000000%
# At minibatch 613800, batch loss 0.397907, batch error rate 14.000000%
# At minibatch 613900, batch loss 0.330823, batch error rate 6.000000%
# At minibatch 614000, batch loss 0.367197, batch error rate 11.000000%
# After epoch 1228: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 614100, batch loss 0.293141, batch error rate 6.000000%
# At minibatch 614200, batch loss 0.332675, batch error rate 9.000000%
# At minibatch 614300, batch loss 0.386385, batch error rate 8.000000%
# At minibatch 614400, batch loss 0.374106, batch error rate 11.000000%
# At minibatch 614500, batch loss 0.436715, batch error rate 11.000000%
# After epoch 1229: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 614600, batch loss 0.463882, batch error rate 14.000000%
# At minibatch 614700, batch loss 0.296066, batch error rate 5.000000%
# At minibatch 614800, batch loss 0.326781, batch error rate 7.000000%
# At minibatch 614900, batch loss 0.315708, batch error rate 8.000000%
# At minibatch 615000, batch loss 0.366537, batch error rate 10.000000%
# After epoch 1230: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 615100, batch loss 0.224511, batch error rate 7.000000%
# At minibatch 615200, batch loss 0.303805, batch error rate 10.000000%
# At minibatch 615300, batch loss 0.167834, batch error rate 2.000000%
# At minibatch 615400, batch loss 0.254331, batch error rate 6.000000%
# At minibatch 615500, batch loss 0.392517, batch error rate 8.000000%
# After epoch 1231: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 615600, batch loss 0.243955, batch error rate 5.000000%
# At minibatch 615700, batch loss 0.357960, batch error rate 8.000000%
# At minibatch 615800, batch loss 0.319764, batch error rate 10.000000%
# At minibatch 615900, batch loss 0.398000, batch error rate 10.000000%
# At minibatch 616000, batch loss 0.268725, batch error rate 5.000000%
# After epoch 1232: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 616100, batch loss 0.408771, batch error rate 8.000000%
# At minibatch 616200, batch loss 0.293657, batch error rate 5.000000%
# At minibatch 616300, batch loss 0.287806, batch error rate 10.000000%
# At minibatch 616400, batch loss 0.342417, batch error rate 9.000000%
# At minibatch 616500, batch loss 0.392678, batch error rate 10.000000%
# After epoch 1233: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 616600, batch loss 0.394378, batch error rate 11.000000%
# At minibatch 616700, batch loss 0.408197, batch error rate 16.000000%
# At minibatch 616800, batch loss 0.405478, batch error rate 13.000000%
# At minibatch 616900, batch loss 0.311579, batch error rate 6.000000%
# At minibatch 617000, batch loss 0.275215, batch error rate 7.000000%
# After epoch 1234: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 617100, batch loss 0.262839, batch error rate 5.000000%
# At minibatch 617200, batch loss 0.281084, batch error rate 6.000000%
# At minibatch 617300, batch loss 0.325088, batch error rate 11.000000%
# At minibatch 617400, batch loss 0.383383, batch error rate 9.000000%
# At minibatch 617500, batch loss 0.374886, batch error rate 12.000000%
# After epoch 1235: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 617600, batch loss 0.350809, batch error rate 7.000000%
# At minibatch 617700, batch loss 0.281483, batch error rate 6.000000%
# At minibatch 617800, batch loss 0.336883, batch error rate 8.000000%
# At minibatch 617900, batch loss 0.288306, batch error rate 9.000000%
# At minibatch 618000, batch loss 0.241233, batch error rate 6.000000%
# After epoch 1236: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 618100, batch loss 0.312471, batch error rate 8.000000%
# At minibatch 618200, batch loss 0.190287, batch error rate 4.000000%
# At minibatch 618300, batch loss 0.480473, batch error rate 16.000000%
# At minibatch 618400, batch loss 0.362853, batch error rate 7.000000%
# At minibatch 618500, batch loss 0.385957, batch error rate 8.000000%
# After epoch 1237: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 618600, batch loss 0.419327, batch error rate 9.000000%
# At minibatch 618700, batch loss 0.248043, batch error rate 3.000000%
# At minibatch 618800, batch loss 0.465379, batch error rate 10.000000%
# At minibatch 618900, batch loss 0.331326, batch error rate 8.000000%
# At minibatch 619000, batch loss 0.351458, batch error rate 9.000000%
# After epoch 1238: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 619100, batch loss 0.238436, batch error rate 7.000000%
# At minibatch 619200, batch loss 0.247680, batch error rate 7.000000%
# At minibatch 619300, batch loss 0.389575, batch error rate 10.000000%
# At minibatch 619400, batch loss 0.258036, batch error rate 5.000000%
# At minibatch 619500, batch loss 0.384979, batch error rate 7.000000%
# After epoch 1239: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 619600, batch loss 0.248658, batch error rate 8.000000%
# At minibatch 619700, batch loss 0.265610, batch error rate 8.000000%
# At minibatch 619800, batch loss 0.364655, batch error rate 8.000000%
# At minibatch 619900, batch loss 0.349889, batch error rate 8.000000%
# At minibatch 620000, batch loss 0.303073, batch error rate 7.000000%
# After epoch 1240: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 620100, batch loss 0.215734, batch error rate 4.000000%
# At minibatch 620200, batch loss 0.335427, batch error rate 10.000000%
# At minibatch 620300, batch loss 0.293789, batch error rate 8.000000%
# At minibatch 620400, batch loss 0.201676, batch error rate 3.000000%
# At minibatch 620500, batch loss 0.438862, batch error rate 13.000000%
# After epoch 1241: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 620600, batch loss 0.328687, batch error rate 10.000000%
# At minibatch 620700, batch loss 0.287904, batch error rate 7.000000%
# At minibatch 620800, batch loss 0.419587, batch error rate 14.000000%
# At minibatch 620900, batch loss 0.389683, batch error rate 9.000000%
# At minibatch 621000, batch loss 0.324175, batch error rate 6.000000%
# After epoch 1242: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 621100, batch loss 0.315206, batch error rate 8.000000%
# At minibatch 621200, batch loss 0.293325, batch error rate 5.000000%
# At minibatch 621300, batch loss 0.446852, batch error rate 11.000000%
# At minibatch 621400, batch loss 0.281696, batch error rate 7.000000%
# At minibatch 621500, batch loss 0.301906, batch error rate 5.000000%
# After epoch 1243: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 621600, batch loss 0.355379, batch error rate 10.000000%
# At minibatch 621700, batch loss 0.303845, batch error rate 6.000000%
# At minibatch 621800, batch loss 0.409004, batch error rate 10.000000%
# At minibatch 621900, batch loss 0.308265, batch error rate 9.000000%
# At minibatch 622000, batch loss 0.498713, batch error rate 15.000000%
# After epoch 1244: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 622100, batch loss 0.246041, batch error rate 8.000000%
# At minibatch 622200, batch loss 0.198427, batch error rate 3.000000%
# At minibatch 622300, batch loss 0.228430, batch error rate 6.000000%
# At minibatch 622400, batch loss 0.326746, batch error rate 8.000000%
# At minibatch 622500, batch loss 0.244850, batch error rate 4.000000%
# After epoch 1245: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 622600, batch loss 0.287847, batch error rate 8.000000%
# At minibatch 622700, batch loss 0.344651, batch error rate 7.000000%
# At minibatch 622800, batch loss 0.280912, batch error rate 4.000000%
# At minibatch 622900, batch loss 0.354722, batch error rate 8.000000%
# At minibatch 623000, batch loss 0.355051, batch error rate 8.000000%
# After epoch 1246: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 623100, batch loss 0.292962, batch error rate 6.000000%
# At minibatch 623200, batch loss 0.352030, batch error rate 9.000000%
# At minibatch 623300, batch loss 0.370455, batch error rate 10.000000%
# At minibatch 623400, batch loss 0.321060, batch error rate 8.000000%
# At minibatch 623500, batch loss 0.358759, batch error rate 8.000000%
# After epoch 1247: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 623600, batch loss 0.172773, batch error rate 4.000000%
# At minibatch 623700, batch loss 0.284632, batch error rate 8.000000%
# At minibatch 623800, batch loss 0.289486, batch error rate 8.000000%
# At minibatch 623900, batch loss 0.203451, batch error rate 7.000000%
# At minibatch 624000, batch loss 0.367655, batch error rate 9.000000%
# After epoch 1248: valid_err_rate: 0.061400% currently going ot do 2000 epochs
# At minibatch 624100, batch loss 0.314519, batch error rate 7.000000%
# At minibatch 624200, batch loss 0.290817, batch error rate 7.000000%
# At minibatch 624300, batch loss 0.367724, batch error rate 12.000000%
# At minibatch 624400, batch loss 0.292405, batch error rate 9.000000%
# At minibatch 624500, batch loss 0.222237, batch error rate 4.000000%
# After epoch 1249: valid_err_rate: 0.061300% currently going ot do 2000 epochs
# At minibatch 624600, batch loss 0.426994, batch error rate 8.000000%
# At minibatch 624700, batch loss 0.324234, batch error rate 11.000000%
# At minibatch 624800, batch loss 0.290067, batch error rate 8.000000%
# At minibatch 624900, batch loss 0.321524, batch error rate 10.000000%
# At minibatch 625000, batch loss 0.338234, batch error rate 8.000000%
# After epoch 1250: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 625100, batch loss 0.310802, batch error rate 7.000000%
# At minibatch 625200, batch loss 0.331166, batch error rate 11.000000%
# At minibatch 625300, batch loss 0.471813, batch error rate 11.000000%
# At minibatch 625400, batch loss 0.278733, batch error rate 7.000000%
# At minibatch 625500, batch loss 0.389779, batch error rate 7.000000%
# After epoch 1251: valid_err_rate: 0.061200% currently going ot do 2000 epochs
# At minibatch 625600, batch loss 0.209695, batch error rate 3.000000%
# Setting network parameters from after epoch 403
# 0.0676

# %%
weight_init = IsotropicGaussian(std=0.05, mean=0.0)
net = FeedForwardNet([
        InputDropoutLayer(dropout = 0.8),
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 800, weight_init = weight_init, dropout = 0.5),
        ReLULayer(dropout = 0.5),
        AffineLayer(800, 10, weight_init = weight_init, dropout = 0.5),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 2000,
    regularization_rate = 0.0,
    norm_limiting = None,
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg3())

net3 = net

compute_error_rate(net, mnist_test_stream)
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 2.061831, batch error rate 59.000000%
# At minibatch 200, batch loss 1.714746, batch error rate 48.000000%
# At minibatch 300, batch loss 1.140159, batch error rate 33.000000%
# At minibatch 400, batch loss 1.023027, batch error rate 35.000000%
# At minibatch 500, batch loss 0.673407, batch error rate 24.000000%
# After epoch 1: valid_err_rate: 0.168400% currently going ot do 2000 epochs [best: 0.168400%]
# At minibatch 600, batch loss 0.739864, batch error rate 23.000000%
# At minibatch 700, batch loss 0.683271, batch error rate 24.000000%
# At minibatch 800, batch loss 0.937584, batch error rate 29.000000%
# At minibatch 900, batch loss 0.930648, batch error rate 31.000000%
# At minibatch 1000, batch loss 0.540441, batch error rate 17.000000%
# After epoch 2: valid_err_rate: 0.120300% currently going ot do 2000 epochs [best: 0.120300%]
# At minibatch 1100, batch loss 0.578607, batch error rate 24.000000%
# At minibatch 1200, batch loss 0.570780, batch error rate 18.000000%
# At minibatch 1300, batch loss 0.511968, batch error rate 21.000000%
# At minibatch 1400, batch loss 0.679635, batch error rate 20.000000%
# At minibatch 1500, batch loss 0.723625, batch error rate 23.000000%
# After epoch 3: valid_err_rate: 0.090300% currently going ot do 2000 epochs [best: 0.090300%]
# At minibatch 1600, batch loss 0.507435, batch error rate 13.000000%
# At minibatch 1700, batch loss 0.505450, batch error rate 15.000000%
# At minibatch 1800, batch loss 0.496616, batch error rate 16.000000%
# At minibatch 1900, batch loss 0.400615, batch error rate 7.000000%
# At minibatch 2000, batch loss 0.297125, batch error rate 8.000000%
# After epoch 4: valid_err_rate: 0.092400% currently going ot do 2000 epochs [best: 0.090300%]
# At minibatch 2100, batch loss 0.284646, batch error rate 8.000000%
# At minibatch 2200, batch loss 0.334248, batch error rate 12.000000%
# At minibatch 2300, batch loss 0.597308, batch error rate 22.000000%
# At minibatch 2400, batch loss 0.414683, batch error rate 13.000000%
# At minibatch 2500, batch loss 0.597756, batch error rate 16.000000%
# After epoch 5: valid_err_rate: 0.076100% currently going ot do 2000 epochs [best: 0.076100%]
# At minibatch 2600, batch loss 0.367828, batch error rate 12.000000%
# At minibatch 2700, batch loss 0.445440, batch error rate 12.000000%
# At minibatch 2800, batch loss 0.500321, batch error rate 20.000000%
# At minibatch 2900, batch loss 0.571579, batch error rate 18.000000%
# At minibatch 3000, batch loss 0.262095, batch error rate 9.000000%
# After epoch 6: valid_err_rate: 0.072300% currently going ot do 2000 epochs [best: 0.072300%]
# At minibatch 3100, batch loss 0.337061, batch error rate 12.000000%
# At minibatch 3200, batch loss 0.366917, batch error rate 10.000000%
# At minibatch 3300, batch loss 0.549200, batch error rate 20.000000%
# At minibatch 3400, batch loss 0.223230, batch error rate 5.000000%
# At minibatch 3500, batch loss 0.617876, batch error rate 16.000000%
# After epoch 7: valid_err_rate: 0.066000% currently going ot do 2000 epochs [best: 0.066000%]
# At minibatch 3600, batch loss 0.225999, batch error rate 7.000000%
# At minibatch 3700, batch loss 0.519381, batch error rate 14.000000%
# At minibatch 3800, batch loss 0.296992, batch error rate 7.000000%
# At minibatch 3900, batch loss 0.468849, batch error rate 10.000000%
# At minibatch 4000, batch loss 0.328632, batch error rate 9.000000%
# After epoch 8: valid_err_rate: 0.067100% currently going ot do 2000 epochs [best: 0.066000%]
# At minibatch 4100, batch loss 0.455970, batch error rate 17.000000%
# At minibatch 4200, batch loss 0.399723, batch error rate 15.000000%
# At minibatch 4300, batch loss 0.429131, batch error rate 13.000000%
# At minibatch 4400, batch loss 0.370002, batch error rate 13.000000%
# At minibatch 4500, batch loss 0.274241, batch error rate 10.000000%
# After epoch 9: valid_err_rate: 0.054400% currently going ot do 2000 epochs [best: 0.054400%]
# At minibatch 4600, batch loss 0.328977, batch error rate 11.000000%
# At minibatch 4700, batch loss 0.255412, batch error rate 9.000000%
# At minibatch 4800, batch loss 0.316714, batch error rate 12.000000%
# At minibatch 4900, batch loss 0.533453, batch error rate 16.000000%
# At minibatch 5000, batch loss 0.491869, batch error rate 17.000000%
# After epoch 10: valid_err_rate: 0.050700% currently going ot do 2000 epochs [best: 0.050700%]
# At minibatch 5100, batch loss 0.279801, batch error rate 10.000000%
# At minibatch 5200, batch loss 0.477448, batch error rate 14.000000%
# At minibatch 5300, batch loss 0.233875, batch error rate 9.000000%
# At minibatch 5400, batch loss 0.286725, batch error rate 13.000000%
# At minibatch 5500, batch loss 0.230974, batch error rate 8.000000%
# After epoch 11: valid_err_rate: 0.049900% currently going ot do 2000 epochs [best: 0.049900%]
# At minibatch 5600, batch loss 0.233146, batch error rate 11.000000%
# At minibatch 5700, batch loss 0.153152, batch error rate 5.000000%
# At minibatch 5800, batch loss 0.367243, batch error rate 12.000000%
# At minibatch 5900, batch loss 0.275028, batch error rate 7.000000%
# At minibatch 6000, batch loss 0.168046, batch error rate 6.000000%
# After epoch 12: valid_err_rate: 0.047900% currently going ot do 2000 epochs [best: 0.047900%]
# At minibatch 6100, batch loss 0.228815, batch error rate 6.000000%
# At minibatch 6200, batch loss 0.108780, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.224775, batch error rate 10.000000%
# At minibatch 6400, batch loss 0.143054, batch error rate 5.000000%
# At minibatch 6500, batch loss 0.269647, batch error rate 6.000000%
# After epoch 13: valid_err_rate: 0.045400% currently going ot do 2000 epochs [best: 0.045400%]
# At minibatch 6600, batch loss 0.291082, batch error rate 9.000000%
# At minibatch 6700, batch loss 0.199090, batch error rate 7.000000%
# At minibatch 6800, batch loss 0.299845, batch error rate 9.000000%
# At minibatch 6900, batch loss 0.254880, batch error rate 6.000000%
# At minibatch 7000, batch loss 0.185038, batch error rate 7.000000%
# After epoch 14: valid_err_rate: 0.044600% currently going ot do 2000 epochs [best: 0.044600%]
# At minibatch 7100, batch loss 0.164914, batch error rate 3.000000%
# At minibatch 7200, batch loss 0.181834, batch error rate 5.000000%
# At minibatch 7300, batch loss 0.551650, batch error rate 20.000000%
# At minibatch 7400, batch loss 0.438410, batch error rate 13.000000%
# At minibatch 7500, batch loss 0.342584, batch error rate 11.000000%
# After epoch 15: valid_err_rate: 0.040000% currently going ot do 2000 epochs [best: 0.040000%]
# At minibatch 7600, batch loss 0.190640, batch error rate 4.000000%
# At minibatch 7700, batch loss 0.199879, batch error rate 8.000000%
# At minibatch 7800, batch loss 0.315241, batch error rate 8.000000%
# At minibatch 7900, batch loss 0.254183, batch error rate 7.000000%
# At minibatch 8000, batch loss 0.202173, batch error rate 7.000000%
# After epoch 16: valid_err_rate: 0.036200% currently going ot do 2000 epochs [best: 0.036200%]
# At minibatch 8100, batch loss 0.183917, batch error rate 5.000000%
# At minibatch 8200, batch loss 0.193671, batch error rate 6.000000%
# At minibatch 8300, batch loss 0.346536, batch error rate 10.000000%
# At minibatch 8400, batch loss 0.329882, batch error rate 9.000000%
# At minibatch 8500, batch loss 0.159989, batch error rate 7.000000%
# After epoch 17: valid_err_rate: 0.037900% currently going ot do 2000 epochs [best: 0.036200%]
# At minibatch 8600, batch loss 0.264327, batch error rate 8.000000%
# At minibatch 8700, batch loss 0.276155, batch error rate 7.000000%
# At minibatch 8800, batch loss 0.156857, batch error rate 5.000000%
# At minibatch 8900, batch loss 0.154387, batch error rate 4.000000%
# At minibatch 9000, batch loss 0.137185, batch error rate 3.000000%
# After epoch 18: valid_err_rate: 0.036000% currently going ot do 2000 epochs [best: 0.036000%]
# At minibatch 9100, batch loss 0.229282, batch error rate 8.000000%
# At minibatch 9200, batch loss 0.149033, batch error rate 4.000000%
# At minibatch 9300, batch loss 0.118117, batch error rate 5.000000%
# At minibatch 9400, batch loss 0.220669, batch error rate 8.000000%
# At minibatch 9500, batch loss 0.140118, batch error rate 6.000000%
# After epoch 19: valid_err_rate: 0.035000% currently going ot do 2000 epochs [best: 0.035000%]
# At minibatch 9600, batch loss 0.198604, batch error rate 6.000000%
# At minibatch 9700, batch loss 0.286677, batch error rate 8.000000%
# At minibatch 9800, batch loss 0.276512, batch error rate 6.000000%
# At minibatch 9900, batch loss 0.247168, batch error rate 7.000000%
# At minibatch 10000, batch loss 0.216855, batch error rate 9.000000%
# After epoch 20: valid_err_rate: 0.033800% currently going ot do 2000 epochs [best: 0.033800%]
# At minibatch 10100, batch loss 0.284256, batch error rate 7.000000%
# At minibatch 10200, batch loss 0.370537, batch error rate 11.000000%
# At minibatch 10300, batch loss 0.231121, batch error rate 7.000000%
# At minibatch 10400, batch loss 0.251728, batch error rate 8.000000%
# At minibatch 10500, batch loss 0.225939, batch error rate 6.000000%
# After epoch 21: valid_err_rate: 0.032000% currently going ot do 2000 epochs [best: 0.032000%]
# At minibatch 10600, batch loss 0.277644, batch error rate 9.000000%
# At minibatch 10700, batch loss 0.187742, batch error rate 7.000000%
# At minibatch 10800, batch loss 0.178336, batch error rate 8.000000%
# At minibatch 10900, batch loss 0.206996, batch error rate 8.000000%
# At minibatch 11000, batch loss 0.390574, batch error rate 13.000000%
# After epoch 22: valid_err_rate: 0.032600% currently going ot do 2000 epochs [best: 0.032000%]
# At minibatch 11100, batch loss 0.129330, batch error rate 4.000000%
# At minibatch 11200, batch loss 0.109513, batch error rate 3.000000%
# At minibatch 11300, batch loss 0.184603, batch error rate 8.000000%
# At minibatch 11400, batch loss 0.109946, batch error rate 4.000000%
# At minibatch 11500, batch loss 0.187095, batch error rate 6.000000%
# After epoch 23: valid_err_rate: 0.032600% currently going ot do 2000 epochs [best: 0.032000%]
# At minibatch 11600, batch loss 0.304997, batch error rate 8.000000%
# At minibatch 11700, batch loss 0.097420, batch error rate 2.000000%
# At minibatch 11800, batch loss 0.117321, batch error rate 3.000000%
# At minibatch 11900, batch loss 0.351820, batch error rate 12.000000%
# At minibatch 12000, batch loss 0.349504, batch error rate 12.000000%
# After epoch 24: valid_err_rate: 0.031000% currently going ot do 2000 epochs [best: 0.031000%]
# At minibatch 12100, batch loss 0.246694, batch error rate 8.000000%
# At minibatch 12200, batch loss 0.178106, batch error rate 6.000000%
# At minibatch 12300, batch loss 0.312888, batch error rate 8.000000%
# At minibatch 12400, batch loss 0.186826, batch error rate 7.000000%
# At minibatch 12500, batch loss 0.183819, batch error rate 5.000000%
# After epoch 25: valid_err_rate: 0.031500% currently going ot do 2000 epochs [best: 0.031000%]
# At minibatch 12600, batch loss 0.212820, batch error rate 6.000000%
# At minibatch 12700, batch loss 0.141217, batch error rate 3.000000%
# At minibatch 12800, batch loss 0.234373, batch error rate 5.000000%
# At minibatch 12900, batch loss 0.166015, batch error rate 6.000000%
# At minibatch 13000, batch loss 0.114773, batch error rate 4.000000%
# After epoch 26: valid_err_rate: 0.029600% currently going ot do 2000 epochs [best: 0.029600%]
# At minibatch 13100, batch loss 0.189085, batch error rate 5.000000%
# At minibatch 13200, batch loss 0.170842, batch error rate 4.000000%
# At minibatch 13300, batch loss 0.183537, batch error rate 7.000000%
# At minibatch 13400, batch loss 0.261118, batch error rate 8.000000%
# At minibatch 13500, batch loss 0.209744, batch error rate 5.000000%
# After epoch 27: valid_err_rate: 0.030900% currently going ot do 2000 epochs [best: 0.029600%]
# At minibatch 13600, batch loss 0.236625, batch error rate 8.000000%
# At minibatch 13700, batch loss 0.131084, batch error rate 3.000000%
# At minibatch 13800, batch loss 0.309554, batch error rate 9.000000%
# At minibatch 13900, batch loss 0.082543, batch error rate 2.000000%
# At minibatch 14000, batch loss 0.211835, batch error rate 5.000000%
# After epoch 28: valid_err_rate: 0.028400% currently going ot do 2000 epochs [best: 0.028400%]
# At minibatch 14100, batch loss 0.271755, batch error rate 9.000000%
# At minibatch 14200, batch loss 0.071722, batch error rate 1.000000%
# At minibatch 14300, batch loss 0.167647, batch error rate 4.000000%
# At minibatch 14400, batch loss 0.340472, batch error rate 8.000000%
# At minibatch 14500, batch loss 0.332973, batch error rate 12.000000%
# After epoch 29: valid_err_rate: 0.029900% currently going ot do 2000 epochs [best: 0.028400%]
# At minibatch 14600, batch loss 0.298771, batch error rate 10.000000%
# At minibatch 14700, batch loss 0.215149, batch error rate 8.000000%
# At minibatch 14800, batch loss 0.119009, batch error rate 4.000000%
# At minibatch 14900, batch loss 0.244624, batch error rate 10.000000%
# At minibatch 15000, batch loss 0.181992, batch error rate 6.000000%
# After epoch 30: valid_err_rate: 0.028700% currently going ot do 2000 epochs [best: 0.028400%]
# At minibatch 15100, batch loss 0.245832, batch error rate 10.000000%
# At minibatch 15200, batch loss 0.116955, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.146332, batch error rate 3.000000%
# At minibatch 15400, batch loss 0.189998, batch error rate 6.000000%
# At minibatch 15500, batch loss 0.170629, batch error rate 5.000000%
# After epoch 31: valid_err_rate: 0.027500% currently going ot do 2000 epochs [best: 0.027500%]
# At minibatch 15600, batch loss 0.212117, batch error rate 8.000000%
# At minibatch 15700, batch loss 0.098207, batch error rate 4.000000%
# At minibatch 15800, batch loss 0.318883, batch error rate 9.000000%
# At minibatch 15900, batch loss 0.255992, batch error rate 5.000000%
# At minibatch 16000, batch loss 0.201379, batch error rate 7.000000%
# After epoch 32: valid_err_rate: 0.027600% currently going ot do 2000 epochs [best: 0.027500%]
# At minibatch 16100, batch loss 0.228783, batch error rate 5.000000%
# At minibatch 16200, batch loss 0.116782, batch error rate 3.000000%
# At minibatch 16300, batch loss 0.155799, batch error rate 7.000000%
# At minibatch 16400, batch loss 0.186773, batch error rate 4.000000%
# At minibatch 16500, batch loss 0.265387, batch error rate 8.000000%
# After epoch 33: valid_err_rate: 0.026500% currently going ot do 2000 epochs [best: 0.026500%]
# At minibatch 16600, batch loss 0.232438, batch error rate 9.000000%
# At minibatch 16700, batch loss 0.361424, batch error rate 8.000000%
# At minibatch 16800, batch loss 0.223398, batch error rate 5.000000%
# At minibatch 16900, batch loss 0.399033, batch error rate 9.000000%
# At minibatch 17000, batch loss 0.218664, batch error rate 6.000000%
# After epoch 34: valid_err_rate: 0.026500% currently going ot do 2000 epochs [best: 0.026500%]
# At minibatch 17100, batch loss 0.210934, batch error rate 7.000000%
# At minibatch 17200, batch loss 0.212627, batch error rate 7.000000%
# At minibatch 17300, batch loss 0.201388, batch error rate 4.000000%
# At minibatch 17400, batch loss 0.133816, batch error rate 4.000000%
# At minibatch 17500, batch loss 0.160497, batch error rate 7.000000%
# After epoch 35: valid_err_rate: 0.026000% currently going ot do 2000 epochs [best: 0.026000%]
# At minibatch 17600, batch loss 0.224741, batch error rate 7.000000%
# At minibatch 17700, batch loss 0.137833, batch error rate 5.000000%
# At minibatch 17800, batch loss 0.143315, batch error rate 5.000000%
# At minibatch 17900, batch loss 0.064413, batch error rate 1.000000%
# At minibatch 18000, batch loss 0.205274, batch error rate 7.000000%
# After epoch 36: valid_err_rate: 0.025300% currently going ot do 2000 epochs [best: 0.025300%]
# At minibatch 18100, batch loss 0.180886, batch error rate 6.000000%
# At minibatch 18200, batch loss 0.137798, batch error rate 4.000000%
# At minibatch 18300, batch loss 0.223199, batch error rate 7.000000%
# At minibatch 18400, batch loss 0.209643, batch error rate 7.000000%
# At minibatch 18500, batch loss 0.264047, batch error rate 6.000000%
# After epoch 37: valid_err_rate: 0.026500% currently going ot do 2000 epochs [best: 0.025300%]
# At minibatch 18600, batch loss 0.115721, batch error rate 3.000000%
# At minibatch 18700, batch loss 0.206152, batch error rate 6.000000%
# At minibatch 18800, batch loss 0.207006, batch error rate 5.000000%
# At minibatch 18900, batch loss 0.209431, batch error rate 6.000000%
# At minibatch 19000, batch loss 0.250466, batch error rate 7.000000%
# After epoch 38: valid_err_rate: 0.025800% currently going ot do 2000 epochs [best: 0.025300%]
# At minibatch 19100, batch loss 0.175398, batch error rate 3.000000%
# At minibatch 19200, batch loss 0.182443, batch error rate 5.000000%
# At minibatch 19300, batch loss 0.188538, batch error rate 6.000000%
# At minibatch 19400, batch loss 0.278955, batch error rate 9.000000%
# At minibatch 19500, batch loss 0.244854, batch error rate 10.000000%
# After epoch 39: valid_err_rate: 0.026900% currently going ot do 2000 epochs [best: 0.025300%]
# At minibatch 19600, batch loss 0.124789, batch error rate 5.000000%
# At minibatch 19700, batch loss 0.140774, batch error rate 3.000000%
# At minibatch 19800, batch loss 0.099106, batch error rate 4.000000%
# At minibatch 19900, batch loss 0.202443, batch error rate 7.000000%
# At minibatch 20000, batch loss 0.204658, batch error rate 6.000000%
# After epoch 40: valid_err_rate: 0.025200% currently going ot do 2000 epochs [best: 0.025200%]
# At minibatch 20100, batch loss 0.126654, batch error rate 4.000000%
# At minibatch 20200, batch loss 0.199554, batch error rate 7.000000%
# At minibatch 20300, batch loss 0.176282, batch error rate 5.000000%
# At minibatch 20400, batch loss 0.233289, batch error rate 10.000000%
# At minibatch 20500, batch loss 0.112961, batch error rate 5.000000%
# After epoch 41: valid_err_rate: 0.024900% currently going ot do 2000 epochs [best: 0.024900%]
# At minibatch 20600, batch loss 0.090520, batch error rate 4.000000%
# At minibatch 20700, batch loss 0.121759, batch error rate 3.000000%
# At minibatch 20800, batch loss 0.112922, batch error rate 5.000000%
# At minibatch 20900, batch loss 0.129438, batch error rate 5.000000%
# At minibatch 21000, batch loss 0.091304, batch error rate 3.000000%
# After epoch 42: valid_err_rate: 0.024800% currently going ot do 2000 epochs [best: 0.024800%]
# At minibatch 21100, batch loss 0.122651, batch error rate 4.000000%
# At minibatch 21200, batch loss 0.171978, batch error rate 6.000000%
# At minibatch 21300, batch loss 0.141048, batch error rate 5.000000%
# At minibatch 21400, batch loss 0.084077, batch error rate 1.000000%
# At minibatch 21500, batch loss 0.110705, batch error rate 4.000000%
# After epoch 43: valid_err_rate: 0.024400% currently going ot do 2000 epochs [best: 0.024400%]
# At minibatch 21600, batch loss 0.169089, batch error rate 5.000000%
# At minibatch 21700, batch loss 0.085838, batch error rate 4.000000%
# At minibatch 21800, batch loss 0.252303, batch error rate 9.000000%
# At minibatch 21900, batch loss 0.119300, batch error rate 3.000000%
# At minibatch 22000, batch loss 0.094264, batch error rate 2.000000%
# After epoch 44: valid_err_rate: 0.023800% currently going ot do 2000 epochs [best: 0.023800%]
# At minibatch 22100, batch loss 0.201378, batch error rate 5.000000%
# At minibatch 22200, batch loss 0.103888, batch error rate 3.000000%
# At minibatch 22300, batch loss 0.177948, batch error rate 4.000000%
# At minibatch 22400, batch loss 0.180325, batch error rate 7.000000%
# At minibatch 22500, batch loss 0.180932, batch error rate 7.000000%
# After epoch 45: valid_err_rate: 0.024400% currently going ot do 2000 epochs [best: 0.023800%]
# At minibatch 22600, batch loss 0.242694, batch error rate 9.000000%
# At minibatch 22700, batch loss 0.126496, batch error rate 3.000000%
# At minibatch 22800, batch loss 0.166671, batch error rate 6.000000%
# At minibatch 22900, batch loss 0.098035, batch error rate 4.000000%
# At minibatch 23000, batch loss 0.136390, batch error rate 5.000000%
# After epoch 46: valid_err_rate: 0.025700% currently going ot do 2000 epochs [best: 0.023800%]
# At minibatch 23100, batch loss 0.155370, batch error rate 8.000000%
# At minibatch 23200, batch loss 0.255605, batch error rate 7.000000%
# At minibatch 23300, batch loss 0.134136, batch error rate 5.000000%
# At minibatch 23400, batch loss 0.155495, batch error rate 4.000000%
# At minibatch 23500, batch loss 0.064637, batch error rate 2.000000%
# After epoch 47: valid_err_rate: 0.023800% currently going ot do 2000 epochs [best: 0.023800%]
# At minibatch 23600, batch loss 0.242198, batch error rate 6.000000%
# At minibatch 23700, batch loss 0.143228, batch error rate 4.000000%
# At minibatch 23800, batch loss 0.056720, batch error rate 2.000000%
# At minibatch 23900, batch loss 0.126146, batch error rate 4.000000%
# At minibatch 24000, batch loss 0.086224, batch error rate 1.000000%
# After epoch 48: valid_err_rate: 0.023200% currently going ot do 2000 epochs [best: 0.023200%]
# At minibatch 24100, batch loss 0.297635, batch error rate 7.000000%
# At minibatch 24200, batch loss 0.110521, batch error rate 5.000000%
# At minibatch 24300, batch loss 0.209912, batch error rate 8.000000%
# At minibatch 24400, batch loss 0.102800, batch error rate 3.000000%
# At minibatch 24500, batch loss 0.066839, batch error rate 1.000000%
# After epoch 49: valid_err_rate: 0.023200% currently going ot do 2000 epochs [best: 0.023200%]
# At minibatch 24600, batch loss 0.054968, batch error rate 2.000000%
# At minibatch 24700, batch loss 0.142008, batch error rate 4.000000%
# At minibatch 24800, batch loss 0.185522, batch error rate 5.000000%
# At minibatch 24900, batch loss 0.148375, batch error rate 7.000000%
# At minibatch 25000, batch loss 0.221229, batch error rate 7.000000%
# After epoch 50: valid_err_rate: 0.023700% currently going ot do 2000 epochs [best: 0.023200%]
# At minibatch 25100, batch loss 0.240402, batch error rate 7.000000%
# At minibatch 25200, batch loss 0.125203, batch error rate 3.000000%
# At minibatch 25300, batch loss 0.199293, batch error rate 8.000000%
# At minibatch 25400, batch loss 0.186905, batch error rate 4.000000%
# At minibatch 25500, batch loss 0.216692, batch error rate 7.000000%
# After epoch 51: valid_err_rate: 0.022800% currently going ot do 2000 epochs [best: 0.022800%]
# At minibatch 25600, batch loss 0.203149, batch error rate 6.000000%
# At minibatch 25700, batch loss 0.217827, batch error rate 7.000000%
# At minibatch 25800, batch loss 0.118148, batch error rate 5.000000%
# At minibatch 25900, batch loss 0.072360, batch error rate 2.000000%
# At minibatch 26000, batch loss 0.280564, batch error rate 7.000000%
# After epoch 52: valid_err_rate: 0.023700% currently going ot do 2000 epochs [best: 0.022800%]
# At minibatch 26100, batch loss 0.175607, batch error rate 5.000000%
# At minibatch 26200, batch loss 0.149453, batch error rate 4.000000%
# At minibatch 26300, batch loss 0.136485, batch error rate 6.000000%
# At minibatch 26400, batch loss 0.185708, batch error rate 5.000000%
# At minibatch 26500, batch loss 0.129219, batch error rate 4.000000%
# After epoch 53: valid_err_rate: 0.023100% currently going ot do 2000 epochs [best: 0.022800%]
# At minibatch 26600, batch loss 0.177584, batch error rate 5.000000%
# At minibatch 26700, batch loss 0.066683, batch error rate 2.000000%
# At minibatch 26800, batch loss 0.039804, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.129803, batch error rate 3.000000%
# At minibatch 27000, batch loss 0.050779, batch error rate 3.000000%
# After epoch 54: valid_err_rate: 0.024200% currently going ot do 2000 epochs [best: 0.022800%]
# At minibatch 27100, batch loss 0.106344, batch error rate 2.000000%
# At minibatch 27200, batch loss 0.199185, batch error rate 6.000000%
# At minibatch 27300, batch loss 0.115246, batch error rate 3.000000%
# At minibatch 27400, batch loss 0.109180, batch error rate 4.000000%
# At minibatch 27500, batch loss 0.054113, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.022800% currently going ot do 2000 epochs [best: 0.022800%]
# At minibatch 27600, batch loss 0.160687, batch error rate 4.000000%
# At minibatch 27700, batch loss 0.035266, batch error rate 1.000000%
# At minibatch 27800, batch loss 0.087610, batch error rate 3.000000%
# At minibatch 27900, batch loss 0.105129, batch error rate 3.000000%
# At minibatch 28000, batch loss 0.076578, batch error rate 2.000000%
# After epoch 56: valid_err_rate: 0.022700% currently going ot do 2000 epochs [best: 0.022700%]
# At minibatch 28100, batch loss 0.165458, batch error rate 5.000000%
# At minibatch 28200, batch loss 0.065817, batch error rate 1.000000%
# At minibatch 28300, batch loss 0.107187, batch error rate 4.000000%
# At minibatch 28400, batch loss 0.081072, batch error rate 6.000000%
# At minibatch 28500, batch loss 0.096239, batch error rate 4.000000%
# After epoch 57: valid_err_rate: 0.021600% currently going ot do 2000 epochs [best: 0.021600%]
# At minibatch 28600, batch loss 0.160442, batch error rate 5.000000%
# At minibatch 28700, batch loss 0.230917, batch error rate 9.000000%
# At minibatch 28800, batch loss 0.147046, batch error rate 4.000000%
# At minibatch 28900, batch loss 0.210995, batch error rate 10.000000%
# At minibatch 29000, batch loss 0.162599, batch error rate 5.000000%
# After epoch 58: valid_err_rate: 0.022800% currently going ot do 2000 epochs [best: 0.021600%]
# At minibatch 29100, batch loss 0.201417, batch error rate 7.000000%
# At minibatch 29200, batch loss 0.064744, batch error rate 2.000000%
# At minibatch 29300, batch loss 0.142018, batch error rate 5.000000%
# At minibatch 29400, batch loss 0.121925, batch error rate 4.000000%
# At minibatch 29500, batch loss 0.042835, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.021000% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 29600, batch loss 0.287972, batch error rate 6.000000%
# At minibatch 29700, batch loss 0.046041, batch error rate 1.000000%
# At minibatch 29800, batch loss 0.206720, batch error rate 7.000000%
# At minibatch 29900, batch loss 0.090958, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.105080, batch error rate 4.000000%
# After epoch 60: valid_err_rate: 0.022500% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 30100, batch loss 0.146600, batch error rate 4.000000%
# At minibatch 30200, batch loss 0.115635, batch error rate 5.000000%
# At minibatch 30300, batch loss 0.073865, batch error rate 1.000000%
# At minibatch 30400, batch loss 0.049619, batch error rate 1.000000%
# At minibatch 30500, batch loss 0.163132, batch error rate 5.000000%
# After epoch 61: valid_err_rate: 0.023300% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 30600, batch loss 0.111788, batch error rate 3.000000%
# At minibatch 30700, batch loss 0.094599, batch error rate 3.000000%
# At minibatch 30800, batch loss 0.113305, batch error rate 3.000000%
# At minibatch 30900, batch loss 0.067130, batch error rate 2.000000%
# At minibatch 31000, batch loss 0.081866, batch error rate 1.000000%
# After epoch 62: valid_err_rate: 0.022900% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 31100, batch loss 0.236112, batch error rate 8.000000%
# At minibatch 31200, batch loss 0.056488, batch error rate 2.000000%
# At minibatch 31300, batch loss 0.134640, batch error rate 5.000000%
# At minibatch 31400, batch loss 0.095026, batch error rate 3.000000%
# At minibatch 31500, batch loss 0.168325, batch error rate 6.000000%
# After epoch 63: valid_err_rate: 0.022300% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 31600, batch loss 0.148992, batch error rate 6.000000%
# At minibatch 31700, batch loss 0.077668, batch error rate 2.000000%
# At minibatch 31800, batch loss 0.195909, batch error rate 5.000000%
# At minibatch 31900, batch loss 0.177654, batch error rate 6.000000%
# At minibatch 32000, batch loss 0.097365, batch error rate 4.000000%
# After epoch 64: valid_err_rate: 0.021300% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 32100, batch loss 0.171428, batch error rate 6.000000%
# At minibatch 32200, batch loss 0.094330, batch error rate 3.000000%
# At minibatch 32300, batch loss 0.060341, batch error rate 2.000000%
# At minibatch 32400, batch loss 0.210814, batch error rate 8.000000%
# At minibatch 32500, batch loss 0.263780, batch error rate 5.000000%
# After epoch 65: valid_err_rate: 0.021900% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 32600, batch loss 0.111587, batch error rate 3.000000%
# At minibatch 32700, batch loss 0.132987, batch error rate 2.000000%
# At minibatch 32800, batch loss 0.070203, batch error rate 3.000000%
# At minibatch 32900, batch loss 0.172104, batch error rate 6.000000%
# At minibatch 33000, batch loss 0.095065, batch error rate 3.000000%
# After epoch 66: valid_err_rate: 0.021300% currently going ot do 2000 epochs [best: 0.021000%]
# At minibatch 33100, batch loss 0.198486, batch error rate 6.000000%
# At minibatch 33200, batch loss 0.145439, batch error rate 5.000000%
# At minibatch 33300, batch loss 0.094379, batch error rate 5.000000%
# At minibatch 33400, batch loss 0.061954, batch error rate 2.000000%
# At minibatch 33500, batch loss 0.081809, batch error rate 3.000000%
# After epoch 67: valid_err_rate: 0.020400% currently going ot do 2000 epochs [best: 0.020400%]
# At minibatch 33600, batch loss 0.125485, batch error rate 3.000000%
# At minibatch 33700, batch loss 0.104839, batch error rate 2.000000%
# At minibatch 33800, batch loss 0.096349, batch error rate 2.000000%
# At minibatch 33900, batch loss 0.179369, batch error rate 6.000000%
# At minibatch 34000, batch loss 0.055153, batch error rate 1.000000%
# After epoch 68: valid_err_rate: 0.021100% currently going ot do 2000 epochs [best: 0.020400%]
# At minibatch 34100, batch loss 0.314328, batch error rate 8.000000%
# At minibatch 34200, batch loss 0.153222, batch error rate 8.000000%
# At minibatch 34300, batch loss 0.115989, batch error rate 3.000000%
# At minibatch 34400, batch loss 0.077902, batch error rate 3.000000%
# At minibatch 34500, batch loss 0.053226, batch error rate 2.000000%
# After epoch 69: valid_err_rate: 0.020900% currently going ot do 2000 epochs [best: 0.020400%]
# At minibatch 34600, batch loss 0.106216, batch error rate 2.000000%
# At minibatch 34700, batch loss 0.064078, batch error rate 2.000000%
# At minibatch 34800, batch loss 0.139735, batch error rate 3.000000%
# At minibatch 34900, batch loss 0.113707, batch error rate 3.000000%
# At minibatch 35000, batch loss 0.095936, batch error rate 4.000000%
# After epoch 70: valid_err_rate: 0.021400% currently going ot do 2000 epochs [best: 0.020400%]
# At minibatch 35100, batch loss 0.229892, batch error rate 4.000000%
# At minibatch 35200, batch loss 0.081809, batch error rate 2.000000%
# At minibatch 35300, batch loss 0.189524, batch error rate 4.000000%
# At minibatch 35400, batch loss 0.149978, batch error rate 3.000000%
# At minibatch 35500, batch loss 0.073227, batch error rate 1.000000%
# After epoch 71: valid_err_rate: 0.021800% currently going ot do 2000 epochs [best: 0.020400%]
# At minibatch 35600, batch loss 0.104243, batch error rate 4.000000%
# At minibatch 35700, batch loss 0.070073, batch error rate 2.000000%
# At minibatch 35800, batch loss 0.042513, batch error rate 1.000000%
# At minibatch 35900, batch loss 0.065958, batch error rate 2.000000%
# At minibatch 36000, batch loss 0.157979, batch error rate 6.000000%
# After epoch 72: valid_err_rate: 0.019900% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 36100, batch loss 0.069869, batch error rate 2.000000%
# At minibatch 36200, batch loss 0.061097, batch error rate 3.000000%
# At minibatch 36300, batch loss 0.098091, batch error rate 4.000000%
# At minibatch 36400, batch loss 0.038962, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.091760, batch error rate 2.000000%
# After epoch 73: valid_err_rate: 0.020800% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 36600, batch loss 0.053991, batch error rate 1.000000%
# At minibatch 36700, batch loss 0.138148, batch error rate 5.000000%
# At minibatch 36800, batch loss 0.053962, batch error rate 1.000000%
# At minibatch 36900, batch loss 0.110168, batch error rate 4.000000%
# At minibatch 37000, batch loss 0.124038, batch error rate 2.000000%
# After epoch 74: valid_err_rate: 0.020200% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 37100, batch loss 0.118718, batch error rate 5.000000%
# At minibatch 37200, batch loss 0.089473, batch error rate 2.000000%
# At minibatch 37300, batch loss 0.116255, batch error rate 4.000000%
# At minibatch 37400, batch loss 0.117370, batch error rate 3.000000%
# At minibatch 37500, batch loss 0.119627, batch error rate 6.000000%
# After epoch 75: valid_err_rate: 0.021300% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 37600, batch loss 0.075299, batch error rate 4.000000%
# At minibatch 37700, batch loss 0.143434, batch error rate 4.000000%
# At minibatch 37800, batch loss 0.133096, batch error rate 6.000000%
# At minibatch 37900, batch loss 0.096792, batch error rate 3.000000%
# At minibatch 38000, batch loss 0.092407, batch error rate 1.000000%
# After epoch 76: valid_err_rate: 0.021100% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 38100, batch loss 0.050080, batch error rate 3.000000%
# At minibatch 38200, batch loss 0.197256, batch error rate 6.000000%
# At minibatch 38300, batch loss 0.043299, batch error rate 1.000000%
# At minibatch 38400, batch loss 0.149244, batch error rate 4.000000%
# At minibatch 38500, batch loss 0.067006, batch error rate 2.000000%
# After epoch 77: valid_err_rate: 0.020900% currently going ot do 2000 epochs [best: 0.019900%]
# At minibatch 38600, batch loss 0.057356, batch error rate 2.000000%
# At minibatch 38700, batch loss 0.116087, batch error rate 4.000000%
# At minibatch 38800, batch loss 0.134165, batch error rate 5.000000%
# At minibatch 38900, batch loss 0.133744, batch error rate 3.000000%
# At minibatch 39000, batch loss 0.110954, batch error rate 2.000000%
# After epoch 78: valid_err_rate: 0.019300% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 39100, batch loss 0.037935, batch error rate 1.000000%
# At minibatch 39200, batch loss 0.075950, batch error rate 3.000000%
# At minibatch 39300, batch loss 0.083639, batch error rate 2.000000%
# At minibatch 39400, batch loss 0.086253, batch error rate 2.000000%
# At minibatch 39500, batch loss 0.153113, batch error rate 5.000000%
# After epoch 79: valid_err_rate: 0.020000% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 39600, batch loss 0.103062, batch error rate 3.000000%
# At minibatch 39700, batch loss 0.083415, batch error rate 3.000000%
# At minibatch 39800, batch loss 0.088795, batch error rate 2.000000%
# At minibatch 39900, batch loss 0.216520, batch error rate 4.000000%
# At minibatch 40000, batch loss 0.136061, batch error rate 4.000000%
# After epoch 80: valid_err_rate: 0.020100% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 40100, batch loss 0.104307, batch error rate 4.000000%
# At minibatch 40200, batch loss 0.065983, batch error rate 3.000000%
# At minibatch 40300, batch loss 0.083968, batch error rate 2.000000%
# At minibatch 40400, batch loss 0.084533, batch error rate 2.000000%
# At minibatch 40500, batch loss 0.100810, batch error rate 3.000000%
# After epoch 81: valid_err_rate: 0.019400% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 40600, batch loss 0.133981, batch error rate 2.000000%
# At minibatch 40700, batch loss 0.106907, batch error rate 4.000000%
# At minibatch 40800, batch loss 0.175082, batch error rate 7.000000%
# At minibatch 40900, batch loss 0.220708, batch error rate 7.000000%
# At minibatch 41000, batch loss 0.105572, batch error rate 3.000000%
# After epoch 82: valid_err_rate: 0.020800% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 41100, batch loss 0.158323, batch error rate 6.000000%
# At minibatch 41200, batch loss 0.172205, batch error rate 4.000000%
# At minibatch 41300, batch loss 0.033100, batch error rate 1.000000%
# At minibatch 41400, batch loss 0.074086, batch error rate 3.000000%
# At minibatch 41500, batch loss 0.077810, batch error rate 4.000000%
# After epoch 83: valid_err_rate: 0.020100% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 41600, batch loss 0.209275, batch error rate 7.000000%
# At minibatch 41700, batch loss 0.112419, batch error rate 4.000000%
# At minibatch 41800, batch loss 0.134035, batch error rate 4.000000%
# At minibatch 41900, batch loss 0.148700, batch error rate 5.000000%
# At minibatch 42000, batch loss 0.131056, batch error rate 3.000000%
# After epoch 84: valid_err_rate: 0.019400% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 42100, batch loss 0.134524, batch error rate 5.000000%
# At minibatch 42200, batch loss 0.131103, batch error rate 3.000000%
# At minibatch 42300, batch loss 0.081065, batch error rate 2.000000%
# At minibatch 42400, batch loss 0.103206, batch error rate 2.000000%
# At minibatch 42500, batch loss 0.136036, batch error rate 4.000000%
# After epoch 85: valid_err_rate: 0.020600% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 42600, batch loss 0.088670, batch error rate 2.000000%
# At minibatch 42700, batch loss 0.205281, batch error rate 7.000000%
# At minibatch 42800, batch loss 0.098405, batch error rate 4.000000%
# At minibatch 42900, batch loss 0.127631, batch error rate 6.000000%
# At minibatch 43000, batch loss 0.125021, batch error rate 5.000000%
# After epoch 86: valid_err_rate: 0.020100% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 43100, batch loss 0.121982, batch error rate 5.000000%
# At minibatch 43200, batch loss 0.248405, batch error rate 10.000000%
# At minibatch 43300, batch loss 0.085595, batch error rate 3.000000%
# At minibatch 43400, batch loss 0.095228, batch error rate 1.000000%
# At minibatch 43500, batch loss 0.063833, batch error rate 3.000000%
# After epoch 87: valid_err_rate: 0.019800% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 43600, batch loss 0.144935, batch error rate 3.000000%
# At minibatch 43700, batch loss 0.048532, batch error rate 2.000000%
# At minibatch 43800, batch loss 0.074067, batch error rate 3.000000%
# At minibatch 43900, batch loss 0.096667, batch error rate 4.000000%
# At minibatch 44000, batch loss 0.066956, batch error rate 3.000000%
# After epoch 88: valid_err_rate: 0.020100% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 44100, batch loss 0.083316, batch error rate 3.000000%
# At minibatch 44200, batch loss 0.059686, batch error rate 3.000000%
# At minibatch 44300, batch loss 0.123231, batch error rate 5.000000%
# At minibatch 44400, batch loss 0.096251, batch error rate 2.000000%
# At minibatch 44500, batch loss 0.183389, batch error rate 5.000000%
# After epoch 89: valid_err_rate: 0.020400% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 44600, batch loss 0.097251, batch error rate 3.000000%
# At minibatch 44700, batch loss 0.068125, batch error rate 1.000000%
# At minibatch 44800, batch loss 0.069683, batch error rate 4.000000%
# At minibatch 44900, batch loss 0.044998, batch error rate 1.000000%
# At minibatch 45000, batch loss 0.126325, batch error rate 3.000000%
# After epoch 90: valid_err_rate: 0.020000% currently going ot do 2000 epochs [best: 0.019300%]
# At minibatch 45100, batch loss 0.164567, batch error rate 5.000000%
# At minibatch 45200, batch loss 0.117363, batch error rate 4.000000%
# At minibatch 45300, batch loss 0.264512, batch error rate 5.000000%
# At minibatch 45400, batch loss 0.092784, batch error rate 3.000000%
# At minibatch 45500, batch loss 0.041840, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.018600% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 45600, batch loss 0.054123, batch error rate 1.000000%
# At minibatch 45700, batch loss 0.051923, batch error rate 2.000000%
# At minibatch 45800, batch loss 0.072229, batch error rate 3.000000%
# At minibatch 45900, batch loss 0.225039, batch error rate 7.000000%
# At minibatch 46000, batch loss 0.130270, batch error rate 4.000000%
# After epoch 92: valid_err_rate: 0.019100% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 46100, batch loss 0.105208, batch error rate 5.000000%
# At minibatch 46200, batch loss 0.092238, batch error rate 4.000000%
# At minibatch 46300, batch loss 0.117900, batch error rate 2.000000%
# At minibatch 46400, batch loss 0.137877, batch error rate 3.000000%
# At minibatch 46500, batch loss 0.193252, batch error rate 5.000000%
# After epoch 93: valid_err_rate: 0.019600% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 46600, batch loss 0.026038, batch error rate 1.000000%
# At minibatch 46700, batch loss 0.054195, batch error rate 1.000000%
# At minibatch 46800, batch loss 0.040302, batch error rate 1.000000%
# At minibatch 46900, batch loss 0.229374, batch error rate 3.000000%
# At minibatch 47000, batch loss 0.095264, batch error rate 2.000000%
# After epoch 94: valid_err_rate: 0.019400% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 47100, batch loss 0.133377, batch error rate 5.000000%
# At minibatch 47200, batch loss 0.080556, batch error rate 2.000000%
# At minibatch 47300, batch loss 0.164454, batch error rate 4.000000%
# At minibatch 47400, batch loss 0.071189, batch error rate 3.000000%
# At minibatch 47500, batch loss 0.135891, batch error rate 4.000000%
# After epoch 95: valid_err_rate: 0.020200% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 47600, batch loss 0.131963, batch error rate 5.000000%
# At minibatch 47700, batch loss 0.219932, batch error rate 9.000000%
# At minibatch 47800, batch loss 0.084795, batch error rate 3.000000%
# At minibatch 47900, batch loss 0.091663, batch error rate 3.000000%
# At minibatch 48000, batch loss 0.130793, batch error rate 7.000000%
# After epoch 96: valid_err_rate: 0.019500% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 48100, batch loss 0.074591, batch error rate 3.000000%
# At minibatch 48200, batch loss 0.157752, batch error rate 5.000000%
# At minibatch 48300, batch loss 0.051837, batch error rate 2.000000%
# At minibatch 48400, batch loss 0.067955, batch error rate 1.000000%
# At minibatch 48500, batch loss 0.123808, batch error rate 4.000000%
# After epoch 97: valid_err_rate: 0.018900% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 48600, batch loss 0.190187, batch error rate 5.000000%
# At minibatch 48700, batch loss 0.246545, batch error rate 7.000000%
# At minibatch 48800, batch loss 0.264276, batch error rate 8.000000%
# At minibatch 48900, batch loss 0.192673, batch error rate 6.000000%
# At minibatch 49000, batch loss 0.199211, batch error rate 7.000000%
# After epoch 98: valid_err_rate: 0.019000% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 49100, batch loss 0.072151, batch error rate 2.000000%
# At minibatch 49200, batch loss 0.325864, batch error rate 9.000000%
# At minibatch 49300, batch loss 0.089632, batch error rate 3.000000%
# At minibatch 49400, batch loss 0.092965, batch error rate 2.000000%
# At minibatch 49500, batch loss 0.063338, batch error rate 2.000000%
# After epoch 99: valid_err_rate: 0.019100% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 49600, batch loss 0.055984, batch error rate 2.000000%
# At minibatch 49700, batch loss 0.098253, batch error rate 3.000000%
# At minibatch 49800, batch loss 0.070637, batch error rate 3.000000%
# At minibatch 49900, batch loss 0.182734, batch error rate 4.000000%
# At minibatch 50000, batch loss 0.063645, batch error rate 2.000000%
# After epoch 100: valid_err_rate: 0.019400% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 50100, batch loss 0.071328, batch error rate 4.000000%
# At minibatch 50200, batch loss 0.148283, batch error rate 6.000000%
# At minibatch 50300, batch loss 0.207216, batch error rate 7.000000%
# At minibatch 50400, batch loss 0.159425, batch error rate 6.000000%
# At minibatch 50500, batch loss 0.092233, batch error rate 5.000000%
# After epoch 101: valid_err_rate: 0.018800% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 50600, batch loss 0.156924, batch error rate 4.000000%
# At minibatch 50700, batch loss 0.093956, batch error rate 2.000000%
# At minibatch 50800, batch loss 0.113368, batch error rate 3.000000%
# At minibatch 50900, batch loss 0.121931, batch error rate 5.000000%
# At minibatch 51000, batch loss 0.056348, batch error rate 2.000000%
# After epoch 102: valid_err_rate: 0.019600% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 51100, batch loss 0.070704, batch error rate 3.000000%
# At minibatch 51200, batch loss 0.139145, batch error rate 4.000000%
# At minibatch 51300, batch loss 0.089833, batch error rate 3.000000%
# At minibatch 51400, batch loss 0.128522, batch error rate 3.000000%
# At minibatch 51500, batch loss 0.104937, batch error rate 2.000000%
# After epoch 103: valid_err_rate: 0.019200% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 51600, batch loss 0.172785, batch error rate 5.000000%
# At minibatch 51700, batch loss 0.137172, batch error rate 4.000000%
# At minibatch 51800, batch loss 0.043551, batch error rate 2.000000%
# At minibatch 51900, batch loss 0.147134, batch error rate 6.000000%
# At minibatch 52000, batch loss 0.133961, batch error rate 4.000000%
# After epoch 104: valid_err_rate: 0.019300% currently going ot do 2000 epochs [best: 0.018600%]
# At minibatch 52100, batch loss 0.170733, batch error rate 5.000000%
# At minibatch 52200, batch loss 0.122145, batch error rate 3.000000%
# At minibatch 52300, batch loss 0.101713, batch error rate 4.000000%
# At minibatch 52400, batch loss 0.105373, batch error rate 3.000000%
# At minibatch 52500, batch loss 0.037767, batch error rate 2.000000%
# After epoch 105: valid_err_rate: 0.018400% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 52600, batch loss 0.119338, batch error rate 4.000000%
# At minibatch 52700, batch loss 0.086856, batch error rate 3.000000%
# At minibatch 52800, batch loss 0.076104, batch error rate 3.000000%
# At minibatch 52900, batch loss 0.175986, batch error rate 7.000000%
# At minibatch 53000, batch loss 0.177066, batch error rate 5.000000%
# After epoch 106: valid_err_rate: 0.019300% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 53100, batch loss 0.037012, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.050048, batch error rate 1.000000%
# At minibatch 53300, batch loss 0.084827, batch error rate 2.000000%
# At minibatch 53400, batch loss 0.115107, batch error rate 3.000000%
# At minibatch 53500, batch loss 0.029917, batch error rate 1.000000%
# After epoch 107: valid_err_rate: 0.018400% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 53600, batch loss 0.077632, batch error rate 3.000000%
# At minibatch 53700, batch loss 0.049284, batch error rate 1.000000%
# At minibatch 53800, batch loss 0.188360, batch error rate 5.000000%
# At minibatch 53900, batch loss 0.160047, batch error rate 5.000000%
# At minibatch 54000, batch loss 0.056248, batch error rate 1.000000%
# After epoch 108: valid_err_rate: 0.018800% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 54100, batch loss 0.258242, batch error rate 8.000000%
# At minibatch 54200, batch loss 0.100809, batch error rate 3.000000%
# At minibatch 54300, batch loss 0.045277, batch error rate 1.000000%
# At minibatch 54400, batch loss 0.159699, batch error rate 6.000000%
# At minibatch 54500, batch loss 0.081096, batch error rate 3.000000%
# After epoch 109: valid_err_rate: 0.018700% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 54600, batch loss 0.076835, batch error rate 2.000000%
# At minibatch 54700, batch loss 0.034051, batch error rate 2.000000%
# At minibatch 54800, batch loss 0.113910, batch error rate 4.000000%
# At minibatch 54900, batch loss 0.134994, batch error rate 4.000000%
# At minibatch 55000, batch loss 0.105146, batch error rate 3.000000%
# After epoch 110: valid_err_rate: 0.018400% currently going ot do 2000 epochs [best: 0.018400%]
# At minibatch 55100, batch loss 0.042489, batch error rate 2.000000%
# At minibatch 55200, batch loss 0.065501, batch error rate 1.000000%
# ...
# At minibatch 720400, batch loss 0.043380, batch error rate 3.000000%
# At minibatch 720500, batch loss 0.188199, batch error rate 6.000000%
# After epoch 1441: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 720600, batch loss 0.090009, batch error rate 3.000000%
# At minibatch 720700, batch loss 0.078337, batch error rate 3.000000%
# At minibatch 720800, batch loss 0.158008, batch error rate 4.000000%
# At minibatch 720900, batch loss 0.075260, batch error rate 4.000000%
# At minibatch 721000, batch loss 0.064490, batch error rate 2.000000%
# After epoch 1442: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 721100, batch loss 0.043667, batch error rate 1.000000%
# At minibatch 721200, batch loss 0.066056, batch error rate 3.000000%
# At minibatch 721300, batch loss 0.063989, batch error rate 1.000000%
# At minibatch 721400, batch loss 0.102907, batch error rate 3.000000%
# At minibatch 721500, batch loss 0.083449, batch error rate 4.000000%
# After epoch 1443: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 721600, batch loss 0.064201, batch error rate 3.000000%
# At minibatch 721700, batch loss 0.068978, batch error rate 4.000000%
# At minibatch 721800, batch loss 0.024733, batch error rate 0.000000%
# At minibatch 721900, batch loss 0.058477, batch error rate 2.000000%
# At minibatch 722000, batch loss 0.105079, batch error rate 2.000000%
# After epoch 1444: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 722100, batch loss 0.061151, batch error rate 2.000000%
# At minibatch 722200, batch loss 0.063832, batch error rate 2.000000%
# At minibatch 722300, batch loss 0.072965, batch error rate 1.000000%
# At minibatch 722400, batch loss 0.094292, batch error rate 3.000000%
# At minibatch 722500, batch loss 0.080489, batch error rate 2.000000%
# After epoch 1445: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 722600, batch loss 0.041480, batch error rate 2.000000%
# At minibatch 722700, batch loss 0.021412, batch error rate 0.000000%
# At minibatch 722800, batch loss 0.035621, batch error rate 2.000000%
# At minibatch 722900, batch loss 0.027803, batch error rate 0.000000%
# At minibatch 723000, batch loss 0.082172, batch error rate 1.000000%
# After epoch 1446: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 723100, batch loss 0.069717, batch error rate 3.000000%
# At minibatch 723200, batch loss 0.079657, batch error rate 3.000000%
# At minibatch 723300, batch loss 0.034465, batch error rate 1.000000%
# At minibatch 723400, batch loss 0.105749, batch error rate 5.000000%
# At minibatch 723500, batch loss 0.072970, batch error rate 2.000000%
# After epoch 1447: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 723600, batch loss 0.128223, batch error rate 4.000000%
# At minibatch 723700, batch loss 0.065212, batch error rate 3.000000%
# At minibatch 723800, batch loss 0.202385, batch error rate 5.000000%
# At minibatch 723900, batch loss 0.050315, batch error rate 2.000000%
# At minibatch 724000, batch loss 0.054335, batch error rate 4.000000%
# After epoch 1448: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 724100, batch loss 0.047351, batch error rate 2.000000%
# At minibatch 724200, batch loss 0.153581, batch error rate 4.000000%
# At minibatch 724300, batch loss 0.080432, batch error rate 3.000000%
# At minibatch 724400, batch loss 0.079463, batch error rate 3.000000%
# At minibatch 724500, batch loss 0.063003, batch error rate 2.000000%
# After epoch 1449: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 724600, batch loss 0.128846, batch error rate 3.000000%
# At minibatch 724700, batch loss 0.129874, batch error rate 2.000000%
# At minibatch 724800, batch loss 0.017891, batch error rate 1.000000%
# At minibatch 724900, batch loss 0.045482, batch error rate 2.000000%
# At minibatch 725000, batch loss 0.040684, batch error rate 1.000000%
# After epoch 1450: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 725100, batch loss 0.027981, batch error rate 1.000000%
# At minibatch 725200, batch loss 0.143655, batch error rate 6.000000%
# At minibatch 725300, batch loss 0.040196, batch error rate 1.000000%
# At minibatch 725400, batch loss 0.073859, batch error rate 3.000000%
# At minibatch 725500, batch loss 0.126468, batch error rate 3.000000%
# After epoch 1451: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 725600, batch loss 0.060743, batch error rate 2.000000%
# At minibatch 725700, batch loss 0.145113, batch error rate 3.000000%
# At minibatch 725800, batch loss 0.127873, batch error rate 7.000000%
# At minibatch 725900, batch loss 0.073312, batch error rate 2.000000%
# At minibatch 726000, batch loss 0.068548, batch error rate 1.000000%
# After epoch 1452: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 726100, batch loss 0.020184, batch error rate 1.000000%
# At minibatch 726200, batch loss 0.083344, batch error rate 3.000000%
# At minibatch 726300, batch loss 0.115943, batch error rate 4.000000%
# At minibatch 726400, batch loss 0.281181, batch error rate 7.000000%
# At minibatch 726500, batch loss 0.048612, batch error rate 1.000000%
# After epoch 1453: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 726600, batch loss 0.039703, batch error rate 2.000000%
# At minibatch 726700, batch loss 0.028477, batch error rate 0.000000%
# At minibatch 726800, batch loss 0.032458, batch error rate 2.000000%
# At minibatch 726900, batch loss 0.013564, batch error rate 0.000000%
# At minibatch 727000, batch loss 0.026492, batch error rate 1.000000%
# After epoch 1454: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 727100, batch loss 0.052442, batch error rate 1.000000%
# At minibatch 727200, batch loss 0.019902, batch error rate 0.000000%
# At minibatch 727300, batch loss 0.117822, batch error rate 4.000000%
# At minibatch 727400, batch loss 0.058720, batch error rate 2.000000%
# At minibatch 727500, batch loss 0.033004, batch error rate 2.000000%
# After epoch 1455: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 727600, batch loss 0.019727, batch error rate 0.000000%
# At minibatch 727700, batch loss 0.085110, batch error rate 4.000000%
# At minibatch 727800, batch loss 0.025508, batch error rate 2.000000%
# At minibatch 727900, batch loss 0.033032, batch error rate 0.000000%
# At minibatch 728000, batch loss 0.058466, batch error rate 3.000000%
# After epoch 1456: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 728100, batch loss 0.074190, batch error rate 3.000000%
# At minibatch 728200, batch loss 0.111820, batch error rate 2.000000%
# At minibatch 728300, batch loss 0.045217, batch error rate 2.000000%
# At minibatch 728400, batch loss 0.088590, batch error rate 3.000000%
# At minibatch 728500, batch loss 0.035872, batch error rate 2.000000%
# After epoch 1457: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 728600, batch loss 0.066648, batch error rate 2.000000%
# At minibatch 728700, batch loss 0.090243, batch error rate 3.000000%
# At minibatch 728800, batch loss 0.029726, batch error rate 0.000000%
# At minibatch 728900, batch loss 0.119503, batch error rate 4.000000%
# At minibatch 729000, batch loss 0.106206, batch error rate 3.000000%
# After epoch 1458: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 729100, batch loss 0.002927, batch error rate 0.000000%
# At minibatch 729200, batch loss 0.184451, batch error rate 4.000000%
# At minibatch 729300, batch loss 0.031111, batch error rate 1.000000%
# At minibatch 729400, batch loss 0.059770, batch error rate 2.000000%
# At minibatch 729500, batch loss 0.055569, batch error rate 1.000000%
# After epoch 1459: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 729600, batch loss 0.040591, batch error rate 2.000000%
# At minibatch 729700, batch loss 0.114337, batch error rate 4.000000%
# At minibatch 729800, batch loss 0.040878, batch error rate 2.000000%
# At minibatch 729900, batch loss 0.166391, batch error rate 3.000000%
# At minibatch 730000, batch loss 0.046492, batch error rate 1.000000%
# After epoch 1460: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 730100, batch loss 0.078378, batch error rate 5.000000%
# At minibatch 730200, batch loss 0.078250, batch error rate 3.000000%
# At minibatch 730300, batch loss 0.072966, batch error rate 2.000000%
# At minibatch 730400, batch loss 0.089471, batch error rate 1.000000%
# At minibatch 730500, batch loss 0.075507, batch error rate 2.000000%
# After epoch 1461: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 730600, batch loss 0.124993, batch error rate 6.000000%
# At minibatch 730700, batch loss 0.133886, batch error rate 4.000000%
# At minibatch 730800, batch loss 0.154885, batch error rate 5.000000%
# At minibatch 730900, batch loss 0.047456, batch error rate 1.000000%
# At minibatch 731000, batch loss 0.019976, batch error rate 1.000000%
# After epoch 1462: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 731100, batch loss 0.018298, batch error rate 1.000000%
# At minibatch 731200, batch loss 0.084187, batch error rate 3.000000%
# At minibatch 731300, batch loss 0.108142, batch error rate 3.000000%
# At minibatch 731400, batch loss 0.280083, batch error rate 6.000000%
# At minibatch 731500, batch loss 0.042074, batch error rate 2.000000%
# After epoch 1463: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 731600, batch loss 0.097318, batch error rate 3.000000%
# At minibatch 731700, batch loss 0.062772, batch error rate 3.000000%
# At minibatch 731800, batch loss 0.050427, batch error rate 2.000000%
# At minibatch 731900, batch loss 0.055668, batch error rate 3.000000%
# At minibatch 732000, batch loss 0.079517, batch error rate 2.000000%
# After epoch 1464: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 732100, batch loss 0.029361, batch error rate 1.000000%
# At minibatch 732200, batch loss 0.079406, batch error rate 3.000000%
# At minibatch 732300, batch loss 0.037724, batch error rate 1.000000%
# At minibatch 732400, batch loss 0.079815, batch error rate 3.000000%
# At minibatch 732500, batch loss 0.089587, batch error rate 3.000000%
# After epoch 1465: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 732600, batch loss 0.056573, batch error rate 4.000000%
# At minibatch 732700, batch loss 0.033211, batch error rate 1.000000%
# At minibatch 732800, batch loss 0.058396, batch error rate 3.000000%
# At minibatch 732900, batch loss 0.017419, batch error rate 1.000000%
# At minibatch 733000, batch loss 0.204653, batch error rate 7.000000%
# After epoch 1466: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 733100, batch loss 0.052761, batch error rate 1.000000%
# At minibatch 733200, batch loss 0.057740, batch error rate 2.000000%
# At minibatch 733300, batch loss 0.052688, batch error rate 1.000000%
# At minibatch 733400, batch loss 0.031633, batch error rate 1.000000%
# At minibatch 733500, batch loss 0.072423, batch error rate 2.000000%
# After epoch 1467: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 733600, batch loss 0.047389, batch error rate 1.000000%
# At minibatch 733700, batch loss 0.062681, batch error rate 2.000000%
# At minibatch 733800, batch loss 0.060684, batch error rate 1.000000%
# At minibatch 733900, batch loss 0.104705, batch error rate 4.000000%
# At minibatch 734000, batch loss 0.023754, batch error rate 1.000000%
# After epoch 1468: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 734100, batch loss 0.079485, batch error rate 2.000000%
# At minibatch 734200, batch loss 0.040198, batch error rate 2.000000%
# At minibatch 734300, batch loss 0.018058, batch error rate 0.000000%
# At minibatch 734400, batch loss 0.034513, batch error rate 1.000000%
# At minibatch 734500, batch loss 0.019777, batch error rate 0.000000%
# After epoch 1469: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 734600, batch loss 0.021398, batch error rate 1.000000%
# At minibatch 734700, batch loss 0.113207, batch error rate 3.000000%
# At minibatch 734800, batch loss 0.099411, batch error rate 4.000000%
# At minibatch 734900, batch loss 0.040724, batch error rate 1.000000%
# At minibatch 735000, batch loss 0.082516, batch error rate 3.000000%
# After epoch 1470: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 735100, batch loss 0.056131, batch error rate 2.000000%
# At minibatch 735200, batch loss 0.035726, batch error rate 1.000000%
# At minibatch 735300, batch loss 0.033543, batch error rate 1.000000%
# At minibatch 735400, batch loss 0.056261, batch error rate 2.000000%
# At minibatch 735500, batch loss 0.070067, batch error rate 2.000000%
# After epoch 1471: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 735600, batch loss 0.069181, batch error rate 2.000000%
# At minibatch 735700, batch loss 0.010008, batch error rate 0.000000%
# At minibatch 735800, batch loss 0.039083, batch error rate 2.000000%
# At minibatch 735900, batch loss 0.123596, batch error rate 3.000000%
# At minibatch 736000, batch loss 0.054389, batch error rate 3.000000%
# After epoch 1472: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 736100, batch loss 0.172929, batch error rate 6.000000%
# At minibatch 736200, batch loss 0.022605, batch error rate 1.000000%
# At minibatch 736300, batch loss 0.040084, batch error rate 2.000000%
# At minibatch 736400, batch loss 0.025900, batch error rate 1.000000%
# At minibatch 736500, batch loss 0.117533, batch error rate 5.000000%
# After epoch 1473: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 736600, batch loss 0.059897, batch error rate 1.000000%
# At minibatch 736700, batch loss 0.112041, batch error rate 5.000000%
# At minibatch 736800, batch loss 0.099531, batch error rate 2.000000%
# At minibatch 736900, batch loss 0.078024, batch error rate 5.000000%
# At minibatch 737000, batch loss 0.079798, batch error rate 3.000000%
# After epoch 1474: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 737100, batch loss 0.194492, batch error rate 6.000000%
# At minibatch 737200, batch loss 0.107651, batch error rate 4.000000%
# At minibatch 737300, batch loss 0.085068, batch error rate 2.000000%
# At minibatch 737400, batch loss 0.028017, batch error rate 1.000000%
# At minibatch 737500, batch loss 0.089179, batch error rate 7.000000%
# After epoch 1475: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 737600, batch loss 0.095284, batch error rate 3.000000%
# At minibatch 737700, batch loss 0.052365, batch error rate 1.000000%
# At minibatch 737800, batch loss 0.021389, batch error rate 0.000000%
# At minibatch 737900, batch loss 0.091627, batch error rate 4.000000%
# At minibatch 738000, batch loss 0.020246, batch error rate 1.000000%
# After epoch 1476: valid_err_rate: 0.015300% currently going ot do 2000 epochs [best: 0.014800%]
# At minibatch 738100, batch loss 0.108171, batch error rate 3.000000%
# At minibatch 738200, batch loss 0.039397, batch error rate 1.000000%
# At minibatch 738300, batch loss 0.013742, batch error rate 0.000000%
# At minibatch 738400, batch loss 0.162048, batch error rate 3.000000%
# Setting network parameters from after epoch 340
# 0.0158

# %%
print np.sqrt(15)
# for p in net.parameters:
    #print np.sum(np.sum(p, axis=1) > 3.9)
#     print np.sum(np.linalg.norm(p, axis=1) > 3.9)
#     print np.linalg.norm(p, axis=1).shape

for l in net.layers:
    if l.parameter_names and l.parameter_names[0] == 'W':
        W, b = l.parameters
        r = np.sqrt(np.sum(np.square(W), axis = 1) + np.square(b).ravel())
        print W.shape
        #print (r[r > 1.6]).shape
        #print (np.sum(np.square(W), axis = 1) + np.square(b).ravel()).shape
        W[r > 1.6] /= r[r > 1.6].reshape(-1, 1)
        #print r[r > 1.7]
# Out:
# 3.87298334621
# (800, 784)
# (800, 800)
# (800, 800)
# (10, 800)

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
