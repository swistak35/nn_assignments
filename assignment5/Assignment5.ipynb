# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        #print(np.sum(m > 0.))
        #print(np.sum(m == 0.))
        #print(np.sum(m < 0.))
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return [] 

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)

        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) + self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
            
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
#GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=3)
# Out:
# At iteration 0, loss 1.001210, train error rate 46.666667%
# At iteration 1000, loss 0.051114, train error rate 2.000000%
# At iteration 2000, loss 0.043210, train error rate 1.333333%
# At iteration 3000, loss 0.041108, train error rate 1.333333%
# At iteration 4000, loss 0.040190, train error rate 1.333333%
# At iteration 5000, loss 0.039649, train error rate 1.333333%
# At iteration 6000, loss 0.039252, train error rate 1.333333%
# At iteration 7000, loss 0.038914, train error rate 1.333333%
# At iteration 8000, loss 0.038601, train error rate 1.333333%
# At iteration 9000, loss 0.038297, train error rate 1.333333%
# At iteration 10000, loss 0.037994, train error rate 1.333333%
# At iteration 11000, loss 0.037689, train error rate 1.333333%
# At iteration 12000, loss 0.037380, train error rate 1.333333%
# At iteration 13000, loss 0.037064, train error rate 1.333333%
# At iteration 14000, loss 0.036736, train error rate 1.333333%
# At iteration 15000, loss 0.036390, train error rate 1.333333%
# At iteration 16000, loss 0.036016, train error rate 1.333333%
# At iteration 17000, loss 0.035607, train error rate 1.333333%
# At iteration 18000, loss 0.035157, train error rate 1.333333%
# At iteration 19000, loss 0.034660, train error rate 1.333333%
# At iteration 20000, loss 0.034113, train error rate 1.333333%
# At iteration 21000, loss 0.033514, train error rate 1.333333%
# At iteration 22000, loss 0.032859, train error rate 1.333333%
# At iteration 23000, loss 0.032144, train error rate 1.333333%
# At iteration 24000, loss 0.031357, train error rate 1.333333%
# At iteration 25000, loss 0.030487, train error rate 1.333333%
# At iteration 26000, loss 0.029525, train error rate 1.333333%
# At iteration 27000, loss 0.028480, train error rate 1.333333%
# At iteration 28000, loss 0.027370, train error rate 1.333333%
# At iteration 29000, loss 0.026212, train error rate 1.333333%
# At iteration 30000, loss 0.025005, train error rate 1.333333%
# At iteration 31000, loss 0.023748, train error rate 1.333333%
# At iteration 32000, loss 0.022448, train error rate 1.333333%
# At iteration 33000, loss 0.021121, train error rate 1.333333%
# At iteration 34000, loss 0.019786, train error rate 1.333333%
# At iteration 35000, loss 0.018460, train error rate 0.666667%
# At iteration 36000, loss 0.017153, train error rate 0.666667%
# At iteration 37000, loss 0.015871, train error rate 0.666667%
# At iteration 38000, loss 0.014619, train error rate 0.000000%
# At iteration 39000, loss 0.013404, train error rate 0.000000%
# At iteration 40000, loss 0.012238, train error rate 0.000000%
# At iteration 41000, loss 0.011138, train error rate 0.000000%
# At iteration 42000, loss 0.010118, train error rate 0.000000%
# At iteration 43000, loss 0.009190, train error rate 0.000000%
# At iteration 44000, loss 0.008357, train error rate 0.000000%
# At iteration 45000, loss 0.007618, train error rate 0.000000%
# At iteration 46000, loss 0.006966, train error rate 0.000000%
# At iteration 47000, loss 0.006393, train error rate 0.000000%
# At iteration 48000, loss 0.005889, train error rate 0.000000%
# At iteration 49000, loss 0.005445, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def print_stats(train_loss, train_errors, validation_errors):
    subplot(2,1,1)
    train_loss = np.array(train_loss)
    semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
    legend()

    subplot(2,1,2)
    train_errors = np.array(train_errors)
    plot(train_errors[:,0], train_errors[:,1], label='batch train error rate')
    validation_errors = np.array(validation_errors)
    plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
    ylim(0,0.2)
    legend()

class AlphaAlgExp:
    def __init__(self, initial = 5e-2, rate = 0.998):
        self.initial = initial
        self.rate = rate
    
    def __call__(self, i, e):
        return (self.initial * np.power(self.rate, e))
    
class AlphaAlgBct:
    def __init__(self, b = 1e3, c = 2e4):
        self.b = b
        self.c = c
    
    def __call__(self, i, e):
        return (self.b / (self.c + i))
    
class AlphaAlgConst:
    def __init__(self, constant = 1e-2):
        self.constant = constant
        
    def __call__(self, i, e):
        return self.constant
    
    
class MomentumAlgConst:
    def __init__(self, constant = 0.5):
        self.constant = constant
        
    def __call__(self, i):
        return self.constant
    
class MomentumAlg1:
    def __call__(self, i):
        return (1. - 3. / (5. + i))

class MomentumAlg2:
    def __call__(self, i, limit = 0.9):
        v = (1. - 3. / (5. + i))
        return (v if v < limit else limit)
    
class MomentumAlg3:
    def __init__(self, start = 0.5, stop = 0.9, epochs = 500):
        self.start = start
        self.stop = stop
        self.epochs = epochs
    
    #def __call__(self, i, e):
    #    self.start 

def SGD(net, train_stream, validation_stream, test_stream,
       print_debug = True,
       epochs = 3,
       patience = 1.5,
       alpha_alg = AlphaAlgExp(),
       momentum_alg = MomentumAlg1(),
       regularization_rate = 1e-3,
       dropout = None):
    
    print "Network configuration: "
    print ", ".join([ "%s%s" %(N, P.shape) for P, N in zip(net.parameters, net.parameter_names) ])
    
    i=0
    e=0
    
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    alpha = None
    
    train_errors = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = epochs
    patience_expansion = patience
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_errors.append((i,err_rate))
                if i % 100 == 0 and print_debug:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W' and regularization_rate:
                        G += regularization_rate * P
                        
                    
                    alpha = alpha_alg(i, e)
                    
                    epsilon = momentum_alg(i)
                    
                    V = epsilon * V - alpha * G
                    
                    P += V
                    
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            if print_debug or (e % 20 == 1):
                print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                    e, val_error_rate, number_of_epochs)
        print "Finished with %d epochs (minibatch %d), with best valid error rate %f" % (e, i, best_valid_error_rate)
        print_stats(train_loss, train_errors, validation_errors)
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        print_stats(train_loss, train_errors, validation_errors)

# %%
net = FeedForwardNet([
        AffineLayer(784,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# Network configuration:
# W(10, 784), b(10, 1)
# At minibatch 100, batch loss 0.740973, batch error rate 27.000000%
# At minibatch 200, batch loss 0.680448, batch error rate 23.000000%
# At minibatch 300, batch loss 0.601968, batch error rate 19.000000%
# At minibatch 400, batch loss 0.543680, batch error rate 14.000000%
# At minibatch 500, batch loss 0.464686, batch error rate 16.000000%
# After epoch 1: valid_err_rate: 0.125300% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.360327, batch error rate 15.000000%
# At minibatch 700, batch loss 0.192809, batch error rate 6.000000%
# At minibatch 800, batch loss 0.474110, batch error rate 17.000000%
# At minibatch 900, batch loss 0.394569, batch error rate 9.000000%
# At minibatch 1000, batch loss 0.385914, batch error rate 13.000000%
# After epoch 2: valid_err_rate: 0.108500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.621349, batch error rate 15.000000%
# At minibatch 1200, batch loss 0.322686, batch error rate 9.000000%
# At minibatch 1300, batch loss 0.375372, batch error rate 13.000000%
# At minibatch 1400, batch loss 0.415682, batch error rate 15.000000%
# At minibatch 1500, batch loss 0.364343, batch error rate 13.000000%
# After epoch 3: valid_err_rate: 0.099600% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.342938, batch error rate 11.000000%
# At minibatch 1700, batch loss 0.247416, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.347736, batch error rate 11.000000%
# At minibatch 1900, batch loss 0.440091, batch error rate 15.000000%
# At minibatch 2000, batch loss 0.412682, batch error rate 10.000000%
# After epoch 4: valid_err_rate: 0.095700% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.344580, batch error rate 9.000000%
# At minibatch 2200, batch loss 0.340456, batch error rate 7.000000%
# At minibatch 2300, batch loss 0.214881, batch error rate 6.000000%
# At minibatch 2400, batch loss 0.275181, batch error rate 8.000000%
# At minibatch 2500, batch loss 0.454124, batch error rate 14.000000%
# After epoch 5: valid_err_rate: 0.093900% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.239873, batch error rate 6.000000%
# At minibatch 2700, batch loss 0.405343, batch error rate 12.000000%
# At minibatch 2800, batch loss 0.339708, batch error rate 11.000000%
# At minibatch 2900, batch loss 0.418900, batch error rate 12.000000%
# At minibatch 3000, batch loss 0.260233, batch error rate 11.000000%
# After epoch 6: valid_err_rate: 0.087800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.283751, batch error rate 7.000000%
# At minibatch 3200, batch loss 0.298385, batch error rate 9.000000%
# At minibatch 3300, batch loss 0.274503, batch error rate 9.000000%
# At minibatch 3400, batch loss 0.309766, batch error rate 8.000000%
# At minibatch 3500, batch loss 0.333230, batch error rate 14.000000%
# After epoch 7: valid_err_rate: 0.083700% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.271224, batch error rate 7.000000%
# At minibatch 3700, batch loss 0.251963, batch error rate 8.000000%
# At minibatch 3800, batch loss 0.328895, batch error rate 9.000000%
# At minibatch 3900, batch loss 0.338339, batch error rate 11.000000%
# At minibatch 4000, batch loss 0.367609, batch error rate 12.000000%
# After epoch 8: valid_err_rate: 0.084400% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.270506, batch error rate 9.000000%
# At minibatch 4200, batch loss 0.378331, batch error rate 13.000000%
# At minibatch 4300, batch loss 0.273683, batch error rate 13.000000%
# At minibatch 4400, batch loss 0.226347, batch error rate 6.000000%
# At minibatch 4500, batch loss 0.303648, batch error rate 8.000000%
# After epoch 9: valid_err_rate: 0.086400% currently going ot do 11 epochs
# At minibatch 4600, batch loss 0.547532, batch error rate 13.000000%
# At minibatch 4700, batch loss 0.318179, batch error rate 10.000000%
# At minibatch 4800, batch loss 0.394654, batch error rate 10.000000%
# At minibatch 4900, batch loss 0.286206, batch error rate 9.000000%
# At minibatch 5000, batch loss 0.434514, batch error rate 14.000000%
# After epoch 10: valid_err_rate: 0.082600% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.291171, batch error rate 12.000000%
# At minibatch 5200, batch loss 0.378254, batch error rate 13.000000%
# At minibatch 5300, batch loss 0.272216, batch error rate 5.000000%
# At minibatch 5400, batch loss 0.266956, batch error rate 9.000000%
# At minibatch 5500, batch loss 0.200407, batch error rate 3.000000%
# After epoch 11: valid_err_rate: 0.081600% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.218749, batch error rate 7.000000%
# At minibatch 5700, batch loss 0.252554, batch error rate 7.000000%
# At minibatch 5800, batch loss 0.298431, batch error rate 8.000000%
# At minibatch 5900, batch loss 0.354022, batch error rate 11.000000%
# At minibatch 6000, batch loss 0.147049, batch error rate 2.000000%
# After epoch 12: valid_err_rate: 0.081900% currently going ot do 17 epochs
# At minibatch 6100, batch loss 0.273258, batch error rate 6.000000%
# At minibatch 6200, batch loss 0.336471, batch error rate 9.000000%
# At minibatch 6300, batch loss 0.330006, batch error rate 10.000000%
# At minibatch 6400, batch loss 0.372628, batch error rate 12.000000%
# At minibatch 6500, batch loss 0.223340, batch error rate 7.000000%
# After epoch 13: valid_err_rate: 0.081600% currently going ot do 17 epochs
# At minibatch 6600, batch loss 0.175850, batch error rate 8.000000%
# At minibatch 6700, batch loss 0.226265, batch error rate 6.000000%
# At minibatch 6800, batch loss 0.259445, batch error rate 9.000000%
# At minibatch 6900, batch loss 0.309479, batch error rate 11.000000%
# At minibatch 7000, batch loss 0.306560, batch error rate 5.000000%
# After epoch 14: valid_err_rate: 0.083700% currently going ot do 17 epochs
# At minibatch 7100, batch loss 0.266203, batch error rate 6.000000%
# At minibatch 7200, batch loss 0.247998, batch error rate 8.000000%
# At minibatch 7300, batch loss 0.172085, batch error rate 4.000000%
# At minibatch 7400, batch loss 0.386859, batch error rate 14.000000%
# At minibatch 7500, batch loss 0.407505, batch error rate 7.000000%
# After epoch 15: valid_err_rate: 0.082100% currently going ot do 17 epochs
# At minibatch 7600, batch loss 0.245838, batch error rate 11.000000%
# At minibatch 7700, batch loss 0.278321, batch error rate 6.000000%
# At minibatch 7800, batch loss 0.287730, batch error rate 7.000000%
# At minibatch 7900, batch loss 0.322272, batch error rate 6.000000%
# At minibatch 8000, batch loss 0.358469, batch error rate 11.000000%
# After epoch 16: valid_err_rate: 0.080600% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.316656, batch error rate 7.000000%
# At minibatch 8200, batch loss 0.206162, batch error rate 6.000000%
# At minibatch 8300, batch loss 0.211224, batch error rate 6.000000%
# At minibatch 8400, batch loss 0.330906, batch error rate 12.000000%
# At minibatch 8500, batch loss 0.272456, batch error rate 5.000000%
# After epoch 17: valid_err_rate: 0.081400% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.559550, batch error rate 16.000000%
# At minibatch 8700, batch loss 0.226035, batch error rate 8.000000%
# At minibatch 8800, batch loss 0.649672, batch error rate 19.000000%
# At minibatch 8900, batch loss 0.247226, batch error rate 7.000000%
# At minibatch 9000, batch loss 0.169009, batch error rate 4.000000%
# After epoch 18: valid_err_rate: 0.077100% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.407508, batch error rate 8.000000%
# At minibatch 9200, batch loss 0.319961, batch error rate 10.000000%
# At minibatch 9300, batch loss 0.228650, batch error rate 5.000000%
# At minibatch 9400, batch loss 0.319512, batch error rate 8.000000%
# At minibatch 9500, batch loss 0.390527, batch error rate 9.000000%
# After epoch 19: valid_err_rate: 0.082300% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.175537, batch error rate 4.000000%
# At minibatch 9700, batch loss 0.198286, batch error rate 7.000000%
# At minibatch 9800, batch loss 0.200012, batch error rate 5.000000%
# At minibatch 9900, batch loss 0.225288, batch error rate 6.000000%
# At minibatch 10000, batch loss 0.253806, batch error rate 7.000000%
# After epoch 20: valid_err_rate: 0.079900% currently going ot do 28 epochs
# At minibatch 10100, batch loss 0.195985, batch error rate 5.000000%
# At minibatch 10200, batch loss 0.131755, batch error rate 3.000000%
# At minibatch 10300, batch loss 0.355605, batch error rate 12.000000%
# At minibatch 10400, batch loss 0.248060, batch error rate 8.000000%
# At minibatch 10500, batch loss 0.135279, batch error rate 4.000000%
# After epoch 21: valid_err_rate: 0.080900% currently going ot do 28 epochs
# At minibatch 10600, batch loss 0.275773, batch error rate 10.000000%
# At minibatch 10700, batch loss 0.199023, batch error rate 8.000000%
# At minibatch 10800, batch loss 0.441155, batch error rate 10.000000%
# At minibatch 10900, batch loss 0.268404, batch error rate 8.000000%
# At minibatch 11000, batch loss 0.164316, batch error rate 5.000000%
# After epoch 22: valid_err_rate: 0.077700% currently going ot do 28 epochs
# At minibatch 11100, batch loss 0.434933, batch error rate 9.000000%
# At minibatch 11200, batch loss 0.259283, batch error rate 6.000000%
# At minibatch 11300, batch loss 0.263089, batch error rate 8.000000%
# At minibatch 11400, batch loss 0.220842, batch error rate 7.000000%
# At minibatch 11500, batch loss 0.395512, batch error rate 12.000000%
# After epoch 23: valid_err_rate: 0.079400% currently going ot do 28 epochs
# At minibatch 11600, batch loss 0.271348, batch error rate 8.000000%
# At minibatch 11700, batch loss 0.218209, batch error rate 8.000000%
# At minibatch 11800, batch loss 0.229911, batch error rate 4.000000%
# At minibatch 11900, batch loss 0.232644, batch error rate 8.000000%
# At minibatch 12000, batch loss 0.267894, batch error rate 8.000000%
# After epoch 24: valid_err_rate: 0.078600% currently going ot do 28 epochs
# At minibatch 12100, batch loss 0.314995, batch error rate 8.000000%
# At minibatch 12200, batch loss 0.274134, batch error rate 11.000000%
# At minibatch 12300, batch loss 0.195476, batch error rate 8.000000%
# At minibatch 12400, batch loss 0.237909, batch error rate 8.000000%
# At minibatch 12500, batch loss 0.397571, batch error rate 13.000000%
# After epoch 25: valid_err_rate: 0.077000% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.275604, batch error rate 8.000000%
# At minibatch 12700, batch loss 0.306078, batch error rate 4.000000%
# At minibatch 12800, batch loss 0.360772, batch error rate 10.000000%
# At minibatch 12900, batch loss 0.325601, batch error rate 9.000000%
# At minibatch 13000, batch loss 0.264348, batch error rate 10.000000%
# After epoch 26: valid_err_rate: 0.081300% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.250911, batch error rate 9.000000%
# At minibatch 13200, batch loss 0.149137, batch error rate 6.000000%
# At minibatch 13300, batch loss 0.172229, batch error rate 4.000000%
# At minibatch 13400, batch loss 0.185516, batch error rate 6.000000%
# At minibatch 13500, batch loss 0.249912, batch error rate 7.000000%
# After epoch 27: valid_err_rate: 0.078700% currently going ot do 38 epochs
# At minibatch 13600, batch loss 0.218476, batch error rate 5.000000%
# At minibatch 13700, batch loss 0.307938, batch error rate 8.000000%
# At minibatch 13800, batch loss 0.278963, batch error rate 8.000000%
# At minibatch 13900, batch loss 0.220983, batch error rate 5.000000%
# At minibatch 14000, batch loss 0.378173, batch error rate 13.000000%
# After epoch 28: valid_err_rate: 0.080600% currently going ot do 38 epochs
# At minibatch 14100, batch loss 0.356031, batch error rate 11.000000%
# At minibatch 14200, batch loss 0.289292, batch error rate 8.000000%
# At minibatch 14300, batch loss 0.190228, batch error rate 7.000000%
# At minibatch 14400, batch loss 0.168910, batch error rate 6.000000%
# At minibatch 14500, batch loss 0.251000, batch error rate 9.000000%
# After epoch 29: valid_err_rate: 0.078000% currently going ot do 38 epochs
# At minibatch 14600, batch loss 0.385579, batch error rate 10.000000%
# At minibatch 14700, batch loss 0.263786, batch error rate 9.000000%
# At minibatch 14800, batch loss 0.410760, batch error rate 10.000000%
# At minibatch 14900, batch loss 0.310217, batch error rate 11.000000%
# At minibatch 15000, batch loss 0.309349, batch error rate 10.000000%
# After epoch 30: valid_err_rate: 0.077200% currently going ot do 38 epochs
# At minibatch 15100, batch loss 0.378734, batch error rate 13.000000%
# At minibatch 15200, batch loss 0.349693, batch error rate 9.000000%
# At minibatch 15300, batch loss 0.252741, batch error rate 6.000000%
# At minibatch 15400, batch loss 0.292960, batch error rate 12.000000%
# At minibatch 15500, batch loss 0.194670, batch error rate 4.000000%
# After epoch 31: valid_err_rate: 0.076600% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.363850, batch error rate 12.000000%
# At minibatch 15700, batch loss 0.165958, batch error rate 6.000000%
# At minibatch 15800, batch loss 0.203693, batch error rate 5.000000%
# At minibatch 15900, batch loss 0.238487, batch error rate 9.000000%
# At minibatch 16000, batch loss 0.205866, batch error rate 6.000000%
# After epoch 32: valid_err_rate: 0.078700% currently going ot do 47 epochs
# At minibatch 16100, batch loss 0.329135, batch error rate 10.000000%
# At minibatch 16200, batch loss 0.213682, batch error rate 6.000000%
# At minibatch 16300, batch loss 0.297423, batch error rate 9.000000%
# At minibatch 16400, batch loss 0.157609, batch error rate 5.000000%
# At minibatch 16500, batch loss 0.246421, batch error rate 6.000000%
# After epoch 33: valid_err_rate: 0.077200% currently going ot do 47 epochs
# At minibatch 16600, batch loss 0.275644, batch error rate 9.000000%
# At minibatch 16700, batch loss 0.187071, batch error rate 8.000000%
# At minibatch 16800, batch loss 0.222434, batch error rate 5.000000%
# At minibatch 16900, batch loss 0.408268, batch error rate 10.000000%
# At minibatch 17000, batch loss 0.136160, batch error rate 3.000000%
# After epoch 34: valid_err_rate: 0.080100% currently going ot do 47 epochs
# At minibatch 17100, batch loss 0.204477, batch error rate 5.000000%
# At minibatch 17200, batch loss 0.399261, batch error rate 7.000000%
# At minibatch 17300, batch loss 0.189866, batch error rate 6.000000%
# At minibatch 17400, batch loss 0.185976, batch error rate 5.000000%
# At minibatch 17500, batch loss 0.128960, batch error rate 4.000000%
# After epoch 35: valid_err_rate: 0.076700% currently going ot do 47 epochs
# At minibatch 17600, batch loss 0.248514, batch error rate 11.000000%
# At minibatch 17700, batch loss 0.201447, batch error rate 8.000000%
# At minibatch 17800, batch loss 0.287714, batch error rate 10.000000%
# At minibatch 17900, batch loss 0.337300, batch error rate 6.000000%
# At minibatch 18000, batch loss 0.241171, batch error rate 8.000000%
# After epoch 36: valid_err_rate: 0.076800% currently going ot do 47 epochs
# At minibatch 18100, batch loss 0.273514, batch error rate 8.000000%
# At minibatch 18200, batch loss 0.363529, batch error rate 11.000000%
# At minibatch 18300, batch loss 0.303283, batch error rate 11.000000%
# At minibatch 18400, batch loss 0.310583, batch error rate 11.000000%
# At minibatch 18500, batch loss 0.240133, batch error rate 7.000000%
# After epoch 37: valid_err_rate: 0.078300% currently going ot do 47 epochs
# At minibatch 18600, batch loss 0.197004, batch error rate 5.000000%
# At minibatch 18700, batch loss 0.263486, batch error rate 8.000000%
# At minibatch 18800, batch loss 0.306174, batch error rate 5.000000%
# At minibatch 18900, batch loss 0.407865, batch error rate 13.000000%
# At minibatch 19000, batch loss 0.114576, batch error rate 3.000000%
# After epoch 38: valid_err_rate: 0.077100% currently going ot do 47 epochs
# At minibatch 19100, batch loss 0.223235, batch error rate 7.000000%
# At minibatch 19200, batch loss 0.283659, batch error rate 9.000000%
# At minibatch 19300, batch loss 0.177418, batch error rate 6.000000%
# At minibatch 19400, batch loss 0.468941, batch error rate 10.000000%
# At minibatch 19500, batch loss 0.378501, batch error rate 7.000000%
# After epoch 39: valid_err_rate: 0.075900% currently going ot do 59 epochs
# At minibatch 19600, batch loss 0.409729, batch error rate 8.000000%
# At minibatch 19700, batch loss 0.223595, batch error rate 10.000000%
# At minibatch 19800, batch loss 0.362831, batch error rate 7.000000%
# At minibatch 19900, batch loss 0.250954, batch error rate 10.000000%
# At minibatch 20000, batch loss 0.122617, batch error rate 4.000000%
# After epoch 40: valid_err_rate: 0.076900% currently going ot do 59 epochs
# At minibatch 20100, batch loss 0.374917, batch error rate 13.000000%
# At minibatch 20200, batch loss 0.368446, batch error rate 7.000000%
# At minibatch 20300, batch loss 0.297117, batch error rate 8.000000%
# At minibatch 20400, batch loss 0.306425, batch error rate 11.000000%
# At minibatch 20500, batch loss 0.400859, batch error rate 13.000000%
# After epoch 41: valid_err_rate: 0.077300% currently going ot do 59 epochs
# At minibatch 20600, batch loss 0.216197, batch error rate 6.000000%
# At minibatch 20700, batch loss 0.101585, batch error rate 2.000000%
# At minibatch 20800, batch loss 0.266296, batch error rate 5.000000%
# At minibatch 20900, batch loss 0.324347, batch error rate 8.000000%
# At minibatch 21000, batch loss 0.282853, batch error rate 8.000000%
# After epoch 42: valid_err_rate: 0.077700% currently going ot do 59 epochs
# At minibatch 21100, batch loss 0.247575, batch error rate 8.000000%
# At minibatch 21200, batch loss 0.422547, batch error rate 12.000000%
# At minibatch 21300, batch loss 0.255078, batch error rate 10.000000%
# At minibatch 21400, batch loss 0.297020, batch error rate 5.000000%
# At minibatch 21500, batch loss 0.158143, batch error rate 8.000000%
# After epoch 43: valid_err_rate: 0.078000% currently going ot do 59 epochs
# At minibatch 21600, batch loss 0.282540, batch error rate 7.000000%
# At minibatch 21700, batch loss 0.291306, batch error rate 9.000000%
# At minibatch 21800, batch loss 0.130814, batch error rate 3.000000%
# At minibatch 21900, batch loss 0.361504, batch error rate 10.000000%
# At minibatch 22000, batch loss 0.324503, batch error rate 10.000000%
# After epoch 44: valid_err_rate: 0.076300% currently going ot do 59 epochs
# At minibatch 22100, batch loss 0.232805, batch error rate 7.000000%
# At minibatch 22200, batch loss 0.161768, batch error rate 5.000000%
# At minibatch 22300, batch loss 0.264781, batch error rate 8.000000%
# At minibatch 22400, batch loss 0.271878, batch error rate 10.000000%
# At minibatch 22500, batch loss 0.403866, batch error rate 13.000000%
# After epoch 45: valid_err_rate: 0.078500% currently going ot do 59 epochs
# At minibatch 22600, batch loss 0.281925, batch error rate 9.000000%
# At minibatch 22700, batch loss 0.184358, batch error rate 7.000000%
# At minibatch 22800, batch loss 0.322584, batch error rate 10.000000%
# At minibatch 22900, batch loss 0.271019, batch error rate 10.000000%
# At minibatch 23000, batch loss 0.340315, batch error rate 10.000000%
# After epoch 46: valid_err_rate: 0.078600% currently going ot do 59 epochs
# At minibatch 23100, batch loss 0.196063, batch error rate 7.000000%
# At minibatch 23200, batch loss 0.249115, batch error rate 6.000000%
# At minibatch 23300, batch loss 0.189504, batch error rate 4.000000%
# At minibatch 23400, batch loss 0.107182, batch error rate 3.000000%
# At minibatch 23500, batch loss 0.304607, batch error rate 11.000000%
# After epoch 47: valid_err_rate: 0.078800% currently going ot do 59 epochs
# At minibatch 23600, batch loss 0.222992, batch error rate 9.000000%
# At minibatch 23700, batch loss 0.336017, batch error rate 8.000000%
# At minibatch 23800, batch loss 0.242498, batch error rate 5.000000%
# At minibatch 23900, batch loss 0.261250, batch error rate 11.000000%
# At minibatch 24000, batch loss 0.261081, batch error rate 6.000000%
# After epoch 48: valid_err_rate: 0.075300% currently going ot do 73 epochs
# At minibatch 24100, batch loss 0.186310, batch error rate 7.000000%
# At minibatch 24200, batch loss 0.167915, batch error rate 5.000000%
# At minibatch 24300, batch loss 0.163118, batch error rate 4.000000%
# At minibatch 24400, batch loss 0.236165, batch error rate 7.000000%
# At minibatch 24500, batch loss 0.500112, batch error rate 14.000000%
# After epoch 49: valid_err_rate: 0.088400% currently going ot do 73 epochs
# At minibatch 24600, batch loss 0.112804, batch error rate 2.000000%
# At minibatch 24700, batch loss 0.287464, batch error rate 9.000000%
# At minibatch 24800, batch loss 0.213027, batch error rate 6.000000%
# At minibatch 24900, batch loss 0.242369, batch error rate 7.000000%
# At minibatch 25000, batch loss 0.299940, batch error rate 10.000000%
# After epoch 50: valid_err_rate: 0.072900% currently going ot do 76 epochs
# At minibatch 25100, batch loss 0.211094, batch error rate 7.000000%
# At minibatch 25200, batch loss 0.361232, batch error rate 9.000000%
# At minibatch 25300, batch loss 0.232993, batch error rate 8.000000%
# At minibatch 25400, batch loss 0.229573, batch error rate 6.000000%
# At minibatch 25500, batch loss 0.244965, batch error rate 7.000000%
# After epoch 51: valid_err_rate: 0.076000% currently going ot do 76 epochs
# At minibatch 25600, batch loss 0.270743, batch error rate 8.000000%
# At minibatch 25700, batch loss 0.260784, batch error rate 10.000000%
# At minibatch 25800, batch loss 0.267946, batch error rate 8.000000%
# At minibatch 25900, batch loss 0.133616, batch error rate 3.000000%
# At minibatch 26000, batch loss 0.239410, batch error rate 8.000000%
# After epoch 52: valid_err_rate: 0.074800% currently going ot do 76 epochs
# At minibatch 26100, batch loss 0.382184, batch error rate 7.000000%
# At minibatch 26200, batch loss 0.255339, batch error rate 5.000000%
# At minibatch 26300, batch loss 0.370808, batch error rate 9.000000%
# At minibatch 26400, batch loss 0.277039, batch error rate 8.000000%
# At minibatch 26500, batch loss 0.246942, batch error rate 7.000000%
# After epoch 53: valid_err_rate: 0.072700% currently going ot do 80 epochs
# At minibatch 26600, batch loss 0.290968, batch error rate 8.000000%
# At minibatch 26700, batch loss 0.378085, batch error rate 10.000000%
# At minibatch 26800, batch loss 0.374247, batch error rate 10.000000%
# At minibatch 26900, batch loss 0.311684, batch error rate 12.000000%
# At minibatch 27000, batch loss 0.187005, batch error rate 9.000000%
# After epoch 54: valid_err_rate: 0.072800% currently going ot do 80 epochs
# At minibatch 27100, batch loss 0.434759, batch error rate 12.000000%
# At minibatch 27200, batch loss 0.516823, batch error rate 12.000000%
# At minibatch 27300, batch loss 0.233174, batch error rate 5.000000%
# At minibatch 27400, batch loss 0.226079, batch error rate 6.000000%
# At minibatch 27500, batch loss 0.187508, batch error rate 5.000000%
# After epoch 55: valid_err_rate: 0.075200% currently going ot do 80 epochs
# At minibatch 27600, batch loss 0.117157, batch error rate 3.000000%
# At minibatch 27700, batch loss 0.430556, batch error rate 12.000000%
# At minibatch 27800, batch loss 0.162981, batch error rate 5.000000%
# At minibatch 27900, batch loss 0.256831, batch error rate 8.000000%
# At minibatch 28000, batch loss 0.185410, batch error rate 7.000000%
# After epoch 56: valid_err_rate: 0.074000% currently going ot do 80 epochs
# At minibatch 28100, batch loss 0.243222, batch error rate 9.000000%
# At minibatch 28200, batch loss 0.276426, batch error rate 4.000000%
# At minibatch 28300, batch loss 0.141153, batch error rate 4.000000%
# At minibatch 28400, batch loss 0.297936, batch error rate 13.000000%
# At minibatch 28500, batch loss 0.492080, batch error rate 8.000000%
# After epoch 57: valid_err_rate: 0.074200% currently going ot do 80 epochs
# At minibatch 28600, batch loss 0.194352, batch error rate 6.000000%
# At minibatch 28700, batch loss 0.178523, batch error rate 4.000000%
# At minibatch 28800, batch loss 0.413417, batch error rate 9.000000%
# At minibatch 28900, batch loss 0.345318, batch error rate 10.000000%
# At minibatch 29000, batch loss 0.153571, batch error rate 4.000000%
# After epoch 58: valid_err_rate: 0.075600% currently going ot do 80 epochs
# At minibatch 29100, batch loss 0.413496, batch error rate 15.000000%
# At minibatch 29200, batch loss 0.325660, batch error rate 11.000000%
# At minibatch 29300, batch loss 0.289345, batch error rate 6.000000%
# At minibatch 29400, batch loss 0.130669, batch error rate 2.000000%
# At minibatch 29500, batch loss 0.197866, batch error rate 6.000000%
# After epoch 59: valid_err_rate: 0.077800% currently going ot do 80 epochs
# At minibatch 29600, batch loss 0.267970, batch error rate 6.000000%
# At minibatch 29700, batch loss 0.189033, batch error rate 6.000000%
# At minibatch 29800, batch loss 0.182880, batch error rate 5.000000%
# At minibatch 29900, batch loss 0.374542, batch error rate 10.000000%
# At minibatch 30000, batch loss 0.251323, batch error rate 7.000000%
# After epoch 60: valid_err_rate: 0.078100% currently going ot do 80 epochs
# At minibatch 30100, batch loss 0.288432, batch error rate 6.000000%
# At minibatch 30200, batch loss 0.293799, batch error rate 7.000000%
# At minibatch 30300, batch loss 0.256967, batch error rate 8.000000%
# At minibatch 30400, batch loss 0.174047, batch error rate 5.000000%
# At minibatch 30500, batch loss 0.232266, batch error rate 5.000000%
# After epoch 61: valid_err_rate: 0.073600% currently going ot do 80 epochs
# At minibatch 30600, batch loss 0.215886, batch error rate 4.000000%
# At minibatch 30700, batch loss 0.405357, batch error rate 9.000000%
# At minibatch 30800, batch loss 0.384402, batch error rate 10.000000%
# At minibatch 30900, batch loss 0.406127, batch error rate 12.000000%
# At minibatch 31000, batch loss 0.216192, batch error rate 7.000000%
# After epoch 62: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 31100, batch loss 0.416884, batch error rate 11.000000%
# At minibatch 31200, batch loss 0.340921, batch error rate 9.000000%
# At minibatch 31300, batch loss 0.240431, batch error rate 9.000000%
# At minibatch 31400, batch loss 0.205909, batch error rate 7.000000%
# At minibatch 31500, batch loss 0.166855, batch error rate 4.000000%
# After epoch 63: valid_err_rate: 0.073400% currently going ot do 80 epochs
# At minibatch 31600, batch loss 0.201640, batch error rate 6.000000%
# At minibatch 31700, batch loss 0.266002, batch error rate 9.000000%
# At minibatch 31800, batch loss 0.125754, batch error rate 2.000000%
# At minibatch 31900, batch loss 0.317868, batch error rate 7.000000%
# At minibatch 32000, batch loss 0.262930, batch error rate 6.000000%
# After epoch 64: valid_err_rate: 0.077700% currently going ot do 80 epochs
# At minibatch 32100, batch loss 0.190049, batch error rate 6.000000%
# At minibatch 32200, batch loss 0.214746, batch error rate 5.000000%
# At minibatch 32300, batch loss 0.250524, batch error rate 8.000000%
# At minibatch 32400, batch loss 0.217614, batch error rate 4.000000%
# At minibatch 32500, batch loss 0.218063, batch error rate 5.000000%
# After epoch 65: valid_err_rate: 0.073500% currently going ot do 80 epochs
# At minibatch 32600, batch loss 0.154874, batch error rate 6.000000%
# At minibatch 32700, batch loss 0.191774, batch error rate 4.000000%
# At minibatch 32800, batch loss 0.340164, batch error rate 14.000000%
# At minibatch 32900, batch loss 0.345773, batch error rate 11.000000%
# At minibatch 33000, batch loss 0.344159, batch error rate 10.000000%
# After epoch 66: valid_err_rate: 0.074800% currently going ot do 80 epochs
# At minibatch 33100, batch loss 0.198900, batch error rate 6.000000%
# At minibatch 33200, batch loss 0.129303, batch error rate 3.000000%
# At minibatch 33300, batch loss 0.343612, batch error rate 12.000000%
# At minibatch 33400, batch loss 0.152916, batch error rate 2.000000%
# At minibatch 33500, batch loss 0.239631, batch error rate 8.000000%
# After epoch 67: valid_err_rate: 0.076600% currently going ot do 80 epochs
# At minibatch 33600, batch loss 0.251999, batch error rate 8.000000%
# At minibatch 33700, batch loss 0.268558, batch error rate 8.000000%
# At minibatch 33800, batch loss 0.167383, batch error rate 6.000000%
# At minibatch 33900, batch loss 0.287809, batch error rate 6.000000%
# At minibatch 34000, batch loss 0.212205, batch error rate 9.000000%
# After epoch 68: valid_err_rate: 0.076500% currently going ot do 80 epochs
# At minibatch 34100, batch loss 0.332858, batch error rate 9.000000%
# At minibatch 34200, batch loss 0.292982, batch error rate 9.000000%
# At minibatch 34300, batch loss 0.376241, batch error rate 16.000000%
# At minibatch 34400, batch loss 0.214889, batch error rate 6.000000%
# At minibatch 34500, batch loss 0.426535, batch error rate 11.000000%
# After epoch 69: valid_err_rate: 0.073100% currently going ot do 80 epochs
# At minibatch 34600, batch loss 0.312457, batch error rate 12.000000%
# At minibatch 34700, batch loss 0.195879, batch error rate 4.000000%
# At minibatch 34800, batch loss 0.320395, batch error rate 6.000000%
# At minibatch 34900, batch loss 0.389707, batch error rate 8.000000%
# At minibatch 35000, batch loss 0.402277, batch error rate 13.000000%
# After epoch 70: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 35100, batch loss 0.213005, batch error rate 6.000000%
# At minibatch 35200, batch loss 0.115307, batch error rate 2.000000%
# At minibatch 35300, batch loss 0.355527, batch error rate 9.000000%
# At minibatch 35400, batch loss 0.335941, batch error rate 10.000000%
# At minibatch 35500, batch loss 0.196660, batch error rate 5.000000%
# After epoch 71: valid_err_rate: 0.075200% currently going ot do 80 epochs
# At minibatch 35600, batch loss 0.432545, batch error rate 9.000000%
# At minibatch 35700, batch loss 0.261248, batch error rate 6.000000%
# At minibatch 35800, batch loss 0.225274, batch error rate 6.000000%
# At minibatch 35900, batch loss 0.196854, batch error rate 5.000000%
# At minibatch 36000, batch loss 0.301510, batch error rate 11.000000%
# After epoch 72: valid_err_rate: 0.073800% currently going ot do 80 epochs
# At minibatch 36100, batch loss 0.181046, batch error rate 6.000000%
# At minibatch 36200, batch loss 0.301011, batch error rate 8.000000%
# At minibatch 36300, batch loss 0.255940, batch error rate 9.000000%
# At minibatch 36400, batch loss 0.231640, batch error rate 7.000000%
# At minibatch 36500, batch loss 0.353715, batch error rate 13.000000%
# After epoch 73: valid_err_rate: 0.074900% currently going ot do 80 epochs
# At minibatch 36600, batch loss 0.247080, batch error rate 8.000000%
# At minibatch 36700, batch loss 0.247444, batch error rate 11.000000%
# At minibatch 36800, batch loss 0.152068, batch error rate 5.000000%
# At minibatch 36900, batch loss 0.287072, batch error rate 10.000000%
# At minibatch 37000, batch loss 0.141465, batch error rate 5.000000%
# After epoch 74: valid_err_rate: 0.078000% currently going ot do 80 epochs
# At minibatch 37100, batch loss 0.228414, batch error rate 7.000000%
# At minibatch 37200, batch loss 0.214678, batch error rate 5.000000%
# At minibatch 37300, batch loss 0.164372, batch error rate 4.000000%
# At minibatch 37400, batch loss 0.209843, batch error rate 6.000000%
# At minibatch 37500, batch loss 0.278802, batch error rate 8.000000%
# After epoch 75: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 37600, batch loss 0.280233, batch error rate 4.000000%
# At minibatch 37700, batch loss 0.272187, batch error rate 7.000000%
# At minibatch 37800, batch loss 0.209753, batch error rate 7.000000%
# At minibatch 37900, batch loss 0.410677, batch error rate 12.000000%
# At minibatch 38000, batch loss 0.203933, batch error rate 9.000000%
# After epoch 76: valid_err_rate: 0.077800% currently going ot do 80 epochs
# At minibatch 38100, batch loss 0.229977, batch error rate 8.000000%
# At minibatch 38200, batch loss 0.442982, batch error rate 12.000000%
# At minibatch 38300, batch loss 0.192894, batch error rate 7.000000%
# At minibatch 38400, batch loss 0.328600, batch error rate 7.000000%
# At minibatch 38500, batch loss 0.265915, batch error rate 6.000000%
# After epoch 77: valid_err_rate: 0.074600% currently going ot do 80 epochs
# At minibatch 38600, batch loss 0.343703, batch error rate 3.000000%
# At minibatch 38700, batch loss 0.479349, batch error rate 8.000000%
# At minibatch 38800, batch loss 0.169222, batch error rate 4.000000%
# At minibatch 38900, batch loss 0.198668, batch error rate 4.000000%
# At minibatch 39000, batch loss 0.239293, batch error rate 7.000000%
# After epoch 78: valid_err_rate: 0.073600% currently going ot do 80 epochs
# At minibatch 39100, batch loss 0.172373, batch error rate 4.000000%
# At minibatch 39200, batch loss 0.182658, batch error rate 6.000000%
# At minibatch 39300, batch loss 0.199119, batch error rate 7.000000%
# At minibatch 39400, batch loss 0.314168, batch error rate 7.000000%
# At minibatch 39500, batch loss 0.220843, batch error rate 5.000000%
# After epoch 79: valid_err_rate: 0.073700% currently going ot do 80 epochs
# At minibatch 39600, batch loss 0.244220, batch error rate 8.000000%
# At minibatch 39700, batch loss 0.227120, batch error rate 7.000000%
# At minibatch 39800, batch loss 0.170354, batch error rate 7.000000%
# At minibatch 39900, batch loss 0.175074, batch error rate 7.000000%
# At minibatch 40000, batch loss 0.255331, batch error rate 6.000000%
# After epoch 80: valid_err_rate: 0.075400% currently going ot do 80 epochs
# At minibatch 40100, batch loss 0.368457, batch error rate 8.000000%
# At minibatch 40200, batch loss 0.149208, batch error rate 7.000000%
# At minibatch 40300, batch loss 0.315956, batch error rate 9.000000%
# At minibatch 40400, batch loss 0.255082, batch error rate 10.000000%
# At minibatch 40500, batch loss 0.248717, batch error rate 6.000000%
# After epoch 81: valid_err_rate: 0.072800% currently going ot do 80 epochs
# Finished with 81 epochs (minibatch 40500), with best valid error rate 0.072700
# Test error rate: 0.076300

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlg1(rate = 1e-3),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg1())
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 0.361025, batch error rate 11.000000%
# At minibatch 200, batch loss 0.360373, batch error rate 10.000000%
# At minibatch 300, batch loss 0.354910, batch error rate 12.000000%
# At minibatch 400, batch loss 0.238891, batch error rate 9.000000%
# At minibatch 500, batch loss 0.131693, batch error rate 4.000000%
# After epoch 1: valid_err_rate: 0.059600% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.183866, batch error rate 5.000000%
# At minibatch 700, batch loss 0.071052, batch error rate 1.000000%
# At minibatch 800, batch loss 0.293823, batch error rate 9.000000%
# At minibatch 900, batch loss 0.122559, batch error rate 4.000000%
# At minibatch 1000, batch loss 0.093580, batch error rate 3.000000%
# After epoch 2: valid_err_rate: 0.041100% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.158893, batch error rate 5.000000%
# At minibatch 1200, batch loss 0.133334, batch error rate 5.000000%
# At minibatch 1300, batch loss 0.160749, batch error rate 4.000000%
# At minibatch 1400, batch loss 0.092120, batch error rate 3.000000%
# At minibatch 1500, batch loss 0.112340, batch error rate 3.000000%
# After epoch 3: valid_err_rate: 0.037900% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.060266, batch error rate 3.000000%
# At minibatch 1700, batch loss 0.086663, batch error rate 3.000000%
# At minibatch 1800, batch loss 0.060457, batch error rate 2.000000%
# At minibatch 1900, batch loss 0.122432, batch error rate 4.000000%
# At minibatch 2000, batch loss 0.109286, batch error rate 3.000000%
# After epoch 4: valid_err_rate: 0.036400% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.089274, batch error rate 4.000000%
# At minibatch 2200, batch loss 0.253411, batch error rate 10.000000%
# At minibatch 2300, batch loss 0.128552, batch error rate 7.000000%
# At minibatch 2400, batch loss 0.043774, batch error rate 1.000000%
# At minibatch 2500, batch loss 0.033858, batch error rate 0.000000%
# After epoch 5: valid_err_rate: 0.030600% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.026462, batch error rate 1.000000%
# At minibatch 2700, batch loss 0.071691, batch error rate 3.000000%
# At minibatch 2800, batch loss 0.094127, batch error rate 3.000000%
# At minibatch 2900, batch loss 0.075824, batch error rate 1.000000%
# At minibatch 3000, batch loss 0.044983, batch error rate 0.000000%
# After epoch 6: valid_err_rate: 0.030800% currently going ot do 8 epochs
# At minibatch 3100, batch loss 0.053518, batch error rate 2.000000%
# At minibatch 3200, batch loss 0.088773, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.024247, batch error rate 0.000000%
# At minibatch 3400, batch loss 0.045027, batch error rate 2.000000%
# At minibatch 3500, batch loss 0.061679, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.028900% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.071931, batch error rate 2.000000%
# At minibatch 3700, batch loss 0.017280, batch error rate 0.000000%
# At minibatch 3800, batch loss 0.035467, batch error rate 1.000000%
# At minibatch 3900, batch loss 0.052880, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.037966, batch error rate 0.000000%
# After epoch 8: valid_err_rate: 0.029200% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.087265, batch error rate 2.000000%
# At minibatch 4200, batch loss 0.035446, batch error rate 1.000000%
# At minibatch 4300, batch loss 0.040201, batch error rate 1.000000%
# At minibatch 4400, batch loss 0.013046, batch error rate 0.000000%
# At minibatch 4500, batch loss 0.034019, batch error rate 0.000000%
# After epoch 9: valid_err_rate: 0.024800% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.051945, batch error rate 1.000000%
# At minibatch 4700, batch loss 0.052244, batch error rate 3.000000%
# At minibatch 4800, batch loss 0.048825, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.039789, batch error rate 2.000000%
# At minibatch 5000, batch loss 0.097803, batch error rate 4.000000%
# After epoch 10: valid_err_rate: 0.027100% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.013953, batch error rate 0.000000%
# At minibatch 5200, batch loss 0.034599, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.033198, batch error rate 0.000000%
# At minibatch 5400, batch loss 0.015636, batch error rate 0.000000%
# At minibatch 5500, batch loss 0.020852, batch error rate 0.000000%
# After epoch 11: valid_err_rate: 0.024700% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.046321, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.030472, batch error rate 0.000000%
# At minibatch 5800, batch loss 0.081743, batch error rate 1.000000%
# At minibatch 5900, batch loss 0.032953, batch error rate 1.000000%
# At minibatch 6000, batch loss 0.020177, batch error rate 1.000000%
# After epoch 12: valid_err_rate: 0.023800% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.022013, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.060381, batch error rate 2.000000%
# At minibatch 6300, batch loss 0.037124, batch error rate 1.000000%
# At minibatch 6400, batch loss 0.048410, batch error rate 1.000000%
# At minibatch 6500, batch loss 0.034640, batch error rate 2.000000%
# After epoch 13: valid_err_rate: 0.024900% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.006771, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.016487, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.038041, batch error rate 1.000000%
# At minibatch 6900, batch loss 0.034395, batch error rate 1.000000%
# At minibatch 7000, batch loss 0.023462, batch error rate 0.000000%
# After epoch 14: valid_err_rate: 0.021900% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.030661, batch error rate 0.000000%
# At minibatch 7200, batch loss 0.022822, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.058509, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.025610, batch error rate 0.000000%
# At minibatch 7500, batch loss 0.068808, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.024100% currently going ot do 22 epochs
# At minibatch 7600, batch loss 0.022618, batch error rate 0.000000%
# At minibatch 7700, batch loss 0.030373, batch error rate 0.000000%
# At minibatch 7800, batch loss 0.084305, batch error rate 3.000000%
# At minibatch 7900, batch loss 0.031780, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.016397, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.023900% currently going ot do 22 epochs
# At minibatch 8100, batch loss 0.028386, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.023667, batch error rate 0.000000%
# At minibatch 8300, batch loss 0.020499, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.010954, batch error rate 0.000000%
# At minibatch 8500, batch loss 0.028692, batch error rate 0.000000%
# After epoch 17: valid_err_rate: 0.023400% currently going ot do 22 epochs
# At minibatch 8600, batch loss 0.010360, batch error rate 0.000000%
# At minibatch 8700, batch loss 0.034899, batch error rate 1.000000%
# At minibatch 8800, batch loss 0.024683, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.011348, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.069151, batch error rate 2.000000%
# After epoch 18: valid_err_rate: 0.023000% currently going ot do 22 epochs
# At minibatch 9100, batch loss 0.015384, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.014946, batch error rate 0.000000%
# At minibatch 9300, batch loss 0.037797, batch error rate 1.000000%
# At minibatch 9400, batch loss 0.018546, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.008890, batch error rate 0.000000%
# After epoch 19: valid_err_rate: 0.023200% currently going ot do 22 epochs
# At minibatch 9600, batch loss 0.011705, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.023945, batch error rate 0.000000%
# At minibatch 9800, batch loss 0.033785, batch error rate 2.000000%
# At minibatch 9900, batch loss 0.050704, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.033635, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.027500% currently going ot do 22 epochs
# At minibatch 10100, batch loss 0.019098, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.014932, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.039003, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.012700, batch error rate 0.000000%
# At minibatch 10500, batch loss 0.016891, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 0.022200% currently going ot do 22 epochs
# At minibatch 10600, batch loss 0.013290, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.024046, batch error rate 1.000000%
# At minibatch 10800, batch loss 0.037418, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.017729, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.006311, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.021600% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.021342, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.019742, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.054579, batch error rate 2.000000%
# At minibatch 11400, batch loss 0.016860, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.017384, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.021400% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.011951, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.031084, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.009249, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.014918, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.021416, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.021200% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.012070, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.026116, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.010819, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.015013, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.009028, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.020600% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.020740, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.025221, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.029117, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.024879, batch error rate 1.000000%
# At minibatch 13000, batch loss 0.041515, batch error rate 2.000000%
# After epoch 26: valid_err_rate: 0.021600% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.042322, batch error rate 1.000000%
# At minibatch 13200, batch loss 0.016738, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.023062, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.023010, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.028392, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.019900% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.022295, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.022864, batch error rate 0.000000%
# At minibatch 13800, batch loss 0.025517, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.015813, batch error rate 1.000000%
# At minibatch 14000, batch loss 0.013133, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.021400% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.015392, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.021809, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.040236, batch error rate 1.000000%
# At minibatch 14400, batch loss 0.014910, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.048812, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.020600% currently going ot do 41 epochs
# At minibatch 14600, batch loss 0.035972, batch error rate 1.000000%
# At minibatch 14700, batch loss 0.017445, batch error rate 0.000000%
# At minibatch 14800, batch loss 0.021876, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.042945, batch error rate 2.000000%
# At minibatch 15000, batch loss 0.026258, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.019900% currently going ot do 41 epochs
# At minibatch 15100, batch loss 0.012629, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.016952, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.030388, batch error rate 1.000000%
# At minibatch 15400, batch loss 0.008129, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.024612, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.020900% currently going ot do 41 epochs
# At minibatch 15600, batch loss 0.028008, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.033254, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.010042, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.036253, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.013183, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.018900% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.036695, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.031282, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.028708, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.011101, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.022157, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.020400% currently going ot do 49 epochs
# At minibatch 16600, batch loss 0.011948, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.019996, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.030389, batch error rate 1.000000%
# At minibatch 16900, batch loss 0.029518, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.021633, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.021200% currently going ot do 49 epochs
# At minibatch 17100, batch loss 0.022018, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.019351, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.015590, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.028491, batch error rate 1.000000%
# At minibatch 17500, batch loss 0.027259, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.020200% currently going ot do 49 epochs
# At minibatch 17600, batch loss 0.017890, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.011864, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.035616, batch error rate 1.000000%
# At minibatch 17900, batch loss 0.025476, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.017478, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.019500% currently going ot do 49 epochs
# At minibatch 18100, batch loss 0.023876, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.025365, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.030950, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.042201, batch error rate 1.000000%
# At minibatch 18500, batch loss 0.027816, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.019800% currently going ot do 49 epochs
# At minibatch 18600, batch loss 0.037409, batch error rate 2.000000%
# At minibatch 18700, batch loss 0.016369, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.023174, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.024949, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.012681, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.018800% currently going ot do 58 epochs
# At minibatch 19100, batch loss 0.018894, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.027185, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.032420, batch error rate 1.000000%
# At minibatch 19400, batch loss 0.025254, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.009849, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.019200% currently going ot do 58 epochs
# At minibatch 19600, batch loss 0.015793, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.016806, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.008821, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.018232, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.020802, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.019700% currently going ot do 58 epochs
# At minibatch 20100, batch loss 0.027345, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.014548, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.018853, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.017210, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.028491, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.018400% currently going ot do 62 epochs
# At minibatch 20600, batch loss 0.030729, batch error rate 1.000000%
# At minibatch 20700, batch loss 0.017252, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.024673, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.009880, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.013121, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.019200% currently going ot do 62 epochs
# At minibatch 21100, batch loss 0.007342, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.016815, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.013892, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.012210, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.013538, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.019200% currently going ot do 62 epochs
# At minibatch 21600, batch loss 0.020086, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.027004, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.039024, batch error rate 1.000000%
# At minibatch 21900, batch loss 0.018742, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.012937, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.018100% currently going ot do 67 epochs
# At minibatch 22100, batch loss 0.024635, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.024141, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.014185, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.013528, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.036043, batch error rate 1.000000%
# After epoch 45: valid_err_rate: 0.019000% currently going ot do 67 epochs
# At minibatch 22600, batch loss 0.016715, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.013498, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.032801, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.024153, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.028426, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.020100% currently going ot do 67 epochs
# At minibatch 23100, batch loss 0.030189, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.011524, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.039394, batch error rate 2.000000%
# At minibatch 23400, batch loss 0.035997, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.019590, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.018300% currently going ot do 67 epochs
# At minibatch 23600, batch loss 0.011203, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.022064, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.026516, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.016147, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.021750, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.018900% currently going ot do 67 epochs
# At minibatch 24100, batch loss 0.013016, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.012597, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.014097, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.022243, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.050167, batch error rate 2.000000%
# After epoch 49: valid_err_rate: 0.019300% currently going ot do 67 epochs
# At minibatch 24600, batch loss 0.021842, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.036952, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.011822, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.021501, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.011163, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.018600% currently going ot do 67 epochs
# At minibatch 25100, batch loss 0.019946, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.023522, batch error rate 1.000000%
# At minibatch 25300, batch loss 0.031478, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.019488, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.016297, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.020400% currently going ot do 67 epochs
# At minibatch 25600, batch loss 0.025031, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.017589, batch error rate 1.000000%
# At minibatch 25800, batch loss 0.035127, batch error rate 1.000000%
# At minibatch 25900, batch loss 0.013831, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.037647, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.019200% currently going ot do 67 epochs
# At minibatch 26100, batch loss 0.019075, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.009012, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.032278, batch error rate 1.000000%
# At minibatch 26400, batch loss 0.016626, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.011513, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.018600% currently going ot do 67 epochs
# At minibatch 26600, batch loss 0.016602, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.015168, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.016149, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.020389, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.023937, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.018300% currently going ot do 67 epochs
# At minibatch 27100, batch loss 0.017052, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.013690, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.011757, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.021785, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.020971, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.019200% currently going ot do 67 epochs
# At minibatch 27600, batch loss 0.011242, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.022160, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.020780, batch error rate 1.000000%
# At minibatch 27900, batch loss 0.017884, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.015251, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.018500% currently going ot do 67 epochs
# At minibatch 28100, batch loss 0.034980, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.023802, batch error rate 1.000000%
# At minibatch 28300, batch loss 0.011307, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.010577, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.027551, batch error rate 1.000000%
# After epoch 57: valid_err_rate: 0.018000% currently going ot do 86 epochs
# At minibatch 28600, batch loss 0.026267, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.012717, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.027486, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.023497, batch error rate 1.000000%
# At minibatch 29000, batch loss 0.038081, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.019700% currently going ot do 86 epochs
# At minibatch 29100, batch loss 0.012512, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.015635, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.019557, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.012773, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.014188, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.018800% currently going ot do 86 epochs
# At minibatch 29600, batch loss 0.029660, batch error rate 1.000000%
# At minibatch 29700, batch loss 0.015391, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.011034, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.020838, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.020009, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.018800% currently going ot do 86 epochs
# At minibatch 30100, batch loss 0.016255, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.035760, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.015491, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.012665, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.016931, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.019000% currently going ot do 86 epochs
# At minibatch 30600, batch loss 0.053722, batch error rate 2.000000%
# At minibatch 30700, batch loss 0.019856, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.037837, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.054929, batch error rate 2.000000%
# At minibatch 31000, batch loss 0.014172, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.018700% currently going ot do 86 epochs
# At minibatch 31100, batch loss 0.011418, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.011209, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.027771, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.019824, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.033185, batch error rate 1.000000%
# After epoch 63: valid_err_rate: 0.018400% currently going ot do 86 epochs
# At minibatch 31600, batch loss 0.028754, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.008498, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.013925, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.010108, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.011484, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.018200% currently going ot do 86 epochs
# At minibatch 32100, batch loss 0.009226, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.013307, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.014998, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.023902, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.021086, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.017900% currently going ot do 98 epochs
# At minibatch 32600, batch loss 0.017187, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.014278, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.006913, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.006929, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.022329, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.018300% currently going ot do 98 epochs
# At minibatch 33100, batch loss 0.013597, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.014636, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.021431, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.012884, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.013790, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.017200% currently going ot do 101 epochs
# At minibatch 33600, batch loss 0.020163, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.037428, batch error rate 1.000000%
# At minibatch 33800, batch loss 0.020809, batch error rate 1.000000%
# At minibatch 33900, batch loss 0.012032, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.028741, batch error rate 1.000000%
# After epoch 68: valid_err_rate: 0.019400% currently going ot do 101 epochs
# At minibatch 34100, batch loss 0.028916, batch error rate 1.000000%
# At minibatch 34200, batch loss 0.019753, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.016335, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.012532, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.021205, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.018700% currently going ot do 101 epochs
# At minibatch 34600, batch loss 0.012870, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.013147, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.010049, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.009012, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.021465, batch error rate 1.000000%
# After epoch 70: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 35100, batch loss 0.009577, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.019856, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.021233, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.016744, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.025564, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.018900% currently going ot do 101 epochs
# At minibatch 35600, batch loss 0.017618, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.019719, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.032682, batch error rate 1.000000%
# At minibatch 35900, batch loss 0.020560, batch error rate 1.000000%
# At minibatch 36000, batch loss 0.016383, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.018200% currently going ot do 101 epochs
# At minibatch 36100, batch loss 0.019918, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.011398, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.015632, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.012502, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.010633, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.019200% currently going ot do 101 epochs
# At minibatch 36600, batch loss 0.015259, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.014908, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.008467, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.012093, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.038116, batch error rate 1.000000%
# After epoch 74: valid_err_rate: 0.018700% currently going ot do 101 epochs
# At minibatch 37100, batch loss 0.013199, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.020022, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.027117, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.018792, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.018456, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.018400% currently going ot do 101 epochs
# At minibatch 37600, batch loss 0.028312, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.020313, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.021191, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.021093, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.016001, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 38100, batch loss 0.020772, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.022954, batch error rate 1.000000%
# At minibatch 38300, batch loss 0.023737, batch error rate 1.000000%
# At minibatch 38400, batch loss 0.011749, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.019503, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.017500% currently going ot do 101 epochs
# At minibatch 38600, batch loss 0.026647, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.010519, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.007329, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.012962, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.007727, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.018000% currently going ot do 101 epochs
# At minibatch 39100, batch loss 0.016160, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.015032, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.019359, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.033059, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.016865, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.018300% currently going ot do 101 epochs
# At minibatch 39600, batch loss 0.039321, batch error rate 2.000000%
# At minibatch 39700, batch loss 0.008847, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.016713, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.021755, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.028868, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.016300% currently going ot do 121 epochs
# At minibatch 40100, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.018886, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.015629, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.029071, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.017644, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.017500% currently going ot do 121 epochs
# At minibatch 40600, batch loss 0.017967, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.010441, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.031549, batch error rate 1.000000%
# At minibatch 40900, batch loss 0.017871, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.012357, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.016500% currently going ot do 121 epochs
# At minibatch 41100, batch loss 0.020174, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.031512, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.013897, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.013238, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.007627, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.019400% currently going ot do 121 epochs
# At minibatch 41600, batch loss 0.010112, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.023764, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.018137, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.018109, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.012156, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.019000% currently going ot do 121 epochs
# At minibatch 42100, batch loss 0.009177, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.016395, batch error rate 1.000000%
# At minibatch 42300, batch loss 0.007600, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.022446, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.011767, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.018400% currently going ot do 121 epochs
# At minibatch 42600, batch loss 0.028497, batch error rate 1.000000%
# At minibatch 42700, batch loss 0.008029, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.019868, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.019324, batch error rate 0.000000%
# At minibatch 43000, batch loss 0.046210, batch error rate 1.000000%
# After epoch 86: valid_err_rate: 0.019200% currently going ot do 121 epochs
# At minibatch 43100, batch loss 0.012345, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.015968, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.039137, batch error rate 1.000000%
# At minibatch 43400, batch loss 0.017781, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.014449, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 43600, batch loss 0.017025, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.013035, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.010269, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.015681, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 44100, batch loss 0.042911, batch error rate 1.000000%
# At minibatch 44200, batch loss 0.022664, batch error rate 1.000000%
# At minibatch 44300, batch loss 0.027462, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.032448, batch error rate 1.000000%
# At minibatch 44500, batch loss 0.020443, batch error rate 1.000000%
# After epoch 89: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 44600, batch loss 0.016332, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.014254, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.013029, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.012116, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.015315, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.017500% currently going ot do 121 epochs
# At minibatch 45100, batch loss 0.016320, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.020971, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.019624, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.016326, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.018238, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.019600% currently going ot do 121 epochs
# At minibatch 45600, batch loss 0.009554, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.020640, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.025815, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.010225, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.012594, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.017200% currently going ot do 121 epochs
# At minibatch 46100, batch loss 0.014934, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.024804, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.009738, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.021447, batch error rate 1.000000%
# At minibatch 46500, batch loss 0.011121, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.018500% currently going ot do 121 epochs
# At minibatch 46600, batch loss 0.014700, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.015326, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.017151, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.020063, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.009515, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.018300% currently going ot do 121 epochs
# At minibatch 47100, batch loss 0.022973, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.016892, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.026333, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.018653, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.021400, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 47600, batch loss 0.011592, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.012700, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.020599, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.015280, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.034231, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.017300% currently going ot do 121 epochs
# At minibatch 48100, batch loss 0.011092, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.009717, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.028589, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.021318, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.019138, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.017700% currently going ot do 121 epochs
# At minibatch 48600, batch loss 0.024113, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.006874, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.021189, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.009018, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.027520, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.018900% currently going ot do 121 epochs
# At minibatch 49100, batch loss 0.013283, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.019252, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.023177, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.023980, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.016554, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.018700% currently going ot do 121 epochs
# At minibatch 49600, batch loss 0.011228, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.021124, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.021918, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.021672, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.016453, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 50100, batch loss 0.013830, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.011159, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.014902, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.012468, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.012518, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.017400% currently going ot do 121 epochs
# At minibatch 50600, batch loss 0.013041, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.036260, batch error rate 2.000000%
# At minibatch 50800, batch loss 0.027137, batch error rate 1.000000%
# At minibatch 50900, batch loss 0.012278, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.007474, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.017200% currently going ot do 121 epochs
# At minibatch 51100, batch loss 0.013243, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.019252, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.026720, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.011840, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.030166, batch error rate 1.000000%
# After epoch 103: valid_err_rate: 0.018100% currently going ot do 121 epochs
# At minibatch 51600, batch loss 0.014137, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.019039, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.018138, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.014336, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.011331, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.017400% currently going ot do 121 epochs
# At minibatch 52100, batch loss 0.024577, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.011339, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.014918, batch error rate 0.000000%
# At minibatch 52400, batch loss 0.024967, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.019673, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 52600, batch loss 0.018649, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.027665, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.020995, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.007034, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.009823, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.016600% currently going ot do 121 epochs
# At minibatch 53100, batch loss 0.009422, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.010772, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.025245, batch error rate 1.000000%
# At minibatch 53400, batch loss 0.013340, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.022997, batch error rate 1.000000%
# After epoch 107: valid_err_rate: 0.018700% currently going ot do 121 epochs
# At minibatch 53600, batch loss 0.009473, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.012321, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.008953, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.012913, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.028329, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.019300% currently going ot do 121 epochs
# At minibatch 54100, batch loss 0.015847, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.005305, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.041033, batch error rate 1.000000%
# At minibatch 54400, batch loss 0.013919, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.021071, batch error rate 1.000000%
# After epoch 109: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 54600, batch loss 0.020151, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.031970, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.016032, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.017815, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.019259, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.018300% currently going ot do 121 epochs
# At minibatch 55100, batch loss 0.011327, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.020200, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.019332, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.028087, batch error rate 1.000000%
# At minibatch 55500, batch loss 0.011845, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 55600, batch loss 0.020769, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.012160, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.013792, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.022415, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.016967, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 56100, batch loss 0.034665, batch error rate 1.000000%
# At minibatch 56200, batch loss 0.038785, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.006469, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.009274, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.008775, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 56600, batch loss 0.017385, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.007844, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.006447, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.025327, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.022001, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.018600% currently going ot do 121 epochs
# At minibatch 57100, batch loss 0.020235, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.019268, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.026652, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.018541, batch error rate 1.000000%
# At minibatch 57500, batch loss 0.013917, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.017900% currently going ot do 121 epochs
# At minibatch 57600, batch loss 0.026536, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.012815, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.022720, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.019683, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.014940, batch error rate 0.000000%
# After epoch 116: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 58100, batch loss 0.016128, batch error rate 0.000000%
# At minibatch 58200, batch loss 0.035083, batch error rate 0.000000%
# At minibatch 58300, batch loss 0.022390, batch error rate 0.000000%
# At minibatch 58400, batch loss 0.022168, batch error rate 0.000000%
# At minibatch 58500, batch loss 0.022470, batch error rate 1.000000%
# After epoch 117: valid_err_rate: 0.017800% currently going ot do 121 epochs
# At minibatch 58600, batch loss 0.006153, batch error rate 0.000000%
# At minibatch 58700, batch loss 0.013314, batch error rate 0.000000%
# At minibatch 58800, batch loss 0.009477, batch error rate 0.000000%
# At minibatch 58900, batch loss 0.025113, batch error rate 0.000000%
# At minibatch 59000, batch loss 0.016335, batch error rate 0.000000%
# After epoch 118: valid_err_rate: 0.016800% currently going ot do 121 epochs
# At minibatch 59100, batch loss 0.010722, batch error rate 0.000000%
# At minibatch 59200, batch loss 0.031408, batch error rate 1.000000%
# At minibatch 59300, batch loss 0.022215, batch error rate 0.000000%
# At minibatch 59400, batch loss 0.016463, batch error rate 0.000000%
# At minibatch 59500, batch loss 0.021183, batch error rate 0.000000%
# After epoch 119: valid_err_rate: 0.017100% currently going ot do 121 epochs
# At minibatch 59600, batch loss 0.014341, batch error rate 0.000000%
# At minibatch 59700, batch loss 0.008557, batch error rate 0.000000%
# At minibatch 59800, batch loss 0.022984, batch error rate 0.000000%
# At minibatch 59900, batch loss 0.016729, batch error rate 0.000000%
# At minibatch 60000, batch loss 0.021550, batch error rate 0.000000%
# After epoch 120: valid_err_rate: 0.018200% currently going ot do 121 epochs
# At minibatch 60100, batch loss 0.018297, batch error rate 1.000000%
# At minibatch 60200, batch loss 0.015829, batch error rate 0.000000%
# At minibatch 60300, batch loss 0.017416, batch error rate 0.000000%
# At minibatch 60400, batch loss 0.021518, batch error rate 0.000000%
# At minibatch 60500, batch loss 0.012580, batch error rate 0.000000%
# After epoch 121: valid_err_rate: 0.017700% currently going ot do 121 epochs
# Finished with 121 epochs (minibatch 60500), with best valid error rate 0.016300

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0188

# %%
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_rate = 1e-3,
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg2())
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 0.354171, batch error rate 10.000000%
# At minibatch 200, batch loss 0.355988, batch error rate 11.000000%
# At minibatch 300, batch loss 0.341935, batch error rate 10.000000%
# At minibatch 400, batch loss 0.175670, batch error rate 6.000000%
# At minibatch 500, batch loss 0.219663, batch error rate 7.000000%
# After epoch 1: valid_err_rate: 0.060900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.318057, batch error rate 11.000000%
# At minibatch 700, batch loss 0.264658, batch error rate 6.000000%
# At minibatch 800, batch loss 0.071079, batch error rate 1.000000%
# At minibatch 900, batch loss 0.091895, batch error rate 2.000000%
# At minibatch 1000, batch loss 0.098270, batch error rate 4.000000%
# After epoch 2: valid_err_rate: 0.051800% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.118651, batch error rate 4.000000%
# At minibatch 1200, batch loss 0.185271, batch error rate 6.000000%
# At minibatch 1300, batch loss 0.129637, batch error rate 6.000000%
# At minibatch 1400, batch loss 0.139516, batch error rate 3.000000%
# At minibatch 1500, batch loss 0.182212, batch error rate 6.000000%
# After epoch 3: valid_err_rate: 0.038000% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.121026, batch error rate 6.000000%
# At minibatch 1700, batch loss 0.054431, batch error rate 1.000000%
# At minibatch 1800, batch loss 0.132137, batch error rate 5.000000%
# At minibatch 1900, batch loss 0.102446, batch error rate 5.000000%
# At minibatch 2000, batch loss 0.080119, batch error rate 1.000000%
# After epoch 4: valid_err_rate: 0.035800% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.069040, batch error rate 4.000000%
# At minibatch 2200, batch loss 0.052911, batch error rate 2.000000%
# At minibatch 2300, batch loss 0.059997, batch error rate 2.000000%
# At minibatch 2400, batch loss 0.054650, batch error rate 3.000000%
# At minibatch 2500, batch loss 0.067253, batch error rate 3.000000%
# After epoch 5: valid_err_rate: 0.033200% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.102407, batch error rate 3.000000%
# At minibatch 2700, batch loss 0.043607, batch error rate 2.000000%
# At minibatch 2800, batch loss 0.050734, batch error rate 3.000000%
# At minibatch 2900, batch loss 0.045464, batch error rate 2.000000%
# At minibatch 3000, batch loss 0.038039, batch error rate 1.000000%
# After epoch 6: valid_err_rate: 0.030200% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.049674, batch error rate 1.000000%
# At minibatch 3200, batch loss 0.053932, batch error rate 1.000000%
# At minibatch 3300, batch loss 0.022990, batch error rate 0.000000%
# At minibatch 3400, batch loss 0.049587, batch error rate 1.000000%
# At minibatch 3500, batch loss 0.075297, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.028200% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.064041, batch error rate 1.000000%
# At minibatch 3700, batch loss 0.079257, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.057745, batch error rate 3.000000%
# At minibatch 3900, batch loss 0.086297, batch error rate 1.000000%
# At minibatch 4000, batch loss 0.024552, batch error rate 0.000000%
# After epoch 8: valid_err_rate: 0.026500% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.039926, batch error rate 1.000000%
# At minibatch 4200, batch loss 0.024592, batch error rate 0.000000%
# At minibatch 4300, batch loss 0.030927, batch error rate 0.000000%
# At minibatch 4400, batch loss 0.061254, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.044545, batch error rate 1.000000%
# After epoch 9: valid_err_rate: 0.027700% currently going ot do 13 epochs
# At minibatch 4600, batch loss 0.014052, batch error rate 0.000000%
# At minibatch 4700, batch loss 0.016378, batch error rate 1.000000%
# At minibatch 4800, batch loss 0.033137, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.069872, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.012658, batch error rate 0.000000%
# After epoch 10: valid_err_rate: 0.026800% currently going ot do 13 epochs
# At minibatch 5100, batch loss 0.013648, batch error rate 0.000000%
# At minibatch 5200, batch loss 0.038603, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.023261, batch error rate 1.000000%
# At minibatch 5400, batch loss 0.029456, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.024378, batch error rate 0.000000%
# After epoch 11: valid_err_rate: 0.024700% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.027362, batch error rate 1.000000%
# At minibatch 5700, batch loss 0.028191, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.104048, batch error rate 5.000000%
# At minibatch 5900, batch loss 0.021539, batch error rate 0.000000%
# At minibatch 6000, batch loss 0.014733, batch error rate 0.000000%
# After epoch 12: valid_err_rate: 0.026200% currently going ot do 17 epochs
# At minibatch 6100, batch loss 0.006505, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.044095, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.026746, batch error rate 1.000000%
# At minibatch 6400, batch loss 0.043746, batch error rate 2.000000%
# At minibatch 6500, batch loss 0.019694, batch error rate 0.000000%
# After epoch 13: valid_err_rate: 0.024800% currently going ot do 17 epochs
# At minibatch 6600, batch loss 0.014686, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.010765, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.034809, batch error rate 1.000000%
# At minibatch 6900, batch loss 0.013698, batch error rate 0.000000%
# At minibatch 7000, batch loss 0.024221, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.025100% currently going ot do 17 epochs
# At minibatch 7100, batch loss 0.014103, batch error rate 0.000000%
# At minibatch 7200, batch loss 0.022375, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.021035, batch error rate 0.000000%
# At minibatch 7400, batch loss 0.039454, batch error rate 2.000000%
# At minibatch 7500, batch loss 0.040210, batch error rate 1.000000%
# After epoch 15: valid_err_rate: 0.025600% currently going ot do 17 epochs
# At minibatch 7600, batch loss 0.030180, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.046354, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.028714, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.028530, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.022895, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.024300% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.022425, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.049549, batch error rate 2.000000%
# At minibatch 8300, batch loss 0.051911, batch error rate 1.000000%
# At minibatch 8400, batch loss 0.030893, batch error rate 0.000000%
# At minibatch 8500, batch loss 0.019287, batch error rate 0.000000%
# After epoch 17: valid_err_rate: 0.025900% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.034621, batch error rate 1.000000%
# At minibatch 8700, batch loss 0.022175, batch error rate 0.000000%
# At minibatch 8800, batch loss 0.030440, batch error rate 1.000000%
# At minibatch 8900, batch loss 0.038443, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.023931, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.024900% currently going ot do 25 epochs
# At minibatch 9100, batch loss 0.026202, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.029384, batch error rate 1.000000%
# At minibatch 9300, batch loss 0.027484, batch error rate 0.000000%
# At minibatch 9400, batch loss 0.027877, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.040084, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.023700% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.026035, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.028992, batch error rate 1.000000%
# At minibatch 9800, batch loss 0.047688, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.035533, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.035409, batch error rate 1.000000%
# After epoch 20: valid_err_rate: 0.023600% currently going ot do 31 epochs
# At minibatch 10100, batch loss 0.054093, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.017349, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.018086, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.025452, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.025112, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.023700% currently going ot do 31 epochs
# At minibatch 10600, batch loss 0.028870, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.005592, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.018832, batch error rate 1.000000%
# At minibatch 10900, batch loss 0.013704, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.013641, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.024500% currently going ot do 31 epochs
# At minibatch 11100, batch loss 0.067437, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.013371, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.013362, batch error rate 0.000000%
# At minibatch 11400, batch loss 0.025251, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.013035, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.022700% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.012330, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.015757, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.023001, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.021200, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.020153, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.022800% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.053338, batch error rate 1.000000%
# At minibatch 12200, batch loss 0.038080, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.021105, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.016456, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.029131, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.022600% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.039397, batch error rate 1.000000%
# At minibatch 12700, batch loss 0.041405, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.019576, batch error rate 0.000000%
# At minibatch 12900, batch loss 0.015424, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.039110, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.023300% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.035559, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.023477, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.018138, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.020846, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.040031, batch error rate 2.000000%
# After epoch 27: valid_err_rate: 0.023100% currently going ot do 38 epochs
# At minibatch 13600, batch loss 0.022403, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.021287, batch error rate 0.000000%
# At minibatch 13800, batch loss 0.010191, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.036125, batch error rate 1.000000%
# At minibatch 14000, batch loss 0.021849, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.021900% currently going ot do 43 epochs
# At minibatch 14100, batch loss 0.020631, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.030339, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.022602, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.029511, batch error rate 1.000000%
# At minibatch 14500, batch loss 0.033463, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.022200% currently going ot do 43 epochs
# At minibatch 14600, batch loss 0.020696, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.042093, batch error rate 3.000000%
# At minibatch 14800, batch loss 0.028018, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.027032, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.030665, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.021600% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.015883, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.016903, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.022603, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.026367, batch error rate 1.000000%
# At minibatch 15500, batch loss 0.024197, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.021000% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.023905, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.013380, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.011527, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.030389, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.039941, batch error rate 1.000000%
# After epoch 32: valid_err_rate: 0.024500% currently going ot do 47 epochs
# At minibatch 16100, batch loss 0.026692, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.015755, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.026848, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.015858, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.019498, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.022900% currently going ot do 47 epochs
# At minibatch 16600, batch loss 0.026999, batch error rate 1.000000%
# At minibatch 16700, batch loss 0.018484, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.015268, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.011345, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.036184, batch error rate 1.000000%
# After epoch 34: valid_err_rate: 0.022400% currently going ot do 47 epochs
# At minibatch 17100, batch loss 0.013328, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.023862, batch error rate 1.000000%
# At minibatch 17300, batch loss 0.026333, batch error rate 1.000000%
# At minibatch 17400, batch loss 0.014924, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.016690, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.022000% currently going ot do 47 epochs
# At minibatch 17600, batch loss 0.016413, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.014824, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.033814, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.006835, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.024476, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.022100% currently going ot do 47 epochs
# At minibatch 18100, batch loss 0.029447, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.009785, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.018186, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.025550, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.021633, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.021900% currently going ot do 47 epochs
# At minibatch 18600, batch loss 0.020514, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.024700, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.022478, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.042474, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.037997, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.021700% currently going ot do 47 epochs
# At minibatch 19100, batch loss 0.032298, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.013307, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.023405, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.015010, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.018038, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.021600% currently going ot do 47 epochs
# At minibatch 19600, batch loss 0.012565, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.012184, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.010777, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.022241, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.012801, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.020900% currently going ot do 61 epochs
# At minibatch 20100, batch loss 0.015478, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.047822, batch error rate 2.000000%
# At minibatch 20300, batch loss 0.030095, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.013005, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.016080, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.021600% currently going ot do 61 epochs
# At minibatch 20600, batch loss 0.014404, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.013429, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.025314, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.019392, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.021748, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.022800% currently going ot do 61 epochs
# At minibatch 21100, batch loss 0.015040, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.032593, batch error rate 1.000000%
# At minibatch 21300, batch loss 0.011172, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.016545, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.017618, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.021600% currently going ot do 61 epochs
# At minibatch 21600, batch loss 0.032393, batch error rate 2.000000%
# At minibatch 21700, batch loss 0.024133, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.016961, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.020802, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.022407, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.022000% currently going ot do 61 epochs
# At minibatch 22100, batch loss 0.018163, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.020051, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.029390, batch error rate 1.000000%
# At minibatch 22400, batch loss 0.040986, batch error rate 1.000000%
# At minibatch 22500, batch loss 0.018760, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.021100% currently going ot do 61 epochs
# At minibatch 22600, batch loss 0.013847, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.039715, batch error rate 2.000000%
# At minibatch 22800, batch loss 0.028415, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.014865, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.027944, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.020900% currently going ot do 61 epochs
# At minibatch 23100, batch loss 0.022799, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.020299, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.005445, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.038717, batch error rate 1.000000%
# At minibatch 23500, batch loss 0.020315, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.020700% currently going ot do 71 epochs
# At minibatch 23600, batch loss 0.010048, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.018498, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.020937, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.031451, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.041628, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.020400% currently going ot do 73 epochs
# At minibatch 24100, batch loss 0.032014, batch error rate 1.000000%
# At minibatch 24200, batch loss 0.013338, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.046038, batch error rate 2.000000%
# At minibatch 24400, batch loss 0.012342, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.019969, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.021400% currently going ot do 73 epochs
# At minibatch 24600, batch loss 0.015809, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.014867, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.014780, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.016916, batch error rate 1.000000%
# At minibatch 25000, batch loss 0.008941, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.020900% currently going ot do 73 epochs
# At minibatch 25100, batch loss 0.022238, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.012540, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.012915, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.009214, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.011331, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.020100% currently going ot do 77 epochs
# At minibatch 25600, batch loss 0.011505, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.033414, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.025257, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.015561, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.022604, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.019900% currently going ot do 79 epochs
# At minibatch 26100, batch loss 0.030688, batch error rate 1.000000%
# At minibatch 26200, batch loss 0.025610, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.041437, batch error rate 2.000000%
# At minibatch 26400, batch loss 0.017280, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.019987, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.020000% currently going ot do 79 epochs
# At minibatch 26600, batch loss 0.010632, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.013616, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.022863, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.010283, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.019182, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.020500% currently going ot do 79 epochs
# At minibatch 27100, batch loss 0.016247, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.022507, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.031419, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.015717, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.007836, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.021500% currently going ot do 79 epochs
# At minibatch 27600, batch loss 0.044254, batch error rate 1.000000%
# At minibatch 27700, batch loss 0.025770, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.024904, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.017458, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.015902, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.020600% currently going ot do 79 epochs
# At minibatch 28100, batch loss 0.041795, batch error rate 1.000000%
# At minibatch 28200, batch loss 0.017865, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.016057, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.022014, batch error rate 1.000000%
# At minibatch 28500, batch loss 0.016713, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.020100% currently going ot do 79 epochs
# At minibatch 28600, batch loss 0.017170, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.016212, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.042092, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.052571, batch error rate 2.000000%
# At minibatch 29000, batch loss 0.007469, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.020400% currently going ot do 79 epochs
# At minibatch 29100, batch loss 0.020495, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.023778, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.010424, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.024303, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.020181, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.020500% currently going ot do 79 epochs
# At minibatch 29600, batch loss 0.019032, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.032081, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.012748, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.022043, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.014218, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.021000% currently going ot do 79 epochs
# At minibatch 30100, batch loss 0.027829, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.026641, batch error rate 1.000000%
# At minibatch 30300, batch loss 0.011366, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.010903, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.022429, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.020500% currently going ot do 79 epochs
# At minibatch 30600, batch loss 0.024831, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.012236, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.053614, batch error rate 1.000000%
# At minibatch 30900, batch loss 0.025355, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.018960, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.019900% currently going ot do 79 epochs
# At minibatch 31100, batch loss 0.024455, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.015717, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.018958, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.024185, batch error rate 1.000000%
# At minibatch 31500, batch loss 0.024976, batch error rate 1.000000%
# After epoch 63: valid_err_rate: 0.021600% currently going ot do 79 epochs
# At minibatch 31600, batch loss 0.018013, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.021276, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.031193, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.025518, batch error rate 1.000000%
# At minibatch 32000, batch loss 0.014236, batch error rate 1.000000%
# After epoch 64: valid_err_rate: 0.020700% currently going ot do 79 epochs
# At minibatch 32100, batch loss 0.012682, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.023757, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.015818, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.023204, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.013436, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.019500% currently going ot do 98 epochs
# At minibatch 32600, batch loss 0.005314, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.014388, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.013966, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.023784, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.021128, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.019900% currently going ot do 98 epochs
# At minibatch 33100, batch loss 0.014690, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.016847, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.014721, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.020895, batch error rate 1.000000%
# At minibatch 33500, batch loss 0.008628, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.020200% currently going ot do 98 epochs
# At minibatch 33600, batch loss 0.051682, batch error rate 1.000000%
# At minibatch 33700, batch loss 0.018715, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.011062, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.040707, batch error rate 1.000000%
# At minibatch 34000, batch loss 0.018958, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.020300% currently going ot do 98 epochs
# At minibatch 34100, batch loss 0.011830, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.009047, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.020209, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.017189, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.027189, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.020700% currently going ot do 98 epochs
# At minibatch 34600, batch loss 0.016051, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.018738, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.019512, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.015590, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.012858, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.020900% currently going ot do 98 epochs
# At minibatch 35100, batch loss 0.033045, batch error rate 1.000000%
# At minibatch 35200, batch loss 0.012678, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.018923, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.043854, batch error rate 1.000000%
# At minibatch 35500, batch loss 0.030845, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.020200% currently going ot do 98 epochs
# At minibatch 35600, batch loss 0.034940, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.014407, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.034880, batch error rate 2.000000%
# At minibatch 35900, batch loss 0.033100, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.014382, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.020200% currently going ot do 98 epochs
# At minibatch 36100, batch loss 0.017791, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.019725, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.023630, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.022945, batch error rate 1.000000%
# At minibatch 36500, batch loss 0.020933, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.020000% currently going ot do 98 epochs
# At minibatch 36600, batch loss 0.014108, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.024114, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.022519, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.012662, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.023949, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.020200% currently going ot do 98 epochs
# At minibatch 37100, batch loss 0.009027, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.014555, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.017207, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.011145, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.028417, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.019900% currently going ot do 98 epochs
# At minibatch 37600, batch loss 0.023294, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.024634, batch error rate 1.000000%
# At minibatch 37800, batch loss 0.012414, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.013975, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.024376, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.020200% currently going ot do 98 epochs
# At minibatch 38100, batch loss 0.014653, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.024269, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.019738, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.032991, batch error rate 1.000000%
# At minibatch 38500, batch loss 0.010990, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.019000% currently going ot do 116 epochs
# At minibatch 38600, batch loss 0.010770, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.017561, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.016387, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.012468, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.023142, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.019800% currently going ot do 116 epochs
# At minibatch 39100, batch loss 0.023706, batch error rate 1.000000%
# At minibatch 39200, batch loss 0.036390, batch error rate 1.000000%
# At minibatch 39300, batch loss 0.018752, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.019088, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.013318, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.018800% currently going ot do 119 epochs
# At minibatch 39600, batch loss 0.018723, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.025387, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.027255, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.016056, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.012660, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.020200% currently going ot do 119 epochs
# At minibatch 40100, batch loss 0.018573, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.020809, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.009416, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.014370, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.019211, batch error rate 1.000000%
# After epoch 81: valid_err_rate: 0.020600% currently going ot do 119 epochs
# At minibatch 40600, batch loss 0.025062, batch error rate 1.000000%
# At minibatch 40700, batch loss 0.011795, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.022610, batch error rate 0.000000%
# At minibatch 40900, batch loss 0.032575, batch error rate 1.000000%
# At minibatch 41000, batch loss 0.020634, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.019300% currently going ot do 119 epochs
# At minibatch 41100, batch loss 0.007666, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.015776, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.021263, batch error rate 1.000000%
# At minibatch 41400, batch loss 0.008167, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.015949, batch error rate 1.000000%
# After epoch 83: valid_err_rate: 0.020000% currently going ot do 119 epochs
# At minibatch 41600, batch loss 0.032682, batch error rate 2.000000%
# At minibatch 41700, batch loss 0.012535, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.029086, batch error rate 1.000000%
# At minibatch 41900, batch loss 0.011499, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.012987, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.019400% currently going ot do 119 epochs
# At minibatch 42100, batch loss 0.021673, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.009081, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.015925, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.020580, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.018220, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.019300% currently going ot do 119 epochs
# At minibatch 42600, batch loss 0.029522, batch error rate 2.000000%
# At minibatch 42700, batch loss 0.019809, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.015581, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.019151, batch error rate 1.000000%
# At minibatch 43000, batch loss 0.023179, batch error rate 1.000000%
# After epoch 86: valid_err_rate: 0.019100% currently going ot do 119 epochs
# At minibatch 43100, batch loss 0.028290, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.013170, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.010008, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.017966, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.025945, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.020100% currently going ot do 119 epochs
# At minibatch 43600, batch loss 0.016621, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.011884, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.016414, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.034738, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.045950, batch error rate 1.000000%
# After epoch 88: valid_err_rate: 0.019600% currently going ot do 119 epochs
# At minibatch 44100, batch loss 0.020989, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.007045, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.023482, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.013015, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.012264, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.020300% currently going ot do 119 epochs
# At minibatch 44600, batch loss 0.025313, batch error rate 1.000000%
# At minibatch 44700, batch loss 0.018471, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.016760, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.025674, batch error rate 1.000000%
# At minibatch 45000, batch loss 0.019408, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.020300% currently going ot do 119 epochs
# At minibatch 45100, batch loss 0.012739, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.013834, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.011931, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.010364, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.033967, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.019100% currently going ot do 119 epochs
# At minibatch 45600, batch loss 0.034544, batch error rate 1.000000%
# At minibatch 45700, batch loss 0.014645, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.017179, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.008250, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.015657, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.019100% currently going ot do 119 epochs
# At minibatch 46100, batch loss 0.018741, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.009058, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.018226, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.025178, batch error rate 0.000000%
# At minibatch 46500, batch loss 0.026960, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.018700% currently going ot do 140 epochs
# At minibatch 46600, batch loss 0.013815, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.019696, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.018842, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.023109, batch error rate 1.000000%
# At minibatch 47000, batch loss 0.014634, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.019300% currently going ot do 140 epochs
# At minibatch 47100, batch loss 0.016484, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.020179, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.009867, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.011389, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.011459, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.019500% currently going ot do 140 epochs
# At minibatch 47600, batch loss 0.014755, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.014988, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.024227, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.019396, batch error rate 1.000000%
# At minibatch 48000, batch loss 0.029341, batch error rate 1.000000%
# After epoch 96: valid_err_rate: 0.019200% currently going ot do 140 epochs
# At minibatch 48100, batch loss 0.008323, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.021682, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.013572, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.019201, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.025084, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.019100% currently going ot do 140 epochs
# At minibatch 48600, batch loss 0.021491, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.018966, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.011178, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.017661, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.012186, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.018700% currently going ot do 140 epochs
# At minibatch 49100, batch loss 0.022493, batch error rate 1.000000%
# At minibatch 49200, batch loss 0.012501, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.015500, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.014491, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.019388, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.019500% currently going ot do 140 epochs
# At minibatch 49600, batch loss 0.021397, batch error rate 1.000000%
# At minibatch 49700, batch loss 0.013502, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.021489, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.030163, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.017703, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.019500% currently going ot do 140 epochs
# At minibatch 50100, batch loss 0.013716, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.030640, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.007198, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.010497, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.022478, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.020000% currently going ot do 140 epochs
# At minibatch 50600, batch loss 0.009625, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.020485, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.029915, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.023676, batch error rate 1.000000%
# At minibatch 51000, batch loss 0.027985, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.019800% currently going ot do 140 epochs
# At minibatch 51100, batch loss 0.022847, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.010079, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.013872, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.007725, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.022055, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.019300% currently going ot do 140 epochs
# At minibatch 51600, batch loss 0.008623, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.016719, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.010482, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.013334, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.011457, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.019700% currently going ot do 140 epochs
# At minibatch 52100, batch loss 0.019202, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.021017, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.021042, batch error rate 1.000000%
# At minibatch 52400, batch loss 0.012489, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.037001, batch error rate 2.000000%
# After epoch 105: valid_err_rate: 0.019100% currently going ot do 140 epochs
# At minibatch 52600, batch loss 0.031980, batch error rate 1.000000%
# At minibatch 52700, batch loss 0.029657, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.011863, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.029570, batch error rate 1.000000%
# At minibatch 53000, batch loss 0.025875, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.019800% currently going ot do 140 epochs
# At minibatch 53100, batch loss 0.018717, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.019776, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.011114, batch error rate 0.000000%
# At minibatch 53400, batch loss 0.008271, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.013865, batch error rate 0.000000%
# After epoch 107: valid_err_rate: 0.018800% currently going ot do 140 epochs
# At minibatch 53600, batch loss 0.014458, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.021102, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.011627, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.021832, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.009910, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.020400% currently going ot do 140 epochs
# At minibatch 54100, batch loss 0.024324, batch error rate 1.000000%
# At minibatch 54200, batch loss 0.024360, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.016862, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.015749, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.016522, batch error rate 0.000000%
# After epoch 109: valid_err_rate: 0.020500% currently going ot do 140 epochs
# At minibatch 54600, batch loss 0.018418, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.014556, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.013057, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.019202, batch error rate 1.000000%
# At minibatch 55000, batch loss 0.016667, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.019600% currently going ot do 140 epochs
# At minibatch 55100, batch loss 0.014714, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.017433, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.019854, batch error rate 1.000000%
# At minibatch 55400, batch loss 0.010602, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.007828, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.019300% currently going ot do 140 epochs
# At minibatch 55600, batch loss 0.024614, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.012761, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.014020, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.018785, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.015068, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.018900% currently going ot do 140 epochs
# At minibatch 56100, batch loss 0.008701, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.010662, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.022891, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.018218, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.014618, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.018700% currently going ot do 140 epochs
# At minibatch 56600, batch loss 0.017828, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.006434, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.015225, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.020905, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.040786, batch error rate 1.000000%
# After epoch 114: valid_err_rate: 0.019300% currently going ot do 140 epochs
# At minibatch 57100, batch loss 0.007644, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.017378, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.032281, batch error rate 1.000000%
# At minibatch 57400, batch loss 0.019510, batch error rate 0.000000%
# At minibatch 57500, batch loss 0.010551, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.019100% currently going ot do 140 epochs
# At minibatch 57600, batch loss 0.013564, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.012573, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.020513, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.017323, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.016816, batch error rate 0.000000%
# ...
# At minibatch 207800, batch loss 0.007142, batch error rate 0.000000%
# At minibatch 207900, batch loss 0.018039, batch error rate 0.000000%
# At minibatch 208000, batch loss 0.010593, batch error rate 0.000000%
# After epoch 416: valid_err_rate: 0.017800% currently going ot do 452 epochs
# At minibatch 208100, batch loss 0.006940, batch error rate 0.000000%
# At minibatch 208200, batch loss 0.019997, batch error rate 0.000000%
# At minibatch 208300, batch loss 0.009739, batch error rate 0.000000%
# At minibatch 208400, batch loss 0.005070, batch error rate 0.000000%
# At minibatch 208500, batch loss 0.013566, batch error rate 0.000000%
# After epoch 417: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 208600, batch loss 0.008465, batch error rate 0.000000%
# At minibatch 208700, batch loss 0.014119, batch error rate 0.000000%
# At minibatch 208800, batch loss 0.020859, batch error rate 0.000000%
# At minibatch 208900, batch loss 0.007718, batch error rate 0.000000%
# At minibatch 209000, batch loss 0.014126, batch error rate 0.000000%
# After epoch 418: valid_err_rate: 0.017900% currently going ot do 452 epochs
# At minibatch 209100, batch loss 0.023747, batch error rate 0.000000%
# At minibatch 209200, batch loss 0.015317, batch error rate 0.000000%
# At minibatch 209300, batch loss 0.017068, batch error rate 0.000000%
# At minibatch 209400, batch loss 0.007429, batch error rate 0.000000%
# At minibatch 209500, batch loss 0.005874, batch error rate 0.000000%
# After epoch 419: valid_err_rate: 0.018000% currently going ot do 452 epochs
# At minibatch 209600, batch loss 0.008572, batch error rate 0.000000%
# At minibatch 209700, batch loss 0.018275, batch error rate 0.000000%
# At minibatch 209800, batch loss 0.017110, batch error rate 0.000000%
# At minibatch 209900, batch loss 0.016600, batch error rate 0.000000%
# At minibatch 210000, batch loss 0.007743, batch error rate 0.000000%
# After epoch 420: valid_err_rate: 0.017700% currently going ot do 452 epochs
# At minibatch 210100, batch loss 0.021208, batch error rate 0.000000%
# At minibatch 210200, batch loss 0.017963, batch error rate 0.000000%
# At minibatch 210300, batch loss 0.018075, batch error rate 0.000000%
# At minibatch 210400, batch loss 0.013563, batch error rate 0.000000%
# At minibatch 210500, batch loss 0.020512, batch error rate 1.000000%
# After epoch 421: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 210600, batch loss 0.015472, batch error rate 0.000000%
# At minibatch 210700, batch loss 0.009128, batch error rate 0.000000%
# At minibatch 210800, batch loss 0.027815, batch error rate 1.000000%
# At minibatch 210900, batch loss 0.008768, batch error rate 0.000000%
# At minibatch 211000, batch loss 0.037078, batch error rate 1.000000%
# After epoch 422: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 211100, batch loss 0.013614, batch error rate 0.000000%
# At minibatch 211200, batch loss 0.015274, batch error rate 0.000000%
# At minibatch 211300, batch loss 0.013019, batch error rate 0.000000%
# At minibatch 211400, batch loss 0.019459, batch error rate 0.000000%
# At minibatch 211500, batch loss 0.024706, batch error rate 0.000000%
# After epoch 423: valid_err_rate: 0.017900% currently going ot do 452 epochs
# At minibatch 211600, batch loss 0.015962, batch error rate 0.000000%
# At minibatch 211700, batch loss 0.012306, batch error rate 0.000000%
# At minibatch 211800, batch loss 0.009485, batch error rate 0.000000%
# At minibatch 211900, batch loss 0.012089, batch error rate 0.000000%
# At minibatch 212000, batch loss 0.014912, batch error rate 0.000000%
# After epoch 424: valid_err_rate: 0.017600% currently going ot do 452 epochs
# At minibatch 212100, batch loss 0.020482, batch error rate 0.000000%
# At minibatch 212200, batch loss 0.013390, batch error rate 0.000000%
# At minibatch 212300, batch loss 0.011421, batch error rate 0.000000%
# At minibatch 212400, batch loss 0.015012, batch error rate 0.000000%
# At minibatch 212500, batch loss 0.022369, batch error rate 0.000000%
# After epoch 425: valid_err_rate: 0.017600% currently going ot do 452 epochs
# At minibatch 212600, batch loss 0.010103, batch error rate 0.000000%
# At minibatch 212700, batch loss 0.014554, batch error rate 0.000000%
# At minibatch 212800, batch loss 0.007027, batch error rate 0.000000%
# At minibatch 212900, batch loss 0.011795, batch error rate 0.000000%
# At minibatch 213000, batch loss 0.015427, batch error rate 0.000000%
# After epoch 426: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 213100, batch loss 0.018884, batch error rate 0.000000%
# At minibatch 213200, batch loss 0.011214, batch error rate 0.000000%
# At minibatch 213300, batch loss 0.012085, batch error rate 0.000000%
# At minibatch 213400, batch loss 0.019632, batch error rate 0.000000%
# At minibatch 213500, batch loss 0.016887, batch error rate 0.000000%
# After epoch 427: valid_err_rate: 0.018000% currently going ot do 452 epochs
# At minibatch 213600, batch loss 0.008732, batch error rate 0.000000%
# At minibatch 213700, batch loss 0.007539, batch error rate 0.000000%
# At minibatch 213800, batch loss 0.012571, batch error rate 0.000000%
# At minibatch 213900, batch loss 0.015418, batch error rate 0.000000%
# At minibatch 214000, batch loss 0.008185, batch error rate 0.000000%
# After epoch 428: valid_err_rate: 0.017800% currently going ot do 452 epochs
# At minibatch 214100, batch loss 0.011964, batch error rate 0.000000%
# At minibatch 214200, batch loss 0.004814, batch error rate 0.000000%
# At minibatch 214300, batch loss 0.015395, batch error rate 0.000000%
# At minibatch 214400, batch loss 0.011854, batch error rate 0.000000%
# At minibatch 214500, batch loss 0.014384, batch error rate 0.000000%
# After epoch 429: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 214600, batch loss 0.014882, batch error rate 0.000000%
# At minibatch 214700, batch loss 0.012255, batch error rate 0.000000%
# At minibatch 214800, batch loss 0.016092, batch error rate 0.000000%
# At minibatch 214900, batch loss 0.012576, batch error rate 0.000000%
# At minibatch 215000, batch loss 0.015745, batch error rate 0.000000%
# After epoch 430: valid_err_rate: 0.017900% currently going ot do 452 epochs
# At minibatch 215100, batch loss 0.017305, batch error rate 0.000000%
# At minibatch 215200, batch loss 0.017627, batch error rate 0.000000%
# At minibatch 215300, batch loss 0.021314, batch error rate 0.000000%
# At minibatch 215400, batch loss 0.018641, batch error rate 0.000000%
# At minibatch 215500, batch loss 0.007013, batch error rate 0.000000%
# After epoch 431: valid_err_rate: 0.018000% currently going ot do 452 epochs
# At minibatch 215600, batch loss 0.016925, batch error rate 0.000000%
# At minibatch 215700, batch loss 0.013436, batch error rate 0.000000%
# At minibatch 215800, batch loss 0.011911, batch error rate 0.000000%
# At minibatch 215900, batch loss 0.008802, batch error rate 0.000000%
# At minibatch 216000, batch loss 0.026944, batch error rate 0.000000%
# After epoch 432: valid_err_rate: 0.017800% currently going ot do 452 epochs
# At minibatch 216100, batch loss 0.015585, batch error rate 0.000000%
# At minibatch 216200, batch loss 0.017852, batch error rate 0.000000%
# At minibatch 216300, batch loss 0.010159, batch error rate 0.000000%
# At minibatch 216400, batch loss 0.019033, batch error rate 0.000000%
# At minibatch 216500, batch loss 0.012932, batch error rate 0.000000%
# After epoch 433: valid_err_rate: 0.017700% currently going ot do 452 epochs
# At minibatch 216600, batch loss 0.016937, batch error rate 0.000000%
# At minibatch 216700, batch loss 0.017312, batch error rate 0.000000%
# At minibatch 216800, batch loss 0.008652, batch error rate 0.000000%
# At minibatch 216900, batch loss 0.008475, batch error rate 0.000000%
# At minibatch 217000, batch loss 0.012195, batch error rate 0.000000%
# After epoch 434: valid_err_rate: 0.017600% currently going ot do 452 epochs
# At minibatch 217100, batch loss 0.010275, batch error rate 0.000000%
# At minibatch 217200, batch loss 0.012160, batch error rate 0.000000%
# At minibatch 217300, batch loss 0.017138, batch error rate 0.000000%
# At minibatch 217400, batch loss 0.008533, batch error rate 0.000000%
# At minibatch 217500, batch loss 0.014868, batch error rate 0.000000%
# After epoch 435: valid_err_rate: 0.017700% currently going ot do 452 epochs
# At minibatch 217600, batch loss 0.015987, batch error rate 0.000000%
# At minibatch 217700, batch loss 0.019376, batch error rate 0.000000%
# At minibatch 217800, batch loss 0.017148, batch error rate 0.000000%
# At minibatch 217900, batch loss 0.015563, batch error rate 0.000000%
# At minibatch 218000, batch loss 0.019094, batch error rate 0.000000%
# After epoch 436: valid_err_rate: 0.017400% currently going ot do 452 epochs
# At minibatch 218100, batch loss 0.009175, batch error rate 0.000000%
# At minibatch 218200, batch loss 0.016156, batch error rate 0.000000%
# At minibatch 218300, batch loss 0.017041, batch error rate 0.000000%
# At minibatch 218400, batch loss 0.015604, batch error rate 0.000000%
# At minibatch 218500, batch loss 0.012587, batch error rate 0.000000%
# After epoch 437: valid_err_rate: 0.017400% currently going ot do 452 epochs
# At minibatch 218600, batch loss 0.009859, batch error rate 0.000000%
# At minibatch 218700, batch loss 0.019536, batch error rate 0.000000%
# At minibatch 218800, batch loss 0.011408, batch error rate 0.000000%
# At minibatch 218900, batch loss 0.013361, batch error rate 0.000000%
# At minibatch 219000, batch loss 0.010007, batch error rate 0.000000%
# After epoch 438: valid_err_rate: 0.017600% currently going ot do 452 epochs
# At minibatch 219100, batch loss 0.008805, batch error rate 0.000000%
# At minibatch 219200, batch loss 0.013610, batch error rate 0.000000%
# At minibatch 219300, batch loss 0.016624, batch error rate 0.000000%
# At minibatch 219400, batch loss 0.010217, batch error rate 0.000000%
# At minibatch 219500, batch loss 0.010690, batch error rate 0.000000%
# After epoch 439: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 219600, batch loss 0.012574, batch error rate 0.000000%
# At minibatch 219700, batch loss 0.014448, batch error rate 0.000000%
# At minibatch 219800, batch loss 0.015079, batch error rate 0.000000%
# At minibatch 219900, batch loss 0.018392, batch error rate 0.000000%
# At minibatch 220000, batch loss 0.011520, batch error rate 0.000000%
# After epoch 440: valid_err_rate: 0.017400% currently going ot do 452 epochs
# At minibatch 220100, batch loss 0.015635, batch error rate 0.000000%
# At minibatch 220200, batch loss 0.012207, batch error rate 0.000000%
# At minibatch 220300, batch loss 0.011206, batch error rate 0.000000%
# At minibatch 220400, batch loss 0.011660, batch error rate 0.000000%
# At minibatch 220500, batch loss 0.011820, batch error rate 0.000000%
# After epoch 441: valid_err_rate: 0.018100% currently going ot do 452 epochs
# At minibatch 220600, batch loss 0.029179, batch error rate 0.000000%
# At minibatch 220700, batch loss 0.006115, batch error rate 0.000000%
# At minibatch 220800, batch loss 0.009594, batch error rate 0.000000%
# At minibatch 220900, batch loss 0.012267, batch error rate 0.000000%
# At minibatch 221000, batch loss 0.012204, batch error rate 0.000000%
# After epoch 442: valid_err_rate: 0.018100% currently going ot do 452 epochs
# At minibatch 221100, batch loss 0.017968, batch error rate 0.000000%
# At minibatch 221200, batch loss 0.014152, batch error rate 0.000000%
# At minibatch 221300, batch loss 0.007284, batch error rate 0.000000%
# At minibatch 221400, batch loss 0.023618, batch error rate 0.000000%
# At minibatch 221500, batch loss 0.017386, batch error rate 0.000000%
# After epoch 443: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 221600, batch loss 0.007556, batch error rate 0.000000%
# At minibatch 221700, batch loss 0.010079, batch error rate 0.000000%
# At minibatch 221800, batch loss 0.020627, batch error rate 0.000000%
# At minibatch 221900, batch loss 0.013093, batch error rate 0.000000%
# At minibatch 222000, batch loss 0.004996, batch error rate 0.000000%
# After epoch 444: valid_err_rate: 0.018000% currently going ot do 452 epochs
# At minibatch 222100, batch loss 0.017427, batch error rate 0.000000%
# At minibatch 222200, batch loss 0.021800, batch error rate 0.000000%
# At minibatch 222300, batch loss 0.012164, batch error rate 0.000000%
# At minibatch 222400, batch loss 0.009739, batch error rate 0.000000%
# At minibatch 222500, batch loss 0.010791, batch error rate 0.000000%
# After epoch 445: valid_err_rate: 0.017800% currently going ot do 452 epochs
# At minibatch 222600, batch loss 0.017147, batch error rate 0.000000%
# At minibatch 222700, batch loss 0.012772, batch error rate 0.000000%
# At minibatch 222800, batch loss 0.013890, batch error rate 0.000000%
# At minibatch 222900, batch loss 0.009796, batch error rate 0.000000%
# At minibatch 223000, batch loss 0.019862, batch error rate 0.000000%
# After epoch 446: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 223100, batch loss 0.012594, batch error rate 0.000000%
# At minibatch 223200, batch loss 0.018291, batch error rate 0.000000%
# At minibatch 223300, batch loss 0.016047, batch error rate 0.000000%
# At minibatch 223400, batch loss 0.010258, batch error rate 0.000000%
# At minibatch 223500, batch loss 0.006059, batch error rate 0.000000%
# After epoch 447: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 223600, batch loss 0.011578, batch error rate 0.000000%
# At minibatch 223700, batch loss 0.013382, batch error rate 0.000000%
# At minibatch 223800, batch loss 0.024495, batch error rate 1.000000%
# At minibatch 223900, batch loss 0.011557, batch error rate 0.000000%
# At minibatch 224000, batch loss 0.009072, batch error rate 0.000000%
# After epoch 448: valid_err_rate: 0.017800% currently going ot do 452 epochs
# At minibatch 224100, batch loss 0.017473, batch error rate 0.000000%
# At minibatch 224200, batch loss 0.039545, batch error rate 1.000000%
# At minibatch 224300, batch loss 0.013836, batch error rate 0.000000%
# At minibatch 224400, batch loss 0.015014, batch error rate 0.000000%
# At minibatch 224500, batch loss 0.014777, batch error rate 0.000000%
# After epoch 449: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 224600, batch loss 0.019499, batch error rate 1.000000%
# At minibatch 224700, batch loss 0.015841, batch error rate 0.000000%
# At minibatch 224800, batch loss 0.015031, batch error rate 0.000000%
# At minibatch 224900, batch loss 0.022501, batch error rate 0.000000%
# At minibatch 225000, batch loss 0.011031, batch error rate 0.000000%
# After epoch 450: valid_err_rate: 0.017500% currently going ot do 452 epochs
# At minibatch 225100, batch loss 0.008596, batch error rate 0.000000%
# At minibatch 225200, batch loss 0.009942, batch error rate 0.000000%
# At minibatch 225300, batch loss 0.011406, batch error rate 0.000000%
# At minibatch 225400, batch loss 0.018236, batch error rate 0.000000%
# At minibatch 225500, batch loss 0.013710, batch error rate 0.000000%
# After epoch 451: valid_err_rate: 0.017900% currently going ot do 452 epochs
# At minibatch 225600, batch loss 0.018409, batch error rate 0.000000%
# At minibatch 225700, batch loss 0.010716, batch error rate 0.000000%
# At minibatch 225800, batch loss 0.008907, batch error rate 0.000000%
# At minibatch 225900, batch loss 0.012212, batch error rate 0.000000%
# At minibatch 226000, batch loss 0.007538, batch error rate 0.000000%
# After epoch 452: valid_err_rate: 0.017300% currently going ot do 452 epochs
# At minibatch 226100, batch loss 0.016053, batch error rate 0.000000%
# At minibatch 226200, batch loss 0.021419, batch error rate 0.000000%
# At minibatch 226300, batch loss 0.011368, batch error rate 0.000000%
# At minibatch 226400, batch loss 0.013029, batch error rate 0.000000%
# At minibatch 226500, batch loss 0.015941, batch error rate 0.000000%
# After epoch 453: valid_err_rate: 0.017200% currently going ot do 452 epochs
# Finished with 453 epochs (minibatch 226500), with best valid error rate 0.017000

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0175

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %%
weight_init = IsotropicGaussian(std=0.05, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 800, weight_init = weight_init),
        ReLULayer(),
        AffineLayer(800, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlg1(rate = 1e-3),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg2())
# Out:
# Network configuration:
# W(800, 784), b(800, 1), W(800, 800), b(800, 1), W(800, 800), b(800, 1), W(10, 800), b(10, 1)
# At minibatch 100, batch loss 1.727881, batch error rate 58.000000%
# At minibatch 200, batch loss 1.153083, batch error rate 42.000000%
# At minibatch 300, batch loss 0.934405, batch error rate 25.000000%
# At minibatch 400, batch loss 0.658457, batch error rate 26.000000%
# At minibatch 500, batch loss 0.731867, batch error rate 32.000000%
# After epoch 1: valid_err_rate: 0.135600% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.763237, batch error rate 29.000000%
# At minibatch 700, batch loss 0.432947, batch error rate 11.000000%
# At minibatch 800, batch loss 0.546115, batch error rate 16.000000%
# At minibatch 900, batch loss 0.518793, batch error rate 15.000000%
# At minibatch 1000, batch loss 0.418123, batch error rate 13.000000%
# After epoch 2: valid_err_rate: 0.092200% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.275672, batch error rate 6.000000%
# At minibatch 1200, batch loss 0.564904, batch error rate 14.000000%
# At minibatch 1300, batch loss 0.367251, batch error rate 11.000000%
# At minibatch 1400, batch loss 0.559853, batch error rate 19.000000%
# At minibatch 1500, batch loss 0.461692, batch error rate 11.000000%
# After epoch 3: valid_err_rate: 0.083600% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.444919, batch error rate 16.000000%
# At minibatch 1700, batch loss 0.339656, batch error rate 12.000000%
# At minibatch 1800, batch loss 0.287365, batch error rate 8.000000%
# At minibatch 1900, batch loss 0.414693, batch error rate 11.000000%
# At minibatch 2000, batch loss 0.300598, batch error rate 8.000000%
# After epoch 4: valid_err_rate: 0.069500% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.415024, batch error rate 14.000000%
# At minibatch 2200, batch loss 0.201137, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.238879, batch error rate 5.000000%
# At minibatch 2400, batch loss 0.478154, batch error rate 14.000000%
# At minibatch 2500, batch loss 0.300279, batch error rate 11.000000%
# After epoch 5: valid_err_rate: 0.066100% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.262467, batch error rate 8.000000%
# At minibatch 2700, batch loss 0.307776, batch error rate 8.000000%
# At minibatch 2800, batch loss 0.308554, batch error rate 10.000000%
# At minibatch 2900, batch loss 0.301410, batch error rate 9.000000%
# At minibatch 3000, batch loss 0.209045, batch error rate 6.000000%
# After epoch 6: valid_err_rate: 0.056600% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.362680, batch error rate 11.000000%
# At minibatch 3200, batch loss 0.309952, batch error rate 8.000000%
# At minibatch 3300, batch loss 0.244897, batch error rate 8.000000%
# At minibatch 3400, batch loss 0.147998, batch error rate 4.000000%
# At minibatch 3500, batch loss 0.173210, batch error rate 7.000000%
# After epoch 7: valid_err_rate: 0.051100% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.319539, batch error rate 9.000000%
# At minibatch 3700, batch loss 0.171792, batch error rate 5.000000%
# At minibatch 3800, batch loss 0.250547, batch error rate 7.000000%
# At minibatch 3900, batch loss 0.486154, batch error rate 14.000000%
# At minibatch 4000, batch loss 0.142017, batch error rate 4.000000%
# After epoch 8: valid_err_rate: 0.049200% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.247440, batch error rate 9.000000%
# At minibatch 4200, batch loss 0.146787, batch error rate 4.000000%
# At minibatch 4300, batch loss 0.184147, batch error rate 5.000000%
# At minibatch 4400, batch loss 0.126545, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.121687, batch error rate 5.000000%
# After epoch 9: valid_err_rate: 0.045600% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.214733, batch error rate 6.000000%
# At minibatch 4700, batch loss 0.225527, batch error rate 5.000000%
# At minibatch 4800, batch loss 0.228239, batch error rate 8.000000%
# At minibatch 4900, batch loss 0.279335, batch error rate 8.000000%
# At minibatch 5000, batch loss 0.185207, batch error rate 5.000000%
# After epoch 10: valid_err_rate: 0.048200% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.175851, batch error rate 5.000000%
# At minibatch 5200, batch loss 0.223420, batch error rate 8.000000%
# At minibatch 5300, batch loss 0.226819, batch error rate 7.000000%
# At minibatch 5400, batch loss 0.158493, batch error rate 6.000000%
# At minibatch 5500, batch loss 0.239344, batch error rate 8.000000%
# After epoch 11: valid_err_rate: 0.043400% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.187810, batch error rate 5.000000%
# At minibatch 5700, batch loss 0.202923, batch error rate 5.000000%
# At minibatch 5800, batch loss 0.212177, batch error rate 6.000000%
# At minibatch 5900, batch loss 0.242044, batch error rate 9.000000%
# At minibatch 6000, batch loss 0.202482, batch error rate 6.000000%
# After epoch 12: valid_err_rate: 0.038000% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.158379, batch error rate 4.000000%
# At minibatch 6200, batch loss 0.283198, batch error rate 9.000000%
# At minibatch 6300, batch loss 0.139491, batch error rate 4.000000%
# At minibatch 6400, batch loss 0.130055, batch error rate 4.000000%
# At minibatch 6500, batch loss 0.264894, batch error rate 9.000000%
# After epoch 13: valid_err_rate: 0.038100% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.168585, batch error rate 4.000000%
# At minibatch 6700, batch loss 0.222951, batch error rate 6.000000%
# At minibatch 6800, batch loss 0.129853, batch error rate 4.000000%
# At minibatch 6900, batch loss 0.119133, batch error rate 4.000000%
# At minibatch 7000, batch loss 0.200637, batch error rate 7.000000%
# After epoch 14: valid_err_rate: 0.036600% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.090161, batch error rate 1.000000%
# At minibatch 7200, batch loss 0.108661, batch error rate 3.000000%
# At minibatch 7300, batch loss 0.177161, batch error rate 6.000000%
# At minibatch 7400, batch loss 0.147190, batch error rate 3.000000%
# At minibatch 7500, batch loss 0.136186, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.034500% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.126496, batch error rate 3.000000%
# At minibatch 7700, batch loss 0.146703, batch error rate 4.000000%
# At minibatch 7800, batch loss 0.188942, batch error rate 6.000000%
# At minibatch 7900, batch loss 0.122263, batch error rate 4.000000%
# At minibatch 8000, batch loss 0.072121, batch error rate 1.000000%
# After epoch 16: valid_err_rate: 0.034600% currently going ot do 23 epochs
# At minibatch 8100, batch loss 0.151038, batch error rate 7.000000%
# At minibatch 8200, batch loss 0.269027, batch error rate 6.000000%
# At minibatch 8300, batch loss 0.195813, batch error rate 6.000000%
# At minibatch 8400, batch loss 0.157442, batch error rate 4.000000%
# At minibatch 8500, batch loss 0.209488, batch error rate 8.000000%
# After epoch 17: valid_err_rate: 0.035400% currently going ot do 23 epochs
# At minibatch 8600, batch loss 0.154178, batch error rate 4.000000%
# At minibatch 8700, batch loss 0.124294, batch error rate 3.000000%
# At minibatch 8800, batch loss 0.214398, batch error rate 4.000000%
# At minibatch 8900, batch loss 0.226358, batch error rate 8.000000%
# At minibatch 9000, batch loss 0.176085, batch error rate 5.000000%
# After epoch 18: valid_err_rate: 0.033300% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.091430, batch error rate 4.000000%
# At minibatch 9200, batch loss 0.120196, batch error rate 5.000000%
# At minibatch 9300, batch loss 0.084944, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.122554, batch error rate 5.000000%
# At minibatch 9500, batch loss 0.180221, batch error rate 6.000000%
# After epoch 19: valid_err_rate: 0.037300% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.076247, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.199541, batch error rate 6.000000%
# At minibatch 9800, batch loss 0.050154, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.109991, batch error rate 3.000000%
# At minibatch 10000, batch loss 0.208967, batch error rate 6.000000%
# After epoch 20: valid_err_rate: 0.034000% currently going ot do 28 epochs
# At minibatch 10100, batch loss 0.137985, batch error rate 5.000000%
# At minibatch 10200, batch loss 0.142278, batch error rate 4.000000%
# At minibatch 10300, batch loss 0.092864, batch error rate 3.000000%
# At minibatch 10400, batch loss 0.103206, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.211913, batch error rate 5.000000%
# After epoch 21: valid_err_rate: 0.030300% currently going ot do 32 epochs
# At minibatch 10600, batch loss 0.089091, batch error rate 4.000000%
# At minibatch 10700, batch loss 0.188582, batch error rate 6.000000%
# At minibatch 10800, batch loss 0.113091, batch error rate 3.000000%
# At minibatch 10900, batch loss 0.250950, batch error rate 6.000000%
# At minibatch 11000, batch loss 0.181306, batch error rate 4.000000%
# After epoch 22: valid_err_rate: 0.030400% currently going ot do 32 epochs
# At minibatch 11100, batch loss 0.108876, batch error rate 5.000000%
# At minibatch 11200, batch loss 0.084988, batch error rate 2.000000%
# At minibatch 11300, batch loss 0.208788, batch error rate 4.000000%
# At minibatch 11400, batch loss 0.103475, batch error rate 3.000000%
# At minibatch 11500, batch loss 0.105448, batch error rate 3.000000%
# After epoch 23: valid_err_rate: 0.031400% currently going ot do 32 epochs
# At minibatch 11600, batch loss 0.105098, batch error rate 4.000000%
# At minibatch 11700, batch loss 0.079272, batch error rate 3.000000%
# At minibatch 11800, batch loss 0.135623, batch error rate 5.000000%
# At minibatch 11900, batch loss 0.102614, batch error rate 2.000000%
# At minibatch 12000, batch loss 0.096291, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.029300% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.129341, batch error rate 2.000000%
# At minibatch 12200, batch loss 0.069001, batch error rate 2.000000%
# At minibatch 12300, batch loss 0.152053, batch error rate 4.000000%
# At minibatch 12400, batch loss 0.110609, batch error rate 2.000000%
# At minibatch 12500, batch loss 0.137281, batch error rate 3.000000%
# After epoch 25: valid_err_rate: 0.030500% currently going ot do 37 epochs
# At minibatch 12600, batch loss 0.158469, batch error rate 2.000000%
# At minibatch 12700, batch loss 0.166290, batch error rate 6.000000%
# At minibatch 12800, batch loss 0.072882, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.141495, batch error rate 4.000000%
# At minibatch 13000, batch loss 0.178064, batch error rate 7.000000%
# After epoch 26: valid_err_rate: 0.030300% currently going ot do 37 epochs
# At minibatch 13100, batch loss 0.136472, batch error rate 2.000000%
# At minibatch 13200, batch loss 0.081556, batch error rate 1.000000%
# At minibatch 13300, batch loss 0.172198, batch error rate 4.000000%
# At minibatch 13400, batch loss 0.061137, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.116440, batch error rate 3.000000%
# After epoch 27: valid_err_rate: 0.028200% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.112742, batch error rate 4.000000%
# At minibatch 13700, batch loss 0.082213, batch error rate 2.000000%
# At minibatch 13800, batch loss 0.071794, batch error rate 1.000000%
# At minibatch 13900, batch loss 0.099030, batch error rate 4.000000%
# At minibatch 14000, batch loss 0.104077, batch error rate 3.000000%
# After epoch 28: valid_err_rate: 0.028700% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.183010, batch error rate 5.000000%
# At minibatch 14200, batch loss 0.185326, batch error rate 5.000000%
# At minibatch 14300, batch loss 0.111153, batch error rate 3.000000%
# At minibatch 14400, batch loss 0.183383, batch error rate 6.000000%
# At minibatch 14500, batch loss 0.081874, batch error rate 3.000000%
# After epoch 29: valid_err_rate: 0.031300% currently going ot do 41 epochs
# At minibatch 14600, batch loss 0.086552, batch error rate 3.000000%
# At minibatch 14700, batch loss 0.059702, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.141246, batch error rate 3.000000%
# At minibatch 14900, batch loss 0.074004, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.094750, batch error rate 1.000000%
# After epoch 30: valid_err_rate: 0.027400% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.106846, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.130662, batch error rate 6.000000%
# At minibatch 15300, batch loss 0.124584, batch error rate 2.000000%
# At minibatch 15400, batch loss 0.114153, batch error rate 3.000000%
# At minibatch 15500, batch loss 0.050668, batch error rate 1.000000%
# After epoch 31: valid_err_rate: 0.030500% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.119591, batch error rate 2.000000%
# At minibatch 15700, batch loss 0.169356, batch error rate 5.000000%
# At minibatch 15800, batch loss 0.127207, batch error rate 3.000000%
# At minibatch 15900, batch loss 0.193148, batch error rate 6.000000%
# At minibatch 16000, batch loss 0.156632, batch error rate 7.000000%
# After epoch 32: valid_err_rate: 0.027800% currently going ot do 46 epochs
# At minibatch 16100, batch loss 0.158993, batch error rate 4.000000%
# At minibatch 16200, batch loss 0.096682, batch error rate 3.000000%
# At minibatch 16300, batch loss 0.212030, batch error rate 4.000000%
# At minibatch 16400, batch loss 0.123194, batch error rate 5.000000%
# At minibatch 16500, batch loss 0.070256, batch error rate 3.000000%
# After epoch 33: valid_err_rate: 0.026300% currently going ot do 50 epochs
# At minibatch 16600, batch loss 0.158509, batch error rate 4.000000%
# At minibatch 16700, batch loss 0.137786, batch error rate 5.000000%
# At minibatch 16800, batch loss 0.143894, batch error rate 3.000000%
# At minibatch 16900, batch loss 0.119868, batch error rate 3.000000%
# At minibatch 17000, batch loss 0.101841, batch error rate 2.000000%
# After epoch 34: valid_err_rate: 0.026900% currently going ot do 50 epochs
# At minibatch 17100, batch loss 0.073957, batch error rate 3.000000%
# At minibatch 17200, batch loss 0.174621, batch error rate 5.000000%
# At minibatch 17300, batch loss 0.121607, batch error rate 4.000000%
# At minibatch 17400, batch loss 0.100972, batch error rate 3.000000%
# At minibatch 17500, batch loss 0.164132, batch error rate 6.000000%
# After epoch 35: valid_err_rate: 0.027400% currently going ot do 50 epochs
# At minibatch 17600, batch loss 0.259460, batch error rate 7.000000%
# At minibatch 17700, batch loss 0.107781, batch error rate 4.000000%
# At minibatch 17800, batch loss 0.135656, batch error rate 5.000000%
# At minibatch 17900, batch loss 0.116203, batch error rate 5.000000%
# At minibatch 18000, batch loss 0.109211, batch error rate 4.000000%
# After epoch 36: valid_err_rate: 0.028200% currently going ot do 50 epochs
# At minibatch 18100, batch loss 0.103394, batch error rate 3.000000%
# At minibatch 18200, batch loss 0.094942, batch error rate 3.000000%
# At minibatch 18300, batch loss 0.078453, batch error rate 2.000000%
# At minibatch 18400, batch loss 0.149439, batch error rate 6.000000%
# At minibatch 18500, batch loss 0.161776, batch error rate 5.000000%
# After epoch 37: valid_err_rate: 0.023700% currently going ot do 56 epochs
# At minibatch 18600, batch loss 0.014900, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.074776, batch error rate 3.000000%
# At minibatch 18800, batch loss 0.073238, batch error rate 1.000000%
# At minibatch 18900, batch loss 0.175322, batch error rate 4.000000%
# At minibatch 19000, batch loss 0.088423, batch error rate 4.000000%
# After epoch 38: valid_err_rate: 0.028900% currently going ot do 56 epochs
# At minibatch 19100, batch loss 0.075875, batch error rate 1.000000%
# At minibatch 19200, batch loss 0.058230, batch error rate 2.000000%
# At minibatch 19300, batch loss 0.077255, batch error rate 2.000000%
# At minibatch 19400, batch loss 0.154266, batch error rate 2.000000%
# At minibatch 19500, batch loss 0.191209, batch error rate 4.000000%
# After epoch 39: valid_err_rate: 0.028100% currently going ot do 56 epochs
# At minibatch 19600, batch loss 0.136546, batch error rate 5.000000%
# At minibatch 19700, batch loss 0.128674, batch error rate 4.000000%
# At minibatch 19800, batch loss 0.093314, batch error rate 2.000000%
# At minibatch 19900, batch loss 0.110211, batch error rate 3.000000%
# At minibatch 20000, batch loss 0.065305, batch error rate 2.000000%
# After epoch 40: valid_err_rate: 0.025100% currently going ot do 56 epochs
# At minibatch 20100, batch loss 0.090028, batch error rate 2.000000%
# At minibatch 20200, batch loss 0.140439, batch error rate 2.000000%
# At minibatch 20300, batch loss 0.075172, batch error rate 2.000000%
# At minibatch 20400, batch loss 0.150845, batch error rate 2.000000%
# At minibatch 20500, batch loss 0.111124, batch error rate 3.000000%
# After epoch 41: valid_err_rate: 0.026700% currently going ot do 56 epochs
# At minibatch 20600, batch loss 0.136830, batch error rate 3.000000%
# At minibatch 20700, batch loss 0.174653, batch error rate 5.000000%
# At minibatch 20800, batch loss 0.174268, batch error rate 5.000000%
# At minibatch 20900, batch loss 0.078869, batch error rate 2.000000%
# At minibatch 21000, batch loss 0.153722, batch error rate 3.000000%
# After epoch 42: valid_err_rate: 0.028800% currently going ot do 56 epochs
# At minibatch 21100, batch loss 0.109397, batch error rate 2.000000%
# At minibatch 21200, batch loss 0.146589, batch error rate 5.000000%
# At minibatch 21300, batch loss 0.073900, batch error rate 1.000000%
# At minibatch 21400, batch loss 0.114072, batch error rate 3.000000%
# At minibatch 21500, batch loss 0.123432, batch error rate 4.000000%
# After epoch 43: valid_err_rate: 0.025800% currently going ot do 56 epochs
# At minibatch 21600, batch loss 0.176262, batch error rate 6.000000%
# At minibatch 21700, batch loss 0.078628, batch error rate 4.000000%
# At minibatch 21800, batch loss 0.051647, batch error rate 2.000000%
# At minibatch 21900, batch loss 0.040090, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.119955, batch error rate 3.000000%
# After epoch 44: valid_err_rate: 0.027300% currently going ot do 56 epochs
# At minibatch 22100, batch loss 0.113317, batch error rate 3.000000%
# At minibatch 22200, batch loss 0.088316, batch error rate 3.000000%
# At minibatch 22300, batch loss 0.118747, batch error rate 2.000000%
# At minibatch 22400, batch loss 0.047607, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.077058, batch error rate 2.000000%
# After epoch 45: valid_err_rate: 0.026400% currently going ot do 56 epochs
# At minibatch 22600, batch loss 0.107603, batch error rate 2.000000%
# At minibatch 22700, batch loss 0.057987, batch error rate 2.000000%
# At minibatch 22800, batch loss 0.132572, batch error rate 5.000000%
# At minibatch 22900, batch loss 0.075063, batch error rate 3.000000%
# At minibatch 23000, batch loss 0.117580, batch error rate 5.000000%
# After epoch 46: valid_err_rate: 0.023800% currently going ot do 56 epochs
# At minibatch 23100, batch loss 0.079867, batch error rate 2.000000%
# At minibatch 23200, batch loss 0.113615, batch error rate 3.000000%
# At minibatch 23300, batch loss 0.146121, batch error rate 5.000000%
# At minibatch 23400, batch loss 0.038316, batch error rate 1.000000%
# At minibatch 23500, batch loss 0.040810, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.027600% currently going ot do 56 epochs
# At minibatch 23600, batch loss 0.135716, batch error rate 4.000000%
# At minibatch 23700, batch loss 0.092308, batch error rate 3.000000%
# At minibatch 23800, batch loss 0.055518, batch error rate 1.000000%
# At minibatch 23900, batch loss 0.084126, batch error rate 2.000000%
# At minibatch 24000, batch loss 0.106008, batch error rate 3.000000%
# After epoch 48: valid_err_rate: 0.027500% currently going ot do 56 epochs
# At minibatch 24100, batch loss 0.064492, batch error rate 1.000000%
# At minibatch 24200, batch loss 0.071375, batch error rate 1.000000%
# At minibatch 24300, batch loss 0.062029, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.062546, batch error rate 2.000000%
# At minibatch 24500, batch loss 0.141609, batch error rate 6.000000%
# After epoch 49: valid_err_rate: 0.025300% currently going ot do 56 epochs
# At minibatch 24600, batch loss 0.114135, batch error rate 5.000000%
# At minibatch 24700, batch loss 0.027502, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.083433, batch error rate 2.000000%
# At minibatch 24900, batch loss 0.106718, batch error rate 5.000000%
# At minibatch 25000, batch loss 0.069848, batch error rate 2.000000%
# After epoch 50: valid_err_rate: 0.024100% currently going ot do 56 epochs
# At minibatch 25100, batch loss 0.125423, batch error rate 4.000000%
# At minibatch 25200, batch loss 0.141866, batch error rate 5.000000%
# At minibatch 25300, batch loss 0.243639, batch error rate 8.000000%
# At minibatch 25400, batch loss 0.194866, batch error rate 8.000000%
# At minibatch 25500, batch loss 0.070971, batch error rate 2.000000%
# After epoch 51: valid_err_rate: 0.026400% currently going ot do 56 epochs
# At minibatch 25600, batch loss 0.084871, batch error rate 2.000000%
# At minibatch 25700, batch loss 0.092236, batch error rate 2.000000%
# At minibatch 25800, batch loss 0.113894, batch error rate 4.000000%
# At minibatch 25900, batch loss 0.110059, batch error rate 2.000000%
# At minibatch 26000, batch loss 0.147305, batch error rate 2.000000%
# After epoch 52: valid_err_rate: 0.026900% currently going ot do 56 epochs
# At minibatch 26100, batch loss 0.067577, batch error rate 2.000000%
# At minibatch 26200, batch loss 0.161959, batch error rate 3.000000%
# At minibatch 26300, batch loss 0.091951, batch error rate 3.000000%
# At minibatch 26400, batch loss 0.078678, batch error rate 3.000000%
# At minibatch 26500, batch loss 0.144881, batch error rate 6.000000%
# After epoch 53: valid_err_rate: 0.030300% currently going ot do 56 epochs
# At minibatch 26600, batch loss 0.061004, batch error rate 1.000000%
# At minibatch 26700, batch loss 0.092821, batch error rate 4.000000%
# At minibatch 26800, batch loss 0.092977, batch error rate 2.000000%
# At minibatch 26900, batch loss 0.053674, batch error rate 1.000000%
# At minibatch 27000, batch loss 0.042014, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.025700% currently going ot do 56 epochs
# At minibatch 27100, batch loss 0.103222, batch error rate 3.000000%
# At minibatch 27200, batch loss 0.113070, batch error rate 4.000000%
# At minibatch 27300, batch loss 0.097110, batch error rate 4.000000%
# At minibatch 27400, batch loss 0.031439, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.048805, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.024700% currently going ot do 56 epochs
# At minibatch 27600, batch loss 0.051820, batch error rate 1.000000%
# At minibatch 27700, batch loss 0.108857, batch error rate 2.000000%
# At minibatch 27800, batch loss 0.076984, batch error rate 2.000000%
# At minibatch 27900, batch loss 0.052727, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.074042, batch error rate 3.000000%
# After epoch 56: valid_err_rate: 0.026100% currently going ot do 56 epochs
# At minibatch 28100, batch loss 0.212343, batch error rate 6.000000%
# At minibatch 28200, batch loss 0.122752, batch error rate 4.000000%
# At minibatch 28300, batch loss 0.062021, batch error rate 1.000000%
# At minibatch 28400, batch loss 0.043789, batch error rate 1.000000%
# At minibatch 28500, batch loss 0.043515, batch error rate 2.000000%
# After epoch 57: valid_err_rate: 0.024000% currently going ot do 56 epochs
# Finished with 57 epochs (minibatch 28500), with best valid error rate 0.023700

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.

# %%
#old dropout version:

class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return [] 
    
#     def revert_dropout(self, fp_context):
#         return

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, dropout=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)
        
#         self.dropout = dropout
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X, with_dropout = False):
        if with_dropout and self.dropout:
            choice = (np.random.rand(self.b.shape[0]) < self.dropout)
            W_dropout = self.W[choice]
            self.W[choice] = 0.0
            #b_dropout = self.b[choice]
            #self.b[choice] = 0.0
            #fprop_context = dict(X=X, W_dropout=W_dropout, b_dropout=b_dropout, choice=choice)
            fprop_context = dict(X=X, W_dropout=W_dropout, choice=choice)
        else:
            fprop_context = dict(X=X)
            
        Y = np.dot(self.W, X) + self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
    def revert_dropout(self, fp_context):
        if self.dropout:
            choice = fp_context['choice']
            W_dropout = fp_context['W_dropout']
            #b_dropout = fp_context['b_dropout']
            self.W[choice] = W_dropout
            #self.b[choice] = b_dropout
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X, with_dropout = False):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X, with_dropout = False):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y, with_dropout = False):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
#             if len(layer.parameter_names) > 0 and layer.parameter_names[0] == 'W':
#                 print "W before fprop"
#                 print layer.parameters[0]
                
            #if len(layer.parameter_names) > 0 and layer.parameter_names[0] == 'W':
            X, fp_context = layer.fprop(X, with_dropout = True)
            #else:
            #    X, fp_context = layer.fprop(X)
#             if len(layer.parameter_names) > 0 and layer.parameter_names[0] == 'W':
#                 print "W after fprop"
#                 print layer.parameters[0]
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
#             if len(layer.parameter_names) > 0 and layer.parameter_names[0] == 'W':
#                 print "During backprop"
#                 print layer.parameters[0]
#                 print dLdP
#                 print dLdX
            #if layer != self.layers[-2]:
            layer.revert_dropout(fp_context)
#             if len(layer.parameter_names) > 0 and layer.parameter_names[0] == 'W':
#                 print "After backprop"
#                 print layer.parameters[0]
        return L, O, dLdP
