# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 0.949864, train error rate 44.666667%
# At iteration 1000, loss 0.052694, train error rate 2.000000%
# At iteration 2000, loss 0.043831, train error rate 1.333333%
# At iteration 3000, loss 0.041411, train error rate 1.333333%
# At iteration 4000, loss 0.040305, train error rate 1.333333%
# At iteration 5000, loss 0.039611, train error rate 1.333333%
# At iteration 6000, loss 0.039070, train error rate 1.333333%
# At iteration 7000, loss 0.038593, train error rate 1.333333%
# At iteration 8000, loss 0.038146, train error rate 1.333333%
# At iteration 9000, loss 0.037714, train error rate 1.333333%
# At iteration 10000, loss 0.037293, train error rate 1.333333%
# At iteration 11000, loss 0.036878, train error rate 1.333333%
# At iteration 12000, loss 0.036464, train error rate 1.333333%
# At iteration 13000, loss 0.036049, train error rate 1.333333%
# At iteration 14000, loss 0.035627, train error rate 1.333333%
# At iteration 15000, loss 0.035195, train error rate 1.333333%
# At iteration 16000, loss 0.034750, train error rate 1.333333%
# At iteration 17000, loss 0.034289, train error rate 1.333333%
# At iteration 18000, loss 0.033808, train error rate 1.333333%
# At iteration 19000, loss 0.033301, train error rate 1.333333%
# At iteration 20000, loss 0.032758, train error rate 1.333333%
# At iteration 21000, loss 0.032171, train error rate 1.333333%
# At iteration 22000, loss 0.031529, train error rate 1.333333%
# At iteration 23000, loss 0.030826, train error rate 1.333333%
# At iteration 24000, loss 0.030060, train error rate 1.333333%
# At iteration 25000, loss 0.029235, train error rate 1.333333%
# At iteration 26000, loss 0.028356, train error rate 1.333333%
# At iteration 27000, loss 0.027433, train error rate 1.333333%
# At iteration 28000, loss 0.026482, train error rate 1.333333%
# At iteration 29000, loss 0.025515, train error rate 1.333333%
# At iteration 30000, loss 0.024542, train error rate 1.333333%
# At iteration 31000, loss 0.023565, train error rate 1.333333%
# At iteration 32000, loss 0.022579, train error rate 1.333333%
# At iteration 33000, loss 0.021579, train error rate 1.333333%
# At iteration 34000, loss 0.020559, train error rate 1.333333%
# At iteration 35000, loss 0.019513, train error rate 1.333333%
# At iteration 36000, loss 0.018442, train error rate 1.333333%
# At iteration 37000, loss 0.017353, train error rate 1.333333%
# At iteration 38000, loss 0.016260, train error rate 0.666667%
# At iteration 39000, loss 0.015179, train error rate 0.000000%
# At iteration 40000, loss 0.014126, train error rate 0.000000%
# At iteration 41000, loss 0.013113, train error rate 0.000000%
# At iteration 42000, loss 0.012151, train error rate 0.000000%
# At iteration 43000, loss 0.011247, train error rate 0.000000%
# At iteration 44000, loss 0.010403, train error rate 0.000000%
# At iteration 45000, loss 0.009624, train error rate 0.000000%
# At iteration 46000, loss 0.008908, train error rate 0.000000%
# At iteration 47000, loss 0.008254, train error rate 0.000000%
# At iteration 48000, loss 0.007659, train error rate 0.000000%
# At iteration 49000, loss 0.007118, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def print_stats(train_loss, train_errors, validation_errors):
    subplot(2,1,1)
    train_loss = np.array(train_loss)
    semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
    legend()

    subplot(2,1,2)
    train_errors = np.array(train_errors)
    plot(train_errors[:,0], train_errors[:,1], label='batch train error rate')
    validation_errors = np.array(validation_errors)
    plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
    ylim(0,0.2)
    legend()

def alpha_alg_exp(_alpha, _i, e, initial = 5e-2, rate = 0.995):
    return (initial * np.power(rate, e))

def SGD(net, train_stream, validation_stream, test_stream,
       print_debug = True,
       alpha_alg = alpha_alg_exp,
       alpha_alg_params = {}):
    
    print "Network configuration: "
    print ", ".join([ "%s%s" %(N, P.shape) for P, N in zip(net.parameters, net.parameter_names) ])
    
    i=0
    e=0
    
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    alpha = None
    
    train_errors = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_errors.append((i,err_rate))
                if i % 100 == 0 and print_debug:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        pass
                        #G -= 0.001 * P
                    

                    #alpha = 5e-2 * np.power(0.995, e)
                    alpha = alpha_alg(alpha, i, e, **alpha_alg_params)
                    
                    epsilon = 1. - 3. / (5. + i)
                    
                    V = epsilon * V - alpha * G
                    
                    #P += -5e-2 * G
                    P += V
                    
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            if print_debug or (e % 20 == 1):
                print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                    e, val_error_rate, number_of_epochs)
        print "Finished with %d epochs (minibatch %d), with best valid error rate %f" % (e, i, best_valid_error_rate)
        print_stats(train_loss, train_errors, validation_errors)
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        print_stats(train_loss, train_errors, validation_errors)

# %%
net = FeedForwardNet([
        AffineLayer(784,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# Network configuration:
# W(10, 784), b(10, 1)
# At minibatch 100, batch loss 0.793603, batch error rate 28.000000%
# At minibatch 200, batch loss 0.890689, batch error rate 29.000000%
# At minibatch 300, batch loss 0.662910, batch error rate 22.000000%
# At minibatch 400, batch loss 0.753750, batch error rate 21.000000%
# At minibatch 500, batch loss 0.638651, batch error rate 23.000000%
# After epoch 1: valid_err_rate: 0.132900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.460408, batch error rate 13.000000%
# At minibatch 700, batch loss 0.461209, batch error rate 13.000000%
# At minibatch 800, batch loss 0.491990, batch error rate 14.000000%
# At minibatch 900, batch loss 0.366405, batch error rate 7.000000%
# At minibatch 1000, batch loss 0.199703, batch error rate 6.000000%
# After epoch 2: valid_err_rate: 0.107200% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.466349, batch error rate 15.000000%
# At minibatch 1200, batch loss 0.589620, batch error rate 15.000000%
# At minibatch 1300, batch loss 0.345842, batch error rate 10.000000%
# At minibatch 1400, batch loss 0.174180, batch error rate 7.000000%
# At minibatch 1500, batch loss 0.557729, batch error rate 16.000000%
# After epoch 3: valid_err_rate: 0.101100% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.309249, batch error rate 7.000000%
# At minibatch 1700, batch loss 0.372006, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.303966, batch error rate 8.000000%
# At minibatch 1900, batch loss 0.343593, batch error rate 9.000000%
# At minibatch 2000, batch loss 0.276987, batch error rate 11.000000%
# After epoch 4: valid_err_rate: 0.099800% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.325526, batch error rate 11.000000%
# At minibatch 2200, batch loss 0.360788, batch error rate 8.000000%
# At minibatch 2300, batch loss 0.274961, batch error rate 10.000000%
# At minibatch 2400, batch loss 0.486685, batch error rate 15.000000%
# At minibatch 2500, batch loss 0.391974, batch error rate 8.000000%
# After epoch 5: valid_err_rate: 0.095600% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.231943, batch error rate 8.000000%
# At minibatch 2700, batch loss 0.230422, batch error rate 10.000000%
# At minibatch 2800, batch loss 0.224003, batch error rate 6.000000%
# At minibatch 2900, batch loss 0.514016, batch error rate 9.000000%
# At minibatch 3000, batch loss 0.468444, batch error rate 14.000000%
# After epoch 6: valid_err_rate: 0.088200% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.311715, batch error rate 11.000000%
# At minibatch 3200, batch loss 0.304403, batch error rate 11.000000%
# At minibatch 3300, batch loss 0.198571, batch error rate 8.000000%
# At minibatch 3400, batch loss 0.284367, batch error rate 9.000000%
# At minibatch 3500, batch loss 0.485854, batch error rate 11.000000%
# After epoch 7: valid_err_rate: 0.087500% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.274086, batch error rate 7.000000%
# At minibatch 3700, batch loss 0.333692, batch error rate 13.000000%
# At minibatch 3800, batch loss 0.309820, batch error rate 12.000000%
# At minibatch 3900, batch loss 0.369937, batch error rate 11.000000%
# At minibatch 4000, batch loss 0.248938, batch error rate 6.000000%
# After epoch 8: valid_err_rate: 0.087900% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.326052, batch error rate 11.000000%
# At minibatch 4200, batch loss 0.291888, batch error rate 11.000000%
# At minibatch 4300, batch loss 0.414852, batch error rate 10.000000%
# At minibatch 4400, batch loss 0.288321, batch error rate 8.000000%
# At minibatch 4500, batch loss 0.337091, batch error rate 9.000000%
# After epoch 9: valid_err_rate: 0.084500% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.594032, batch error rate 21.000000%
# At minibatch 4700, batch loss 0.228817, batch error rate 8.000000%
# At minibatch 4800, batch loss 0.191874, batch error rate 4.000000%
# At minibatch 4900, batch loss 0.277139, batch error rate 10.000000%
# At minibatch 5000, batch loss 0.236504, batch error rate 6.000000%
# After epoch 10: valid_err_rate: 0.088100% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.242477, batch error rate 8.000000%
# At minibatch 5200, batch loss 0.183003, batch error rate 4.000000%
# At minibatch 5300, batch loss 0.380526, batch error rate 12.000000%
# At minibatch 5400, batch loss 0.404230, batch error rate 12.000000%
# At minibatch 5500, batch loss 0.412253, batch error rate 11.000000%
# After epoch 11: valid_err_rate: 0.084300% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.198374, batch error rate 8.000000%
# At minibatch 5700, batch loss 0.211057, batch error rate 4.000000%
# At minibatch 5800, batch loss 0.314812, batch error rate 8.000000%
# At minibatch 5900, batch loss 0.474046, batch error rate 8.000000%
# At minibatch 6000, batch loss 0.335780, batch error rate 6.000000%
# After epoch 12: valid_err_rate: 0.083000% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.140536, batch error rate 4.000000%
# At minibatch 6200, batch loss 0.313850, batch error rate 7.000000%
# At minibatch 6300, batch loss 0.279000, batch error rate 10.000000%
# At minibatch 6400, batch loss 0.329674, batch error rate 7.000000%
# At minibatch 6500, batch loss 0.167743, batch error rate 7.000000%
# After epoch 13: valid_err_rate: 0.083500% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.383087, batch error rate 10.000000%
# At minibatch 6700, batch loss 0.450884, batch error rate 12.000000%
# At minibatch 6800, batch loss 0.364909, batch error rate 10.000000%
# At minibatch 6900, batch loss 0.194162, batch error rate 3.000000%
# At minibatch 7000, batch loss 0.481153, batch error rate 11.000000%
# After epoch 14: valid_err_rate: 0.089300% currently going ot do 19 epochs
# At minibatch 7100, batch loss 0.389391, batch error rate 9.000000%
# At minibatch 7200, batch loss 0.140154, batch error rate 5.000000%
# At minibatch 7300, batch loss 0.437428, batch error rate 14.000000%
# At minibatch 7400, batch loss 0.171917, batch error rate 4.000000%
# At minibatch 7500, batch loss 0.283064, batch error rate 6.000000%
# After epoch 15: valid_err_rate: 0.083200% currently going ot do 19 epochs
# At minibatch 7600, batch loss 0.251593, batch error rate 10.000000%
# At minibatch 7700, batch loss 0.216989, batch error rate 6.000000%
# At minibatch 7800, batch loss 0.469432, batch error rate 11.000000%
# At minibatch 7900, batch loss 0.489262, batch error rate 11.000000%
# At minibatch 8000, batch loss 0.314060, batch error rate 12.000000%
# After epoch 16: valid_err_rate: 0.080900% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.301592, batch error rate 9.000000%
# At minibatch 8200, batch loss 0.104058, batch error rate 3.000000%
# At minibatch 8300, batch loss 0.221999, batch error rate 2.000000%
# At minibatch 8400, batch loss 0.204111, batch error rate 6.000000%
# At minibatch 8500, batch loss 0.211769, batch error rate 8.000000%
# After epoch 17: valid_err_rate: 0.081800% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.252658, batch error rate 8.000000%
# At minibatch 8700, batch loss 0.164023, batch error rate 7.000000%
# At minibatch 8800, batch loss 0.227189, batch error rate 4.000000%
# At minibatch 8900, batch loss 0.280003, batch error rate 7.000000%
# At minibatch 9000, batch loss 0.272637, batch error rate 8.000000%
# After epoch 18: valid_err_rate: 0.081900% currently going ot do 25 epochs
# At minibatch 9100, batch loss 0.364832, batch error rate 11.000000%
# At minibatch 9200, batch loss 0.181360, batch error rate 3.000000%
# At minibatch 9300, batch loss 0.326964, batch error rate 9.000000%
# At minibatch 9400, batch loss 0.202200, batch error rate 6.000000%
# At minibatch 9500, batch loss 0.305085, batch error rate 5.000000%
# After epoch 19: valid_err_rate: 0.083600% currently going ot do 25 epochs
# At minibatch 9600, batch loss 0.458947, batch error rate 14.000000%
# At minibatch 9700, batch loss 0.294155, batch error rate 7.000000%
# At minibatch 9800, batch loss 0.157487, batch error rate 6.000000%
# At minibatch 9900, batch loss 0.457629, batch error rate 10.000000%
# At minibatch 10000, batch loss 0.451796, batch error rate 14.000000%
# After epoch 20: valid_err_rate: 0.080400% currently going ot do 31 epochs
# At minibatch 10100, batch loss 0.220684, batch error rate 6.000000%
# At minibatch 10200, batch loss 0.350381, batch error rate 8.000000%
# At minibatch 10300, batch loss 0.186578, batch error rate 6.000000%
# At minibatch 10400, batch loss 0.199647, batch error rate 8.000000%
# At minibatch 10500, batch loss 0.466645, batch error rate 10.000000%
# After epoch 21: valid_err_rate: 0.081900% currently going ot do 31 epochs
# At minibatch 10600, batch loss 0.223246, batch error rate 5.000000%
# At minibatch 10700, batch loss 0.271671, batch error rate 8.000000%
# At minibatch 10800, batch loss 0.306894, batch error rate 9.000000%
# At minibatch 10900, batch loss 0.231842, batch error rate 6.000000%
# At minibatch 11000, batch loss 0.393862, batch error rate 11.000000%
# After epoch 22: valid_err_rate: 0.081600% currently going ot do 31 epochs
# At minibatch 11100, batch loss 0.602630, batch error rate 7.000000%
# At minibatch 11200, batch loss 0.375353, batch error rate 8.000000%
# At minibatch 11300, batch loss 0.152862, batch error rate 5.000000%
# At minibatch 11400, batch loss 0.275743, batch error rate 4.000000%
# At minibatch 11500, batch loss 0.346128, batch error rate 14.000000%
# After epoch 23: valid_err_rate: 0.081300% currently going ot do 31 epochs
# At minibatch 11600, batch loss 0.332968, batch error rate 6.000000%
# At minibatch 11700, batch loss 0.290921, batch error rate 6.000000%
# At minibatch 11800, batch loss 0.336603, batch error rate 11.000000%
# At minibatch 11900, batch loss 0.267759, batch error rate 8.000000%
# At minibatch 12000, batch loss 0.140687, batch error rate 4.000000%
# After epoch 24: valid_err_rate: 0.079200% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.233949, batch error rate 7.000000%
# At minibatch 12200, batch loss 0.258766, batch error rate 7.000000%
# At minibatch 12300, batch loss 0.234408, batch error rate 7.000000%
# At minibatch 12400, batch loss 0.290424, batch error rate 9.000000%
# At minibatch 12500, batch loss 0.246440, batch error rate 8.000000%
# After epoch 25: valid_err_rate: 0.078200% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.326255, batch error rate 11.000000%
# At minibatch 12700, batch loss 0.303124, batch error rate 9.000000%
# At minibatch 12800, batch loss 0.409408, batch error rate 11.000000%
# At minibatch 12900, batch loss 0.237009, batch error rate 8.000000%
# At minibatch 13000, batch loss 0.198945, batch error rate 7.000000%
# After epoch 26: valid_err_rate: 0.079900% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.514858, batch error rate 9.000000%
# At minibatch 13200, batch loss 0.250277, batch error rate 9.000000%
# At minibatch 13300, batch loss 0.244765, batch error rate 7.000000%
# At minibatch 13400, batch loss 0.222610, batch error rate 6.000000%
# At minibatch 13500, batch loss 0.347887, batch error rate 9.000000%
# After epoch 27: valid_err_rate: 0.077000% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.287335, batch error rate 11.000000%
# At minibatch 13700, batch loss 0.312240, batch error rate 12.000000%
# At minibatch 13800, batch loss 0.276406, batch error rate 6.000000%
# At minibatch 13900, batch loss 0.336158, batch error rate 9.000000%
# At minibatch 14000, batch loss 0.252943, batch error rate 6.000000%
# After epoch 28: valid_err_rate: 0.077400% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.128838, batch error rate 4.000000%
# At minibatch 14200, batch loss 0.258313, batch error rate 6.000000%
# At minibatch 14300, batch loss 0.506827, batch error rate 12.000000%
# At minibatch 14400, batch loss 0.299364, batch error rate 10.000000%
# At minibatch 14500, batch loss 0.189879, batch error rate 5.000000%
# After epoch 29: valid_err_rate: 0.076300% currently going ot do 44 epochs
# At minibatch 14600, batch loss 0.188418, batch error rate 4.000000%
# At minibatch 14700, batch loss 0.188235, batch error rate 3.000000%
# At minibatch 14800, batch loss 0.145822, batch error rate 5.000000%
# At minibatch 14900, batch loss 0.379147, batch error rate 12.000000%
# At minibatch 15000, batch loss 0.234090, batch error rate 6.000000%
# After epoch 30: valid_err_rate: 0.076200% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.312335, batch error rate 7.000000%
# At minibatch 15200, batch loss 0.159012, batch error rate 5.000000%
# At minibatch 15300, batch loss 0.412320, batch error rate 12.000000%
# At minibatch 15400, batch loss 0.378525, batch error rate 10.000000%
# At minibatch 15500, batch loss 0.185341, batch error rate 6.000000%
# After epoch 31: valid_err_rate: 0.079500% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.121203, batch error rate 4.000000%
# At minibatch 15700, batch loss 0.269000, batch error rate 5.000000%
# At minibatch 15800, batch loss 0.299814, batch error rate 5.000000%
# At minibatch 15900, batch loss 0.301729, batch error rate 11.000000%
# At minibatch 16000, batch loss 0.337126, batch error rate 9.000000%
# After epoch 32: valid_err_rate: 0.075700% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.557794, batch error rate 9.000000%
# At minibatch 16200, batch loss 0.194418, batch error rate 5.000000%
# At minibatch 16300, batch loss 0.182762, batch error rate 5.000000%
# At minibatch 16400, batch loss 0.305353, batch error rate 8.000000%
# At minibatch 16500, batch loss 0.290235, batch error rate 6.000000%
# After epoch 33: valid_err_rate: 0.077800% currently going ot do 49 epochs
# At minibatch 16600, batch loss 0.135958, batch error rate 6.000000%
# At minibatch 16700, batch loss 0.262825, batch error rate 8.000000%
# At minibatch 16800, batch loss 0.341628, batch error rate 11.000000%
# At minibatch 16900, batch loss 0.430545, batch error rate 11.000000%
# At minibatch 17000, batch loss 0.291491, batch error rate 6.000000%
# After epoch 34: valid_err_rate: 0.079600% currently going ot do 49 epochs
# At minibatch 17100, batch loss 0.371316, batch error rate 8.000000%
# At minibatch 17200, batch loss 0.200417, batch error rate 5.000000%
# At minibatch 17300, batch loss 0.239785, batch error rate 6.000000%
# At minibatch 17400, batch loss 0.399268, batch error rate 7.000000%
# At minibatch 17500, batch loss 0.158334, batch error rate 3.000000%
# After epoch 35: valid_err_rate: 0.080000% currently going ot do 49 epochs
# At minibatch 17600, batch loss 0.153612, batch error rate 3.000000%
# At minibatch 17700, batch loss 0.364148, batch error rate 8.000000%
# At minibatch 17800, batch loss 0.163606, batch error rate 4.000000%
# At minibatch 17900, batch loss 0.198541, batch error rate 8.000000%
# At minibatch 18000, batch loss 0.126453, batch error rate 2.000000%
# After epoch 36: valid_err_rate: 0.075900% currently going ot do 49 epochs
# At minibatch 18100, batch loss 0.204684, batch error rate 8.000000%
# At minibatch 18200, batch loss 0.318880, batch error rate 12.000000%
# At minibatch 18300, batch loss 0.278497, batch error rate 9.000000%
# At minibatch 18400, batch loss 0.258718, batch error rate 10.000000%
# At minibatch 18500, batch loss 0.272266, batch error rate 7.000000%
# After epoch 37: valid_err_rate: 0.079900% currently going ot do 49 epochs
# At minibatch 18600, batch loss 0.314855, batch error rate 6.000000%
# At minibatch 18700, batch loss 0.140537, batch error rate 4.000000%
# At minibatch 18800, batch loss 0.257751, batch error rate 4.000000%
# At minibatch 18900, batch loss 0.224055, batch error rate 5.000000%
# At minibatch 19000, batch loss 0.425587, batch error rate 14.000000%
# After epoch 38: valid_err_rate: 0.077400% currently going ot do 49 epochs
# At minibatch 19100, batch loss 0.264820, batch error rate 7.000000%
# At minibatch 19200, batch loss 0.094762, batch error rate 2.000000%
# At minibatch 19300, batch loss 0.225555, batch error rate 7.000000%
# At minibatch 19400, batch loss 0.150336, batch error rate 6.000000%
# At minibatch 19500, batch loss 0.299511, batch error rate 11.000000%
# After epoch 39: valid_err_rate: 0.077900% currently going ot do 49 epochs
# At minibatch 19600, batch loss 0.331869, batch error rate 11.000000%
# At minibatch 19700, batch loss 0.206484, batch error rate 7.000000%
# At minibatch 19800, batch loss 0.196660, batch error rate 6.000000%
# At minibatch 19900, batch loss 0.261698, batch error rate 6.000000%
# At minibatch 20000, batch loss 0.329278, batch error rate 12.000000%
# After epoch 40: valid_err_rate: 0.074700% currently going ot do 61 epochs
# At minibatch 20100, batch loss 0.212583, batch error rate 5.000000%
# At minibatch 20200, batch loss 0.216432, batch error rate 8.000000%
# At minibatch 20300, batch loss 0.226312, batch error rate 9.000000%
# At minibatch 20400, batch loss 0.302340, batch error rate 8.000000%
# At minibatch 20500, batch loss 0.266592, batch error rate 8.000000%
# After epoch 41: valid_err_rate: 0.076000% currently going ot do 61 epochs
# At minibatch 20600, batch loss 0.164419, batch error rate 7.000000%
# At minibatch 20700, batch loss 0.273035, batch error rate 8.000000%
# At minibatch 20800, batch loss 0.279262, batch error rate 10.000000%
# At minibatch 20900, batch loss 0.304668, batch error rate 6.000000%
# At minibatch 21000, batch loss 0.333761, batch error rate 9.000000%
# After epoch 42: valid_err_rate: 0.077100% currently going ot do 61 epochs
# At minibatch 21100, batch loss 0.428296, batch error rate 11.000000%
# At minibatch 21200, batch loss 0.283887, batch error rate 7.000000%
# At minibatch 21300, batch loss 0.368020, batch error rate 12.000000%
# At minibatch 21400, batch loss 0.268579, batch error rate 8.000000%
# At minibatch 21500, batch loss 0.382642, batch error rate 13.000000%
# After epoch 43: valid_err_rate: 0.076700% currently going ot do 61 epochs
# At minibatch 21600, batch loss 0.099116, batch error rate 3.000000%
# At minibatch 21700, batch loss 0.422983, batch error rate 12.000000%
# At minibatch 21800, batch loss 0.336850, batch error rate 8.000000%
# At minibatch 21900, batch loss 0.324274, batch error rate 6.000000%
# At minibatch 22000, batch loss 0.448854, batch error rate 11.000000%
# After epoch 44: valid_err_rate: 0.078200% currently going ot do 61 epochs
# At minibatch 22100, batch loss 0.222402, batch error rate 4.000000%
# At minibatch 22200, batch loss 0.286251, batch error rate 6.000000%
# At minibatch 22300, batch loss 0.404752, batch error rate 9.000000%
# At minibatch 22400, batch loss 0.125416, batch error rate 3.000000%
# At minibatch 22500, batch loss 0.187085, batch error rate 5.000000%
# After epoch 45: valid_err_rate: 0.076200% currently going ot do 61 epochs
# At minibatch 22600, batch loss 0.416774, batch error rate 10.000000%
# At minibatch 22700, batch loss 0.275195, batch error rate 7.000000%
# At minibatch 22800, batch loss 0.348590, batch error rate 10.000000%
# At minibatch 22900, batch loss 0.297746, batch error rate 9.000000%
# At minibatch 23000, batch loss 0.267400, batch error rate 8.000000%
# After epoch 46: valid_err_rate: 0.076200% currently going ot do 61 epochs
# At minibatch 23100, batch loss 0.247537, batch error rate 10.000000%
# At minibatch 23200, batch loss 0.252622, batch error rate 7.000000%
# At minibatch 23300, batch loss 0.268383, batch error rate 9.000000%
# At minibatch 23400, batch loss 0.204812, batch error rate 7.000000%
# At minibatch 23500, batch loss 0.157795, batch error rate 4.000000%
# After epoch 47: valid_err_rate: 0.075100% currently going ot do 61 epochs
# At minibatch 23600, batch loss 0.395865, batch error rate 9.000000%
# At minibatch 23700, batch loss 0.283431, batch error rate 12.000000%
# At minibatch 23800, batch loss 0.094448, batch error rate 3.000000%
# At minibatch 23900, batch loss 0.212300, batch error rate 5.000000%
# At minibatch 24000, batch loss 0.244600, batch error rate 7.000000%
# After epoch 48: valid_err_rate: 0.075200% currently going ot do 61 epochs
# At minibatch 24100, batch loss 0.433812, batch error rate 11.000000%
# At minibatch 24200, batch loss 0.208892, batch error rate 6.000000%
# At minibatch 24300, batch loss 0.226900, batch error rate 10.000000%
# At minibatch 24400, batch loss 0.121226, batch error rate 5.000000%
# At minibatch 24500, batch loss 0.310787, batch error rate 11.000000%
# After epoch 49: valid_err_rate: 0.078200% currently going ot do 61 epochs
# At minibatch 24600, batch loss 0.274032, batch error rate 6.000000%
# At minibatch 24700, batch loss 0.224583, batch error rate 6.000000%
# At minibatch 24800, batch loss 0.265543, batch error rate 7.000000%
# At minibatch 24900, batch loss 0.284149, batch error rate 9.000000%
# At minibatch 25000, batch loss 0.118740, batch error rate 5.000000%
# After epoch 50: valid_err_rate: 0.079800% currently going ot do 61 epochs
# At minibatch 25100, batch loss 0.251501, batch error rate 9.000000%
# At minibatch 25200, batch loss 0.262463, batch error rate 9.000000%
# At minibatch 25300, batch loss 0.163291, batch error rate 5.000000%
# At minibatch 25400, batch loss 0.251457, batch error rate 9.000000%
# At minibatch 25500, batch loss 0.210661, batch error rate 6.000000%
# After epoch 51: valid_err_rate: 0.077200% currently going ot do 61 epochs
# At minibatch 25600, batch loss 0.233351, batch error rate 5.000000%
# At minibatch 25700, batch loss 0.277857, batch error rate 7.000000%
# At minibatch 25800, batch loss 0.330334, batch error rate 5.000000%
# At minibatch 25900, batch loss 0.292078, batch error rate 11.000000%
# At minibatch 26000, batch loss 0.434050, batch error rate 12.000000%
# After epoch 52: valid_err_rate: 0.073800% currently going ot do 79 epochs
# At minibatch 26100, batch loss 0.273735, batch error rate 7.000000%
# At minibatch 26200, batch loss 0.158136, batch error rate 5.000000%
# At minibatch 26300, batch loss 0.206417, batch error rate 8.000000%
# At minibatch 26400, batch loss 0.268008, batch error rate 6.000000%
# At minibatch 26500, batch loss 0.313464, batch error rate 8.000000%
# After epoch 53: valid_err_rate: 0.075500% currently going ot do 79 epochs
# At minibatch 26600, batch loss 0.334381, batch error rate 10.000000%
# At minibatch 26700, batch loss 0.262250, batch error rate 8.000000%
# At minibatch 26800, batch loss 0.355576, batch error rate 11.000000%
# At minibatch 26900, batch loss 0.253781, batch error rate 8.000000%
# At minibatch 27000, batch loss 0.347467, batch error rate 9.000000%
# After epoch 54: valid_err_rate: 0.074800% currently going ot do 79 epochs
# At minibatch 27100, batch loss 0.389523, batch error rate 12.000000%
# At minibatch 27200, batch loss 0.248510, batch error rate 8.000000%
# At minibatch 27300, batch loss 0.185408, batch error rate 5.000000%
# At minibatch 27400, batch loss 0.222437, batch error rate 7.000000%
# At minibatch 27500, batch loss 0.375155, batch error rate 10.000000%
# After epoch 55: valid_err_rate: 0.073500% currently going ot do 83 epochs
# At minibatch 27600, batch loss 0.180547, batch error rate 6.000000%
# At minibatch 27700, batch loss 0.336749, batch error rate 9.000000%
# At minibatch 27800, batch loss 0.157749, batch error rate 5.000000%
# At minibatch 27900, batch loss 0.247621, batch error rate 8.000000%
# At minibatch 28000, batch loss 0.328965, batch error rate 8.000000%
# After epoch 56: valid_err_rate: 0.074400% currently going ot do 83 epochs
# At minibatch 28100, batch loss 0.259108, batch error rate 10.000000%
# At minibatch 28200, batch loss 0.214480, batch error rate 7.000000%
# At minibatch 28300, batch loss 0.209367, batch error rate 6.000000%
# At minibatch 28400, batch loss 0.200808, batch error rate 6.000000%
# At minibatch 28500, batch loss 0.144328, batch error rate 6.000000%
# After epoch 57: valid_err_rate: 0.074400% currently going ot do 83 epochs
# At minibatch 28600, batch loss 0.450898, batch error rate 11.000000%
# At minibatch 28700, batch loss 0.309341, batch error rate 8.000000%
# At minibatch 28800, batch loss 0.198060, batch error rate 4.000000%
# At minibatch 28900, batch loss 0.173487, batch error rate 5.000000%
# At minibatch 29000, batch loss 0.243404, batch error rate 7.000000%
# After epoch 58: valid_err_rate: 0.074900% currently going ot do 83 epochs
# At minibatch 29100, batch loss 0.270916, batch error rate 10.000000%
# At minibatch 29200, batch loss 0.217877, batch error rate 6.000000%
# At minibatch 29300, batch loss 0.242532, batch error rate 4.000000%
# At minibatch 29400, batch loss 0.234447, batch error rate 3.000000%
# At minibatch 29500, batch loss 0.320663, batch error rate 8.000000%
# After epoch 59: valid_err_rate: 0.072800% currently going ot do 89 epochs
# At minibatch 29600, batch loss 0.398754, batch error rate 7.000000%
# At minibatch 29700, batch loss 0.286117, batch error rate 8.000000%
# At minibatch 29800, batch loss 0.368956, batch error rate 14.000000%
# At minibatch 29900, batch loss 0.245817, batch error rate 10.000000%
# At minibatch 30000, batch loss 0.097883, batch error rate 2.000000%
# After epoch 60: valid_err_rate: 0.074300% currently going ot do 89 epochs
# At minibatch 30100, batch loss 0.259457, batch error rate 7.000000%
# At minibatch 30200, batch loss 0.178775, batch error rate 7.000000%
# At minibatch 30300, batch loss 0.337964, batch error rate 10.000000%
# At minibatch 30400, batch loss 0.271585, batch error rate 5.000000%
# At minibatch 30500, batch loss 0.253077, batch error rate 9.000000%
# After epoch 61: valid_err_rate: 0.071600% currently going ot do 92 epochs
# At minibatch 30600, batch loss 0.150542, batch error rate 6.000000%
# At minibatch 30700, batch loss 0.202467, batch error rate 6.000000%
# At minibatch 30800, batch loss 0.142339, batch error rate 5.000000%
# At minibatch 30900, batch loss 0.244900, batch error rate 8.000000%
# At minibatch 31000, batch loss 0.293564, batch error rate 10.000000%
# After epoch 62: valid_err_rate: 0.076000% currently going ot do 92 epochs
# At minibatch 31100, batch loss 0.178462, batch error rate 5.000000%
# At minibatch 31200, batch loss 0.220067, batch error rate 6.000000%
# At minibatch 31300, batch loss 0.617199, batch error rate 14.000000%
# At minibatch 31400, batch loss 0.233636, batch error rate 7.000000%
# At minibatch 31500, batch loss 0.263743, batch error rate 8.000000%
# After epoch 63: valid_err_rate: 0.074800% currently going ot do 92 epochs
# At minibatch 31600, batch loss 0.235097, batch error rate 7.000000%
# At minibatch 31700, batch loss 0.158340, batch error rate 5.000000%
# At minibatch 31800, batch loss 0.276723, batch error rate 8.000000%
# At minibatch 31900, batch loss 0.247678, batch error rate 10.000000%
# At minibatch 32000, batch loss 0.222968, batch error rate 5.000000%
# After epoch 64: valid_err_rate: 0.077400% currently going ot do 92 epochs
# At minibatch 32100, batch loss 0.186932, batch error rate 6.000000%
# At minibatch 32200, batch loss 0.269995, batch error rate 9.000000%
# At minibatch 32300, batch loss 0.327100, batch error rate 8.000000%
# At minibatch 32400, batch loss 0.342127, batch error rate 12.000000%
# At minibatch 32500, batch loss 0.138224, batch error rate 5.000000%
# After epoch 65: valid_err_rate: 0.072600% currently going ot do 92 epochs
# At minibatch 32600, batch loss 0.251647, batch error rate 8.000000%
# At minibatch 32700, batch loss 0.339425, batch error rate 10.000000%
# At minibatch 32800, batch loss 0.297916, batch error rate 11.000000%
# At minibatch 32900, batch loss 0.188712, batch error rate 7.000000%
# At minibatch 33000, batch loss 0.417801, batch error rate 10.000000%
# After epoch 66: valid_err_rate: 0.071900% currently going ot do 92 epochs
# At minibatch 33100, batch loss 0.249744, batch error rate 6.000000%
# At minibatch 33200, batch loss 0.173804, batch error rate 5.000000%
# At minibatch 33300, batch loss 0.278253, batch error rate 9.000000%
# At minibatch 33400, batch loss 0.185766, batch error rate 5.000000%
# At minibatch 33500, batch loss 0.183573, batch error rate 5.000000%
# After epoch 67: valid_err_rate: 0.075200% currently going ot do 92 epochs
# At minibatch 33600, batch loss 0.211543, batch error rate 9.000000%
# At minibatch 33700, batch loss 0.244573, batch error rate 7.000000%
# At minibatch 33800, batch loss 0.176480, batch error rate 6.000000%
# At minibatch 33900, batch loss 0.397736, batch error rate 7.000000%
# At minibatch 34000, batch loss 0.358288, batch error rate 9.000000%
# After epoch 68: valid_err_rate: 0.076000% currently going ot do 92 epochs
# At minibatch 34100, batch loss 0.192007, batch error rate 7.000000%
# At minibatch 34200, batch loss 0.250912, batch error rate 8.000000%
# At minibatch 34300, batch loss 0.207688, batch error rate 7.000000%
# At minibatch 34400, batch loss 0.218137, batch error rate 6.000000%
# At minibatch 34500, batch loss 0.211682, batch error rate 7.000000%
# After epoch 69: valid_err_rate: 0.073000% currently going ot do 92 epochs
# At minibatch 34600, batch loss 0.260473, batch error rate 7.000000%
# At minibatch 34700, batch loss 0.272052, batch error rate 8.000000%
# At minibatch 34800, batch loss 0.128229, batch error rate 4.000000%
# At minibatch 34900, batch loss 0.386203, batch error rate 9.000000%
# At minibatch 35000, batch loss 0.083394, batch error rate 1.000000%
# After epoch 70: valid_err_rate: 0.073900% currently going ot do 92 epochs
# At minibatch 35100, batch loss 0.219114, batch error rate 7.000000%
# At minibatch 35200, batch loss 0.302650, batch error rate 9.000000%
# At minibatch 35300, batch loss 0.239966, batch error rate 7.000000%
# At minibatch 35400, batch loss 0.222847, batch error rate 3.000000%
# At minibatch 35500, batch loss 0.433507, batch error rate 9.000000%
# After epoch 71: valid_err_rate: 0.072800% currently going ot do 92 epochs
# At minibatch 35600, batch loss 0.243519, batch error rate 6.000000%
# At minibatch 35700, batch loss 0.319462, batch error rate 14.000000%
# At minibatch 35800, batch loss 0.151618, batch error rate 5.000000%
# At minibatch 35900, batch loss 0.124541, batch error rate 3.000000%
# At minibatch 36000, batch loss 0.290458, batch error rate 11.000000%
# After epoch 72: valid_err_rate: 0.072700% currently going ot do 92 epochs
# At minibatch 36100, batch loss 0.255876, batch error rate 6.000000%
# At minibatch 36200, batch loss 0.207185, batch error rate 5.000000%
# At minibatch 36300, batch loss 0.485137, batch error rate 14.000000%
# At minibatch 36400, batch loss 0.389721, batch error rate 10.000000%
# At minibatch 36500, batch loss 0.161494, batch error rate 4.000000%
# After epoch 73: valid_err_rate: 0.073600% currently going ot do 92 epochs
# At minibatch 36600, batch loss 0.306650, batch error rate 9.000000%
# At minibatch 36700, batch loss 0.385441, batch error rate 10.000000%
# At minibatch 36800, batch loss 0.173113, batch error rate 2.000000%
# At minibatch 36900, batch loss 0.124358, batch error rate 3.000000%
# At minibatch 37000, batch loss 0.287904, batch error rate 6.000000%
# After epoch 74: valid_err_rate: 0.074200% currently going ot do 92 epochs
# At minibatch 37100, batch loss 0.154695, batch error rate 6.000000%
# At minibatch 37200, batch loss 0.288789, batch error rate 8.000000%
# At minibatch 37300, batch loss 0.261638, batch error rate 7.000000%
# At minibatch 37400, batch loss 0.343835, batch error rate 10.000000%
# At minibatch 37500, batch loss 0.259234, batch error rate 9.000000%
# After epoch 75: valid_err_rate: 0.071400% currently going ot do 113 epochs
# At minibatch 37600, batch loss 0.148122, batch error rate 5.000000%
# At minibatch 37700, batch loss 0.233084, batch error rate 7.000000%
# At minibatch 37800, batch loss 0.350466, batch error rate 10.000000%
# At minibatch 37900, batch loss 0.223809, batch error rate 10.000000%
# At minibatch 38000, batch loss 0.178884, batch error rate 6.000000%
# After epoch 76: valid_err_rate: 0.074200% currently going ot do 113 epochs
# At minibatch 38100, batch loss 0.224656, batch error rate 6.000000%
# At minibatch 38200, batch loss 0.189354, batch error rate 4.000000%
# At minibatch 38300, batch loss 0.243568, batch error rate 6.000000%
# At minibatch 38400, batch loss 0.123639, batch error rate 2.000000%
# At minibatch 38500, batch loss 0.099018, batch error rate 2.000000%
# After epoch 77: valid_err_rate: 0.074400% currently going ot do 113 epochs
# At minibatch 38600, batch loss 0.427622, batch error rate 11.000000%
# At minibatch 38700, batch loss 0.211191, batch error rate 7.000000%
# At minibatch 38800, batch loss 0.214434, batch error rate 7.000000%
# At minibatch 38900, batch loss 0.265724, batch error rate 9.000000%
# At minibatch 39000, batch loss 0.261472, batch error rate 6.000000%
# After epoch 78: valid_err_rate: 0.075600% currently going ot do 113 epochs
# At minibatch 39100, batch loss 0.184634, batch error rate 5.000000%
# At minibatch 39200, batch loss 0.169492, batch error rate 5.000000%
# At minibatch 39300, batch loss 0.148727, batch error rate 7.000000%
# At minibatch 39400, batch loss 0.294014, batch error rate 7.000000%
# At minibatch 39500, batch loss 0.216720, batch error rate 9.000000%
# After epoch 79: valid_err_rate: 0.074400% currently going ot do 113 epochs
# At minibatch 39600, batch loss 0.318725, batch error rate 12.000000%
# At minibatch 39700, batch loss 0.194356, batch error rate 9.000000%
# At minibatch 39800, batch loss 0.402452, batch error rate 6.000000%
# At minibatch 39900, batch loss 0.163104, batch error rate 6.000000%
# At minibatch 40000, batch loss 0.223976, batch error rate 7.000000%
# After epoch 80: valid_err_rate: 0.072700% currently going ot do 113 epochs
# At minibatch 40100, batch loss 0.204835, batch error rate 3.000000%
# At minibatch 40200, batch loss 0.465470, batch error rate 6.000000%
# At minibatch 40300, batch loss 0.203223, batch error rate 8.000000%
# At minibatch 40400, batch loss 0.246863, batch error rate 6.000000%
# At minibatch 40500, batch loss 0.322900, batch error rate 6.000000%
# After epoch 81: valid_err_rate: 0.073200% currently going ot do 113 epochs
# At minibatch 40600, batch loss 0.239844, batch error rate 8.000000%
# At minibatch 40700, batch loss 0.267546, batch error rate 8.000000%
# At minibatch 40800, batch loss 0.207713, batch error rate 4.000000%
# At minibatch 40900, batch loss 0.243062, batch error rate 8.000000%
# At minibatch 41000, batch loss 0.366619, batch error rate 8.000000%
# After epoch 82: valid_err_rate: 0.076300% currently going ot do 113 epochs
# At minibatch 41100, batch loss 0.386024, batch error rate 6.000000%
# At minibatch 41200, batch loss 0.208372, batch error rate 4.000000%
# At minibatch 41300, batch loss 0.319848, batch error rate 6.000000%
# At minibatch 41400, batch loss 0.343340, batch error rate 11.000000%
# At minibatch 41500, batch loss 0.440326, batch error rate 8.000000%
# After epoch 83: valid_err_rate: 0.074600% currently going ot do 113 epochs
# At minibatch 41600, batch loss 0.179253, batch error rate 4.000000%
# At minibatch 41700, batch loss 0.324995, batch error rate 5.000000%
# At minibatch 41800, batch loss 0.233218, batch error rate 6.000000%
# At minibatch 41900, batch loss 0.230799, batch error rate 7.000000%
# At minibatch 42000, batch loss 0.203172, batch error rate 5.000000%
# After epoch 84: valid_err_rate: 0.071500% currently going ot do 113 epochs
# At minibatch 42100, batch loss 0.160527, batch error rate 5.000000%
# At minibatch 42200, batch loss 0.282826, batch error rate 9.000000%
# At minibatch 42300, batch loss 0.217336, batch error rate 6.000000%
# At minibatch 42400, batch loss 0.295074, batch error rate 5.000000%
# At minibatch 42500, batch loss 0.499166, batch error rate 12.000000%
# After epoch 85: valid_err_rate: 0.074700% currently going ot do 113 epochs
# At minibatch 42600, batch loss 0.291902, batch error rate 8.000000%
# At minibatch 42700, batch loss 0.215293, batch error rate 9.000000%
# At minibatch 42800, batch loss 0.180662, batch error rate 6.000000%
# At minibatch 42900, batch loss 0.216529, batch error rate 10.000000%
# At minibatch 43000, batch loss 0.501333, batch error rate 8.000000%
# After epoch 86: valid_err_rate: 0.074700% currently going ot do 113 epochs
# At minibatch 43100, batch loss 0.251022, batch error rate 7.000000%
# At minibatch 43200, batch loss 0.276080, batch error rate 11.000000%
# At minibatch 43300, batch loss 0.192012, batch error rate 3.000000%
# At minibatch 43400, batch loss 0.187514, batch error rate 7.000000%
# At minibatch 43500, batch loss 0.142198, batch error rate 3.000000%
# After epoch 87: valid_err_rate: 0.074300% currently going ot do 113 epochs
# At minibatch 43600, batch loss 0.275079, batch error rate 9.000000%
# At minibatch 43700, batch loss 0.198810, batch error rate 8.000000%
# At minibatch 43800, batch loss 0.284357, batch error rate 4.000000%
# At minibatch 43900, batch loss 0.177378, batch error rate 5.000000%
# At minibatch 44000, batch loss 0.347136, batch error rate 8.000000%
# After epoch 88: valid_err_rate: 0.076300% currently going ot do 113 epochs
# At minibatch 44100, batch loss 0.277528, batch error rate 10.000000%
# At minibatch 44200, batch loss 0.285266, batch error rate 7.000000%
# At minibatch 44300, batch loss 0.432898, batch error rate 13.000000%
# At minibatch 44400, batch loss 0.176434, batch error rate 6.000000%
# At minibatch 44500, batch loss 0.366162, batch error rate 7.000000%
# After epoch 89: valid_err_rate: 0.073900% currently going ot do 113 epochs
# At minibatch 44600, batch loss 0.217619, batch error rate 9.000000%
# At minibatch 44700, batch loss 0.231783, batch error rate 4.000000%
# At minibatch 44800, batch loss 0.286420, batch error rate 10.000000%
# At minibatch 44900, batch loss 0.154229, batch error rate 2.000000%
# At minibatch 45000, batch loss 0.382151, batch error rate 7.000000%
# After epoch 90: valid_err_rate: 0.074400% currently going ot do 113 epochs
# At minibatch 45100, batch loss 0.338328, batch error rate 7.000000%
# At minibatch 45200, batch loss 0.285007, batch error rate 8.000000%
# At minibatch 45300, batch loss 0.284252, batch error rate 8.000000%
# At minibatch 45400, batch loss 0.193835, batch error rate 7.000000%
# At minibatch 45500, batch loss 0.314697, batch error rate 7.000000%
# After epoch 91: valid_err_rate: 0.073900% currently going ot do 113 epochs
# At minibatch 45600, batch loss 0.179432, batch error rate 3.000000%
# At minibatch 45700, batch loss 0.179033, batch error rate 7.000000%
# At minibatch 45800, batch loss 0.278322, batch error rate 11.000000%
# At minibatch 45900, batch loss 0.160725, batch error rate 3.000000%
# At minibatch 46000, batch loss 0.271462, batch error rate 10.000000%
# After epoch 92: valid_err_rate: 0.073200% currently going ot do 113 epochs
# At minibatch 46100, batch loss 0.226388, batch error rate 8.000000%
# At minibatch 46200, batch loss 0.365616, batch error rate 9.000000%
# At minibatch 46300, batch loss 0.292669, batch error rate 7.000000%
# At minibatch 46400, batch loss 0.192910, batch error rate 7.000000%
# At minibatch 46500, batch loss 0.384902, batch error rate 10.000000%
# After epoch 93: valid_err_rate: 0.073900% currently going ot do 113 epochs
# At minibatch 46600, batch loss 0.262270, batch error rate 10.000000%
# At minibatch 46700, batch loss 0.219915, batch error rate 5.000000%
# At minibatch 46800, batch loss 0.153769, batch error rate 3.000000%
# At minibatch 46900, batch loss 0.307656, batch error rate 11.000000%
# At minibatch 47000, batch loss 0.295485, batch error rate 8.000000%
# After epoch 94: valid_err_rate: 0.072700% currently going ot do 113 epochs
# At minibatch 47100, batch loss 0.365548, batch error rate 11.000000%
# At minibatch 47200, batch loss 0.157902, batch error rate 6.000000%
# At minibatch 47300, batch loss 0.278926, batch error rate 11.000000%
# At minibatch 47400, batch loss 0.326247, batch error rate 9.000000%
# At minibatch 47500, batch loss 0.354315, batch error rate 9.000000%
# After epoch 95: valid_err_rate: 0.072500% currently going ot do 113 epochs
# At minibatch 47600, batch loss 0.197447, batch error rate 7.000000%
# At minibatch 47700, batch loss 0.194006, batch error rate 7.000000%
# At minibatch 47800, batch loss 0.092776, batch error rate 1.000000%
# At minibatch 47900, batch loss 0.129617, batch error rate 4.000000%
# At minibatch 48000, batch loss 0.325128, batch error rate 8.000000%
# After epoch 96: valid_err_rate: 0.073600% currently going ot do 113 epochs
# At minibatch 48100, batch loss 0.351430, batch error rate 8.000000%
# At minibatch 48200, batch loss 0.329096, batch error rate 7.000000%
# At minibatch 48300, batch loss 0.185242, batch error rate 5.000000%
# At minibatch 48400, batch loss 0.278061, batch error rate 7.000000%
# At minibatch 48500, batch loss 0.172307, batch error rate 5.000000%
# After epoch 97: valid_err_rate: 0.074900% currently going ot do 113 epochs
# At minibatch 48600, batch loss 0.259694, batch error rate 8.000000%
# At minibatch 48700, batch loss 0.312609, batch error rate 9.000000%
# At minibatch 48800, batch loss 0.285440, batch error rate 7.000000%
# At minibatch 48900, batch loss 0.340590, batch error rate 13.000000%
# At minibatch 49000, batch loss 0.166263, batch error rate 4.000000%
# After epoch 98: valid_err_rate: 0.071500% currently going ot do 113 epochs
# At minibatch 49100, batch loss 0.266816, batch error rate 5.000000%
# At minibatch 49200, batch loss 0.367551, batch error rate 6.000000%
# At minibatch 49300, batch loss 0.137180, batch error rate 5.000000%
# At minibatch 49400, batch loss 0.156375, batch error rate 5.000000%
# At minibatch 49500, batch loss 0.207931, batch error rate 5.000000%
# After epoch 99: valid_err_rate: 0.075300% currently going ot do 113 epochs
# At minibatch 49600, batch loss 0.207442, batch error rate 6.000000%
# At minibatch 49700, batch loss 0.185896, batch error rate 6.000000%
# At minibatch 49800, batch loss 0.489726, batch error rate 12.000000%
# At minibatch 49900, batch loss 0.109338, batch error rate 4.000000%
# At minibatch 50000, batch loss 0.179636, batch error rate 5.000000%
# After epoch 100: valid_err_rate: 0.075100% currently going ot do 113 epochs
# At minibatch 50100, batch loss 0.189047, batch error rate 5.000000%
# At minibatch 50200, batch loss 0.267059, batch error rate 10.000000%
# At minibatch 50300, batch loss 0.375998, batch error rate 11.000000%
# At minibatch 50400, batch loss 0.335940, batch error rate 9.000000%
# At minibatch 50500, batch loss 0.215533, batch error rate 6.000000%
# After epoch 101: valid_err_rate: 0.073200% currently going ot do 113 epochs
# At minibatch 50600, batch loss 0.243242, batch error rate 6.000000%
# At minibatch 50700, batch loss 0.588071, batch error rate 19.000000%
# At minibatch 50800, batch loss 0.154155, batch error rate 5.000000%
# At minibatch 50900, batch loss 0.133108, batch error rate 4.000000%
# At minibatch 51000, batch loss 0.410646, batch error rate 11.000000%
# After epoch 102: valid_err_rate: 0.073100% currently going ot do 113 epochs
# At minibatch 51100, batch loss 0.152047, batch error rate 5.000000%
# At minibatch 51200, batch loss 0.314760, batch error rate 10.000000%
# At minibatch 51300, batch loss 0.433799, batch error rate 10.000000%
# At minibatch 51400, batch loss 0.235930, batch error rate 8.000000%
# At minibatch 51500, batch loss 0.235107, batch error rate 6.000000%
# After epoch 103: valid_err_rate: 0.073600% currently going ot do 113 epochs
# At minibatch 51600, batch loss 0.134904, batch error rate 4.000000%
# At minibatch 51700, batch loss 0.271806, batch error rate 9.000000%
# At minibatch 51800, batch loss 0.246734, batch error rate 5.000000%
# At minibatch 51900, batch loss 0.235659, batch error rate 7.000000%
# At minibatch 52000, batch loss 0.204396, batch error rate 7.000000%
# After epoch 104: valid_err_rate: 0.072500% currently going ot do 113 epochs
# At minibatch 52100, batch loss 0.324525, batch error rate 11.000000%
# At minibatch 52200, batch loss 0.281958, batch error rate 9.000000%
# At minibatch 52300, batch loss 0.178389, batch error rate 6.000000%
# At minibatch 52400, batch loss 0.229868, batch error rate 6.000000%
# At minibatch 52500, batch loss 0.273739, batch error rate 9.000000%
# After epoch 105: valid_err_rate: 0.073100% currently going ot do 113 epochs
# At minibatch 52600, batch loss 0.316914, batch error rate 10.000000%
# At minibatch 52700, batch loss 0.241235, batch error rate 8.000000%
# At minibatch 52800, batch loss 0.401927, batch error rate 11.000000%
# At minibatch 52900, batch loss 0.547988, batch error rate 11.000000%
# At minibatch 53000, batch loss 0.219171, batch error rate 7.000000%
# After epoch 106: valid_err_rate: 0.074000% currently going ot do 113 epochs
# At minibatch 53100, batch loss 0.184897, batch error rate 8.000000%
# At minibatch 53200, batch loss 0.205886, batch error rate 4.000000%
# At minibatch 53300, batch loss 0.281947, batch error rate 8.000000%
# At minibatch 53400, batch loss 0.352337, batch error rate 9.000000%
# At minibatch 53500, batch loss 0.267887, batch error rate 8.000000%
# After epoch 107: valid_err_rate: 0.071500% currently going ot do 113 epochs
# At minibatch 53600, batch loss 0.391631, batch error rate 8.000000%
# At minibatch 53700, batch loss 0.180386, batch error rate 4.000000%
# At minibatch 53800, batch loss 0.341351, batch error rate 12.000000%
# At minibatch 53900, batch loss 0.102999, batch error rate 4.000000%
# At minibatch 54000, batch loss 0.458742, batch error rate 12.000000%
# After epoch 108: valid_err_rate: 0.073300% currently going ot do 113 epochs
# At minibatch 54100, batch loss 0.077409, batch error rate 2.000000%
# At minibatch 54200, batch loss 0.205643, batch error rate 9.000000%
# At minibatch 54300, batch loss 0.275699, batch error rate 9.000000%
# At minibatch 54400, batch loss 0.451953, batch error rate 15.000000%
# At minibatch 54500, batch loss 0.236539, batch error rate 7.000000%
# After epoch 109: valid_err_rate: 0.072400% currently going ot do 113 epochs
# At minibatch 54600, batch loss 0.196481, batch error rate 3.000000%
# At minibatch 54700, batch loss 0.289181, batch error rate 8.000000%
# At minibatch 54800, batch loss 0.540657, batch error rate 9.000000%
# At minibatch 54900, batch loss 0.227121, batch error rate 7.000000%
# At minibatch 55000, batch loss 0.273234, batch error rate 9.000000%
# After epoch 110: valid_err_rate: 0.073200% currently going ot do 113 epochs
# At minibatch 55100, batch loss 0.123840, batch error rate 1.000000%
# At minibatch 55200, batch loss 0.239855, batch error rate 5.000000%
# At minibatch 55300, batch loss 0.223600, batch error rate 8.000000%
# At minibatch 55400, batch loss 0.230458, batch error rate 6.000000%
# At minibatch 55500, batch loss 0.213022, batch error rate 6.000000%
# After epoch 111: valid_err_rate: 0.074200% currently going ot do 113 epochs
# At minibatch 55600, batch loss 0.310270, batch error rate 10.000000%
# At minibatch 55700, batch loss 0.357759, batch error rate 5.000000%
# At minibatch 55800, batch loss 0.300809, batch error rate 9.000000%
# At minibatch 55900, batch loss 0.239566, batch error rate 10.000000%
# At minibatch 56000, batch loss 0.286272, batch error rate 11.000000%
# After epoch 112: valid_err_rate: 0.072700% currently going ot do 113 epochs
# At minibatch 56100, batch loss 0.259586, batch error rate 7.000000%
# At minibatch 56200, batch loss 0.311261, batch error rate 8.000000%
# At minibatch 56300, batch loss 0.304232, batch error rate 8.000000%
# At minibatch 56400, batch loss 0.259167, batch error rate 4.000000%
# At minibatch 56500, batch loss 0.159368, batch error rate 3.000000%
# After epoch 113: valid_err_rate: 0.072300% currently going ot do 113 epochs
# At minibatch 56600, batch loss 0.263378, batch error rate 11.000000%
# At minibatch 56700, batch loss 0.357633, batch error rate 8.000000%
# At minibatch 56800, batch loss 0.270457, batch error rate 9.000000%
# At minibatch 56900, batch loss 0.225048, batch error rate 6.000000%
# At minibatch 57000, batch loss 0.148882, batch error rate 5.000000%
# After epoch 114: valid_err_rate: 0.072600% currently going ot do 113 epochs
# Finished with 114 epochs (minibatch 57000), with best valid error rate 0.071400
# Test error rate: 0.076600

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
for middle_num in [100, 200, 500]:
    net = FeedForwardNet([
            AffineLayer(784, middle_num),
            TanhLayer(),
            AffineLayer(middle_num, 10),
            SoftMaxLayer()
        ])
    SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream, print_debug = False)

#print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 0.752358, batch error rate 21.000000%
# At minibatch 200, batch loss 0.477998, batch error rate 12.000000%
# At minibatch 300, batch loss 0.547733, batch error rate 17.000000%
# At minibatch 400, batch loss 0.453687, batch error rate 16.000000%
# At minibatch 500, batch loss 0.431252, batch error rate 11.000000%
# After epoch 1: valid_err_rate: 0.113400% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.324906, batch error rate 11.000000%
# At minibatch 700, batch loss 0.374277, batch error rate 12.000000%
# At minibatch 800, batch loss 0.272138, batch error rate 12.000000%
# At minibatch 900, batch loss 0.388996, batch error rate 17.000000%
# At minibatch 1000, batch loss 0.460029, batch error rate 12.000000%
# After epoch 2: valid_err_rate: 0.087500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.221656, batch error rate 6.000000%
# At minibatch 1200, batch loss 0.180643, batch error rate 8.000000%
# At minibatch 1300, batch loss 0.362333, batch error rate 13.000000%
# At minibatch 1400, batch loss 0.276459, batch error rate 7.000000%
# At minibatch 1500, batch loss 0.268781, batch error rate 7.000000%
# After epoch 3: valid_err_rate: 0.073800% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.343457, batch error rate 11.000000%
# At minibatch 1700, batch loss 0.245306, batch error rate 7.000000%
# At minibatch 1800, batch loss 0.207813, batch error rate 6.000000%
# At minibatch 1900, batch loss 0.218877, batch error rate 5.000000%
# At minibatch 2000, batch loss 0.244151, batch error rate 8.000000%
# After epoch 4: valid_err_rate: 0.068100% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.174347, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.214285, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.289601, batch error rate 10.000000%
# At minibatch 2400, batch loss 0.170966, batch error rate 8.000000%
# At minibatch 2500, batch loss 0.223228, batch error rate 10.000000%
# After epoch 5: valid_err_rate: 0.062900% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.213366, batch error rate 7.000000%
# At minibatch 2700, batch loss 0.173209, batch error rate 5.000000%
# At minibatch 2800, batch loss 0.182224, batch error rate 4.000000%
# At minibatch 2900, batch loss 0.295090, batch error rate 8.000000%
# At minibatch 3000, batch loss 0.207581, batch error rate 7.000000%
# After epoch 6: valid_err_rate: 0.060700% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.226308, batch error rate 8.000000%
# At minibatch 3200, batch loss 0.198450, batch error rate 7.000000%
# At minibatch 3300, batch loss 0.140384, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.409883, batch error rate 12.000000%
# At minibatch 3500, batch loss 0.066216, batch error rate 0.000000%
# After epoch 7: valid_err_rate: 0.057000% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.161462, batch error rate 6.000000%
# At minibatch 3700, batch loss 0.115996, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.111561, batch error rate 5.000000%
# At minibatch 3900, batch loss 0.168991, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.158475, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.054300% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.269930, batch error rate 5.000000%
# At minibatch 4200, batch loss 0.169232, batch error rate 4.000000%
# At minibatch 4300, batch loss 0.211767, batch error rate 9.000000%
# At minibatch 4400, batch loss 0.084686, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.153879, batch error rate 4.000000%
# After epoch 9: valid_err_rate: 0.052200% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.233302, batch error rate 5.000000%
# At minibatch 4700, batch loss 0.127637, batch error rate 4.000000%
# At minibatch 4800, batch loss 0.215808, batch error rate 6.000000%
# At minibatch 4900, batch loss 0.118505, batch error rate 4.000000%
# At minibatch 5000, batch loss 0.150525, batch error rate 6.000000%
# After epoch 10: valid_err_rate: 0.052000% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.081524, batch error rate 3.000000%
# At minibatch 5200, batch loss 0.170148, batch error rate 8.000000%
# At minibatch 5300, batch loss 0.062151, batch error rate 1.000000%
# At minibatch 5400, batch loss 0.093439, batch error rate 3.000000%
# At minibatch 5500, batch loss 0.241791, batch error rate 5.000000%
# After epoch 11: valid_err_rate: 0.048600% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.133334, batch error rate 4.000000%
# At minibatch 5700, batch loss 0.098893, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.105354, batch error rate 5.000000%
# At minibatch 5900, batch loss 0.063708, batch error rate 1.000000%
# At minibatch 6000, batch loss 0.170980, batch error rate 7.000000%
# After epoch 12: valid_err_rate: 0.047800% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.077788, batch error rate 3.000000%
# At minibatch 6200, batch loss 0.120947, batch error rate 5.000000%
# At minibatch 6300, batch loss 0.204294, batch error rate 5.000000%
# At minibatch 6400, batch loss 0.135321, batch error rate 4.000000%
# At minibatch 6500, batch loss 0.048353, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.046400% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.023978, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.098857, batch error rate 4.000000%
# At minibatch 6800, batch loss 0.135554, batch error rate 5.000000%
# At minibatch 6900, batch loss 0.187983, batch error rate 5.000000%
# At minibatch 7000, batch loss 0.062873, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.047600% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.058227, batch error rate 0.000000%
# At minibatch 7200, batch loss 0.045037, batch error rate 1.000000%
# At minibatch 7300, batch loss 0.081496, batch error rate 1.000000%
# At minibatch 7400, batch loss 0.088557, batch error rate 2.000000%
# At minibatch 7500, batch loss 0.120465, batch error rate 5.000000%
# After epoch 15: valid_err_rate: 0.045900% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.039549, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.044194, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.049112, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.073540, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.111701, batch error rate 4.000000%
# After epoch 16: valid_err_rate: 0.044400% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.044941, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.108550, batch error rate 2.000000%
# At minibatch 8300, batch loss 0.070173, batch error rate 2.000000%
# At minibatch 8400, batch loss 0.097821, batch error rate 4.000000%
# At minibatch 8500, batch loss 0.075818, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.045800% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.078022, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.072675, batch error rate 2.000000%
# At minibatch 8800, batch loss 0.132635, batch error rate 5.000000%
# At minibatch 8900, batch loss 0.086029, batch error rate 4.000000%
# At minibatch 9000, batch loss 0.028508, batch error rate 0.000000%
# After epoch 18: valid_err_rate: 0.045200% currently going ot do 25 epochs
# At minibatch 9100, batch loss 0.043769, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.066261, batch error rate 2.000000%
# At minibatch 9300, batch loss 0.105735, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.065717, batch error rate 2.000000%
# At minibatch 9500, batch loss 0.080313, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.042100% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.036725, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.044402, batch error rate 1.000000%
# At minibatch 9800, batch loss 0.056610, batch error rate 2.000000%
# At minibatch 9900, batch loss 0.086853, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.066189, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.043700% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.059155, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.044765, batch error rate 1.000000%
# At minibatch 10300, batch loss 0.041255, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.067508, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.128905, batch error rate 4.000000%
# After epoch 21: valid_err_rate: 0.044900% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.033079, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.040597, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.034760, batch error rate 2.000000%
# At minibatch 10900, batch loss 0.079532, batch error rate 3.000000%
# At minibatch 11000, batch loss 0.087463, batch error rate 4.000000%
# After epoch 22: valid_err_rate: 0.042900% currently going ot do 29 epochs
# At minibatch 11100, batch loss 0.022237, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.060090, batch error rate 2.000000%
# At minibatch 11300, batch loss 0.035690, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.057921, batch error rate 3.000000%
# At minibatch 11500, batch loss 0.058877, batch error rate 2.000000%
# After epoch 23: valid_err_rate: 0.041800% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.033604, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.048905, batch error rate 2.000000%
# At minibatch 11800, batch loss 0.059675, batch error rate 1.000000%
# At minibatch 11900, batch loss 0.023314, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.043787, batch error rate 2.000000%
# After epoch 24: valid_err_rate: 0.043000% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.046905, batch error rate 2.000000%
# At minibatch 12200, batch loss 0.033947, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.092866, batch error rate 3.000000%
# At minibatch 12400, batch loss 0.079099, batch error rate 3.000000%
# At minibatch 12500, batch loss 0.109576, batch error rate 1.000000%
# After epoch 25: valid_err_rate: 0.042400% currently going ot do 35 epochs
# At minibatch 12600, batch loss 0.031033, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.043101, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.062872, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.069041, batch error rate 2.000000%
# At minibatch 13000, batch loss 0.050586, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.040900% currently going ot do 40 epochs
# At minibatch 13100, batch loss 0.031294, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.039442, batch error rate 2.000000%
# At minibatch 13300, batch loss 0.052642, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.047637, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.053028, batch error rate 1.000000%
# After epoch 27: valid_err_rate: 0.042000% currently going ot do 40 epochs
# At minibatch 13600, batch loss 0.041267, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.075255, batch error rate 2.000000%
# At minibatch 13800, batch loss 0.024206, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.058728, batch error rate 2.000000%
# At minibatch 14000, batch loss 0.066312, batch error rate 2.000000%
# After epoch 28: valid_err_rate: 0.042300% currently going ot do 40 epochs
# At minibatch 14100, batch loss 0.015939, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.017873, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.035153, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.031162, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.058069, batch error rate 2.000000%
# After epoch 29: valid_err_rate: 0.040000% currently going ot do 44 epochs
# At minibatch 14600, batch loss 0.033881, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.070655, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.013887, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.041191, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.083720, batch error rate 1.000000%
# After epoch 30: valid_err_rate: 0.041300% currently going ot do 44 epochs
# At minibatch 15100, batch loss 0.037196, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.037664, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.023856, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.025034, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.023094, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.042100% currently going ot do 44 epochs
# At minibatch 15600, batch loss 0.027601, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.051829, batch error rate 2.000000%
# At minibatch 15800, batch loss 0.027362, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.022856, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.058474, batch error rate 1.000000%
# After epoch 32: valid_err_rate: 0.041500% currently going ot do 44 epochs
# At minibatch 16100, batch loss 0.027250, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.038235, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.018066, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.024948, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.030697, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.041200% currently going ot do 44 epochs
# At minibatch 16600, batch loss 0.036649, batch error rate 2.000000%
# At minibatch 16700, batch loss 0.031238, batch error rate 1.000000%
# At minibatch 16800, batch loss 0.024768, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.031555, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.043303, batch error rate 2.000000%
# After epoch 34: valid_err_rate: 0.040800% currently going ot do 44 epochs
# At minibatch 17100, batch loss 0.065072, batch error rate 1.000000%
# At minibatch 17200, batch loss 0.022987, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.009035, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.048662, batch error rate 1.000000%
# At minibatch 17500, batch loss 0.018593, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.040900% currently going ot do 44 epochs
# At minibatch 17600, batch loss 0.157792, batch error rate 3.000000%
# At minibatch 17700, batch loss 0.024149, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.021335, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.012537, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.047792, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.040300% currently going ot do 44 epochs
# At minibatch 18100, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.035768, batch error rate 1.000000%
# At minibatch 18300, batch loss 0.034052, batch error rate 1.000000%
# At minibatch 18400, batch loss 0.021310, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.042974, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.040300% currently going ot do 44 epochs
# At minibatch 18600, batch loss 0.015448, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.030388, batch error rate 1.000000%
# At minibatch 18800, batch loss 0.020926, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.023663, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.043157, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.040100% currently going ot do 44 epochs
# At minibatch 19100, batch loss 0.019743, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.025432, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.019967, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.035740, batch error rate 1.000000%
# At minibatch 19500, batch loss 0.022754, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.039000% currently going ot do 59 epochs
# At minibatch 19600, batch loss 0.019637, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.012368, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.027230, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.010795, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.071821, batch error rate 1.000000%
# After epoch 40: valid_err_rate: 0.039300% currently going ot do 59 epochs
# At minibatch 20100, batch loss 0.018024, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.068486, batch error rate 1.000000%
# At minibatch 20300, batch loss 0.013826, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.025085, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.028449, batch error rate 1.000000%
# After epoch 41: valid_err_rate: 0.040800% currently going ot do 59 epochs
# At minibatch 20600, batch loss 0.011177, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.021011, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.012655, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.032176, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.017979, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.040400% currently going ot do 59 epochs
# At minibatch 21100, batch loss 0.013865, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.028414, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.018785, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.031535, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.012175, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.038900% currently going ot do 65 epochs
# At minibatch 21600, batch loss 0.032178, batch error rate 1.000000%
# At minibatch 21700, batch loss 0.028000, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.082997, batch error rate 2.000000%
# At minibatch 21900, batch loss 0.035478, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.011270, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.039900% currently going ot do 65 epochs
# At minibatch 22100, batch loss 0.010933, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.064643, batch error rate 1.000000%
# At minibatch 22300, batch loss 0.014078, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.018574, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.085936, batch error rate 2.000000%
# After epoch 45: valid_err_rate: 0.040100% currently going ot do 65 epochs
# At minibatch 22600, batch loss 0.020292, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.015120, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.013129, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.006902, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.008007, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.039800% currently going ot do 65 epochs
# At minibatch 23100, batch loss 0.011260, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.013117, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.011630, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.006745, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.016324, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.039500% currently going ot do 65 epochs
# At minibatch 23600, batch loss 0.012270, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.014683, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.008814, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.021994, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.021949, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.039500% currently going ot do 65 epochs
# At minibatch 24100, batch loss 0.011258, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.009569, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.015517, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.015353, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.015028, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.039600% currently going ot do 65 epochs
# At minibatch 24600, batch loss 0.008364, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.011259, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.039233, batch error rate 1.000000%
# At minibatch 24900, batch loss 0.010989, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.021564, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 25100, batch loss 0.020214, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.013102, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.024997, batch error rate 1.000000%
# At minibatch 25400, batch loss 0.033849, batch error rate 2.000000%
# At minibatch 25500, batch loss 0.008629, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.040200% currently going ot do 76 epochs
# At minibatch 25600, batch loss 0.030839, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.018719, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.009088, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.014284, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.011039, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 26100, batch loss 0.011666, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.033498, batch error rate 1.000000%
# At minibatch 26300, batch loss 0.021060, batch error rate 1.000000%
# At minibatch 26400, batch loss 0.013491, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.015957, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.039500% currently going ot do 76 epochs
# At minibatch 26600, batch loss 0.017625, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.021424, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.036307, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.009404, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.010457, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.038900% currently going ot do 76 epochs
# At minibatch 27100, batch loss 0.013218, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.019756, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.007686, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.008944, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.039581, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 27600, batch loss 0.007509, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.008372, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.010333, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.011130, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.007983, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 28100, batch loss 0.006799, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.010930, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.018323, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.013754, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.007933, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 28600, batch loss 0.005917, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.013511, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.015695, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.003876, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.008486, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.039500% currently going ot do 76 epochs
# At minibatch 29100, batch loss 0.007956, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.006895, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.005714, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.013782, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.006142, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.039400% currently going ot do 76 epochs
# At minibatch 29600, batch loss 0.011267, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.009674, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.006813, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.012121, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.024620, batch error rate 1.000000%
# After epoch 60: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 30100, batch loss 0.007947, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.004037, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.007608, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.029219, batch error rate 1.000000%
# At minibatch 30500, batch loss 0.016499, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.038600% currently going ot do 76 epochs
# At minibatch 30600, batch loss 0.007498, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.012337, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.009622, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.011275, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.009877, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.038800% currently going ot do 76 epochs
# At minibatch 31100, batch loss 0.015146, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.009775, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.005236, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.005664, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.010845, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.039600% currently going ot do 76 epochs
# At minibatch 31600, batch loss 0.004780, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.012639, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.004466, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.012814, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.013206, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.041200% currently going ot do 76 epochs
# At minibatch 32100, batch loss 0.006943, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.011504, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.015493, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.011306, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.005351, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.038900% currently going ot do 76 epochs
# At minibatch 32600, batch loss 0.021986, batch error rate 1.000000%
# At minibatch 32700, batch loss 0.009570, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.004740, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.005802, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.006476, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.039200% currently going ot do 76 epochs
# At minibatch 33100, batch loss 0.009840, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.003499, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.006760, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.006875, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.007697, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 33600, batch loss 0.013796, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.014163, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.006759, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.012106, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.011981, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 34100, batch loss 0.006461, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.005778, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.009644, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.005874, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.008751, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 34600, batch loss 0.007641, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.008348, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.001595, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.009726, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.002548, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.038800% currently going ot do 76 epochs
# At minibatch 35100, batch loss 0.004277, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.012030, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.006763, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.001690, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.008431, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 35600, batch loss 0.004615, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.010752, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.010706, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.003895, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.005607, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 36100, batch loss 0.036910, batch error rate 1.000000%
# At minibatch 36200, batch loss 0.011330, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.010214, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.003402, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.002292, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 36600, batch loss 0.006251, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.014974, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.009583, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.011105, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.004760, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 37100, batch loss 0.009571, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.010823, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.013812, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.008803, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.010118, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.039200% currently going ot do 76 epochs
# At minibatch 37600, batch loss 0.008371, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.006577, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.011679, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.006033, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.013167, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.039000% currently going ot do 76 epochs
# Test error rate: 0.042300

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.078

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
