# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 0.949864, train error rate 44.666667%
# At iteration 1000, loss 0.052694, train error rate 2.000000%
# At iteration 2000, loss 0.043831, train error rate 1.333333%
# At iteration 3000, loss 0.041411, train error rate 1.333333%
# At iteration 4000, loss 0.040305, train error rate 1.333333%
# At iteration 5000, loss 0.039611, train error rate 1.333333%
# At iteration 6000, loss 0.039070, train error rate 1.333333%
# At iteration 7000, loss 0.038593, train error rate 1.333333%
# At iteration 8000, loss 0.038146, train error rate 1.333333%
# At iteration 9000, loss 0.037714, train error rate 1.333333%
# At iteration 10000, loss 0.037293, train error rate 1.333333%
# At iteration 11000, loss 0.036878, train error rate 1.333333%
# At iteration 12000, loss 0.036464, train error rate 1.333333%
# At iteration 13000, loss 0.036049, train error rate 1.333333%
# At iteration 14000, loss 0.035627, train error rate 1.333333%
# At iteration 15000, loss 0.035195, train error rate 1.333333%
# At iteration 16000, loss 0.034750, train error rate 1.333333%
# At iteration 17000, loss 0.034289, train error rate 1.333333%
# At iteration 18000, loss 0.033808, train error rate 1.333333%
# At iteration 19000, loss 0.033301, train error rate 1.333333%
# At iteration 20000, loss 0.032758, train error rate 1.333333%
# At iteration 21000, loss 0.032171, train error rate 1.333333%
# At iteration 22000, loss 0.031529, train error rate 1.333333%
# At iteration 23000, loss 0.030826, train error rate 1.333333%
# At iteration 24000, loss 0.030060, train error rate 1.333333%
# At iteration 25000, loss 0.029235, train error rate 1.333333%
# At iteration 26000, loss 0.028356, train error rate 1.333333%
# At iteration 27000, loss 0.027433, train error rate 1.333333%
# At iteration 28000, loss 0.026482, train error rate 1.333333%
# At iteration 29000, loss 0.025515, train error rate 1.333333%
# At iteration 30000, loss 0.024542, train error rate 1.333333%
# At iteration 31000, loss 0.023565, train error rate 1.333333%
# At iteration 32000, loss 0.022579, train error rate 1.333333%
# At iteration 33000, loss 0.021579, train error rate 1.333333%
# At iteration 34000, loss 0.020559, train error rate 1.333333%
# At iteration 35000, loss 0.019513, train error rate 1.333333%
# At iteration 36000, loss 0.018442, train error rate 1.333333%
# At iteration 37000, loss 0.017353, train error rate 1.333333%
# At iteration 38000, loss 0.016260, train error rate 0.666667%
# At iteration 39000, loss 0.015179, train error rate 0.000000%
# At iteration 40000, loss 0.014126, train error rate 0.000000%
# At iteration 41000, loss 0.013113, train error rate 0.000000%
# At iteration 42000, loss 0.012151, train error rate 0.000000%
# At iteration 43000, loss 0.011247, train error rate 0.000000%
# At iteration 44000, loss 0.010403, train error rate 0.000000%
# At iteration 45000, loss 0.009624, train error rate 0.000000%
# At iteration 46000, loss 0.008908, train error rate 0.000000%
# At iteration 47000, loss 0.008254, train error rate 0.000000%
# At iteration 48000, loss 0.007659, train error rate 0.000000%
# At iteration 49000, loss 0.007118, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    #velocities = [None for P in net.parameters]
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        pass
                        #G -= 0.001 * P
                    

                    alpha = 5e-2 * np.power(0.995, e)
                    
                    epsilon = 1. - 3. / (5. + i)
                    
                    V = epsilon * V - alpha * G
                    
                    #P += -5e-2 * G
                    P += V
                    
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                e, val_error_rate, number_of_epochs)
            
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 0.623129, batch error rate 18.000000%
# At minibatch 200, batch loss 0.592192, batch error rate 14.000000%
# At minibatch 300, batch loss 0.489330, batch error rate 12.000000%
# At minibatch 400, batch loss 0.496650, batch error rate 15.000000%
# At minibatch 500, batch loss 0.427581, batch error rate 13.000000%
# After epoch 1: valid_err_rate: 0.122700% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.420649, batch error rate 14.000000%
# At minibatch 700, batch loss 0.388706, batch error rate 16.000000%
# At minibatch 800, batch loss 0.510863, batch error rate 15.000000%
# At minibatch 900, batch loss 0.381738, batch error rate 10.000000%
# At minibatch 1000, batch loss 0.562004, batch error rate 10.000000%
# After epoch 2: valid_err_rate: 0.109200% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.522165, batch error rate 13.000000%
# At minibatch 1200, batch loss 0.385621, batch error rate 12.000000%
# At minibatch 1300, batch loss 0.457173, batch error rate 17.000000%
# At minibatch 1400, batch loss 0.354588, batch error rate 10.000000%
# At minibatch 1500, batch loss 0.517191, batch error rate 10.000000%
# After epoch 3: valid_err_rate: 0.097900% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.327583, batch error rate 11.000000%
# At minibatch 1700, batch loss 0.239365, batch error rate 8.000000%
# At minibatch 1800, batch loss 0.420681, batch error rate 9.000000%
# At minibatch 1900, batch loss 0.223403, batch error rate 5.000000%
# At minibatch 2000, batch loss 0.372792, batch error rate 13.000000%
# After epoch 4: valid_err_rate: 0.096800% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.244316, batch error rate 7.000000%
# At minibatch 2200, batch loss 0.338343, batch error rate 13.000000%
# At minibatch 2300, batch loss 0.170965, batch error rate 6.000000%
# At minibatch 2400, batch loss 0.790573, batch error rate 19.000000%
# At minibatch 2500, batch loss 0.591871, batch error rate 11.000000%
# After epoch 5: valid_err_rate: 0.090600% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.365719, batch error rate 5.000000%
# At minibatch 2700, batch loss 0.469171, batch error rate 16.000000%
# At minibatch 2800, batch loss 0.453119, batch error rate 15.000000%
# At minibatch 2900, batch loss 0.258563, batch error rate 8.000000%
# At minibatch 3000, batch loss 0.322687, batch error rate 10.000000%
# After epoch 6: valid_err_rate: 0.089800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.258965, batch error rate 5.000000%
# At minibatch 3200, batch loss 0.262874, batch error rate 7.000000%
# At minibatch 3300, batch loss 0.239801, batch error rate 7.000000%
# At minibatch 3400, batch loss 0.257325, batch error rate 12.000000%
# At minibatch 3500, batch loss 0.281878, batch error rate 7.000000%
# After epoch 7: valid_err_rate: 0.086200% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.641348, batch error rate 19.000000%
# At minibatch 3700, batch loss 0.347940, batch error rate 11.000000%
# At minibatch 3800, batch loss 0.398869, batch error rate 13.000000%
# At minibatch 3900, batch loss 0.160515, batch error rate 5.000000%
# At minibatch 4000, batch loss 0.356115, batch error rate 12.000000%
# After epoch 8: valid_err_rate: 0.086500% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.169105, batch error rate 4.000000%
# At minibatch 4200, batch loss 0.449502, batch error rate 10.000000%
# At minibatch 4300, batch loss 0.362683, batch error rate 11.000000%
# At minibatch 4400, batch loss 0.201186, batch error rate 7.000000%
# At minibatch 4500, batch loss 0.317111, batch error rate 11.000000%
# After epoch 9: valid_err_rate: 0.084200% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.454991, batch error rate 12.000000%
# At minibatch 4700, batch loss 0.430001, batch error rate 12.000000%
# At minibatch 4800, batch loss 0.167307, batch error rate 3.000000%
# At minibatch 4900, batch loss 0.309788, batch error rate 10.000000%
# At minibatch 5000, batch loss 0.344443, batch error rate 10.000000%
# After epoch 10: valid_err_rate: 0.087400% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.258293, batch error rate 8.000000%
# At minibatch 5200, batch loss 0.461089, batch error rate 17.000000%
# At minibatch 5300, batch loss 0.243479, batch error rate 6.000000%
# At minibatch 5400, batch loss 0.360019, batch error rate 9.000000%
# At minibatch 5500, batch loss 0.295846, batch error rate 7.000000%
# After epoch 11: valid_err_rate: 0.082800% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.303903, batch error rate 8.000000%
# At minibatch 5700, batch loss 0.203869, batch error rate 7.000000%
# At minibatch 5800, batch loss 0.235048, batch error rate 8.000000%
# At minibatch 5900, batch loss 0.200235, batch error rate 7.000000%
# At minibatch 6000, batch loss 0.269390, batch error rate 8.000000%
# After epoch 12: valid_err_rate: 0.080300% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.282439, batch error rate 10.000000%
# At minibatch 6200, batch loss 0.355317, batch error rate 7.000000%
# At minibatch 6300, batch loss 0.327424, batch error rate 11.000000%
# At minibatch 6400, batch loss 0.392821, batch error rate 11.000000%
# At minibatch 6500, batch loss 0.234022, batch error rate 8.000000%
# After epoch 13: valid_err_rate: 0.079000% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.357876, batch error rate 9.000000%
# At minibatch 6700, batch loss 0.362019, batch error rate 8.000000%
# At minibatch 6800, batch loss 0.280627, batch error rate 10.000000%
# At minibatch 6900, batch loss 0.217459, batch error rate 7.000000%
# At minibatch 7000, batch loss 0.410573, batch error rate 9.000000%
# After epoch 14: valid_err_rate: 0.078800% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.262306, batch error rate 8.000000%
# At minibatch 7200, batch loss 0.289867, batch error rate 9.000000%
# At minibatch 7300, batch loss 0.628995, batch error rate 16.000000%
# At minibatch 7400, batch loss 0.268089, batch error rate 8.000000%
# At minibatch 7500, batch loss 0.254042, batch error rate 8.000000%
# After epoch 15: valid_err_rate: 0.079800% currently going ot do 22 epochs
# At minibatch 7600, batch loss 0.232411, batch error rate 6.000000%
# At minibatch 7700, batch loss 0.164015, batch error rate 5.000000%
# At minibatch 7800, batch loss 0.503311, batch error rate 15.000000%
# At minibatch 7900, batch loss 0.242489, batch error rate 6.000000%
# At minibatch 8000, batch loss 0.368312, batch error rate 11.000000%
# After epoch 16: valid_err_rate: 0.080600% currently going ot do 22 epochs
# At minibatch 8100, batch loss 0.315309, batch error rate 9.000000%
# At minibatch 8200, batch loss 0.194100, batch error rate 4.000000%
# At minibatch 8300, batch loss 0.348889, batch error rate 8.000000%
# At minibatch 8400, batch loss 0.320315, batch error rate 11.000000%
# At minibatch 8500, batch loss 0.231841, batch error rate 5.000000%
# After epoch 17: valid_err_rate: 0.080400% currently going ot do 22 epochs
# At minibatch 8600, batch loss 0.194581, batch error rate 5.000000%
# At minibatch 8700, batch loss 0.332907, batch error rate 11.000000%
# At minibatch 8800, batch loss 0.272423, batch error rate 9.000000%
# At minibatch 8900, batch loss 0.271579, batch error rate 10.000000%
# At minibatch 9000, batch loss 0.285477, batch error rate 9.000000%
# After epoch 18: valid_err_rate: 0.083800% currently going ot do 22 epochs
# At minibatch 9100, batch loss 0.306891, batch error rate 7.000000%
# At minibatch 9200, batch loss 0.294278, batch error rate 6.000000%
# At minibatch 9300, batch loss 0.225751, batch error rate 6.000000%
# At minibatch 9400, batch loss 0.354146, batch error rate 9.000000%
# At minibatch 9500, batch loss 0.242197, batch error rate 6.000000%
# After epoch 19: valid_err_rate: 0.077400% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.224963, batch error rate 8.000000%
# At minibatch 9700, batch loss 0.373950, batch error rate 11.000000%
# At minibatch 9800, batch loss 0.299507, batch error rate 9.000000%
# At minibatch 9900, batch loss 0.220867, batch error rate 5.000000%
# At minibatch 10000, batch loss 0.244203, batch error rate 5.000000%
# After epoch 20: valid_err_rate: 0.078200% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.604756, batch error rate 11.000000%
# At minibatch 10200, batch loss 0.343141, batch error rate 8.000000%
# At minibatch 10300, batch loss 0.269553, batch error rate 8.000000%
# At minibatch 10400, batch loss 0.434185, batch error rate 10.000000%
# At minibatch 10500, batch loss 0.175545, batch error rate 8.000000%
# After epoch 21: valid_err_rate: 0.078200% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.373248, batch error rate 10.000000%
# At minibatch 10700, batch loss 0.359700, batch error rate 9.000000%
# At minibatch 10800, batch loss 0.235349, batch error rate 6.000000%
# At minibatch 10900, batch loss 0.315643, batch error rate 8.000000%
# At minibatch 11000, batch loss 0.086899, batch error rate 2.000000%
# After epoch 22: valid_err_rate: 0.078300% currently going ot do 29 epochs
# At minibatch 11100, batch loss 0.332834, batch error rate 9.000000%
# At minibatch 11200, batch loss 0.178775, batch error rate 6.000000%
# At minibatch 11300, batch loss 0.315214, batch error rate 9.000000%
# At minibatch 11400, batch loss 0.250316, batch error rate 8.000000%
# At minibatch 11500, batch loss 0.215564, batch error rate 8.000000%
# After epoch 23: valid_err_rate: 0.075100% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.252769, batch error rate 9.000000%
# At minibatch 11700, batch loss 0.233218, batch error rate 6.000000%
# At minibatch 11800, batch loss 0.448728, batch error rate 7.000000%
# At minibatch 11900, batch loss 0.312334, batch error rate 10.000000%
# At minibatch 12000, batch loss 0.435350, batch error rate 12.000000%
# After epoch 24: valid_err_rate: 0.078600% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.189338, batch error rate 7.000000%
# At minibatch 12200, batch loss 0.320044, batch error rate 5.000000%
# At minibatch 12300, batch loss 0.318913, batch error rate 10.000000%
# At minibatch 12400, batch loss 0.293197, batch error rate 7.000000%
# At minibatch 12500, batch loss 0.282730, batch error rate 11.000000%
# After epoch 25: valid_err_rate: 0.078600% currently going ot do 35 epochs
# At minibatch 12600, batch loss 0.335168, batch error rate 9.000000%
# At minibatch 12700, batch loss 0.197578, batch error rate 5.000000%
# At minibatch 12800, batch loss 0.364743, batch error rate 10.000000%
# At minibatch 12900, batch loss 0.140646, batch error rate 7.000000%
# At minibatch 13000, batch loss 0.330096, batch error rate 9.000000%
# After epoch 26: valid_err_rate: 0.075300% currently going ot do 35 epochs
# At minibatch 13100, batch loss 0.303881, batch error rate 9.000000%
# At minibatch 13200, batch loss 0.311572, batch error rate 8.000000%
# At minibatch 13300, batch loss 0.255055, batch error rate 8.000000%
# At minibatch 13400, batch loss 0.344404, batch error rate 7.000000%
# At minibatch 13500, batch loss 0.156721, batch error rate 6.000000%
# After epoch 27: valid_err_rate: 0.077100% currently going ot do 35 epochs
# At minibatch 13600, batch loss 0.281125, batch error rate 10.000000%
# At minibatch 13700, batch loss 0.201339, batch error rate 4.000000%
# At minibatch 13800, batch loss 0.293763, batch error rate 10.000000%
# At minibatch 13900, batch loss 0.388969, batch error rate 12.000000%
# At minibatch 14000, batch loss 0.489966, batch error rate 11.000000%
# After epoch 28: valid_err_rate: 0.076700% currently going ot do 35 epochs
# At minibatch 14100, batch loss 0.195103, batch error rate 3.000000%
# At minibatch 14200, batch loss 0.379157, batch error rate 12.000000%
# At minibatch 14300, batch loss 0.159202, batch error rate 6.000000%
# At minibatch 14400, batch loss 0.194021, batch error rate 7.000000%
# At minibatch 14500, batch loss 0.406121, batch error rate 10.000000%
# After epoch 29: valid_err_rate: 0.076500% currently going ot do 35 epochs
# At minibatch 14600, batch loss 0.453381, batch error rate 9.000000%
# At minibatch 14700, batch loss 0.391902, batch error rate 5.000000%
# At minibatch 14800, batch loss 0.135711, batch error rate 4.000000%
# At minibatch 14900, batch loss 0.299900, batch error rate 8.000000%
# At minibatch 15000, batch loss 0.395637, batch error rate 10.000000%
# After epoch 30: valid_err_rate: 0.079400% currently going ot do 35 epochs
# At minibatch 15100, batch loss 0.283386, batch error rate 9.000000%
# At minibatch 15200, batch loss 0.269981, batch error rate 8.000000%
# At minibatch 15300, batch loss 0.411062, batch error rate 7.000000%
# At minibatch 15400, batch loss 0.370802, batch error rate 10.000000%
# At minibatch 15500, batch loss 0.177544, batch error rate 5.000000%
# After epoch 31: valid_err_rate: 0.075200% currently going ot do 35 epochs
# At minibatch 15600, batch loss 0.292104, batch error rate 12.000000%
# At minibatch 15700, batch loss 0.254885, batch error rate 11.000000%
# At minibatch 15800, batch loss 0.200876, batch error rate 7.000000%
# At minibatch 15900, batch loss 0.160774, batch error rate 5.000000%
# At minibatch 16000, batch loss 0.174686, batch error rate 5.000000%
# After epoch 32: valid_err_rate: 0.074700% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.211774, batch error rate 4.000000%
# At minibatch 16200, batch loss 0.215241, batch error rate 7.000000%
# At minibatch 16300, batch loss 0.188056, batch error rate 7.000000%
# At minibatch 16400, batch loss 0.231428, batch error rate 3.000000%
# At minibatch 16500, batch loss 0.176481, batch error rate 3.000000%
# After epoch 33: valid_err_rate: 0.076200% currently going ot do 49 epochs
# At minibatch 16600, batch loss 0.313461, batch error rate 8.000000%
# At minibatch 16700, batch loss 0.124388, batch error rate 3.000000%
# At minibatch 16800, batch loss 0.322765, batch error rate 7.000000%
# At minibatch 16900, batch loss 0.184175, batch error rate 5.000000%
# At minibatch 17000, batch loss 0.384765, batch error rate 6.000000%
# After epoch 34: valid_err_rate: 0.077100% currently going ot do 49 epochs
# At minibatch 17100, batch loss 0.241805, batch error rate 8.000000%
# At minibatch 17200, batch loss 0.324337, batch error rate 10.000000%
# At minibatch 17300, batch loss 0.213965, batch error rate 6.000000%
# At minibatch 17400, batch loss 0.187997, batch error rate 6.000000%
# At minibatch 17500, batch loss 0.198171, batch error rate 7.000000%
# After epoch 35: valid_err_rate: 0.075400% currently going ot do 49 epochs
# At minibatch 17600, batch loss 0.324082, batch error rate 9.000000%
# At minibatch 17700, batch loss 0.203199, batch error rate 9.000000%
# At minibatch 17800, batch loss 0.266690, batch error rate 7.000000%
# At minibatch 17900, batch loss 0.269540, batch error rate 9.000000%
# At minibatch 18000, batch loss 0.302269, batch error rate 9.000000%
# After epoch 36: valid_err_rate: 0.075800% currently going ot do 49 epochs
# At minibatch 18100, batch loss 0.315328, batch error rate 7.000000%
# At minibatch 18200, batch loss 0.433037, batch error rate 11.000000%
# At minibatch 18300, batch loss 0.219208, batch error rate 6.000000%
# At minibatch 18400, batch loss 0.225479, batch error rate 6.000000%
# At minibatch 18500, batch loss 0.257493, batch error rate 8.000000%
# After epoch 37: valid_err_rate: 0.077800% currently going ot do 49 epochs
# At minibatch 18600, batch loss 0.160790, batch error rate 6.000000%
# At minibatch 18700, batch loss 0.227876, batch error rate 8.000000%
# At minibatch 18800, batch loss 0.321345, batch error rate 7.000000%
# At minibatch 18900, batch loss 0.251614, batch error rate 10.000000%
# At minibatch 19000, batch loss 0.310090, batch error rate 6.000000%
# After epoch 38: valid_err_rate: 0.076300% currently going ot do 49 epochs
# At minibatch 19100, batch loss 0.199047, batch error rate 4.000000%
# At minibatch 19200, batch loss 0.264929, batch error rate 7.000000%
# At minibatch 19300, batch loss 0.155830, batch error rate 5.000000%
# At minibatch 19400, batch loss 0.177441, batch error rate 6.000000%
# At minibatch 19500, batch loss 0.178606, batch error rate 6.000000%
# After epoch 39: valid_err_rate: 0.075500% currently going ot do 49 epochs
# At minibatch 19600, batch loss 0.112728, batch error rate 3.000000%
# At minibatch 19700, batch loss 0.476450, batch error rate 10.000000%
# At minibatch 19800, batch loss 0.161053, batch error rate 5.000000%
# At minibatch 19900, batch loss 0.284603, batch error rate 8.000000%
# At minibatch 20000, batch loss 0.301281, batch error rate 14.000000%
# After epoch 40: valid_err_rate: 0.078000% currently going ot do 49 epochs
# At minibatch 20100, batch loss 0.221958, batch error rate 9.000000%
# At minibatch 20200, batch loss 0.418071, batch error rate 11.000000%
# At minibatch 20300, batch loss 0.262362, batch error rate 4.000000%
# At minibatch 20400, batch loss 0.333096, batch error rate 8.000000%
# At minibatch 20500, batch loss 0.325611, batch error rate 10.000000%
# After epoch 41: valid_err_rate: 0.077200% currently going ot do 49 epochs
# At minibatch 20600, batch loss 0.227671, batch error rate 7.000000%
# At minibatch 20700, batch loss 0.257862, batch error rate 9.000000%
# At minibatch 20800, batch loss 0.323211, batch error rate 12.000000%
# At minibatch 20900, batch loss 0.194039, batch error rate 7.000000%
# At minibatch 21000, batch loss 0.318766, batch error rate 9.000000%
# After epoch 42: valid_err_rate: 0.076300% currently going ot do 49 epochs
# At minibatch 21100, batch loss 0.271842, batch error rate 8.000000%
# At minibatch 21200, batch loss 0.274403, batch error rate 7.000000%
# At minibatch 21300, batch loss 0.348903, batch error rate 8.000000%
# At minibatch 21400, batch loss 0.172684, batch error rate 3.000000%
# At minibatch 21500, batch loss 0.377127, batch error rate 7.000000%
# After epoch 43: valid_err_rate: 0.074100% currently going ot do 65 epochs
# At minibatch 21600, batch loss 0.398600, batch error rate 11.000000%
# At minibatch 21700, batch loss 0.199490, batch error rate 7.000000%
# At minibatch 21800, batch loss 0.242199, batch error rate 5.000000%
# At minibatch 21900, batch loss 0.331727, batch error rate 9.000000%
# At minibatch 22000, batch loss 0.395605, batch error rate 11.000000%
# After epoch 44: valid_err_rate: 0.073100% currently going ot do 67 epochs
# At minibatch 22100, batch loss 0.171774, batch error rate 4.000000%
# At minibatch 22200, batch loss 0.318230, batch error rate 8.000000%
# At minibatch 22300, batch loss 0.264460, batch error rate 4.000000%
# At minibatch 22400, batch loss 0.250953, batch error rate 8.000000%
# At minibatch 22500, batch loss 0.245047, batch error rate 7.000000%
# After epoch 45: valid_err_rate: 0.076900% currently going ot do 67 epochs
# At minibatch 22600, batch loss 0.216439, batch error rate 7.000000%
# At minibatch 22700, batch loss 0.322756, batch error rate 8.000000%
# At minibatch 22800, batch loss 0.497598, batch error rate 13.000000%
# At minibatch 22900, batch loss 0.171052, batch error rate 8.000000%
# At minibatch 23000, batch loss 0.514978, batch error rate 11.000000%
# After epoch 46: valid_err_rate: 0.073300% currently going ot do 67 epochs
# At minibatch 23100, batch loss 0.193213, batch error rate 5.000000%
# At minibatch 23200, batch loss 0.197325, batch error rate 6.000000%
# At minibatch 23300, batch loss 0.270699, batch error rate 7.000000%
# At minibatch 23400, batch loss 0.400379, batch error rate 12.000000%
# At minibatch 23500, batch loss 0.313669, batch error rate 7.000000%
# After epoch 47: valid_err_rate: 0.075600% currently going ot do 67 epochs
# At minibatch 23600, batch loss 0.236184, batch error rate 8.000000%
# At minibatch 23700, batch loss 0.304489, batch error rate 8.000000%
# At minibatch 23800, batch loss 0.258846, batch error rate 9.000000%
# At minibatch 23900, batch loss 0.272968, batch error rate 7.000000%
# At minibatch 24000, batch loss 0.251196, batch error rate 6.000000%
# After epoch 48: valid_err_rate: 0.076300% currently going ot do 67 epochs
# At minibatch 24100, batch loss 0.156979, batch error rate 5.000000%
# At minibatch 24200, batch loss 0.164336, batch error rate 3.000000%
# At minibatch 24300, batch loss 0.200903, batch error rate 8.000000%
# At minibatch 24400, batch loss 0.293769, batch error rate 8.000000%
# At minibatch 24500, batch loss 0.271468, batch error rate 8.000000%
# After epoch 49: valid_err_rate: 0.075700% currently going ot do 67 epochs
# At minibatch 24600, batch loss 0.281031, batch error rate 7.000000%
# At minibatch 24700, batch loss 0.204464, batch error rate 6.000000%
# At minibatch 24800, batch loss 0.180943, batch error rate 8.000000%
# At minibatch 24900, batch loss 0.302005, batch error rate 9.000000%
# At minibatch 25000, batch loss 0.210549, batch error rate 8.000000%
# After epoch 50: valid_err_rate: 0.076400% currently going ot do 67 epochs
# At minibatch 25100, batch loss 0.307564, batch error rate 8.000000%
# At minibatch 25200, batch loss 0.293119, batch error rate 8.000000%
# At minibatch 25300, batch loss 0.247110, batch error rate 6.000000%
# At minibatch 25400, batch loss 0.283297, batch error rate 5.000000%
# At minibatch 25500, batch loss 0.161001, batch error rate 6.000000%
# After epoch 51: valid_err_rate: 0.075600% currently going ot do 67 epochs
# At minibatch 25600, batch loss 0.318926, batch error rate 9.000000%
# At minibatch 25700, batch loss 0.168586, batch error rate 2.000000%
# At minibatch 25800, batch loss 0.176154, batch error rate 7.000000%
# At minibatch 25900, batch loss 0.354272, batch error rate 9.000000%
# At minibatch 26000, batch loss 0.312742, batch error rate 6.000000%
# After epoch 52: valid_err_rate: 0.075900% currently going ot do 67 epochs
# At minibatch 26100, batch loss 0.218959, batch error rate 7.000000%
# At minibatch 26200, batch loss 0.259285, batch error rate 7.000000%
# At minibatch 26300, batch loss 0.278418, batch error rate 9.000000%
# At minibatch 26400, batch loss 0.129773, batch error rate 4.000000%
# At minibatch 26500, batch loss 0.186948, batch error rate 6.000000%
# After epoch 53: valid_err_rate: 0.072600% currently going ot do 80 epochs
# At minibatch 26600, batch loss 0.136739, batch error rate 4.000000%
# At minibatch 26700, batch loss 0.168136, batch error rate 6.000000%
# At minibatch 26800, batch loss 0.338373, batch error rate 7.000000%
# At minibatch 26900, batch loss 0.243368, batch error rate 8.000000%
# At minibatch 27000, batch loss 0.293396, batch error rate 6.000000%
# After epoch 54: valid_err_rate: 0.074900% currently going ot do 80 epochs
# At minibatch 27100, batch loss 0.297547, batch error rate 9.000000%
# At minibatch 27200, batch loss 0.247454, batch error rate 11.000000%
# At minibatch 27300, batch loss 0.183228, batch error rate 6.000000%
# At minibatch 27400, batch loss 0.208617, batch error rate 6.000000%
# At minibatch 27500, batch loss 0.102972, batch error rate 2.000000%
# After epoch 55: valid_err_rate: 0.074400% currently going ot do 80 epochs
# At minibatch 27600, batch loss 0.240776, batch error rate 7.000000%
# At minibatch 27700, batch loss 0.285775, batch error rate 9.000000%
# At minibatch 27800, batch loss 0.232105, batch error rate 5.000000%
# At minibatch 27900, batch loss 0.266609, batch error rate 10.000000%
# At minibatch 28000, batch loss 0.165359, batch error rate 4.000000%
# After epoch 56: valid_err_rate: 0.075500% currently going ot do 80 epochs
# At minibatch 28100, batch loss 0.280605, batch error rate 10.000000%
# At minibatch 28200, batch loss 0.343737, batch error rate 9.000000%
# At minibatch 28300, batch loss 0.323035, batch error rate 12.000000%
# At minibatch 28400, batch loss 0.310476, batch error rate 8.000000%
# At minibatch 28500, batch loss 0.175380, batch error rate 3.000000%
# After epoch 57: valid_err_rate: 0.074500% currently going ot do 80 epochs
# At minibatch 28600, batch loss 0.121457, batch error rate 2.000000%
# At minibatch 28700, batch loss 0.139501, batch error rate 5.000000%
# At minibatch 28800, batch loss 0.316023, batch error rate 6.000000%
# At minibatch 28900, batch loss 0.213281, batch error rate 6.000000%
# At minibatch 29000, batch loss 0.266776, batch error rate 8.000000%
# After epoch 58: valid_err_rate: 0.073800% currently going ot do 80 epochs
# At minibatch 29100, batch loss 0.180995, batch error rate 4.000000%
# At minibatch 29200, batch loss 0.219040, batch error rate 8.000000%
# At minibatch 29300, batch loss 0.291464, batch error rate 9.000000%
# At minibatch 29400, batch loss 0.213641, batch error rate 5.000000%
# At minibatch 29500, batch loss 0.358570, batch error rate 8.000000%
# After epoch 59: valid_err_rate: 0.075800% currently going ot do 80 epochs
# At minibatch 29600, batch loss 0.268030, batch error rate 8.000000%
# At minibatch 29700, batch loss 0.292096, batch error rate 9.000000%
# At minibatch 29800, batch loss 0.236688, batch error rate 3.000000%
# At minibatch 29900, batch loss 0.117380, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.360512, batch error rate 11.000000%
# After epoch 60: valid_err_rate: 0.074900% currently going ot do 80 epochs
# At minibatch 30100, batch loss 0.289870, batch error rate 8.000000%
# At minibatch 30200, batch loss 0.346763, batch error rate 10.000000%
# At minibatch 30300, batch loss 0.252222, batch error rate 9.000000%
# At minibatch 30400, batch loss 0.208685, batch error rate 5.000000%
# At minibatch 30500, batch loss 0.296041, batch error rate 9.000000%
# After epoch 61: valid_err_rate: 0.074100% currently going ot do 80 epochs
# At minibatch 30600, batch loss 0.255469, batch error rate 10.000000%
# At minibatch 30700, batch loss 0.390823, batch error rate 13.000000%
# At minibatch 30800, batch loss 0.368005, batch error rate 9.000000%
# At minibatch 30900, batch loss 0.309246, batch error rate 5.000000%
# At minibatch 31000, batch loss 0.438062, batch error rate 12.000000%
# After epoch 62: valid_err_rate: 0.074000% currently going ot do 80 epochs
# At minibatch 31100, batch loss 0.323537, batch error rate 8.000000%
# At minibatch 31200, batch loss 0.210530, batch error rate 8.000000%
# At minibatch 31300, batch loss 0.229340, batch error rate 8.000000%
# At minibatch 31400, batch loss 0.190444, batch error rate 6.000000%
# At minibatch 31500, batch loss 0.234378, batch error rate 9.000000%
# After epoch 63: valid_err_rate: 0.073000% currently going ot do 80 epochs
# At minibatch 31600, batch loss 0.401379, batch error rate 9.000000%
# At minibatch 31700, batch loss 0.300671, batch error rate 9.000000%
# At minibatch 31800, batch loss 0.213793, batch error rate 7.000000%
# At minibatch 31900, batch loss 0.364569, batch error rate 8.000000%
# At minibatch 32000, batch loss 0.195530, batch error rate 3.000000%
# After epoch 64: valid_err_rate: 0.074700% currently going ot do 80 epochs
# At minibatch 32100, batch loss 0.353629, batch error rate 9.000000%
# At minibatch 32200, batch loss 0.282989, batch error rate 8.000000%
# At minibatch 32300, batch loss 0.279568, batch error rate 9.000000%
# At minibatch 32400, batch loss 0.197767, batch error rate 5.000000%
# At minibatch 32500, batch loss 0.142959, batch error rate 4.000000%
# After epoch 65: valid_err_rate: 0.072600% currently going ot do 80 epochs
# At minibatch 32600, batch loss 0.231045, batch error rate 6.000000%
# At minibatch 32700, batch loss 0.373465, batch error rate 9.000000%
# At minibatch 32800, batch loss 0.293356, batch error rate 7.000000%
# At minibatch 32900, batch loss 0.126766, batch error rate 3.000000%
# At minibatch 33000, batch loss 0.215886, batch error rate 7.000000%
# After epoch 66: valid_err_rate: 0.072700% currently going ot do 80 epochs
# At minibatch 33100, batch loss 0.192575, batch error rate 9.000000%
# At minibatch 33200, batch loss 0.273823, batch error rate 9.000000%
# At minibatch 33300, batch loss 0.219215, batch error rate 6.000000%
# At minibatch 33400, batch loss 0.331325, batch error rate 9.000000%
# At minibatch 33500, batch loss 0.392787, batch error rate 10.000000%
# After epoch 67: valid_err_rate: 0.072400% currently going ot do 101 epochs
# At minibatch 33600, batch loss 0.385464, batch error rate 12.000000%
# At minibatch 33700, batch loss 0.205987, batch error rate 9.000000%
# At minibatch 33800, batch loss 0.257187, batch error rate 5.000000%
# At minibatch 33900, batch loss 0.164360, batch error rate 4.000000%
# At minibatch 34000, batch loss 0.368174, batch error rate 6.000000%
# After epoch 68: valid_err_rate: 0.075100% currently going ot do 101 epochs
# At minibatch 34100, batch loss 0.205769, batch error rate 6.000000%
# At minibatch 34200, batch loss 0.289733, batch error rate 13.000000%
# At minibatch 34300, batch loss 0.200336, batch error rate 4.000000%
# At minibatch 34400, batch loss 0.276352, batch error rate 7.000000%
# At minibatch 34500, batch loss 0.338490, batch error rate 10.000000%
# After epoch 69: valid_err_rate: 0.074200% currently going ot do 101 epochs
# At minibatch 34600, batch loss 0.143106, batch error rate 5.000000%
# At minibatch 34700, batch loss 0.337275, batch error rate 5.000000%
# At minibatch 34800, batch loss 0.374756, batch error rate 9.000000%
# At minibatch 34900, batch loss 0.268032, batch error rate 7.000000%
# At minibatch 35000, batch loss 0.245731, batch error rate 9.000000%
# After epoch 70: valid_err_rate: 0.080400% currently going ot do 101 epochs
# At minibatch 35100, batch loss 0.245867, batch error rate 5.000000%
# At minibatch 35200, batch loss 0.503548, batch error rate 12.000000%
# At minibatch 35300, batch loss 0.184734, batch error rate 9.000000%
# At minibatch 35400, batch loss 0.160880, batch error rate 5.000000%
# At minibatch 35500, batch loss 0.326179, batch error rate 8.000000%
# After epoch 71: valid_err_rate: 0.075900% currently going ot do 101 epochs
# At minibatch 35600, batch loss 0.181161, batch error rate 6.000000%
# At minibatch 35700, batch loss 0.321770, batch error rate 9.000000%
# At minibatch 35800, batch loss 0.258099, batch error rate 7.000000%
# At minibatch 35900, batch loss 0.269268, batch error rate 7.000000%
# At minibatch 36000, batch loss 0.326317, batch error rate 8.000000%
# After epoch 72: valid_err_rate: 0.077300% currently going ot do 101 epochs
# At minibatch 36100, batch loss 0.200642, batch error rate 7.000000%
# At minibatch 36200, batch loss 0.297381, batch error rate 6.000000%
# At minibatch 36300, batch loss 0.283769, batch error rate 9.000000%
# At minibatch 36400, batch loss 0.339615, batch error rate 7.000000%
# At minibatch 36500, batch loss 0.425153, batch error rate 13.000000%
# After epoch 73: valid_err_rate: 0.074600% currently going ot do 101 epochs
# At minibatch 36600, batch loss 0.183683, batch error rate 6.000000%
# At minibatch 36700, batch loss 0.233937, batch error rate 10.000000%
# At minibatch 36800, batch loss 0.248439, batch error rate 7.000000%
# At minibatch 36900, batch loss 0.231726, batch error rate 11.000000%
# At minibatch 37000, batch loss 0.238596, batch error rate 7.000000%
# After epoch 74: valid_err_rate: 0.073900% currently going ot do 101 epochs
# At minibatch 37100, batch loss 0.169020, batch error rate 6.000000%
# At minibatch 37200, batch loss 0.334240, batch error rate 13.000000%
# At minibatch 37300, batch loss 0.286521, batch error rate 6.000000%
# At minibatch 37400, batch loss 0.253955, batch error rate 6.000000%
# At minibatch 37500, batch loss 0.387910, batch error rate 10.000000%
# After epoch 75: valid_err_rate: 0.073500% currently going ot do 101 epochs
# At minibatch 37600, batch loss 0.449822, batch error rate 12.000000%
# At minibatch 37700, batch loss 0.176018, batch error rate 3.000000%
# At minibatch 37800, batch loss 0.279642, batch error rate 12.000000%
# At minibatch 37900, batch loss 0.147816, batch error rate 3.000000%
# At minibatch 38000, batch loss 0.283318, batch error rate 9.000000%
# After epoch 76: valid_err_rate: 0.073800% currently going ot do 101 epochs
# At minibatch 38100, batch loss 0.161622, batch error rate 5.000000%
# At minibatch 38200, batch loss 0.206410, batch error rate 4.000000%
# At minibatch 38300, batch loss 0.208682, batch error rate 6.000000%
# At minibatch 38400, batch loss 0.217817, batch error rate 5.000000%
# At minibatch 38500, batch loss 0.299241, batch error rate 10.000000%
# After epoch 77: valid_err_rate: 0.075300% currently going ot do 101 epochs
# At minibatch 38600, batch loss 0.325631, batch error rate 5.000000%
# At minibatch 38700, batch loss 0.399587, batch error rate 10.000000%
# At minibatch 38800, batch loss 0.418747, batch error rate 7.000000%
# At minibatch 38900, batch loss 0.129473, batch error rate 2.000000%
# At minibatch 39000, batch loss 0.216726, batch error rate 6.000000%
# After epoch 78: valid_err_rate: 0.073000% currently going ot do 101 epochs
# At minibatch 39100, batch loss 0.246541, batch error rate 8.000000%
# At minibatch 39200, batch loss 0.297057, batch error rate 10.000000%
# At minibatch 39300, batch loss 0.161909, batch error rate 3.000000%
# At minibatch 39400, batch loss 0.226369, batch error rate 9.000000%
# At minibatch 39500, batch loss 0.259234, batch error rate 8.000000%
# After epoch 79: valid_err_rate: 0.074100% currently going ot do 101 epochs
# At minibatch 39600, batch loss 0.290682, batch error rate 9.000000%
# At minibatch 39700, batch loss 0.228152, batch error rate 7.000000%
# At minibatch 39800, batch loss 0.274828, batch error rate 11.000000%
# At minibatch 39900, batch loss 0.196273, batch error rate 6.000000%
# At minibatch 40000, batch loss 0.186856, batch error rate 4.000000%
# After epoch 80: valid_err_rate: 0.071200% currently going ot do 121 epochs
# At minibatch 40100, batch loss 0.236922, batch error rate 7.000000%
# At minibatch 40200, batch loss 0.181119, batch error rate 5.000000%
# At minibatch 40300, batch loss 0.325432, batch error rate 11.000000%
# At minibatch 40400, batch loss 0.315447, batch error rate 7.000000%
# At minibatch 40500, batch loss 0.176868, batch error rate 4.000000%
# After epoch 81: valid_err_rate: 0.074900% currently going ot do 121 epochs
# At minibatch 40600, batch loss 0.182000, batch error rate 6.000000%
# At minibatch 40700, batch loss 0.415708, batch error rate 7.000000%
# At minibatch 40800, batch loss 0.318243, batch error rate 9.000000%
# At minibatch 40900, batch loss 0.327913, batch error rate 8.000000%
# At minibatch 41000, batch loss 0.334655, batch error rate 7.000000%
# After epoch 82: valid_err_rate: 0.075000% currently going ot do 121 epochs
# At minibatch 41100, batch loss 0.229015, batch error rate 7.000000%
# At minibatch 41200, batch loss 0.119846, batch error rate 1.000000%
# At minibatch 41300, batch loss 0.306448, batch error rate 9.000000%
# At minibatch 41400, batch loss 0.350025, batch error rate 9.000000%
# At minibatch 41500, batch loss 0.192513, batch error rate 4.000000%
# After epoch 83: valid_err_rate: 0.072400% currently going ot do 121 epochs
# At minibatch 41600, batch loss 0.347582, batch error rate 12.000000%
# At minibatch 41700, batch loss 0.250888, batch error rate 8.000000%
# At minibatch 41800, batch loss 0.218494, batch error rate 6.000000%
# At minibatch 41900, batch loss 0.251564, batch error rate 4.000000%
# At minibatch 42000, batch loss 0.207547, batch error rate 8.000000%
# After epoch 84: valid_err_rate: 0.071200% currently going ot do 121 epochs
# At minibatch 42100, batch loss 0.275021, batch error rate 8.000000%
# At minibatch 42200, batch loss 0.466895, batch error rate 9.000000%
# At minibatch 42300, batch loss 0.439228, batch error rate 8.000000%
# At minibatch 42400, batch loss 0.459324, batch error rate 9.000000%
# At minibatch 42500, batch loss 0.444795, batch error rate 14.000000%
# After epoch 85: valid_err_rate: 0.071900% currently going ot do 121 epochs
# At minibatch 42600, batch loss 0.226462, batch error rate 5.000000%
# At minibatch 42700, batch loss 0.291149, batch error rate 8.000000%
# At minibatch 42800, batch loss 0.185189, batch error rate 6.000000%
# At minibatch 42900, batch loss 0.356960, batch error rate 13.000000%
# At minibatch 43000, batch loss 0.322126, batch error rate 9.000000%
# After epoch 86: valid_err_rate: 0.073000% currently going ot do 121 epochs
# At minibatch 43100, batch loss 0.171501, batch error rate 4.000000%
# At minibatch 43200, batch loss 0.406220, batch error rate 10.000000%
# At minibatch 43300, batch loss 0.318916, batch error rate 7.000000%
# At minibatch 43400, batch loss 0.295685, batch error rate 10.000000%
# At minibatch 43500, batch loss 0.209457, batch error rate 5.000000%
# After epoch 87: valid_err_rate: 0.073400% currently going ot do 121 epochs
# At minibatch 43600, batch loss 0.192893, batch error rate 4.000000%
# At minibatch 43700, batch loss 0.270148, batch error rate 10.000000%
# At minibatch 43800, batch loss 0.376692, batch error rate 11.000000%
# At minibatch 43900, batch loss 0.315424, batch error rate 7.000000%
# At minibatch 44000, batch loss 0.257411, batch error rate 5.000000%
# After epoch 88: valid_err_rate: 0.072900% currently going ot do 121 epochs
# At minibatch 44100, batch loss 0.183983, batch error rate 5.000000%
# At minibatch 44200, batch loss 0.396799, batch error rate 9.000000%
# At minibatch 44300, batch loss 0.210122, batch error rate 8.000000%
# At minibatch 44400, batch loss 0.112963, batch error rate 3.000000%
# At minibatch 44500, batch loss 0.457751, batch error rate 10.000000%
# After epoch 89: valid_err_rate: 0.073400% currently going ot do 121 epochs
# At minibatch 44600, batch loss 0.357058, batch error rate 8.000000%
# At minibatch 44700, batch loss 0.391173, batch error rate 10.000000%
# At minibatch 44800, batch loss 0.289327, batch error rate 8.000000%
# At minibatch 44900, batch loss 0.291899, batch error rate 8.000000%
# At minibatch 45000, batch loss 0.286589, batch error rate 6.000000%
# After epoch 90: valid_err_rate: 0.072500% currently going ot do 121 epochs
# At minibatch 45100, batch loss 0.100522, batch error rate 2.000000%
# At minibatch 45200, batch loss 0.154397, batch error rate 5.000000%
# At minibatch 45300, batch loss 0.353510, batch error rate 9.000000%
# At minibatch 45400, batch loss 0.078865, batch error rate 3.000000%
# At minibatch 45500, batch loss 0.202112, batch error rate 6.000000%
# After epoch 91: valid_err_rate: 0.074100% currently going ot do 121 epochs
# At minibatch 45600, batch loss 0.324493, batch error rate 8.000000%
# At minibatch 45700, batch loss 0.220403, batch error rate 6.000000%
# At minibatch 45800, batch loss 0.246113, batch error rate 10.000000%
# At minibatch 45900, batch loss 0.175819, batch error rate 5.000000%
# At minibatch 46000, batch loss 0.354343, batch error rate 12.000000%
# After epoch 92: valid_err_rate: 0.073900% currently going ot do 121 epochs
# At minibatch 46100, batch loss 0.184683, batch error rate 6.000000%
# At minibatch 46200, batch loss 0.128823, batch error rate 5.000000%
# At minibatch 46300, batch loss 0.306942, batch error rate 7.000000%
# At minibatch 46400, batch loss 0.314191, batch error rate 11.000000%
# At minibatch 46500, batch loss 0.244020, batch error rate 6.000000%
# After epoch 93: valid_err_rate: 0.072900% currently going ot do 121 epochs
# At minibatch 46600, batch loss 0.334377, batch error rate 6.000000%
# At minibatch 46700, batch loss 0.467816, batch error rate 9.000000%
# At minibatch 46800, batch loss 0.503310, batch error rate 14.000000%
# At minibatch 46900, batch loss 0.239591, batch error rate 5.000000%
# At minibatch 47000, batch loss 0.285967, batch error rate 9.000000%
# After epoch 94: valid_err_rate: 0.076200% currently going ot do 121 epochs
# At minibatch 47100, batch loss 0.164013, batch error rate 5.000000%
# At minibatch 47200, batch loss 0.379710, batch error rate 6.000000%
# At minibatch 47300, batch loss 0.212624, batch error rate 6.000000%
# At minibatch 47400, batch loss 0.309889, batch error rate 10.000000%
# At minibatch 47500, batch loss 0.403223, batch error rate 9.000000%
# After epoch 95: valid_err_rate: 0.072000% currently going ot do 121 epochs
# At minibatch 47600, batch loss 0.278619, batch error rate 7.000000%
# At minibatch 47700, batch loss 0.165621, batch error rate 6.000000%
# At minibatch 47800, batch loss 0.207275, batch error rate 7.000000%
# At minibatch 47900, batch loss 0.331628, batch error rate 9.000000%
# At minibatch 48000, batch loss 0.314412, batch error rate 8.000000%
# After epoch 96: valid_err_rate: 0.074500% currently going ot do 121 epochs
# At minibatch 48100, batch loss 0.412974, batch error rate 9.000000%
# At minibatch 48200, batch loss 0.117285, batch error rate 4.000000%
# At minibatch 48300, batch loss 0.285671, batch error rate 12.000000%
# At minibatch 48400, batch loss 0.260140, batch error rate 10.000000%
# At minibatch 48500, batch loss 0.190125, batch error rate 6.000000%
# After epoch 97: valid_err_rate: 0.073500% currently going ot do 121 epochs
# At minibatch 48600, batch loss 0.343006, batch error rate 13.000000%
# At minibatch 48700, batch loss 0.207462, batch error rate 7.000000%
# At minibatch 48800, batch loss 0.315144, batch error rate 7.000000%
# At minibatch 48900, batch loss 0.266549, batch error rate 10.000000%
# At minibatch 49000, batch loss 0.164804, batch error rate 4.000000%
# After epoch 98: valid_err_rate: 0.074100% currently going ot do 121 epochs
# At minibatch 49100, batch loss 0.218652, batch error rate 5.000000%
# At minibatch 49200, batch loss 0.244358, batch error rate 6.000000%
# At minibatch 49300, batch loss 0.210793, batch error rate 6.000000%
# At minibatch 49400, batch loss 0.503073, batch error rate 8.000000%
# At minibatch 49500, batch loss 0.174451, batch error rate 8.000000%
# After epoch 99: valid_err_rate: 0.074600% currently going ot do 121 epochs
# At minibatch 49600, batch loss 0.204359, batch error rate 5.000000%
# At minibatch 49700, batch loss 0.090604, batch error rate 2.000000%
# At minibatch 49800, batch loss 0.319972, batch error rate 7.000000%
# At minibatch 49900, batch loss 0.200806, batch error rate 7.000000%
# At minibatch 50000, batch loss 0.153110, batch error rate 4.000000%
# After epoch 100: valid_err_rate: 0.074300% currently going ot do 121 epochs
# At minibatch 50100, batch loss 0.269901, batch error rate 6.000000%
# At minibatch 50200, batch loss 0.171724, batch error rate 6.000000%
# At minibatch 50300, batch loss 0.302885, batch error rate 7.000000%
# At minibatch 50400, batch loss 0.161540, batch error rate 4.000000%
# At minibatch 50500, batch loss 0.391159, batch error rate 10.000000%
# After epoch 101: valid_err_rate: 0.074700% currently going ot do 121 epochs
# At minibatch 50600, batch loss 0.228451, batch error rate 7.000000%
# At minibatch 50700, batch loss 0.334654, batch error rate 10.000000%
# At minibatch 50800, batch loss 0.210933, batch error rate 7.000000%
# At minibatch 50900, batch loss 0.273365, batch error rate 8.000000%
# At minibatch 51000, batch loss 0.198457, batch error rate 8.000000%
# After epoch 102: valid_err_rate: 0.074600% currently going ot do 121 epochs
# At minibatch 51100, batch loss 0.143188, batch error rate 5.000000%
# At minibatch 51200, batch loss 0.366956, batch error rate 8.000000%
# At minibatch 51300, batch loss 0.207561, batch error rate 3.000000%
# At minibatch 51400, batch loss 0.273754, batch error rate 7.000000%
# At minibatch 51500, batch loss 0.278328, batch error rate 8.000000%
# After epoch 103: valid_err_rate: 0.072100% currently going ot do 121 epochs
# At minibatch 51600, batch loss 0.439187, batch error rate 9.000000%
# At minibatch 51700, batch loss 0.242881, batch error rate 8.000000%
# At minibatch 51800, batch loss 0.173994, batch error rate 9.000000%
# At minibatch 51900, batch loss 0.110113, batch error rate 1.000000%
# At minibatch 52000, batch loss 0.695180, batch error rate 11.000000%
# After epoch 104: valid_err_rate: 0.072800% currently going ot do 121 epochs
# At minibatch 52100, batch loss 0.285363, batch error rate 10.000000%
# At minibatch 52200, batch loss 0.135344, batch error rate 2.000000%
# At minibatch 52300, batch loss 0.204060, batch error rate 5.000000%
# At minibatch 52400, batch loss 0.214737, batch error rate 6.000000%
# At minibatch 52500, batch loss 0.344557, batch error rate 12.000000%
# After epoch 105: valid_err_rate: 0.072800% currently going ot do 121 epochs
# At minibatch 52600, batch loss 0.225665, batch error rate 6.000000%
# At minibatch 52700, batch loss 0.197792, batch error rate 5.000000%
# At minibatch 52800, batch loss 0.284416, batch error rate 6.000000%
# At minibatch 52900, batch loss 0.293905, batch error rate 7.000000%
# At minibatch 53000, batch loss 0.113661, batch error rate 3.000000%
# After epoch 106: valid_err_rate: 0.071800% currently going ot do 121 epochs
# At minibatch 53100, batch loss 0.215202, batch error rate 6.000000%
# At minibatch 53200, batch loss 0.244870, batch error rate 10.000000%
# At minibatch 53300, batch loss 0.269846, batch error rate 7.000000%
# At minibatch 53400, batch loss 0.374656, batch error rate 10.000000%
# At minibatch 53500, batch loss 0.318882, batch error rate 12.000000%
# After epoch 107: valid_err_rate: 0.070600% currently going ot do 161 epochs
# At minibatch 53600, batch loss 0.283760, batch error rate 5.000000%
# At minibatch 53700, batch loss 0.275720, batch error rate 6.000000%
# At minibatch 53800, batch loss 0.178866, batch error rate 7.000000%
# At minibatch 53900, batch loss 0.255266, batch error rate 8.000000%
# At minibatch 54000, batch loss 0.258360, batch error rate 6.000000%
# After epoch 108: valid_err_rate: 0.074800% currently going ot do 161 epochs
# At minibatch 54100, batch loss 0.328571, batch error rate 8.000000%
# At minibatch 54200, batch loss 0.361455, batch error rate 10.000000%
# At minibatch 54300, batch loss 0.329793, batch error rate 4.000000%
# At minibatch 54400, batch loss 0.411092, batch error rate 6.000000%
# At minibatch 54500, batch loss 0.286642, batch error rate 9.000000%
# After epoch 109: valid_err_rate: 0.072700% currently going ot do 161 epochs
# At minibatch 54600, batch loss 0.138627, batch error rate 4.000000%
# At minibatch 54700, batch loss 0.367372, batch error rate 8.000000%
# At minibatch 54800, batch loss 0.424124, batch error rate 12.000000%
# At minibatch 54900, batch loss 0.332317, batch error rate 7.000000%
# At minibatch 55000, batch loss 0.131423, batch error rate 4.000000%
# After epoch 110: valid_err_rate: 0.072500% currently going ot do 161 epochs
# At minibatch 55100, batch loss 0.302961, batch error rate 9.000000%
# At minibatch 55200, batch loss 0.336994, batch error rate 11.000000%
# At minibatch 55300, batch loss 0.359351, batch error rate 12.000000%
# At minibatch 55400, batch loss 0.287580, batch error rate 10.000000%
# At minibatch 55500, batch loss 0.187408, batch error rate 6.000000%
# After epoch 111: valid_err_rate: 0.075100% currently going ot do 161 epochs
# At minibatch 55600, batch loss 0.161888, batch error rate 7.000000%
# At minibatch 55700, batch loss 0.282590, batch error rate 6.000000%
# At minibatch 55800, batch loss 0.265012, batch error rate 6.000000%
# At minibatch 55900, batch loss 0.254046, batch error rate 10.000000%
# At minibatch 56000, batch loss 0.258927, batch error rate 9.000000%
# After epoch 112: valid_err_rate: 0.071200% currently going ot do 161 epochs
# At minibatch 56100, batch loss 0.177448, batch error rate 6.000000%
# At minibatch 56200, batch loss 0.145772, batch error rate 6.000000%
# At minibatch 56300, batch loss 0.268276, batch error rate 9.000000%
# At minibatch 56400, batch loss 0.258667, batch error rate 8.000000%
# At minibatch 56500, batch loss 0.246423, batch error rate 6.000000%
# After epoch 113: valid_err_rate: 0.072100% currently going ot do 161 epochs
# At minibatch 56600, batch loss 0.312369, batch error rate 8.000000%
# At minibatch 56700, batch loss 0.184419, batch error rate 7.000000%
# At minibatch 56800, batch loss 0.454360, batch error rate 8.000000%
# At minibatch 56900, batch loss 0.301515, batch error rate 8.000000%
# At minibatch 57000, batch loss 0.333308, batch error rate 8.000000%
# After epoch 114: valid_err_rate: 0.073100% currently going ot do 161 epochs
# At minibatch 57100, batch loss 0.327429, batch error rate 12.000000%
# At minibatch 57200, batch loss 0.115301, batch error rate 4.000000%
# At minibatch 57300, batch loss 0.467741, batch error rate 15.000000%
# At minibatch 57400, batch loss 0.097507, batch error rate 1.000000%
# At minibatch 57500, batch loss 0.239147, batch error rate 7.000000%
# After epoch 115: valid_err_rate: 0.072000% currently going ot do 161 epochs
# At minibatch 57600, batch loss 0.339183, batch error rate 6.000000%
# At minibatch 57700, batch loss 0.223131, batch error rate 7.000000%
# At minibatch 57800, batch loss 0.220929, batch error rate 7.000000%
# At minibatch 57900, batch loss 0.160889, batch error rate 5.000000%
# ...
# After epoch 124: valid_err_rate: 0.073400% currently going ot do 161 epochs
# At minibatch 62100, batch loss 0.194907, batch error rate 6.000000%
# At minibatch 62200, batch loss 0.215325, batch error rate 5.000000%
# At minibatch 62300, batch loss 0.155371, batch error rate 6.000000%
# At minibatch 62400, batch loss 0.180104, batch error rate 6.000000%
# At minibatch 62500, batch loss 0.128061, batch error rate 4.000000%
# After epoch 125: valid_err_rate: 0.072300% currently going ot do 161 epochs
# At minibatch 62600, batch loss 0.150100, batch error rate 3.000000%
# At minibatch 62700, batch loss 0.212431, batch error rate 8.000000%
# At minibatch 62800, batch loss 0.263303, batch error rate 7.000000%
# At minibatch 62900, batch loss 0.222588, batch error rate 6.000000%
# At minibatch 63000, batch loss 0.234700, batch error rate 7.000000%
# After epoch 126: valid_err_rate: 0.072200% currently going ot do 161 epochs
# At minibatch 63100, batch loss 0.516124, batch error rate 9.000000%
# At minibatch 63200, batch loss 0.168293, batch error rate 3.000000%
# At minibatch 63300, batch loss 0.385368, batch error rate 7.000000%
# At minibatch 63400, batch loss 0.105370, batch error rate 3.000000%
# At minibatch 63500, batch loss 0.273618, batch error rate 6.000000%
# After epoch 127: valid_err_rate: 0.073300% currently going ot do 161 epochs
# At minibatch 63600, batch loss 0.171114, batch error rate 6.000000%
# At minibatch 63700, batch loss 0.224249, batch error rate 7.000000%
# At minibatch 63800, batch loss 0.174499, batch error rate 6.000000%
# At minibatch 63900, batch loss 0.254629, batch error rate 8.000000%
# At minibatch 64000, batch loss 0.257145, batch error rate 7.000000%
# After epoch 128: valid_err_rate: 0.073100% currently going ot do 161 epochs
# At minibatch 64100, batch loss 0.261192, batch error rate 8.000000%
# At minibatch 64200, batch loss 0.342476, batch error rate 9.000000%
# At minibatch 64300, batch loss 0.134364, batch error rate 5.000000%
# At minibatch 64400, batch loss 0.138281, batch error rate 2.000000%
# At minibatch 64500, batch loss 0.397170, batch error rate 9.000000%
# After epoch 129: valid_err_rate: 0.074400% currently going ot do 161 epochs
# At minibatch 64600, batch loss 0.257459, batch error rate 6.000000%
# At minibatch 64700, batch loss 0.177474, batch error rate 4.000000%
# At minibatch 64800, batch loss 0.108332, batch error rate 2.000000%
# At minibatch 64900, batch loss 0.196127, batch error rate 7.000000%
# At minibatch 65000, batch loss 0.123685, batch error rate 4.000000%
# After epoch 130: valid_err_rate: 0.071100% currently going ot do 161 epochs
# At minibatch 65100, batch loss 0.175882, batch error rate 7.000000%
# At minibatch 65200, batch loss 0.180580, batch error rate 7.000000%
# At minibatch 65300, batch loss 0.476609, batch error rate 14.000000%
# At minibatch 65400, batch loss 0.263431, batch error rate 6.000000%
# At minibatch 65500, batch loss 0.263148, batch error rate 8.000000%
# After epoch 131: valid_err_rate: 0.071800% currently going ot do 161 epochs
# At minibatch 65600, batch loss 0.186598, batch error rate 4.000000%
# At minibatch 65700, batch loss 0.288686, batch error rate 6.000000%
# At minibatch 65800, batch loss 0.349940, batch error rate 10.000000%
# At minibatch 65900, batch loss 0.197985, batch error rate 5.000000%
# At minibatch 66000, batch loss 0.305473, batch error rate 12.000000%
# After epoch 132: valid_err_rate: 0.073300% currently going ot do 161 epochs
# At minibatch 66100, batch loss 0.327210, batch error rate 7.000000%
# At minibatch 66200, batch loss 0.280870, batch error rate 7.000000%
# At minibatch 66300, batch loss 0.192221, batch error rate 5.000000%
# At minibatch 66400, batch loss 0.277414, batch error rate 10.000000%
# At minibatch 66500, batch loss 0.255389, batch error rate 8.000000%
# After epoch 133: valid_err_rate: 0.072800% currently going ot do 161 epochs
# At minibatch 66600, batch loss 0.091871, batch error rate 2.000000%
# At minibatch 66700, batch loss 0.204302, batch error rate 4.000000%
# At minibatch 66800, batch loss 0.079446, batch error rate 2.000000%
# At minibatch 66900, batch loss 0.155407, batch error rate 3.000000%
# At minibatch 67000, batch loss 0.235636, batch error rate 5.000000%
# After epoch 134: valid_err_rate: 0.073000% currently going ot do 161 epochs
# At minibatch 67100, batch loss 0.139844, batch error rate 3.000000%
# At minibatch 67200, batch loss 0.222938, batch error rate 8.000000%
# At minibatch 67300, batch loss 0.239614, batch error rate 7.000000%
# At minibatch 67400, batch loss 0.282853, batch error rate 5.000000%
# At minibatch 67500, batch loss 0.223818, batch error rate 7.000000%
# After epoch 135: valid_err_rate: 0.075700% currently going ot do 161 epochs
# At minibatch 67600, batch loss 0.283101, batch error rate 6.000000%
# At minibatch 67700, batch loss 0.244150, batch error rate 9.000000%
# At minibatch 67800, batch loss 0.204007, batch error rate 5.000000%
# At minibatch 67900, batch loss 0.296514, batch error rate 9.000000%
# At minibatch 68000, batch loss 0.268787, batch error rate 7.000000%
# After epoch 136: valid_err_rate: 0.074700% currently going ot do 161 epochs
# At minibatch 68100, batch loss 0.231222, batch error rate 7.000000%
# At minibatch 68200, batch loss 0.227618, batch error rate 7.000000%
# At minibatch 68300, batch loss 0.173101, batch error rate 4.000000%
# At minibatch 68400, batch loss 0.155920, batch error rate 5.000000%
# At minibatch 68500, batch loss 0.272391, batch error rate 8.000000%
# After epoch 137: valid_err_rate: 0.072300% currently going ot do 161 epochs
# At minibatch 68600, batch loss 0.177085, batch error rate 5.000000%
# At minibatch 68700, batch loss 0.204415, batch error rate 6.000000%
# At minibatch 68800, batch loss 0.399076, batch error rate 8.000000%
# At minibatch 68900, batch loss 0.188059, batch error rate 8.000000%
# At minibatch 69000, batch loss 0.136920, batch error rate 4.000000%
# After epoch 138: valid_err_rate: 0.074800% currently going ot do 161 epochs
# At minibatch 69100, batch loss 0.247710, batch error rate 7.000000%
# At minibatch 69200, batch loss 0.245074, batch error rate 8.000000%
# At minibatch 69300, batch loss 0.205766, batch error rate 8.000000%
# At minibatch 69400, batch loss 0.242170, batch error rate 7.000000%
# At minibatch 69500, batch loss 0.286349, batch error rate 8.000000%
# After epoch 139: valid_err_rate: 0.074200% currently going ot do 161 epochs
# At minibatch 69600, batch loss 0.358134, batch error rate 10.000000%
# At minibatch 69700, batch loss 0.264800, batch error rate 6.000000%
# At minibatch 69800, batch loss 0.266194, batch error rate 5.000000%
# At minibatch 69900, batch loss 0.220327, batch error rate 10.000000%
# At minibatch 70000, batch loss 0.221713, batch error rate 7.000000%
# After epoch 140: valid_err_rate: 0.072100% currently going ot do 161 epochs
# At minibatch 70100, batch loss 0.230901, batch error rate 8.000000%
# At minibatch 70200, batch loss 0.300573, batch error rate 8.000000%
# At minibatch 70300, batch loss 0.136510, batch error rate 4.000000%
# At minibatch 70400, batch loss 0.141144, batch error rate 4.000000%
# At minibatch 70500, batch loss 0.365630, batch error rate 11.000000%
# After epoch 141: valid_err_rate: 0.074000% currently going ot do 161 epochs
# At minibatch 70600, batch loss 0.262556, batch error rate 9.000000%
# At minibatch 70700, batch loss 0.274298, batch error rate 9.000000%
# At minibatch 70800, batch loss 0.208685, batch error rate 6.000000%
# At minibatch 70900, batch loss 0.233003, batch error rate 7.000000%
# At minibatch 71000, batch loss 0.423413, batch error rate 9.000000%
# After epoch 142: valid_err_rate: 0.072600% currently going ot do 161 epochs
# At minibatch 71100, batch loss 0.224269, batch error rate 10.000000%
# At minibatch 71200, batch loss 0.123818, batch error rate 4.000000%
# At minibatch 71300, batch loss 0.274906, batch error rate 7.000000%
# At minibatch 71400, batch loss 0.199057, batch error rate 6.000000%
# At minibatch 71500, batch loss 0.150709, batch error rate 4.000000%
# After epoch 143: valid_err_rate: 0.074300% currently going ot do 161 epochs
# At minibatch 71600, batch loss 0.243936, batch error rate 7.000000%
# At minibatch 71700, batch loss 0.278927, batch error rate 11.000000%
# At minibatch 71800, batch loss 0.207425, batch error rate 7.000000%
# At minibatch 71900, batch loss 0.225499, batch error rate 7.000000%
# At minibatch 72000, batch loss 0.510076, batch error rate 8.000000%
# After epoch 144: valid_err_rate: 0.071500% currently going ot do 161 epochs
# At minibatch 72100, batch loss 0.238019, batch error rate 9.000000%
# At minibatch 72200, batch loss 0.193452, batch error rate 5.000000%
# At minibatch 72300, batch loss 0.621969, batch error rate 15.000000%
# At minibatch 72400, batch loss 0.246383, batch error rate 7.000000%
# At minibatch 72500, batch loss 0.414690, batch error rate 12.000000%
# After epoch 145: valid_err_rate: 0.073100% currently going ot do 161 epochs
# At minibatch 72600, batch loss 0.352192, batch error rate 9.000000%
# At minibatch 72700, batch loss 0.131981, batch error rate 4.000000%
# At minibatch 72800, batch loss 0.262097, batch error rate 6.000000%
# At minibatch 72900, batch loss 0.354756, batch error rate 11.000000%
# At minibatch 73000, batch loss 0.242300, batch error rate 8.000000%
# After epoch 146: valid_err_rate: 0.074500% currently going ot do 161 epochs
# At minibatch 73100, batch loss 0.246509, batch error rate 12.000000%
# At minibatch 73200, batch loss 0.294960, batch error rate 7.000000%
# At minibatch 73300, batch loss 0.234449, batch error rate 4.000000%
# At minibatch 73400, batch loss 0.219788, batch error rate 8.000000%
# At minibatch 73500, batch loss 0.197519, batch error rate 8.000000%
# After epoch 147: valid_err_rate: 0.072100% currently going ot do 161 epochs
# At minibatch 73600, batch loss 0.176148, batch error rate 6.000000%
# At minibatch 73700, batch loss 0.263012, batch error rate 9.000000%
# At minibatch 73800, batch loss 0.213224, batch error rate 3.000000%
# At minibatch 73900, batch loss 0.187326, batch error rate 6.000000%
# At minibatch 74000, batch loss 0.204510, batch error rate 8.000000%
# After epoch 148: valid_err_rate: 0.072100% currently going ot do 161 epochs
# At minibatch 74100, batch loss 0.403493, batch error rate 11.000000%
# At minibatch 74200, batch loss 0.171447, batch error rate 5.000000%
# At minibatch 74300, batch loss 0.383440, batch error rate 9.000000%
# At minibatch 74400, batch loss 0.325122, batch error rate 8.000000%
# At minibatch 74500, batch loss 0.238163, batch error rate 7.000000%
# After epoch 149: valid_err_rate: 0.074400% currently going ot do 161 epochs
# At minibatch 74600, batch loss 0.317191, batch error rate 8.000000%
# At minibatch 74700, batch loss 0.386611, batch error rate 8.000000%
# At minibatch 74800, batch loss 0.288113, batch error rate 9.000000%
# At minibatch 74900, batch loss 0.197912, batch error rate 4.000000%
# At minibatch 75000, batch loss 0.348122, batch error rate 10.000000%
# After epoch 150: valid_err_rate: 0.074000% currently going ot do 161 epochs
# At minibatch 75100, batch loss 0.222697, batch error rate 10.000000%
# At minibatch 75200, batch loss 0.352655, batch error rate 10.000000%
# At minibatch 75300, batch loss 0.266890, batch error rate 10.000000%
# At minibatch 75400, batch loss 0.254798, batch error rate 9.000000%
# At minibatch 75500, batch loss 0.138487, batch error rate 6.000000%
# After epoch 151: valid_err_rate: 0.075400% currently going ot do 161 epochs
# At minibatch 75600, batch loss 0.159227, batch error rate 3.000000%
# At minibatch 75700, batch loss 0.132703, batch error rate 4.000000%
# At minibatch 75800, batch loss 0.306765, batch error rate 7.000000%
# At minibatch 75900, batch loss 0.130151, batch error rate 3.000000%
# At minibatch 76000, batch loss 0.239101, batch error rate 7.000000%
# After epoch 152: valid_err_rate: 0.073300% currently going ot do 161 epochs
# At minibatch 76100, batch loss 0.182424, batch error rate 3.000000%
# At minibatch 76200, batch loss 0.194905, batch error rate 5.000000%
# At minibatch 76300, batch loss 0.209430, batch error rate 10.000000%
# At minibatch 76400, batch loss 0.274968, batch error rate 12.000000%
# At minibatch 76500, batch loss 0.384553, batch error rate 8.000000%
# After epoch 153: valid_err_rate: 0.073500% currently going ot do 161 epochs
# At minibatch 76600, batch loss 0.179425, batch error rate 7.000000%
# At minibatch 76700, batch loss 0.281883, batch error rate 8.000000%
# At minibatch 76800, batch loss 0.253477, batch error rate 8.000000%
# At minibatch 76900, batch loss 0.348228, batch error rate 6.000000%
# At minibatch 77000, batch loss 0.237424, batch error rate 6.000000%
# After epoch 154: valid_err_rate: 0.072500% currently going ot do 161 epochs
# At minibatch 77100, batch loss 0.197340, batch error rate 5.000000%
# At minibatch 77200, batch loss 0.358994, batch error rate 7.000000%
# At minibatch 77300, batch loss 0.216690, batch error rate 6.000000%
# At minibatch 77400, batch loss 0.363067, batch error rate 9.000000%
# At minibatch 77500, batch loss 0.113433, batch error rate 2.000000%
# After epoch 155: valid_err_rate: 0.072700% currently going ot do 161 epochs
# At minibatch 77600, batch loss 0.168873, batch error rate 7.000000%
# At minibatch 77700, batch loss 0.360436, batch error rate 14.000000%
# At minibatch 77800, batch loss 0.149418, batch error rate 5.000000%
# At minibatch 77900, batch loss 0.311092, batch error rate 7.000000%
# At minibatch 78000, batch loss 0.275296, batch error rate 12.000000%
# After epoch 156: valid_err_rate: 0.073000% currently going ot do 161 epochs
# At minibatch 78100, batch loss 0.306355, batch error rate 6.000000%
# At minibatch 78200, batch loss 0.260633, batch error rate 8.000000%
# At minibatch 78300, batch loss 0.373331, batch error rate 9.000000%
# At minibatch 78400, batch loss 0.534606, batch error rate 9.000000%
# At minibatch 78500, batch loss 0.217302, batch error rate 5.000000%
# After epoch 157: valid_err_rate: 0.073700% currently going ot do 161 epochs
# At minibatch 78600, batch loss 0.250790, batch error rate 4.000000%
# At minibatch 78700, batch loss 0.191816, batch error rate 7.000000%
# At minibatch 78800, batch loss 0.207318, batch error rate 7.000000%
# At minibatch 78900, batch loss 0.445356, batch error rate 9.000000%
# At minibatch 79000, batch loss 0.188284, batch error rate 4.000000%
# After epoch 158: valid_err_rate: 0.073500% currently going ot do 161 epochs
# At minibatch 79100, batch loss 0.216935, batch error rate 6.000000%
# At minibatch 79200, batch loss 0.224004, batch error rate 5.000000%
# At minibatch 79300, batch loss 0.284160, batch error rate 12.000000%
# At minibatch 79400, batch loss 0.277085, batch error rate 7.000000%
# At minibatch 79500, batch loss 0.143024, batch error rate 4.000000%
# After epoch 159: valid_err_rate: 0.073100% currently going ot do 161 epochs
# At minibatch 79600, batch loss 0.180765, batch error rate 6.000000%
# At minibatch 79700, batch loss 0.304317, batch error rate 4.000000%
# At minibatch 79800, batch loss 0.283390, batch error rate 7.000000%
# At minibatch 79900, batch loss 0.144731, batch error rate 5.000000%
# At minibatch 80000, batch loss 0.193776, batch error rate 5.000000%
# After epoch 160: valid_err_rate: 0.073500% currently going ot do 161 epochs
# At minibatch 80100, batch loss 0.233180, batch error rate 9.000000%
# At minibatch 80200, batch loss 0.155685, batch error rate 5.000000%
# At minibatch 80300, batch loss 0.274487, batch error rate 9.000000%
# At minibatch 80400, batch loss 0.183218, batch error rate 6.000000%
# At minibatch 80500, batch loss 0.199682, batch error rate 6.000000%
# After epoch 161: valid_err_rate: 0.073700% currently going ot do 161 epochs
# At minibatch 80600, batch loss 0.241044, batch error rate 6.000000%
# At minibatch 80700, batch loss 0.209840, batch error rate 7.000000%
# At minibatch 80800, batch loss 0.183810, batch error rate 6.000000%
# At minibatch 80900, batch loss 0.171264, batch error rate 6.000000%
# At minibatch 81000, batch loss 0.302339, batch error rate 9.000000%
# After epoch 162: valid_err_rate: 0.074600% currently going ot do 161 epochs
# Test error rate: 0.077700

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
net = FeedForwardNet([
        AffineLayer(784,183),
        TanhLayer(),
        AffineLayer(183,69),
        TanhLayer(),
        AffineLayer(69,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 0.752358, batch error rate 21.000000%
# At minibatch 200, batch loss 0.477998, batch error rate 12.000000%
# At minibatch 300, batch loss 0.547733, batch error rate 17.000000%
# At minibatch 400, batch loss 0.453687, batch error rate 16.000000%
# At minibatch 500, batch loss 0.431252, batch error rate 11.000000%
# After epoch 1: valid_err_rate: 0.113400% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.324906, batch error rate 11.000000%
# At minibatch 700, batch loss 0.374277, batch error rate 12.000000%
# At minibatch 800, batch loss 0.272138, batch error rate 12.000000%
# At minibatch 900, batch loss 0.388996, batch error rate 17.000000%
# At minibatch 1000, batch loss 0.460029, batch error rate 12.000000%
# After epoch 2: valid_err_rate: 0.087500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.221656, batch error rate 6.000000%
# At minibatch 1200, batch loss 0.180643, batch error rate 8.000000%
# At minibatch 1300, batch loss 0.362333, batch error rate 13.000000%
# At minibatch 1400, batch loss 0.276459, batch error rate 7.000000%
# At minibatch 1500, batch loss 0.268781, batch error rate 7.000000%
# After epoch 3: valid_err_rate: 0.073800% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.343457, batch error rate 11.000000%
# At minibatch 1700, batch loss 0.245306, batch error rate 7.000000%
# At minibatch 1800, batch loss 0.207813, batch error rate 6.000000%
# At minibatch 1900, batch loss 0.218877, batch error rate 5.000000%
# At minibatch 2000, batch loss 0.244151, batch error rate 8.000000%
# After epoch 4: valid_err_rate: 0.068100% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.174347, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.214285, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.289601, batch error rate 10.000000%
# At minibatch 2400, batch loss 0.170966, batch error rate 8.000000%
# At minibatch 2500, batch loss 0.223228, batch error rate 10.000000%
# After epoch 5: valid_err_rate: 0.062900% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.213366, batch error rate 7.000000%
# At minibatch 2700, batch loss 0.173209, batch error rate 5.000000%
# At minibatch 2800, batch loss 0.182224, batch error rate 4.000000%
# At minibatch 2900, batch loss 0.295090, batch error rate 8.000000%
# At minibatch 3000, batch loss 0.207581, batch error rate 7.000000%
# After epoch 6: valid_err_rate: 0.060700% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.226308, batch error rate 8.000000%
# At minibatch 3200, batch loss 0.198450, batch error rate 7.000000%
# At minibatch 3300, batch loss 0.140384, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.409883, batch error rate 12.000000%
# At minibatch 3500, batch loss 0.066216, batch error rate 0.000000%
# After epoch 7: valid_err_rate: 0.057000% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.161462, batch error rate 6.000000%
# At minibatch 3700, batch loss 0.115996, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.111561, batch error rate 5.000000%
# At minibatch 3900, batch loss 0.168991, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.158475, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.054300% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.269930, batch error rate 5.000000%
# At minibatch 4200, batch loss 0.169232, batch error rate 4.000000%
# At minibatch 4300, batch loss 0.211767, batch error rate 9.000000%
# At minibatch 4400, batch loss 0.084686, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.153879, batch error rate 4.000000%
# After epoch 9: valid_err_rate: 0.052200% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.233302, batch error rate 5.000000%
# At minibatch 4700, batch loss 0.127637, batch error rate 4.000000%
# At minibatch 4800, batch loss 0.215808, batch error rate 6.000000%
# At minibatch 4900, batch loss 0.118505, batch error rate 4.000000%
# At minibatch 5000, batch loss 0.150525, batch error rate 6.000000%
# After epoch 10: valid_err_rate: 0.052000% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.081524, batch error rate 3.000000%
# At minibatch 5200, batch loss 0.170148, batch error rate 8.000000%
# At minibatch 5300, batch loss 0.062151, batch error rate 1.000000%
# At minibatch 5400, batch loss 0.093439, batch error rate 3.000000%
# At minibatch 5500, batch loss 0.241791, batch error rate 5.000000%
# After epoch 11: valid_err_rate: 0.048600% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.133334, batch error rate 4.000000%
# At minibatch 5700, batch loss 0.098893, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.105354, batch error rate 5.000000%
# At minibatch 5900, batch loss 0.063708, batch error rate 1.000000%
# At minibatch 6000, batch loss 0.170980, batch error rate 7.000000%
# After epoch 12: valid_err_rate: 0.047800% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.077788, batch error rate 3.000000%
# At minibatch 6200, batch loss 0.120947, batch error rate 5.000000%
# At minibatch 6300, batch loss 0.204294, batch error rate 5.000000%
# At minibatch 6400, batch loss 0.135321, batch error rate 4.000000%
# At minibatch 6500, batch loss 0.048353, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.046400% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.023978, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.098857, batch error rate 4.000000%
# At minibatch 6800, batch loss 0.135554, batch error rate 5.000000%
# At minibatch 6900, batch loss 0.187983, batch error rate 5.000000%
# At minibatch 7000, batch loss 0.062873, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.047600% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.058227, batch error rate 0.000000%
# At minibatch 7200, batch loss 0.045037, batch error rate 1.000000%
# At minibatch 7300, batch loss 0.081496, batch error rate 1.000000%
# At minibatch 7400, batch loss 0.088557, batch error rate 2.000000%
# At minibatch 7500, batch loss 0.120465, batch error rate 5.000000%
# After epoch 15: valid_err_rate: 0.045900% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.039549, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.044194, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.049112, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.073540, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.111701, batch error rate 4.000000%
# After epoch 16: valid_err_rate: 0.044400% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.044941, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.108550, batch error rate 2.000000%
# At minibatch 8300, batch loss 0.070173, batch error rate 2.000000%
# At minibatch 8400, batch loss 0.097821, batch error rate 4.000000%
# At minibatch 8500, batch loss 0.075818, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.045800% currently going ot do 25 epochs
# At minibatch 8600, batch loss 0.078022, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.072675, batch error rate 2.000000%
# At minibatch 8800, batch loss 0.132635, batch error rate 5.000000%
# At minibatch 8900, batch loss 0.086029, batch error rate 4.000000%
# At minibatch 9000, batch loss 0.028508, batch error rate 0.000000%
# After epoch 18: valid_err_rate: 0.045200% currently going ot do 25 epochs
# At minibatch 9100, batch loss 0.043769, batch error rate 0.000000%
# At minibatch 9200, batch loss 0.066261, batch error rate 2.000000%
# At minibatch 9300, batch loss 0.105735, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.065717, batch error rate 2.000000%
# At minibatch 9500, batch loss 0.080313, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.042100% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.036725, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.044402, batch error rate 1.000000%
# At minibatch 9800, batch loss 0.056610, batch error rate 2.000000%
# At minibatch 9900, batch loss 0.086853, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.066189, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.043700% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.059155, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.044765, batch error rate 1.000000%
# At minibatch 10300, batch loss 0.041255, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.067508, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.128905, batch error rate 4.000000%
# After epoch 21: valid_err_rate: 0.044900% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.033079, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.040597, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.034760, batch error rate 2.000000%
# At minibatch 10900, batch loss 0.079532, batch error rate 3.000000%
# At minibatch 11000, batch loss 0.087463, batch error rate 4.000000%
# After epoch 22: valid_err_rate: 0.042900% currently going ot do 29 epochs
# At minibatch 11100, batch loss 0.022237, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.060090, batch error rate 2.000000%
# At minibatch 11300, batch loss 0.035690, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.057921, batch error rate 3.000000%
# At minibatch 11500, batch loss 0.058877, batch error rate 2.000000%
# After epoch 23: valid_err_rate: 0.041800% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.033604, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.048905, batch error rate 2.000000%
# At minibatch 11800, batch loss 0.059675, batch error rate 1.000000%
# At minibatch 11900, batch loss 0.023314, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.043787, batch error rate 2.000000%
# After epoch 24: valid_err_rate: 0.043000% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.046905, batch error rate 2.000000%
# At minibatch 12200, batch loss 0.033947, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.092866, batch error rate 3.000000%
# At minibatch 12400, batch loss 0.079099, batch error rate 3.000000%
# At minibatch 12500, batch loss 0.109576, batch error rate 1.000000%
# After epoch 25: valid_err_rate: 0.042400% currently going ot do 35 epochs
# At minibatch 12600, batch loss 0.031033, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.043101, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.062872, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.069041, batch error rate 2.000000%
# At minibatch 13000, batch loss 0.050586, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.040900% currently going ot do 40 epochs
# At minibatch 13100, batch loss 0.031294, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.039442, batch error rate 2.000000%
# At minibatch 13300, batch loss 0.052642, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.047637, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.053028, batch error rate 1.000000%
# After epoch 27: valid_err_rate: 0.042000% currently going ot do 40 epochs
# At minibatch 13600, batch loss 0.041267, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.075255, batch error rate 2.000000%
# At minibatch 13800, batch loss 0.024206, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.058728, batch error rate 2.000000%
# At minibatch 14000, batch loss 0.066312, batch error rate 2.000000%
# After epoch 28: valid_err_rate: 0.042300% currently going ot do 40 epochs
# At minibatch 14100, batch loss 0.015939, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.017873, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.035153, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.031162, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.058069, batch error rate 2.000000%
# After epoch 29: valid_err_rate: 0.040000% currently going ot do 44 epochs
# At minibatch 14600, batch loss 0.033881, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.070655, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.013887, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.041191, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.083720, batch error rate 1.000000%
# After epoch 30: valid_err_rate: 0.041300% currently going ot do 44 epochs
# At minibatch 15100, batch loss 0.037196, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.037664, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.023856, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.025034, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.023094, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.042100% currently going ot do 44 epochs
# At minibatch 15600, batch loss 0.027601, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.051829, batch error rate 2.000000%
# At minibatch 15800, batch loss 0.027362, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.022856, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.058474, batch error rate 1.000000%
# After epoch 32: valid_err_rate: 0.041500% currently going ot do 44 epochs
# At minibatch 16100, batch loss 0.027250, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.038235, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.018066, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.024948, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.030697, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.041200% currently going ot do 44 epochs
# At minibatch 16600, batch loss 0.036649, batch error rate 2.000000%
# At minibatch 16700, batch loss 0.031238, batch error rate 1.000000%
# At minibatch 16800, batch loss 0.024768, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.031555, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.043303, batch error rate 2.000000%
# After epoch 34: valid_err_rate: 0.040800% currently going ot do 44 epochs
# At minibatch 17100, batch loss 0.065072, batch error rate 1.000000%
# At minibatch 17200, batch loss 0.022987, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.009035, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.048662, batch error rate 1.000000%
# At minibatch 17500, batch loss 0.018593, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.040900% currently going ot do 44 epochs
# At minibatch 17600, batch loss 0.157792, batch error rate 3.000000%
# At minibatch 17700, batch loss 0.024149, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.021335, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.012537, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.047792, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.040300% currently going ot do 44 epochs
# At minibatch 18100, batch loss 0.023409, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.035768, batch error rate 1.000000%
# At minibatch 18300, batch loss 0.034052, batch error rate 1.000000%
# At minibatch 18400, batch loss 0.021310, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.042974, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.040300% currently going ot do 44 epochs
# At minibatch 18600, batch loss 0.015448, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.030388, batch error rate 1.000000%
# At minibatch 18800, batch loss 0.020926, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.023663, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.043157, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.040100% currently going ot do 44 epochs
# At minibatch 19100, batch loss 0.019743, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.025432, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.019967, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.035740, batch error rate 1.000000%
# At minibatch 19500, batch loss 0.022754, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.039000% currently going ot do 59 epochs
# At minibatch 19600, batch loss 0.019637, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.012368, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.027230, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.010795, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.071821, batch error rate 1.000000%
# After epoch 40: valid_err_rate: 0.039300% currently going ot do 59 epochs
# At minibatch 20100, batch loss 0.018024, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.068486, batch error rate 1.000000%
# At minibatch 20300, batch loss 0.013826, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.025085, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.028449, batch error rate 1.000000%
# After epoch 41: valid_err_rate: 0.040800% currently going ot do 59 epochs
# At minibatch 20600, batch loss 0.011177, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.021011, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.012655, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.032176, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.017979, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.040400% currently going ot do 59 epochs
# At minibatch 21100, batch loss 0.013865, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.028414, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.018785, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.031535, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.012175, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.038900% currently going ot do 65 epochs
# At minibatch 21600, batch loss 0.032178, batch error rate 1.000000%
# At minibatch 21700, batch loss 0.028000, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.082997, batch error rate 2.000000%
# At minibatch 21900, batch loss 0.035478, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.011270, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.039900% currently going ot do 65 epochs
# At minibatch 22100, batch loss 0.010933, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.064643, batch error rate 1.000000%
# At minibatch 22300, batch loss 0.014078, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.018574, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.085936, batch error rate 2.000000%
# After epoch 45: valid_err_rate: 0.040100% currently going ot do 65 epochs
# At minibatch 22600, batch loss 0.020292, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.015120, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.013129, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.006902, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.008007, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.039800% currently going ot do 65 epochs
# At minibatch 23100, batch loss 0.011260, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.013117, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.011630, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.006745, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.016324, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.039500% currently going ot do 65 epochs
# At minibatch 23600, batch loss 0.012270, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.014683, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.008814, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.021994, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.021949, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.039500% currently going ot do 65 epochs
# At minibatch 24100, batch loss 0.011258, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.009569, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.015517, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.015353, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.015028, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.039600% currently going ot do 65 epochs
# At minibatch 24600, batch loss 0.008364, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.011259, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.039233, batch error rate 1.000000%
# At minibatch 24900, batch loss 0.010989, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.021564, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 25100, batch loss 0.020214, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.013102, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.024997, batch error rate 1.000000%
# At minibatch 25400, batch loss 0.033849, batch error rate 2.000000%
# At minibatch 25500, batch loss 0.008629, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.040200% currently going ot do 76 epochs
# At minibatch 25600, batch loss 0.030839, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.018719, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.009088, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.014284, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.011039, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 26100, batch loss 0.011666, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.033498, batch error rate 1.000000%
# At minibatch 26300, batch loss 0.021060, batch error rate 1.000000%
# At minibatch 26400, batch loss 0.013491, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.015957, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.039500% currently going ot do 76 epochs
# At minibatch 26600, batch loss 0.017625, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.021424, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.036307, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.009404, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.010457, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.038900% currently going ot do 76 epochs
# At minibatch 27100, batch loss 0.013218, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.019756, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.007686, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.008944, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.039581, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 27600, batch loss 0.007509, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.008372, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.010333, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.011130, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.007983, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 28100, batch loss 0.006799, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.010930, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.018323, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.013754, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.007933, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 28600, batch loss 0.005917, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.013511, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.015695, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.003876, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.008486, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.039500% currently going ot do 76 epochs
# At minibatch 29100, batch loss 0.007956, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.006895, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.005714, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.013782, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.006142, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.039400% currently going ot do 76 epochs
# At minibatch 29600, batch loss 0.011267, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.009674, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.006813, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.012121, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.024620, batch error rate 1.000000%
# After epoch 60: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 30100, batch loss 0.007947, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.004037, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.007608, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.029219, batch error rate 1.000000%
# At minibatch 30500, batch loss 0.016499, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.038600% currently going ot do 76 epochs
# At minibatch 30600, batch loss 0.007498, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.012337, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.009622, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.011275, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.009877, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.038800% currently going ot do 76 epochs
# At minibatch 31100, batch loss 0.015146, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.009775, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.005236, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.005664, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.010845, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.039600% currently going ot do 76 epochs
# At minibatch 31600, batch loss 0.004780, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.012639, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.004466, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.012814, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.013206, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.041200% currently going ot do 76 epochs
# At minibatch 32100, batch loss 0.006943, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.011504, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.015493, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.011306, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.005351, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.038900% currently going ot do 76 epochs
# At minibatch 32600, batch loss 0.021986, batch error rate 1.000000%
# At minibatch 32700, batch loss 0.009570, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.004740, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.005802, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.006476, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.039200% currently going ot do 76 epochs
# At minibatch 33100, batch loss 0.009840, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.003499, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.006760, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.006875, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.007697, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 33600, batch loss 0.013796, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.014163, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.006759, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.012106, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.011981, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.039100% currently going ot do 76 epochs
# At minibatch 34100, batch loss 0.006461, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.005778, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.009644, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.005874, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.008751, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 34600, batch loss 0.007641, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.008348, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.001595, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.009726, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.002548, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.038800% currently going ot do 76 epochs
# At minibatch 35100, batch loss 0.004277, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.012030, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.006763, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.001690, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.008431, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 35600, batch loss 0.004615, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.010752, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.010706, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.003895, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.005607, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.039300% currently going ot do 76 epochs
# At minibatch 36100, batch loss 0.036910, batch error rate 1.000000%
# At minibatch 36200, batch loss 0.011330, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.010214, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.003402, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.002292, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.038500% currently going ot do 76 epochs
# At minibatch 36600, batch loss 0.006251, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.014974, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.009583, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.011105, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.004760, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.039000% currently going ot do 76 epochs
# At minibatch 37100, batch loss 0.009571, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.010823, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.013812, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.008803, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.010118, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.039200% currently going ot do 76 epochs
# At minibatch 37600, batch loss 0.008371, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.006577, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.011679, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.006033, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.013167, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.039000% currently going ot do 76 epochs
# Test error rate: 0.042300

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.078

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
