# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        print(np.sum(m > 0.))
        print(np.sum(m == 0.))
        print(np.sum(m < 0.))
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = IsotropicGaussian(std=0.2, mean=0.0)
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        return self.W.T.dot(dLdY)
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (1.0 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 1.240357, train error rate 81.333333%
# At iteration 1000, loss 0.052737, train error rate 2.000000%
# At iteration 2000, loss 0.044037, train error rate 2.000000%
# At iteration 3000, loss 0.041707, train error rate 1.333333%
# At iteration 4000, loss 0.040723, train error rate 1.333333%
# At iteration 5000, loss 0.040171, train error rate 1.333333%
# At iteration 6000, loss 0.039781, train error rate 1.333333%
# At iteration 7000, loss 0.039448, train error rate 1.333333%
# At iteration 8000, loss 0.039121, train error rate 1.333333%
# At iteration 9000, loss 0.038774, train error rate 1.333333%
# At iteration 10000, loss 0.038387, train error rate 1.333333%
# At iteration 11000, loss 0.037952, train error rate 1.333333%
# At iteration 12000, loss 0.037465, train error rate 1.333333%
# At iteration 13000, loss 0.036924, train error rate 1.333333%
# At iteration 14000, loss 0.036326, train error rate 1.333333%
# At iteration 15000, loss 0.035661, train error rate 1.333333%
# At iteration 16000, loss 0.034915, train error rate 1.333333%
# At iteration 17000, loss 0.034069, train error rate 1.333333%
# At iteration 18000, loss 0.033094, train error rate 1.333333%
# At iteration 19000, loss 0.031930, train error rate 1.333333%
# At iteration 20000, loss 0.030480, train error rate 1.333333%
# At iteration 21000, loss 0.028615, train error rate 1.333333%
# At iteration 22000, loss 0.026236, train error rate 1.333333%
# At iteration 23000, loss 0.023386, train error rate 1.333333%
# At iteration 24000, loss 0.020305, train error rate 0.666667%
# At iteration 25000, loss 0.017338, train error rate 0.666667%
# At iteration 26000, loss 0.014736, train error rate 0.666667%
# At iteration 27000, loss 0.012577, train error rate 0.000000%
# At iteration 28000, loss 0.010826, train error rate 0.000000%
# At iteration 29000, loss 0.009407, train error rate 0.000000%
# At iteration 30000, loss 0.008251, train error rate 0.000000%
# At iteration 31000, loss 0.007299, train error rate 0.000000%
# At iteration 32000, loss 0.006509, train error rate 0.000000%
# At iteration 33000, loss 0.005846, train error rate 0.000000%
# At iteration 34000, loss 0.005286, train error rate 0.000000%
# At iteration 35000, loss 0.004809, train error rate 0.000000%
# At iteration 36000, loss 0.004399, train error rate 0.000000%
# At iteration 37000, loss 0.004045, train error rate 0.000000%
# At iteration 38000, loss 0.003737, train error rate 0.000000%
# At iteration 39000, loss 0.003466, train error rate 0.000000%
# At iteration 40000, loss 0.003228, train error rate 0.000000%
# At iteration 41000, loss 0.003017, train error rate 0.000000%
# At iteration 42000, loss 0.002829, train error rate 0.000000%
# At iteration 43000, loss 0.002661, train error rate 0.000000%
# At iteration 44000, loss 0.002510, train error rate 0.000000%
# At iteration 45000, loss 0.002373, train error rate 0.000000%
# At iteration 46000, loss 0.002249, train error rate 0.000000%
# At iteration 47000, loss 0.002136, train error rate 0.000000%
# Tolerance level reached exiting

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def print_stats(train_loss, train_errors, validation_errors):
    subplot(2,1,1)
    train_loss = np.array(train_loss)
    semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
    legend()

    subplot(2,1,2)
    train_errors = np.array(train_errors)
    plot(train_errors[:,0], train_errors[:,1], label='batch train error rate')
    validation_errors = np.array(validation_errors)
    plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
    ylim(0,0.2)
    legend()

class AlphaAlgExp:
    def __init__(self, initial = 5e-2, rate = 0.998):
        self.initial = initial
        self.rate = rate
    
    def __call__(self, i, e):
        return (self.initial * np.power(self.rate, e))
    
class AlphaAlgBct:
    def __init__(self, b = 1e3, c = 2e4):
        self.b = b
        self.c = c
    
    def __call__(self, i, e):
        return (self.b / (self.c + i))
    
class AlphaAlgConst:
    def __init__(self, constant = 1e-2):
        self.constant = constant
        
    def __call__(self, i, e):
        return self.constant
    
    
class MomentumAlgConst:
    def __init__(self, constant = 0.5):
        self.constant = constant
        
    def __call__(self, i):
        return self.constant
    
class MomentumAlg1:
    def __call__(self, i):
        return (1. - 3. / (5. + i))
    
class RegularizationAlg1:
    def __init__(self, rate = 1e-3):
        self.rate = rate
        
    def __call__(self, P):
        return self.rate * P
    
class RegularizationAlgNone:
    def __call__(self, P):
        return 0.0
    

def SGD(net, train_stream, validation_stream, test_stream,
       print_debug = True,
       epochs = 3,
       patience = 1.5,
       alpha_alg = AlphaAlgExp(),
       momentum_alg = MomentumAlg1(),
       regularization_alg = RegularizationAlg1()):
    
    print "Network configuration: "
    print ", ".join([ "%s%s" %(N, P.shape) for P, N in zip(net.parameters, net.parameter_names) ])
    
    i=0
    e=0
    
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    alpha = None
    
    train_errors = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = epochs
    patience_expansion = patience
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_errors.append((i,err_rate))
                if i % 100 == 0 and print_debug:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        G -= regularization_alg(P)
                        
                    
                    alpha = alpha_alg(i, e)
                    
                    epsilon = momentum_alg(i)
                    
                    V = epsilon * V - alpha * G
                    
                    #P += -5e-2 * G
                    P += V
                    
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            if print_debug or (e % 20 == 1):
                print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                    e, val_error_rate, number_of_epochs)
        print "Finished with %d epochs (minibatch %d), with best valid error rate %f" % (e, i, best_valid_error_rate)
        print_stats(train_loss, train_errors, validation_errors)
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        print_stats(train_loss, train_errors, validation_errors)

# %%
net = FeedForwardNet([
        AffineLayer(784,10),
        SoftMaxLayer()
        ])

SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# Network configuration:
# W(10, 784), b(10, 1)
# At minibatch 100, batch loss 0.616325, batch error rate 20.000000%
# At minibatch 200, batch loss 0.619109, batch error rate 21.000000%
# At minibatch 300, batch loss 0.526454, batch error rate 18.000000%
# At minibatch 400, batch loss 0.717130, batch error rate 15.000000%
# At minibatch 500, batch loss 0.470039, batch error rate 13.000000%
# After epoch 1: valid_err_rate: 0.128200% currently going ot do 100 epochs
# At minibatch 600, batch loss 0.710695, batch error rate 18.000000%
# At minibatch 700, batch loss 0.363495, batch error rate 14.000000%
# At minibatch 800, batch loss 0.455966, batch error rate 16.000000%
# At minibatch 900, batch loss 0.242331, batch error rate 7.000000%
# At minibatch 1000, batch loss 0.428120, batch error rate 14.000000%
# After epoch 2: valid_err_rate: 0.109800% currently going ot do 100 epochs
# At minibatch 1100, batch loss 0.431201, batch error rate 10.000000%
# At minibatch 1200, batch loss 0.483032, batch error rate 13.000000%
# At minibatch 1300, batch loss 0.283547, batch error rate 10.000000%
# At minibatch 1400, batch loss 0.522377, batch error rate 12.000000%
# At minibatch 1500, batch loss 0.408270, batch error rate 11.000000%
# After epoch 3: valid_err_rate: 0.101500% currently going ot do 100 epochs
# At minibatch 1600, batch loss 0.283472, batch error rate 9.000000%
# At minibatch 1700, batch loss 0.273945, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.223763, batch error rate 9.000000%
# At minibatch 1900, batch loss 0.369000, batch error rate 14.000000%
# At minibatch 2000, batch loss 0.471330, batch error rate 11.000000%
# After epoch 4: valid_err_rate: 0.097600% currently going ot do 100 epochs
# At minibatch 2100, batch loss 0.334158, batch error rate 8.000000%
# At minibatch 2200, batch loss 0.212049, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.329666, batch error rate 8.000000%
# At minibatch 2400, batch loss 0.414613, batch error rate 13.000000%
# At minibatch 2500, batch loss 0.540740, batch error rate 16.000000%
# After epoch 5: valid_err_rate: 0.091100% currently going ot do 100 epochs
# At minibatch 2600, batch loss 0.174110, batch error rate 5.000000%
# At minibatch 2700, batch loss 0.257544, batch error rate 7.000000%
# At minibatch 2800, batch loss 0.174825, batch error rate 5.000000%
# At minibatch 2900, batch loss 0.372854, batch error rate 10.000000%
# At minibatch 3000, batch loss 0.204068, batch error rate 8.000000%
# After epoch 6: valid_err_rate: 0.094200% currently going ot do 100 epochs
# At minibatch 3100, batch loss 0.442086, batch error rate 12.000000%
# At minibatch 3200, batch loss 0.600174, batch error rate 15.000000%
# At minibatch 3300, batch loss 0.355340, batch error rate 11.000000%
# At minibatch 3400, batch loss 0.365711, batch error rate 10.000000%
# At minibatch 3500, batch loss 0.369139, batch error rate 10.000000%
# After epoch 7: valid_err_rate: 0.087600% currently going ot do 100 epochs
# At minibatch 3600, batch loss 0.634144, batch error rate 16.000000%
# At minibatch 3700, batch loss 0.222199, batch error rate 7.000000%
# At minibatch 3800, batch loss 0.215903, batch error rate 6.000000%
# At minibatch 3900, batch loss 0.270995, batch error rate 9.000000%
# At minibatch 4000, batch loss 0.464080, batch error rate 16.000000%
# After epoch 8: valid_err_rate: 0.088400% currently going ot do 100 epochs
# At minibatch 4100, batch loss 0.279654, batch error rate 6.000000%
# At minibatch 4200, batch loss 0.467851, batch error rate 12.000000%
# At minibatch 4300, batch loss 0.377137, batch error rate 9.000000%
# At minibatch 4400, batch loss 0.238772, batch error rate 6.000000%
# At minibatch 4500, batch loss 0.372555, batch error rate 7.000000%
# After epoch 9: valid_err_rate: 0.082800% currently going ot do 100 epochs
# At minibatch 4600, batch loss 0.255064, batch error rate 7.000000%
# At minibatch 4700, batch loss 0.284637, batch error rate 10.000000%
# At minibatch 4800, batch loss 0.509224, batch error rate 14.000000%
# At minibatch 4900, batch loss 0.486139, batch error rate 16.000000%
# At minibatch 5000, batch loss 0.376915, batch error rate 8.000000%
# After epoch 10: valid_err_rate: 0.087700% currently going ot do 100 epochs
# At minibatch 5100, batch loss 0.390368, batch error rate 11.000000%
# At minibatch 5200, batch loss 0.173798, batch error rate 4.000000%
# At minibatch 5300, batch loss 0.301230, batch error rate 9.000000%
# At minibatch 5400, batch loss 0.347067, batch error rate 14.000000%
# At minibatch 5500, batch loss 0.628189, batch error rate 15.000000%
# After epoch 11: valid_err_rate: 0.086000% currently going ot do 100 epochs
# At minibatch 5600, batch loss 0.354473, batch error rate 10.000000%
# At minibatch 5700, batch loss 0.204131, batch error rate 6.000000%
# At minibatch 5800, batch loss 0.329918, batch error rate 10.000000%
# At minibatch 5900, batch loss 0.285005, batch error rate 8.000000%
# At minibatch 6000, batch loss 0.373083, batch error rate 6.000000%
# After epoch 12: valid_err_rate: 0.082300% currently going ot do 100 epochs
# At minibatch 6100, batch loss 0.274651, batch error rate 5.000000%
# At minibatch 6200, batch loss 0.174612, batch error rate 5.000000%
# At minibatch 6300, batch loss 0.202061, batch error rate 7.000000%
# At minibatch 6400, batch loss 0.170000, batch error rate 8.000000%
# At minibatch 6500, batch loss 0.297817, batch error rate 8.000000%
# After epoch 13: valid_err_rate: 0.083500% currently going ot do 100 epochs
# At minibatch 6600, batch loss 0.410461, batch error rate 9.000000%
# At minibatch 6700, batch loss 0.286642, batch error rate 7.000000%
# At minibatch 6800, batch loss 0.251408, batch error rate 5.000000%
# At minibatch 6900, batch loss 0.215418, batch error rate 7.000000%
# At minibatch 7000, batch loss 0.391590, batch error rate 11.000000%
# After epoch 14: valid_err_rate: 0.084400% currently going ot do 100 epochs
# At minibatch 7100, batch loss 0.212484, batch error rate 5.000000%
# At minibatch 7200, batch loss 0.417322, batch error rate 12.000000%
# At minibatch 7300, batch loss 0.549508, batch error rate 12.000000%
# At minibatch 7400, batch loss 0.208200, batch error rate 7.000000%
# At minibatch 7500, batch loss 0.332910, batch error rate 10.000000%
# After epoch 15: valid_err_rate: 0.082800% currently going ot do 100 epochs
# At minibatch 7600, batch loss 0.356742, batch error rate 11.000000%
# At minibatch 7700, batch loss 0.121086, batch error rate 3.000000%
# At minibatch 7800, batch loss 0.279742, batch error rate 10.000000%
# At minibatch 7900, batch loss 0.464832, batch error rate 14.000000%
# At minibatch 8000, batch loss 0.213616, batch error rate 7.000000%
# After epoch 16: valid_err_rate: 0.084600% currently going ot do 100 epochs
# At minibatch 8100, batch loss 0.661600, batch error rate 11.000000%
# At minibatch 8200, batch loss 0.371563, batch error rate 11.000000%
# At minibatch 8300, batch loss 0.331359, batch error rate 9.000000%
# At minibatch 8400, batch loss 0.130861, batch error rate 4.000000%
# At minibatch 8500, batch loss 0.127898, batch error rate 3.000000%
# After epoch 17: valid_err_rate: 0.082000% currently going ot do 100 epochs
# At minibatch 8600, batch loss 0.322705, batch error rate 7.000000%
# At minibatch 8700, batch loss 0.380917, batch error rate 8.000000%
# At minibatch 8800, batch loss 0.128798, batch error rate 3.000000%
# At minibatch 8900, batch loss 0.219122, batch error rate 8.000000%
# At minibatch 9000, batch loss 0.320380, batch error rate 9.000000%
# After epoch 18: valid_err_rate: 0.083600% currently going ot do 100 epochs
# At minibatch 9100, batch loss 0.133990, batch error rate 4.000000%
# At minibatch 9200, batch loss 0.313737, batch error rate 9.000000%
# At minibatch 9300, batch loss 0.250929, batch error rate 7.000000%
# At minibatch 9400, batch loss 0.191879, batch error rate 6.000000%
# At minibatch 9500, batch loss 0.545436, batch error rate 13.000000%
# After epoch 19: valid_err_rate: 0.082900% currently going ot do 100 epochs
# At minibatch 9600, batch loss 0.314524, batch error rate 10.000000%
# At minibatch 9700, batch loss 0.105918, batch error rate 4.000000%
# At minibatch 9800, batch loss 0.286199, batch error rate 10.000000%
# At minibatch 9900, batch loss 0.448288, batch error rate 12.000000%
# At minibatch 10000, batch loss 0.146174, batch error rate 7.000000%
# After epoch 20: valid_err_rate: 0.082700% currently going ot do 100 epochs
# At minibatch 10100, batch loss 0.653681, batch error rate 10.000000%
# At minibatch 10200, batch loss 0.480053, batch error rate 10.000000%
# At minibatch 10300, batch loss 0.262326, batch error rate 6.000000%
# At minibatch 10400, batch loss 0.233133, batch error rate 7.000000%
# At minibatch 10500, batch loss 0.287019, batch error rate 11.000000%
# After epoch 21: valid_err_rate: 0.082700% currently going ot do 100 epochs
# At minibatch 10600, batch loss 0.134621, batch error rate 4.000000%
# At minibatch 10700, batch loss 0.098085, batch error rate 2.000000%
# At minibatch 10800, batch loss 0.226540, batch error rate 6.000000%
# At minibatch 10900, batch loss 0.412031, batch error rate 13.000000%
# At minibatch 11000, batch loss 0.129659, batch error rate 2.000000%
# After epoch 22: valid_err_rate: 0.083200% currently going ot do 100 epochs
# At minibatch 11100, batch loss 0.335645, batch error rate 7.000000%
# At minibatch 11200, batch loss 0.326001, batch error rate 9.000000%
# At minibatch 11300, batch loss 0.502703, batch error rate 13.000000%
# At minibatch 11400, batch loss 0.329604, batch error rate 4.000000%
# At minibatch 11500, batch loss 0.371989, batch error rate 7.000000%
# After epoch 23: valid_err_rate: 0.082400% currently going ot do 100 epochs
# At minibatch 11600, batch loss 0.348773, batch error rate 5.000000%
# At minibatch 11700, batch loss 0.352128, batch error rate 13.000000%
# At minibatch 11800, batch loss 0.295055, batch error rate 7.000000%
# At minibatch 11900, batch loss 0.218839, batch error rate 5.000000%
# At minibatch 12000, batch loss 0.253880, batch error rate 9.000000%
# After epoch 24: valid_err_rate: 0.081700% currently going ot do 100 epochs
# At minibatch 12100, batch loss 0.350098, batch error rate 13.000000%
# At minibatch 12200, batch loss 0.265022, batch error rate 9.000000%
# At minibatch 12300, batch loss 0.245473, batch error rate 7.000000%
# At minibatch 12400, batch loss 0.499037, batch error rate 10.000000%
# At minibatch 12500, batch loss 0.178575, batch error rate 3.000000%
# After epoch 25: valid_err_rate: 0.081100% currently going ot do 100 epochs
# At minibatch 12600, batch loss 0.158840, batch error rate 6.000000%
# At minibatch 12700, batch loss 0.326349, batch error rate 11.000000%
# At minibatch 12800, batch loss 0.386669, batch error rate 12.000000%
# At minibatch 12900, batch loss 0.291204, batch error rate 12.000000%
# At minibatch 13000, batch loss 0.193165, batch error rate 7.000000%
# After epoch 26: valid_err_rate: 0.082300% currently going ot do 100 epochs
# At minibatch 13100, batch loss 0.496469, batch error rate 7.000000%
# At minibatch 13200, batch loss 0.152280, batch error rate 5.000000%
# At minibatch 13300, batch loss 0.102497, batch error rate 2.000000%
# At minibatch 13400, batch loss 0.250733, batch error rate 5.000000%
# At minibatch 13500, batch loss 0.251117, batch error rate 6.000000%
# After epoch 27: valid_err_rate: 0.082500% currently going ot do 100 epochs
# At minibatch 13600, batch loss 0.500843, batch error rate 11.000000%
# At minibatch 13700, batch loss 0.299002, batch error rate 8.000000%
# At minibatch 13800, batch loss 0.311019, batch error rate 6.000000%
# At minibatch 13900, batch loss 0.408878, batch error rate 11.000000%
# At minibatch 14000, batch loss 0.346807, batch error rate 7.000000%
# After epoch 28: valid_err_rate: 0.084700% currently going ot do 100 epochs
# At minibatch 14100, batch loss 0.212208, batch error rate 5.000000%
# At minibatch 14200, batch loss 0.168588, batch error rate 5.000000%
# At minibatch 14300, batch loss 0.129913, batch error rate 3.000000%
# At minibatch 14400, batch loss 0.223974, batch error rate 6.000000%
# At minibatch 14500, batch loss 0.134449, batch error rate 4.000000%
# After epoch 29: valid_err_rate: 0.079400% currently going ot do 100 epochs
# At minibatch 14600, batch loss 0.358632, batch error rate 11.000000%
# At minibatch 14700, batch loss 0.325992, batch error rate 8.000000%
# At minibatch 14800, batch loss 0.163205, batch error rate 7.000000%
# At minibatch 14900, batch loss 0.335685, batch error rate 9.000000%
# At minibatch 15000, batch loss 0.379110, batch error rate 11.000000%
# After epoch 30: valid_err_rate: 0.082400% currently going ot do 100 epochs
# At minibatch 15100, batch loss 0.323815, batch error rate 7.000000%
# At minibatch 15200, batch loss 0.477999, batch error rate 11.000000%
# At minibatch 15300, batch loss 0.633668, batch error rate 13.000000%
# At minibatch 15400, batch loss 0.156749, batch error rate 3.000000%
# At minibatch 15500, batch loss 0.304908, batch error rate 9.000000%
# After epoch 31: valid_err_rate: 0.082300% currently going ot do 100 epochs
# At minibatch 15600, batch loss 0.250366, batch error rate 10.000000%
# At minibatch 15700, batch loss 0.230050, batch error rate 8.000000%
# At minibatch 15800, batch loss 0.142824, batch error rate 5.000000%
# At minibatch 15900, batch loss 0.301698, batch error rate 7.000000%
# At minibatch 16000, batch loss 0.329877, batch error rate 6.000000%
# After epoch 32: valid_err_rate: 0.083800% currently going ot do 100 epochs
# At minibatch 16100, batch loss 0.412282, batch error rate 7.000000%
# At minibatch 16200, batch loss 0.615946, batch error rate 11.000000%
# At minibatch 16300, batch loss 0.651151, batch error rate 9.000000%
# At minibatch 16400, batch loss 0.158364, batch error rate 7.000000%
# At minibatch 16500, batch loss 0.347877, batch error rate 7.000000%
# After epoch 33: valid_err_rate: 0.082300% currently going ot do 100 epochs
# At minibatch 16600, batch loss 0.267414, batch error rate 7.000000%
# At minibatch 16700, batch loss 0.458199, batch error rate 12.000000%
# At minibatch 16800, batch loss 0.317871, batch error rate 9.000000%
# At minibatch 16900, batch loss 0.291032, batch error rate 10.000000%
# At minibatch 17000, batch loss 0.122865, batch error rate 4.000000%
# After epoch 34: valid_err_rate: 0.081200% currently going ot do 100 epochs
# At minibatch 17100, batch loss 0.610652, batch error rate 13.000000%
# At minibatch 17200, batch loss 0.367172, batch error rate 10.000000%
# At minibatch 17300, batch loss 0.137193, batch error rate 5.000000%
# At minibatch 17400, batch loss 0.288354, batch error rate 6.000000%
# At minibatch 17500, batch loss 0.439764, batch error rate 7.000000%
# After epoch 35: valid_err_rate: 0.085500% currently going ot do 100 epochs
# At minibatch 17600, batch loss 0.455248, batch error rate 12.000000%
# At minibatch 17700, batch loss 0.343607, batch error rate 7.000000%
# At minibatch 17800, batch loss 0.367265, batch error rate 11.000000%
# At minibatch 17900, batch loss 0.201744, batch error rate 4.000000%
# At minibatch 18000, batch loss 0.160698, batch error rate 4.000000%
# After epoch 36: valid_err_rate: 0.083900% currently going ot do 100 epochs
# At minibatch 18100, batch loss 0.161076, batch error rate 7.000000%
# At minibatch 18200, batch loss 0.345852, batch error rate 10.000000%
# At minibatch 18300, batch loss 0.337127, batch error rate 10.000000%
# At minibatch 18400, batch loss 0.471678, batch error rate 12.000000%
# At minibatch 18500, batch loss 0.209049, batch error rate 7.000000%
# After epoch 37: valid_err_rate: 0.082200% currently going ot do 100 epochs
# At minibatch 18600, batch loss 0.274890, batch error rate 7.000000%
# At minibatch 18700, batch loss 0.290427, batch error rate 9.000000%
# At minibatch 18800, batch loss 0.469634, batch error rate 9.000000%
# At minibatch 18900, batch loss 0.346808, batch error rate 6.000000%
# At minibatch 19000, batch loss 0.267993, batch error rate 12.000000%
# After epoch 38: valid_err_rate: 0.084000% currently going ot do 100 epochs
# At minibatch 19100, batch loss 0.467376, batch error rate 12.000000%
# At minibatch 19200, batch loss 0.362109, batch error rate 4.000000%
# At minibatch 19300, batch loss 0.282206, batch error rate 8.000000%
# At minibatch 19400, batch loss 0.403059, batch error rate 6.000000%
# At minibatch 19500, batch loss 0.246646, batch error rate 5.000000%
# After epoch 39: valid_err_rate: 0.093700% currently going ot do 100 epochs
# At minibatch 19600, batch loss 0.391701, batch error rate 10.000000%
# At minibatch 19700, batch loss 0.268112, batch error rate 9.000000%
# At minibatch 19800, batch loss 0.238482, batch error rate 6.000000%
# At minibatch 19900, batch loss 0.274538, batch error rate 8.000000%
# At minibatch 20000, batch loss 0.291678, batch error rate 6.000000%
# After epoch 40: valid_err_rate: 0.082300% currently going ot do 100 epochs
# At minibatch 20100, batch loss 0.377879, batch error rate 8.000000%
# At minibatch 20200, batch loss 0.389620, batch error rate 10.000000%
# At minibatch 20300, batch loss 0.164321, batch error rate 5.000000%
# At minibatch 20400, batch loss 0.237997, batch error rate 8.000000%
# At minibatch 20500, batch loss 0.275744, batch error rate 5.000000%
# After epoch 41: valid_err_rate: 0.083400% currently going ot do 100 epochs
# At minibatch 20600, batch loss 0.333161, batch error rate 9.000000%
# At minibatch 20700, batch loss 0.314322, batch error rate 10.000000%
# At minibatch 20800, batch loss 0.488063, batch error rate 9.000000%
# At minibatch 20900, batch loss 0.415039, batch error rate 9.000000%
# At minibatch 21000, batch loss 0.414418, batch error rate 7.000000%
# After epoch 42: valid_err_rate: 0.087200% currently going ot do 100 epochs
# At minibatch 21100, batch loss 0.256495, batch error rate 8.000000%
# At minibatch 21200, batch loss 0.323105, batch error rate 11.000000%
# At minibatch 21300, batch loss 0.440307, batch error rate 10.000000%
# At minibatch 21400, batch loss 0.182701, batch error rate 7.000000%
# At minibatch 21500, batch loss 0.331543, batch error rate 9.000000%
# After epoch 43: valid_err_rate: 0.086400% currently going ot do 100 epochs
# At minibatch 21600, batch loss 0.331702, batch error rate 10.000000%
# At minibatch 21700, batch loss 0.269781, batch error rate 5.000000%
# At minibatch 21800, batch loss 0.179449, batch error rate 4.000000%
# At minibatch 21900, batch loss 0.232171, batch error rate 6.000000%
# At minibatch 22000, batch loss 0.441923, batch error rate 10.000000%
# After epoch 44: valid_err_rate: 0.082700% currently going ot do 100 epochs
# At minibatch 22100, batch loss 0.492063, batch error rate 11.000000%
# At minibatch 22200, batch loss 0.505814, batch error rate 12.000000%
# At minibatch 22300, batch loss 0.371321, batch error rate 9.000000%
# At minibatch 22400, batch loss 0.114583, batch error rate 4.000000%
# At minibatch 22500, batch loss 0.297150, batch error rate 8.000000%
# After epoch 45: valid_err_rate: 0.084300% currently going ot do 100 epochs
# At minibatch 22600, batch loss 0.187557, batch error rate 5.000000%
# At minibatch 22700, batch loss 0.589598, batch error rate 9.000000%
# At minibatch 22800, batch loss 0.189321, batch error rate 5.000000%
# At minibatch 22900, batch loss 0.375603, batch error rate 9.000000%
# At minibatch 23000, batch loss 0.224211, batch error rate 8.000000%
# After epoch 46: valid_err_rate: 0.083700% currently going ot do 100 epochs
# At minibatch 23100, batch loss 0.182941, batch error rate 8.000000%
# At minibatch 23200, batch loss 0.416496, batch error rate 7.000000%
# At minibatch 23300, batch loss 0.478861, batch error rate 7.000000%
# At minibatch 23400, batch loss 0.395189, batch error rate 9.000000%
# At minibatch 23500, batch loss 0.234107, batch error rate 12.000000%
# After epoch 47: valid_err_rate: 0.085700% currently going ot do 100 epochs
# At minibatch 23600, batch loss 0.508775, batch error rate 12.000000%
# At minibatch 23700, batch loss 0.164622, batch error rate 6.000000%
# At minibatch 23800, batch loss 0.386932, batch error rate 12.000000%
# At minibatch 23900, batch loss 0.440357, batch error rate 7.000000%
# At minibatch 24000, batch loss 0.235398, batch error rate 8.000000%
# After epoch 48: valid_err_rate: 0.086600% currently going ot do 100 epochs
# At minibatch 24100, batch loss 0.206512, batch error rate 5.000000%
# At minibatch 24200, batch loss 0.330843, batch error rate 12.000000%
# At minibatch 24300, batch loss 0.302214, batch error rate 6.000000%
# At minibatch 24400, batch loss 0.470552, batch error rate 11.000000%
# At minibatch 24500, batch loss 0.759681, batch error rate 16.000000%
# After epoch 49: valid_err_rate: 0.083900% currently going ot do 100 epochs
# At minibatch 24600, batch loss 0.481424, batch error rate 12.000000%
# At minibatch 24700, batch loss 0.389052, batch error rate 10.000000%
# At minibatch 24800, batch loss 0.656229, batch error rate 10.000000%
# At minibatch 24900, batch loss 0.223103, batch error rate 4.000000%
# At minibatch 25000, batch loss 0.531043, batch error rate 7.000000%
# After epoch 50: valid_err_rate: 0.084100% currently going ot do 100 epochs
# At minibatch 25100, batch loss 0.618630, batch error rate 12.000000%
# At minibatch 25200, batch loss 0.285121, batch error rate 6.000000%
# At minibatch 25300, batch loss 0.511686, batch error rate 7.000000%
# At minibatch 25400, batch loss 0.295674, batch error rate 7.000000%
# At minibatch 25500, batch loss 0.291736, batch error rate 6.000000%
# After epoch 51: valid_err_rate: 0.086900% currently going ot do 100 epochs
# At minibatch 25600, batch loss 0.164635, batch error rate 5.000000%
# At minibatch 25700, batch loss 0.472547, batch error rate 9.000000%
# At minibatch 25800, batch loss 0.350526, batch error rate 9.000000%
# At minibatch 25900, batch loss 0.266697, batch error rate 7.000000%
# At minibatch 26000, batch loss 0.341919, batch error rate 10.000000%
# After epoch 52: valid_err_rate: 0.085000% currently going ot do 100 epochs
# At minibatch 26100, batch loss 0.329555, batch error rate 7.000000%
# At minibatch 26200, batch loss 0.163030, batch error rate 6.000000%
# At minibatch 26300, batch loss 0.126102, batch error rate 5.000000%
# At minibatch 26400, batch loss 0.265614, batch error rate 4.000000%
# At minibatch 26500, batch loss 0.210678, batch error rate 3.000000%
# After epoch 53: valid_err_rate: 0.085300% currently going ot do 100 epochs
# At minibatch 26600, batch loss 0.251763, batch error rate 6.000000%
# At minibatch 26700, batch loss 0.459239, batch error rate 13.000000%
# At minibatch 26800, batch loss 0.455625, batch error rate 6.000000%
# At minibatch 26900, batch loss 0.256937, batch error rate 7.000000%
# At minibatch 27000, batch loss 0.510887, batch error rate 14.000000%
# After epoch 54: valid_err_rate: 0.084200% currently going ot do 100 epochs
# At minibatch 27100, batch loss 0.429565, batch error rate 7.000000%
# At minibatch 27200, batch loss 0.340996, batch error rate 8.000000%
# At minibatch 27300, batch loss 0.149391, batch error rate 5.000000%
# At minibatch 27400, batch loss 0.177428, batch error rate 6.000000%
# At minibatch 27500, batch loss 0.276670, batch error rate 8.000000%
# After epoch 55: valid_err_rate: 0.084200% currently going ot do 100 epochs
# At minibatch 27600, batch loss 0.285370, batch error rate 13.000000%
# At minibatch 27700, batch loss 0.388361, batch error rate 10.000000%
# At minibatch 27800, batch loss 0.203339, batch error rate 7.000000%
# At minibatch 27900, batch loss 0.544199, batch error rate 9.000000%
# At minibatch 28000, batch loss 0.115874, batch error rate 4.000000%
# After epoch 56: valid_err_rate: 0.086500% currently going ot do 100 epochs
# At minibatch 28100, batch loss 0.257386, batch error rate 7.000000%
# At minibatch 28200, batch loss 0.311704, batch error rate 8.000000%
# At minibatch 28300, batch loss 0.245031, batch error rate 7.000000%
# At minibatch 28400, batch loss 0.270651, batch error rate 5.000000%
# At minibatch 28500, batch loss 0.137561, batch error rate 7.000000%
# After epoch 57: valid_err_rate: 0.085400% currently going ot do 100 epochs
# At minibatch 28600, batch loss 0.254711, batch error rate 4.000000%
# At minibatch 28700, batch loss 0.284317, batch error rate 2.000000%
# At minibatch 28800, batch loss 0.302529, batch error rate 6.000000%
# At minibatch 28900, batch loss 0.142585, batch error rate 5.000000%
# At minibatch 29000, batch loss 0.420677, batch error rate 11.000000%
# After epoch 58: valid_err_rate: 0.088100% currently going ot do 100 epochs
# At minibatch 29100, batch loss 0.251809, batch error rate 10.000000%
# At minibatch 29200, batch loss 0.336941, batch error rate 7.000000%
# At minibatch 29300, batch loss 0.286699, batch error rate 6.000000%
# At minibatch 29400, batch loss 0.728190, batch error rate 14.000000%
# At minibatch 29500, batch loss 0.296570, batch error rate 7.000000%
# After epoch 59: valid_err_rate: 0.086500% currently going ot do 100 epochs
# At minibatch 29600, batch loss 0.202257, batch error rate 4.000000%
# At minibatch 29700, batch loss 0.258220, batch error rate 7.000000%
# At minibatch 29800, batch loss 0.245862, batch error rate 9.000000%
# At minibatch 29900, batch loss 0.231657, batch error rate 4.000000%
# At minibatch 30000, batch loss 0.262998, batch error rate 7.000000%
# After epoch 60: valid_err_rate: 0.087100% currently going ot do 100 epochs
# At minibatch 30100, batch loss 0.410582, batch error rate 5.000000%
# At minibatch 30200, batch loss 0.436181, batch error rate 8.000000%
# At minibatch 30300, batch loss 0.415305, batch error rate 13.000000%
# At minibatch 30400, batch loss 0.579990, batch error rate 10.000000%
# At minibatch 30500, batch loss 0.382471, batch error rate 10.000000%
# After epoch 61: valid_err_rate: 0.088200% currently going ot do 100 epochs
# At minibatch 30600, batch loss 0.301816, batch error rate 6.000000%
# At minibatch 30700, batch loss 0.436861, batch error rate 12.000000%
# At minibatch 30800, batch loss 0.349394, batch error rate 10.000000%
# At minibatch 30900, batch loss 0.440665, batch error rate 10.000000%
# At minibatch 31000, batch loss 0.374052, batch error rate 9.000000%
# After epoch 62: valid_err_rate: 0.087500% currently going ot do 100 epochs
# At minibatch 31100, batch loss 0.529649, batch error rate 14.000000%
# At minibatch 31200, batch loss 0.242786, batch error rate 10.000000%
# At minibatch 31300, batch loss 0.472654, batch error rate 8.000000%
# At minibatch 31400, batch loss 0.187836, batch error rate 6.000000%
# At minibatch 31500, batch loss 0.221556, batch error rate 9.000000%
# After epoch 63: valid_err_rate: 0.086400% currently going ot do 100 epochs
# At minibatch 31600, batch loss 0.558862, batch error rate 10.000000%
# At minibatch 31700, batch loss 0.306168, batch error rate 9.000000%
# At minibatch 31800, batch loss 0.134786, batch error rate 7.000000%
# At minibatch 31900, batch loss 0.153052, batch error rate 6.000000%
# At minibatch 32000, batch loss 0.191569, batch error rate 5.000000%
# After epoch 64: valid_err_rate: 0.085900% currently going ot do 100 epochs
# At minibatch 32100, batch loss 0.455924, batch error rate 13.000000%
# At minibatch 32200, batch loss 0.521253, batch error rate 8.000000%
# At minibatch 32300, batch loss 0.353703, batch error rate 8.000000%
# At minibatch 32400, batch loss 0.269049, batch error rate 6.000000%
# At minibatch 32500, batch loss 0.377429, batch error rate 11.000000%
# After epoch 65: valid_err_rate: 0.089700% currently going ot do 100 epochs
# At minibatch 32600, batch loss 0.102552, batch error rate 4.000000%
# At minibatch 32700, batch loss 0.577511, batch error rate 9.000000%
# At minibatch 32800, batch loss 0.193649, batch error rate 7.000000%
# At minibatch 32900, batch loss 0.225964, batch error rate 6.000000%
# At minibatch 33000, batch loss 0.213361, batch error rate 7.000000%
# After epoch 66: valid_err_rate: 0.086200% currently going ot do 100 epochs
# At minibatch 33100, batch loss 0.233946, batch error rate 8.000000%
# At minibatch 33200, batch loss 0.498058, batch error rate 8.000000%
# At minibatch 33300, batch loss 0.192337, batch error rate 3.000000%
# At minibatch 33400, batch loss 0.211152, batch error rate 6.000000%
# At minibatch 33500, batch loss 0.486846, batch error rate 10.000000%
# After epoch 67: valid_err_rate: 0.088500% currently going ot do 100 epochs
# At minibatch 33600, batch loss 0.483936, batch error rate 10.000000%
# At minibatch 33700, batch loss 0.524473, batch error rate 10.000000%
# At minibatch 33800, batch loss 0.216240, batch error rate 3.000000%
# At minibatch 33900, batch loss 0.598202, batch error rate 12.000000%
# At minibatch 34000, batch loss 0.365749, batch error rate 7.000000%
# After epoch 68: valid_err_rate: 0.092800% currently going ot do 100 epochs
# At minibatch 34100, batch loss 0.362534, batch error rate 6.000000%
# At minibatch 34200, batch loss 0.112309, batch error rate 7.000000%
# At minibatch 34300, batch loss 0.618140, batch error rate 12.000000%
# At minibatch 34400, batch loss 0.308727, batch error rate 8.000000%
# At minibatch 34500, batch loss 0.273901, batch error rate 9.000000%
# After epoch 69: valid_err_rate: 0.090800% currently going ot do 100 epochs
# At minibatch 34600, batch loss 0.245541, batch error rate 7.000000%
# At minibatch 34700, batch loss 0.250979, batch error rate 9.000000%
# At minibatch 34800, batch loss 0.443956, batch error rate 9.000000%
# At minibatch 34900, batch loss 0.366716, batch error rate 7.000000%
# At minibatch 35000, batch loss 0.332917, batch error rate 8.000000%
# After epoch 70: valid_err_rate: 0.088700% currently going ot do 100 epochs
# At minibatch 35100, batch loss 0.561752, batch error rate 12.000000%
# At minibatch 35200, batch loss 0.273382, batch error rate 8.000000%
# At minibatch 35300, batch loss 0.290986, batch error rate 9.000000%
# At minibatch 35400, batch loss 0.370361, batch error rate 6.000000%
# At minibatch 35500, batch loss 0.221747, batch error rate 5.000000%
# After epoch 71: valid_err_rate: 0.087400% currently going ot do 100 epochs
# At minibatch 35600, batch loss 0.359425, batch error rate 9.000000%
# At minibatch 35700, batch loss 0.480685, batch error rate 6.000000%
# At minibatch 35800, batch loss 0.357877, batch error rate 9.000000%
# At minibatch 35900, batch loss 0.261540, batch error rate 7.000000%
# At minibatch 36000, batch loss 0.529485, batch error rate 8.000000%
# After epoch 72: valid_err_rate: 0.087900% currently going ot do 100 epochs
# At minibatch 36100, batch loss 0.306178, batch error rate 5.000000%
# At minibatch 36200, batch loss 0.176684, batch error rate 5.000000%
# At minibatch 36300, batch loss 0.412148, batch error rate 6.000000%
# At minibatch 36400, batch loss 0.814336, batch error rate 9.000000%
# At minibatch 36500, batch loss 0.386742, batch error rate 10.000000%
# After epoch 73: valid_err_rate: 0.087400% currently going ot do 100 epochs
# At minibatch 36600, batch loss 0.264268, batch error rate 4.000000%
# At minibatch 36700, batch loss 0.394674, batch error rate 6.000000%
# At minibatch 36800, batch loss 0.578908, batch error rate 14.000000%
# At minibatch 36900, batch loss 0.369041, batch error rate 12.000000%
# At minibatch 37000, batch loss 0.477325, batch error rate 6.000000%
# After epoch 74: valid_err_rate: 0.089000% currently going ot do 100 epochs
# At minibatch 37100, batch loss 0.089444, batch error rate 3.000000%
# At minibatch 37200, batch loss 0.219122, batch error rate 7.000000%
# At minibatch 37300, batch loss 0.288275, batch error rate 7.000000%
# At minibatch 37400, batch loss 0.230008, batch error rate 7.000000%
# At minibatch 37500, batch loss 0.384397, batch error rate 8.000000%
# After epoch 75: valid_err_rate: 0.089900% currently going ot do 100 epochs
# At minibatch 37600, batch loss 0.175479, batch error rate 3.000000%
# At minibatch 37700, batch loss 0.527859, batch error rate 11.000000%
# At minibatch 37800, batch loss 0.222007, batch error rate 7.000000%
# At minibatch 37900, batch loss 0.182513, batch error rate 6.000000%
# At minibatch 38000, batch loss 0.158671, batch error rate 6.000000%
# After epoch 76: valid_err_rate: 0.089200% currently going ot do 100 epochs
# At minibatch 38100, batch loss 0.182357, batch error rate 4.000000%
# At minibatch 38200, batch loss 0.197313, batch error rate 8.000000%
# At minibatch 38300, batch loss 0.243372, batch error rate 6.000000%
# At minibatch 38400, batch loss 0.219232, batch error rate 6.000000%
# At minibatch 38500, batch loss 0.621610, batch error rate 9.000000%
# After epoch 77: valid_err_rate: 0.088900% currently going ot do 100 epochs
# At minibatch 38600, batch loss 0.173457, batch error rate 3.000000%
# At minibatch 38700, batch loss 0.253398, batch error rate 7.000000%
# At minibatch 38800, batch loss 0.362177, batch error rate 12.000000%
# At minibatch 38900, batch loss 0.150188, batch error rate 6.000000%
# At minibatch 39000, batch loss 0.642104, batch error rate 11.000000%
# After epoch 78: valid_err_rate: 0.088000% currently going ot do 100 epochs
# At minibatch 39100, batch loss 0.472846, batch error rate 11.000000%
# At minibatch 39200, batch loss 0.339685, batch error rate 9.000000%
# At minibatch 39300, batch loss 0.240711, batch error rate 9.000000%
# At minibatch 39400, batch loss 0.262906, batch error rate 8.000000%
# At minibatch 39500, batch loss 0.265197, batch error rate 9.000000%
# After epoch 79: valid_err_rate: 0.091600% currently going ot do 100 epochs
# At minibatch 39600, batch loss 0.114755, batch error rate 3.000000%
# At minibatch 39700, batch loss 0.250878, batch error rate 10.000000%
# At minibatch 39800, batch loss 0.273985, batch error rate 7.000000%
# At minibatch 39900, batch loss 0.281436, batch error rate 5.000000%
# At minibatch 40000, batch loss 0.493829, batch error rate 14.000000%
# After epoch 80: valid_err_rate: 0.088900% currently going ot do 100 epochs
# At minibatch 40100, batch loss 0.239329, batch error rate 3.000000%
# At minibatch 40200, batch loss 0.465440, batch error rate 8.000000%
# At minibatch 40300, batch loss 0.313590, batch error rate 8.000000%
# At minibatch 40400, batch loss 0.241017, batch error rate 3.000000%
# At minibatch 40500, batch loss 0.285919, batch error rate 13.000000%
# After epoch 81: valid_err_rate: 0.089400% currently going ot do 100 epochs
# At minibatch 40600, batch loss 0.274878, batch error rate 7.000000%
# At minibatch 40700, batch loss 0.384495, batch error rate 8.000000%
# At minibatch 40800, batch loss 0.195555, batch error rate 4.000000%
# At minibatch 40900, batch loss 0.529973, batch error rate 12.000000%
# At minibatch 41000, batch loss 0.274186, batch error rate 8.000000%
# After epoch 82: valid_err_rate: 0.091200% currently going ot do 100 epochs
# At minibatch 41100, batch loss 0.333716, batch error rate 5.000000%
# At minibatch 41200, batch loss 0.706112, batch error rate 11.000000%
# At minibatch 41300, batch loss 0.100711, batch error rate 3.000000%
# At minibatch 41400, batch loss 0.157377, batch error rate 7.000000%
# At minibatch 41500, batch loss 0.496359, batch error rate 8.000000%
# After epoch 83: valid_err_rate: 0.088300% currently going ot do 100 epochs
# At minibatch 41600, batch loss 0.768950, batch error rate 11.000000%
# At minibatch 41700, batch loss 1.057297, batch error rate 15.000000%
# At minibatch 41800, batch loss 0.259264, batch error rate 5.000000%
# At minibatch 41900, batch loss 0.580349, batch error rate 14.000000%
# At minibatch 42000, batch loss 0.782465, batch error rate 9.000000%
# After epoch 84: valid_err_rate: 0.092600% currently going ot do 100 epochs
# At minibatch 42100, batch loss 0.520041, batch error rate 9.000000%
# At minibatch 42200, batch loss 0.500368, batch error rate 10.000000%
# At minibatch 42300, batch loss 0.470604, batch error rate 7.000000%
# At minibatch 42400, batch loss 0.929458, batch error rate 13.000000%
# At minibatch 42500, batch loss 0.425439, batch error rate 9.000000%
# After epoch 85: valid_err_rate: 0.090400% currently going ot do 100 epochs
# At minibatch 42600, batch loss 0.249806, batch error rate 5.000000%
# At minibatch 42700, batch loss 1.149037, batch error rate 10.000000%
# At minibatch 42800, batch loss 0.330460, batch error rate 6.000000%
# At minibatch 42900, batch loss 0.565621, batch error rate 11.000000%
# At minibatch 43000, batch loss 0.196596, batch error rate 7.000000%
# After epoch 86: valid_err_rate: 0.089900% currently going ot do 100 epochs
# At minibatch 43100, batch loss 0.484067, batch error rate 6.000000%
# At minibatch 43200, batch loss 0.760475, batch error rate 11.000000%
# At minibatch 43300, batch loss 0.155401, batch error rate 3.000000%
# At minibatch 43400, batch loss 0.178801, batch error rate 6.000000%
# At minibatch 43500, batch loss 0.327081, batch error rate 6.000000%
# After epoch 87: valid_err_rate: 0.090400% currently going ot do 100 epochs
# At minibatch 43600, batch loss 0.398677, batch error rate 10.000000%
# At minibatch 43700, batch loss 0.398769, batch error rate 12.000000%
# At minibatch 43800, batch loss 0.251282, batch error rate 8.000000%
# At minibatch 43900, batch loss 0.672098, batch error rate 11.000000%
# At minibatch 44000, batch loss 0.213158, batch error rate 5.000000%
# After epoch 88: valid_err_rate: 0.090400% currently going ot do 100 epochs
# At minibatch 44100, batch loss 0.658956, batch error rate 12.000000%
# At minibatch 44200, batch loss 0.816040, batch error rate 15.000000%
# At minibatch 44300, batch loss 0.375826, batch error rate 6.000000%
# At minibatch 44400, batch loss 0.618405, batch error rate 11.000000%
# At minibatch 44500, batch loss 1.048293, batch error rate 9.000000%
# After epoch 89: valid_err_rate: 0.093100% currently going ot do 100 epochs
# At minibatch 44600, batch loss 0.578092, batch error rate 12.000000%
# At minibatch 44700, batch loss 0.225377, batch error rate 7.000000%
# At minibatch 44800, batch loss 0.226813, batch error rate 8.000000%
# At minibatch 44900, batch loss 0.382513, batch error rate 6.000000%
# At minibatch 45000, batch loss 0.868753, batch error rate 11.000000%
# After epoch 90: valid_err_rate: 0.095400% currently going ot do 100 epochs
# At minibatch 45100, batch loss 0.296260, batch error rate 7.000000%
# At minibatch 45200, batch loss 0.893167, batch error rate 14.000000%
# At minibatch 45300, batch loss 0.331514, batch error rate 9.000000%
# At minibatch 45400, batch loss 0.695372, batch error rate 14.000000%
# At minibatch 45500, batch loss 0.233176, batch error rate 4.000000%
# After epoch 91: valid_err_rate: 0.091200% currently going ot do 100 epochs
# At minibatch 45600, batch loss 0.816845, batch error rate 9.000000%
# At minibatch 45700, batch loss 0.572398, batch error rate 12.000000%
# At minibatch 45800, batch loss 0.331420, batch error rate 10.000000%
# At minibatch 45900, batch loss 0.356902, batch error rate 6.000000%
# At minibatch 46000, batch loss 0.421271, batch error rate 9.000000%
# After epoch 92: valid_err_rate: 0.092000% currently going ot do 100 epochs
# At minibatch 46100, batch loss 0.233685, batch error rate 6.000000%
# At minibatch 46200, batch loss 0.371374, batch error rate 6.000000%
# At minibatch 46300, batch loss 0.462278, batch error rate 7.000000%
# At minibatch 46400, batch loss 0.422204, batch error rate 10.000000%
# At minibatch 46500, batch loss 0.524887, batch error rate 7.000000%
# After epoch 93: valid_err_rate: 0.093300% currently going ot do 100 epochs
# At minibatch 46600, batch loss 0.629552, batch error rate 11.000000%
# At minibatch 46700, batch loss 0.388699, batch error rate 8.000000%
# At minibatch 46800, batch loss 0.285080, batch error rate 7.000000%
# At minibatch 46900, batch loss 0.388052, batch error rate 8.000000%
# At minibatch 47000, batch loss 0.934153, batch error rate 9.000000%
# After epoch 94: valid_err_rate: 0.093100% currently going ot do 100 epochs
# At minibatch 47100, batch loss 0.593244, batch error rate 7.000000%
# At minibatch 47200, batch loss 0.709279, batch error rate 8.000000%
# At minibatch 47300, batch loss 0.809021, batch error rate 9.000000%
# At minibatch 47400, batch loss 0.363721, batch error rate 6.000000%
# At minibatch 47500, batch loss 0.832866, batch error rate 15.000000%
# After epoch 95: valid_err_rate: 0.091100% currently going ot do 100 epochs
# At minibatch 47600, batch loss 0.323369, batch error rate 6.000000%
# At minibatch 47700, batch loss 0.249827, batch error rate 4.000000%
# At minibatch 47800, batch loss 1.807663, batch error rate 9.000000%
# At minibatch 47900, batch loss 0.329678, batch error rate 7.000000%
# At minibatch 48000, batch loss 0.582300, batch error rate 7.000000%
# After epoch 96: valid_err_rate: 0.094000% currently going ot do 100 epochs
# At minibatch 48100, batch loss 0.374703, batch error rate 9.000000%
# At minibatch 48200, batch loss 0.436054, batch error rate 8.000000%
# At minibatch 48300, batch loss 0.770329, batch error rate 9.000000%
# At minibatch 48400, batch loss 0.446349, batch error rate 10.000000%
# At minibatch 48500, batch loss 0.831724, batch error rate 13.000000%
# After epoch 97: valid_err_rate: 0.092800% currently going ot do 100 epochs
# At minibatch 48600, batch loss 0.231705, batch error rate 5.000000%
# At minibatch 48700, batch loss 0.634263, batch error rate 8.000000%
# At minibatch 48800, batch loss 0.304367, batch error rate 7.000000%
# At minibatch 48900, batch loss 0.709459, batch error rate 13.000000%
# At minibatch 49000, batch loss 0.396923, batch error rate 8.000000%
# After epoch 98: valid_err_rate: 0.092600% currently going ot do 100 epochs
# At minibatch 49100, batch loss 0.584522, batch error rate 11.000000%
# At minibatch 49200, batch loss 0.220439, batch error rate 7.000000%
# At minibatch 49300, batch loss 0.779421, batch error rate 14.000000%
# At minibatch 49400, batch loss 0.399199, batch error rate 11.000000%
# At minibatch 49500, batch loss 0.260544, batch error rate 10.000000%
# After epoch 99: valid_err_rate: 0.092500% currently going ot do 100 epochs
# At minibatch 49600, batch loss 0.508629, batch error rate 5.000000%
# At minibatch 49700, batch loss 0.103158, batch error rate 4.000000%
# At minibatch 49800, batch loss 0.464574, batch error rate 6.000000%
# At minibatch 49900, batch loss 0.386023, batch error rate 7.000000%
# At minibatch 50000, batch loss 0.229305, batch error rate 6.000000%
# After epoch 100: valid_err_rate: 0.093700% currently going ot do 100 epochs
# Finished with 100 epochs (minibatch 50000), with best valid error rate 0.079400
# Test error rate: 0.095900

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
#weight_init = Uniform(std=1.0, mean=0.0)
weight_init = IsotropicGaussian(std=0.2, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 200, weight_init = weight_init),
        TanhLayer(),
        AffineLayer(200, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlgNone(),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg1())

#print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# 78585
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-30d0cdc44fef> in <module>()
#       2 weight_init = IsotropicGaussian(std=0.2, mean=0.0)
#       3 net = FeedForwardNet([
# ----> 4         AffineLayer(784, 200, weight_init = weight_init),
#       5         TanhLayer(),
#       6         AffineLayer(200, 10, weight_init = weight_init),
#
# <ipython-input-3-a3ce6599e72f> in __init__(self, num_in, num_out, weight_init, bias_init, **kwargs)
#      30             bias_init = Constant(0.0)
#      31
# ---> 32         self.W = weight_init.generate(self.rng, (num_out, num_in))
#      33         self.b = bias_init.generate(self.rng, (num_out, 1))
#      34
#
# <ipython-input-127-10d95376898a> in generate(self, rng, shape)
#      43         m = rng.normal(self._mean, self._std, size=shape)
#      44         print(np.sum(m > 0))
# ---> 45         print(np.sum(m = 0))
#      46         print(np.sum(m < 0))
#      47         return m.astype(np.float32)
#
# TypeError: sum() got an unexpected keyword argument 'm'

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0373

# %%
#weight_init = Uniform(std=1.0, mean=0.0)
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 200, weight_init = weight_init),
        TanhLayer(),
        AffineLayer(200, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlgNone(),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg1())
# Out:
# Network configuration:
# W(200, 784), b(200, 1), W(10, 200), b(10, 1)
# At minibatch 100, batch loss 0.556690, batch error rate 15.000000%
# At minibatch 200, batch loss 0.459383, batch error rate 15.000000%
# At minibatch 300, batch loss 0.396490, batch error rate 11.000000%
# At minibatch 400, batch loss 0.373450, batch error rate 10.000000%
# At minibatch 500, batch loss 0.245247, batch error rate 8.000000%
# After epoch 1: valid_err_rate: 0.083900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.451910, batch error rate 11.000000%
# At minibatch 700, batch loss 0.326293, batch error rate 10.000000%
# At minibatch 800, batch loss 0.300362, batch error rate 11.000000%
# At minibatch 900, batch loss 0.216259, batch error rate 6.000000%
# At minibatch 1000, batch loss 0.313469, batch error rate 10.000000%
# After epoch 2: valid_err_rate: 0.070500% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.254129, batch error rate 8.000000%
# At minibatch 1200, batch loss 0.283792, batch error rate 8.000000%
# At minibatch 1300, batch loss 0.464374, batch error rate 13.000000%
# At minibatch 1400, batch loss 0.212317, batch error rate 7.000000%
# At minibatch 1500, batch loss 0.366790, batch error rate 10.000000%
# After epoch 3: valid_err_rate: 0.060200% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.156006, batch error rate 5.000000%
# At minibatch 1700, batch loss 0.308693, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.286027, batch error rate 8.000000%
# At minibatch 1900, batch loss 0.192613, batch error rate 6.000000%
# At minibatch 2000, batch loss 0.163455, batch error rate 3.000000%
# After epoch 4: valid_err_rate: 0.056000% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.133177, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.190650, batch error rate 4.000000%
# At minibatch 2300, batch loss 0.050596, batch error rate 0.000000%
# At minibatch 2400, batch loss 0.118249, batch error rate 4.000000%
# At minibatch 2500, batch loss 0.166872, batch error rate 6.000000%
# After epoch 5: valid_err_rate: 0.052100% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.124755, batch error rate 2.000000%
# At minibatch 2700, batch loss 0.096169, batch error rate 1.000000%
# At minibatch 2800, batch loss 0.304138, batch error rate 10.000000%
# At minibatch 2900, batch loss 0.129162, batch error rate 4.000000%
# At minibatch 3000, batch loss 0.137839, batch error rate 4.000000%
# After epoch 6: valid_err_rate: 0.046600% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.214522, batch error rate 8.000000%
# At minibatch 3200, batch loss 0.180013, batch error rate 7.000000%
# At minibatch 3300, batch loss 0.173236, batch error rate 6.000000%
# At minibatch 3400, batch loss 0.140224, batch error rate 5.000000%
# At minibatch 3500, batch loss 0.104168, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.043000% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.113551, batch error rate 5.000000%
# At minibatch 3700, batch loss 0.093408, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.157407, batch error rate 3.000000%
# At minibatch 3900, batch loss 0.090452, batch error rate 4.000000%
# At minibatch 4000, batch loss 0.162029, batch error rate 7.000000%
# After epoch 8: valid_err_rate: 0.040200% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.198351, batch error rate 3.000000%
# At minibatch 4200, batch loss 0.092164, batch error rate 2.000000%
# At minibatch 4300, batch loss 0.036419, batch error rate 0.000000%
# At minibatch 4400, batch loss 0.075254, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.142259, batch error rate 4.000000%
# After epoch 9: valid_err_rate: 0.038400% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.078273, batch error rate 2.000000%
# At minibatch 4700, batch loss 0.223099, batch error rate 7.000000%
# At minibatch 4800, batch loss 0.103328, batch error rate 3.000000%
# At minibatch 4900, batch loss 0.060306, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.105253, batch error rate 3.000000%
# After epoch 10: valid_err_rate: 0.038700% currently going ot do 14 epochs
# At minibatch 5100, batch loss 0.088090, batch error rate 3.000000%
# At minibatch 5200, batch loss 0.064518, batch error rate 0.000000%
# At minibatch 5300, batch loss 0.087321, batch error rate 3.000000%
# At minibatch 5400, batch loss 0.169163, batch error rate 3.000000%
# At minibatch 5500, batch loss 0.109009, batch error rate 2.000000%
# After epoch 11: valid_err_rate: 0.036100% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.080240, batch error rate 3.000000%
# At minibatch 5700, batch loss 0.162855, batch error rate 5.000000%
# At minibatch 5800, batch loss 0.104783, batch error rate 3.000000%
# At minibatch 5900, batch loss 0.191707, batch error rate 6.000000%
# At minibatch 6000, batch loss 0.062004, batch error rate 3.000000%
# After epoch 12: valid_err_rate: 0.035400% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.099185, batch error rate 3.000000%
# At minibatch 6200, batch loss 0.104473, batch error rate 2.000000%
# At minibatch 6300, batch loss 0.106471, batch error rate 3.000000%
# At minibatch 6400, batch loss 0.087809, batch error rate 2.000000%
# At minibatch 6500, batch loss 0.059760, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.034700% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.086767, batch error rate 2.000000%
# At minibatch 6700, batch loss 0.134092, batch error rate 5.000000%
# At minibatch 6800, batch loss 0.116238, batch error rate 4.000000%
# At minibatch 6900, batch loss 0.060674, batch error rate 2.000000%
# At minibatch 7000, batch loss 0.077383, batch error rate 3.000000%
# After epoch 14: valid_err_rate: 0.032500% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.105808, batch error rate 3.000000%
# At minibatch 7200, batch loss 0.046689, batch error rate 2.000000%
# At minibatch 7300, batch loss 0.122902, batch error rate 3.000000%
# At minibatch 7400, batch loss 0.198454, batch error rate 9.000000%
# At minibatch 7500, batch loss 0.061651, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.032500% currently going ot do 22 epochs
# At minibatch 7600, batch loss 0.025351, batch error rate 0.000000%
# At minibatch 7700, batch loss 0.036417, batch error rate 0.000000%
# At minibatch 7800, batch loss 0.096941, batch error rate 3.000000%
# At minibatch 7900, batch loss 0.071174, batch error rate 2.000000%
# At minibatch 8000, batch loss 0.102603, batch error rate 3.000000%
# After epoch 16: valid_err_rate: 0.032400% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.072983, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.034855, batch error rate 1.000000%
# At minibatch 8300, batch loss 0.083857, batch error rate 1.000000%
# At minibatch 8400, batch loss 0.098433, batch error rate 2.000000%
# At minibatch 8500, batch loss 0.059041, batch error rate 2.000000%
# After epoch 17: valid_err_rate: 0.030900% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.067182, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.115903, batch error rate 3.000000%
# At minibatch 8800, batch loss 0.071403, batch error rate 2.000000%
# At minibatch 8900, batch loss 0.064053, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.074103, batch error rate 2.000000%
# After epoch 18: valid_err_rate: 0.030900% currently going ot do 26 epochs
# At minibatch 9100, batch loss 0.050522, batch error rate 2.000000%
# At minibatch 9200, batch loss 0.037767, batch error rate 0.000000%
# At minibatch 9300, batch loss 0.092317, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.046717, batch error rate 2.000000%
# At minibatch 9500, batch loss 0.095606, batch error rate 3.000000%
# After epoch 19: valid_err_rate: 0.030300% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.029561, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.050208, batch error rate 2.000000%
# At minibatch 9800, batch loss 0.064461, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.072316, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.066040, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.030400% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.082061, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.061916, batch error rate 1.000000%
# At minibatch 10300, batch loss 0.057740, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.040788, batch error rate 1.000000%
# At minibatch 10500, batch loss 0.040441, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.031100% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.068076, batch error rate 2.000000%
# At minibatch 10700, batch loss 0.109104, batch error rate 2.000000%
# At minibatch 10800, batch loss 0.040087, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.099545, batch error rate 3.000000%
# At minibatch 11000, batch loss 0.070516, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.029000% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.092683, batch error rate 4.000000%
# At minibatch 11200, batch loss 0.046825, batch error rate 0.000000%
# At minibatch 11300, batch loss 0.062557, batch error rate 3.000000%
# At minibatch 11400, batch loss 0.055171, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.124840, batch error rate 4.000000%
# After epoch 23: valid_err_rate: 0.029600% currently going ot do 34 epochs
# At minibatch 11600, batch loss 0.047067, batch error rate 1.000000%
# At minibatch 11700, batch loss 0.030119, batch error rate 1.000000%
# At minibatch 11800, batch loss 0.073069, batch error rate 3.000000%
# At minibatch 11900, batch loss 0.121383, batch error rate 3.000000%
# At minibatch 12000, batch loss 0.043412, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.029200% currently going ot do 34 epochs
# At minibatch 12100, batch loss 0.124646, batch error rate 2.000000%
# At minibatch 12200, batch loss 0.087106, batch error rate 3.000000%
# At minibatch 12300, batch loss 0.024091, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.039019, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.075548, batch error rate 4.000000%
# After epoch 25: valid_err_rate: 0.027800% currently going ot do 38 epochs
# At minibatch 12600, batch loss 0.043845, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.046832, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.077912, batch error rate 2.000000%
# At minibatch 12900, batch loss 0.042969, batch error rate 1.000000%
# At minibatch 13000, batch loss 0.082379, batch error rate 1.000000%
# After epoch 26: valid_err_rate: 0.029100% currently going ot do 38 epochs
# At minibatch 13100, batch loss 0.043492, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.063180, batch error rate 3.000000%
# At minibatch 13300, batch loss 0.029884, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.040301, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.059841, batch error rate 2.000000%
# After epoch 27: valid_err_rate: 0.027600% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.053835, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.033359, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.013789, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.067267, batch error rate 2.000000%
# At minibatch 14000, batch loss 0.068919, batch error rate 3.000000%
# After epoch 28: valid_err_rate: 0.027600% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.032800, batch error rate 1.000000%
# At minibatch 14200, batch loss 0.031963, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.035804, batch error rate 1.000000%
# At minibatch 14400, batch loss 0.037526, batch error rate 1.000000%
# At minibatch 14500, batch loss 0.038841, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.027700% currently going ot do 41 epochs
# At minibatch 14600, batch loss 0.052211, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.048734, batch error rate 2.000000%
# At minibatch 14800, batch loss 0.029966, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.035253, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.027243, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.027600% currently going ot do 41 epochs
# At minibatch 15100, batch loss 0.049401, batch error rate 2.000000%
# At minibatch 15200, batch loss 0.063745, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.040335, batch error rate 1.000000%
# At minibatch 15400, batch loss 0.028617, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.014576, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.026900% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.058261, batch error rate 3.000000%
# At minibatch 15700, batch loss 0.044055, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.042432, batch error rate 1.000000%
# At minibatch 15900, batch loss 0.018686, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.016476, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.026800% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.027459, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.039244, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.021005, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.050174, batch error rate 1.000000%
# At minibatch 16500, batch loss 0.077810, batch error rate 3.000000%
# After epoch 33: valid_err_rate: 0.026000% currently going ot do 50 epochs
# At minibatch 16600, batch loss 0.046855, batch error rate 1.000000%
# At minibatch 16700, batch loss 0.024681, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.016619, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.023230, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.026458, batch error rate 1.000000%
# After epoch 34: valid_err_rate: 0.026700% currently going ot do 50 epochs
# At minibatch 17100, batch loss 0.028599, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.018471, batch error rate 1.000000%
# At minibatch 17300, batch loss 0.062068, batch error rate 1.000000%
# At minibatch 17400, batch loss 0.016158, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.062400, batch error rate 2.000000%
# After epoch 35: valid_err_rate: 0.026200% currently going ot do 50 epochs
# At minibatch 17600, batch loss 0.039269, batch error rate 2.000000%
# At minibatch 17700, batch loss 0.037430, batch error rate 1.000000%
# At minibatch 17800, batch loss 0.028883, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.031380, batch error rate 1.000000%
# At minibatch 18000, batch loss 0.034236, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.026400% currently going ot do 50 epochs
# At minibatch 18100, batch loss 0.027884, batch error rate 1.000000%
# At minibatch 18200, batch loss 0.024294, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.035111, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.036924, batch error rate 1.000000%
# At minibatch 18500, batch loss 0.011865, batch error rate 0.000000%
# After epoch 37: valid_err_rate: 0.025900% currently going ot do 56 epochs
# At minibatch 18600, batch loss 0.020387, batch error rate 1.000000%
# At minibatch 18700, batch loss 0.039541, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.029490, batch error rate 1.000000%
# At minibatch 18900, batch loss 0.067238, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.035620, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.027600% currently going ot do 56 epochs
# At minibatch 19100, batch loss 0.034585, batch error rate 1.000000%
# At minibatch 19200, batch loss 0.026091, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.027279, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.027297, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.038831, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.026700% currently going ot do 56 epochs
# At minibatch 19600, batch loss 0.016295, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.017826, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.021678, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.021651, batch error rate 1.000000%
# At minibatch 20000, batch loss 0.022303, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.026500% currently going ot do 56 epochs
# At minibatch 20100, batch loss 0.031537, batch error rate 1.000000%
# At minibatch 20200, batch loss 0.023349, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.037453, batch error rate 1.000000%
# At minibatch 20400, batch loss 0.065311, batch error rate 2.000000%
# At minibatch 20500, batch loss 0.032881, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.026000% currently going ot do 56 epochs
# At minibatch 20600, batch loss 0.033931, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.025666, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.058008, batch error rate 2.000000%
# At minibatch 20900, batch loss 0.040799, batch error rate 2.000000%
# At minibatch 21000, batch loss 0.020240, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.026200% currently going ot do 56 epochs
# At minibatch 21100, batch loss 0.014739, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.027208, batch error rate 1.000000%
# At minibatch 21300, batch loss 0.020700, batch error rate 1.000000%
# At minibatch 21400, batch loss 0.019720, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.031364, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.026400% currently going ot do 56 epochs
# At minibatch 21600, batch loss 0.018354, batch error rate 1.000000%
# At minibatch 21700, batch loss 0.023303, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.030899, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.013827, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.018585, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.026300% currently going ot do 56 epochs
# At minibatch 22100, batch loss 0.025274, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.034750, batch error rate 2.000000%
# At minibatch 22300, batch loss 0.020518, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.007044, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.008041, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.026600% currently going ot do 56 epochs
# At minibatch 22600, batch loss 0.043107, batch error rate 2.000000%
# At minibatch 22700, batch loss 0.013474, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.020227, batch error rate 1.000000%
# At minibatch 22900, batch loss 0.030628, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.036141, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.024900% currently going ot do 70 epochs
# At minibatch 23100, batch loss 0.009371, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.006661, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.020072, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.047214, batch error rate 1.000000%
# At minibatch 23500, batch loss 0.023100, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.025900% currently going ot do 70 epochs
# At minibatch 23600, batch loss 0.020989, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.035871, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.022268, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.028298, batch error rate 1.000000%
# At minibatch 24000, batch loss 0.021110, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.025700% currently going ot do 70 epochs
# At minibatch 24100, batch loss 0.035781, batch error rate 1.000000%
# At minibatch 24200, batch loss 0.015887, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.029381, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.026992, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.027049, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.025300% currently going ot do 70 epochs
# At minibatch 24600, batch loss 0.013545, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.019078, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.018338, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.010953, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.026412, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.026000% currently going ot do 70 epochs
# At minibatch 25100, batch loss 0.005469, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.052098, batch error rate 2.000000%
# At minibatch 25300, batch loss 0.017819, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.008624, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.024567, batch error rate 1.000000%
# After epoch 51: valid_err_rate: 0.025800% currently going ot do 70 epochs
# At minibatch 25600, batch loss 0.043812, batch error rate 1.000000%
# At minibatch 25700, batch loss 0.017830, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.016681, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.019052, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.046562, batch error rate 1.000000%
# After epoch 52: valid_err_rate: 0.025600% currently going ot do 70 epochs
# At minibatch 26100, batch loss 0.011576, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.010019, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.014637, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.018782, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.012485, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.026100% currently going ot do 70 epochs
# At minibatch 26600, batch loss 0.016955, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.017599, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.014106, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.016164, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.016427, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.025500% currently going ot do 70 epochs
# At minibatch 27100, batch loss 0.022588, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.023068, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.045569, batch error rate 2.000000%
# At minibatch 27400, batch loss 0.014982, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.011795, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.026800% currently going ot do 70 epochs
# At minibatch 27600, batch loss 0.020986, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.029224, batch error rate 1.000000%
# At minibatch 27800, batch loss 0.014152, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.034425, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.019079, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.025300% currently going ot do 70 epochs
# At minibatch 28100, batch loss 0.017907, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.010803, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.018381, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.062691, batch error rate 2.000000%
# At minibatch 28500, batch loss 0.022953, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.025400% currently going ot do 70 epochs
# At minibatch 28600, batch loss 0.027474, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.022261, batch error rate 1.000000%
# At minibatch 28800, batch loss 0.035813, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.010861, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.008815, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.026100% currently going ot do 70 epochs
# At minibatch 29100, batch loss 0.016974, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.007030, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.019200, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.029651, batch error rate 1.000000%
# At minibatch 29500, batch loss 0.009659, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.026000% currently going ot do 70 epochs
# At minibatch 29600, batch loss 0.018878, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.006407, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.015698, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.023556, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.015241, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.026200% currently going ot do 70 epochs
# At minibatch 30100, batch loss 0.029495, batch error rate 1.000000%
# At minibatch 30200, batch loss 0.025693, batch error rate 1.000000%
# At minibatch 30300, batch loss 0.062696, batch error rate 1.000000%
# At minibatch 30400, batch loss 0.014513, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.028378, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.025000% currently going ot do 70 epochs
# At minibatch 30600, batch loss 0.017085, batch error rate 1.000000%
# At minibatch 30700, batch loss 0.010805, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.016117, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.044932, batch error rate 1.000000%
# At minibatch 31000, batch loss 0.022213, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.026100% currently going ot do 70 epochs
# At minibatch 31100, batch loss 0.010667, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.027145, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.015936, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.011033, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.016179, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.025600% currently going ot do 70 epochs
# At minibatch 31600, batch loss 0.013418, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.015863, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.021162, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.013711, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.018162, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.025600% currently going ot do 70 epochs
# At minibatch 32100, batch loss 0.011234, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.024780, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.021766, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.019514, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.013692, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.026300% currently going ot do 70 epochs
# At minibatch 32600, batch loss 0.024408, batch error rate 1.000000%
# At minibatch 32700, batch loss 0.016318, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.044326, batch error rate 2.000000%
# At minibatch 32900, batch loss 0.016491, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.019591, batch error rate 1.000000%
# After epoch 66: valid_err_rate: 0.026000% currently going ot do 70 epochs
# At minibatch 33100, batch loss 0.022476, batch error rate 1.000000%
# At minibatch 33200, batch loss 0.010398, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.028375, batch error rate 1.000000%
# At minibatch 33400, batch loss 0.009832, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.009028, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.026300% currently going ot do 70 epochs
# At minibatch 33600, batch loss 0.007178, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.015376, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.013914, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.023139, batch error rate 1.000000%
# At minibatch 34000, batch loss 0.021244, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.025800% currently going ot do 70 epochs
# At minibatch 34100, batch loss 0.014457, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.015597, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.002679, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.011796, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.009611, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.025900% currently going ot do 70 epochs
# At minibatch 34600, batch loss 0.021326, batch error rate 1.000000%
# At minibatch 34700, batch loss 0.004521, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.020417, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.014555, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.009556, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.026100% currently going ot do 70 epochs
# Finished with 70 epochs (minibatch 35000), with best valid error rate 0.024900

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0243

# %%
weight_init = IsotropicGaussian(std=0.1, mean=0.0)
net = FeedForwardNet([
        AffineLayer(784, 200, weight_init = weight_init),
        TanhLayer(),
        AffineLayer(200, 10, weight_init = weight_init),
        SoftMaxLayer()
    ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
    print_debug = True,
    epochs = 3,
    regularization_alg = RegularizationAlgNone(),
    alpha_alg = AlphaAlgExp(initial = 5e-2, rate = 0.992),
    momentum_alg = MomentumAlg1())
# Out:
# 78578
# 0
# 78222
# 1020
# 0
# 980
# Network configuration:
# W(200, 784), b(200, 1), W(10, 200), b(10, 1)
# At minibatch 100, batch loss 0.624512, batch error rate 11.000000%
# At minibatch 200, batch loss 0.415893, batch error rate 14.000000%
# At minibatch 300, batch loss 0.444824, batch error rate 13.000000%
# At minibatch 400, batch loss 0.329773, batch error rate 10.000000%
# At minibatch 500, batch loss 0.381223, batch error rate 13.000000%
# After epoch 1: valid_err_rate: 0.086900% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.362454, batch error rate 13.000000%
# At minibatch 700, batch loss 0.396225, batch error rate 11.000000%
# At minibatch 800, batch loss 0.182976, batch error rate 5.000000%
# At minibatch 900, batch loss 0.209926, batch error rate 5.000000%
# At minibatch 1000, batch loss 0.319551, batch error rate 6.000000%
# After epoch 2: valid_err_rate: 0.067000% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.305599, batch error rate 6.000000%
# At minibatch 1200, batch loss 0.159670, batch error rate 5.000000%
# At minibatch 1300, batch loss 0.270019, batch error rate 11.000000%
# At minibatch 1400, batch loss 0.219743, batch error rate 9.000000%
# At minibatch 1500, batch loss 0.188742, batch error rate 7.000000%
# After epoch 3: valid_err_rate: 0.059200% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.287971, batch error rate 9.000000%
# At minibatch 1700, batch loss 0.266651, batch error rate 7.000000%
# At minibatch 1800, batch loss 0.224773, batch error rate 9.000000%
# At minibatch 1900, batch loss 0.221498, batch error rate 8.000000%
# At minibatch 2000, batch loss 0.288149, batch error rate 11.000000%
# After epoch 4: valid_err_rate: 0.056400% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.178101, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.162845, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.301307, batch error rate 7.000000%
# At minibatch 2400, batch loss 0.214685, batch error rate 5.000000%
# At minibatch 2500, batch loss 0.203346, batch error rate 6.000000%
# After epoch 5: valid_err_rate: 0.049100% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.199072, batch error rate 5.000000%
# At minibatch 2700, batch loss 0.072683, batch error rate 1.000000%
# At minibatch 2800, batch loss 0.106071, batch error rate 2.000000%
# At minibatch 2900, batch loss 0.147813, batch error rate 3.000000%
# At minibatch 3000, batch loss 0.163973, batch error rate 5.000000%
# After epoch 6: valid_err_rate: 0.046400% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.154192, batch error rate 7.000000%
# At minibatch 3200, batch loss 0.100950, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.153150, batch error rate 6.000000%
# At minibatch 3400, batch loss 0.108380, batch error rate 3.000000%
# At minibatch 3500, batch loss 0.087607, batch error rate 3.000000%
# After epoch 7: valid_err_rate: 0.043300% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.070017, batch error rate 2.000000%
# At minibatch 3700, batch loss 0.109675, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.220395, batch error rate 8.000000%
# At minibatch 3900, batch loss 0.108730, batch error rate 3.000000%
# At minibatch 4000, batch loss 0.177217, batch error rate 6.000000%
# After epoch 8: valid_err_rate: 0.043400% currently going ot do 11 epochs
# At minibatch 4100, batch loss 0.173623, batch error rate 5.000000%
# At minibatch 4200, batch loss 0.105299, batch error rate 4.000000%
# At minibatch 4300, batch loss 0.101904, batch error rate 5.000000%
# At minibatch 4400, batch loss 0.073099, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.142489, batch error rate 3.000000%
# After epoch 9: valid_err_rate: 0.040500% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.099302, batch error rate 2.000000%
# At minibatch 4700, batch loss 0.077441, batch error rate 2.000000%
# At minibatch 4800, batch loss 0.266359, batch error rate 7.000000%
# At minibatch 4900, batch loss 0.088954, batch error rate 3.000000%
# At minibatch 5000, batch loss 0.081346, batch error rate 4.000000%
# After epoch 10: valid_err_rate: 0.040400% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.090342, batch error rate 2.000000%
# At minibatch 5200, batch loss 0.072461, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.112338, batch error rate 3.000000%
# At minibatch 5400, batch loss 0.075258, batch error rate 2.000000%
# At minibatch 5500, batch loss 0.147393, batch error rate 7.000000%
# After epoch 11: valid_err_rate: 0.039000% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.087851, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.130904, batch error rate 6.000000%
# At minibatch 5800, batch loss 0.133979, batch error rate 4.000000%
# At minibatch 5900, batch loss 0.037109, batch error rate 0.000000%
# At minibatch 6000, batch loss 0.118814, batch error rate 3.000000%
# After epoch 12: valid_err_rate: 0.036600% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.103934, batch error rate 5.000000%
# At minibatch 6200, batch loss 0.105396, batch error rate 3.000000%
# At minibatch 6300, batch loss 0.121497, batch error rate 5.000000%
# At minibatch 6400, batch loss 0.146288, batch error rate 5.000000%
# At minibatch 6500, batch loss 0.055035, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.037500% currently going ot do 19 epochs
# At minibatch 6600, batch loss 0.091343, batch error rate 2.000000%
# At minibatch 6700, batch loss 0.088274, batch error rate 3.000000%
# At minibatch 6800, batch loss 0.163096, batch error rate 6.000000%
# At minibatch 6900, batch loss 0.074998, batch error rate 3.000000%
# At minibatch 7000, batch loss 0.155512, batch error rate 4.000000%
# After epoch 14: valid_err_rate: 0.034000% currently going ot do 22 epochs
# At minibatch 7100, batch loss 0.072504, batch error rate 3.000000%
# At minibatch 7200, batch loss 0.096739, batch error rate 3.000000%
# At minibatch 7300, batch loss 0.053372, batch error rate 0.000000%
# At minibatch 7400, batch loss 0.059947, batch error rate 2.000000%
# At minibatch 7500, batch loss 0.066914, batch error rate 3.000000%
# After epoch 15: valid_err_rate: 0.034100% currently going ot do 22 epochs
# At minibatch 7600, batch loss 0.067624, batch error rate 2.000000%
# At minibatch 7700, batch loss 0.064278, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.112680, batch error rate 3.000000%
# At minibatch 7900, batch loss 0.097672, batch error rate 1.000000%
# At minibatch 8000, batch loss 0.026948, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.033400% currently going ot do 25 epochs
# At minibatch 8100, batch loss 0.040848, batch error rate 1.000000%
# At minibatch 8200, batch loss 0.138381, batch error rate 4.000000%
# At minibatch 8300, batch loss 0.151288, batch error rate 5.000000%
# At minibatch 8400, batch loss 0.139268, batch error rate 5.000000%
# At minibatch 8500, batch loss 0.070376, batch error rate 4.000000%
# After epoch 17: valid_err_rate: 0.031800% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.044643, batch error rate 1.000000%
# At minibatch 8700, batch loss 0.097757, batch error rate 4.000000%
# At minibatch 8800, batch loss 0.041537, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.049110, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.042081, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.032200% currently going ot do 26 epochs
# At minibatch 9100, batch loss 0.038112, batch error rate 1.000000%
# At minibatch 9200, batch loss 0.123515, batch error rate 3.000000%
# At minibatch 9300, batch loss 0.088849, batch error rate 3.000000%
# At minibatch 9400, batch loss 0.054632, batch error rate 1.000000%
# At minibatch 9500, batch loss 0.072725, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.031100% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.029351, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.174674, batch error rate 6.000000%
# At minibatch 9800, batch loss 0.060188, batch error rate 2.000000%
# At minibatch 9900, batch loss 0.089396, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.044121, batch error rate 1.000000%
# After epoch 20: valid_err_rate: 0.030800% currently going ot do 31 epochs
# At minibatch 10100, batch loss 0.048911, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.070966, batch error rate 2.000000%
# At minibatch 10300, batch loss 0.077894, batch error rate 3.000000%
# At minibatch 10400, batch loss 0.056552, batch error rate 3.000000%
# At minibatch 10500, batch loss 0.063468, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.030600% currently going ot do 32 epochs
# At minibatch 10600, batch loss 0.086326, batch error rate 1.000000%
# At minibatch 10700, batch loss 0.022115, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.059937, batch error rate 1.000000%
# At minibatch 10900, batch loss 0.061725, batch error rate 2.000000%
# At minibatch 11000, batch loss 0.062178, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.030400% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.037623, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.082117, batch error rate 3.000000%
# At minibatch 11300, batch loss 0.067252, batch error rate 2.000000%
# At minibatch 11400, batch loss 0.035794, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.054552, batch error rate 1.000000%
# After epoch 23: valid_err_rate: 0.031600% currently going ot do 34 epochs
# At minibatch 11600, batch loss 0.131799, batch error rate 4.000000%
# At minibatch 11700, batch loss 0.035581, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.031916, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.081034, batch error rate 3.000000%
# At minibatch 12000, batch loss 0.060405, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.029500% currently going ot do 37 epochs
# At minibatch 12100, batch loss 0.063212, batch error rate 2.000000%
# At minibatch 12200, batch loss 0.044561, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.039539, batch error rate 1.000000%
# At minibatch 12400, batch loss 0.035650, batch error rate 1.000000%
# At minibatch 12500, batch loss 0.035149, batch error rate 2.000000%
# After epoch 25: valid_err_rate: 0.030000% currently going ot do 37 epochs
# At minibatch 12600, batch loss 0.086965, batch error rate 2.000000%
# At minibatch 12700, batch loss 0.060192, batch error rate 2.000000%
# At minibatch 12800, batch loss 0.054511, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.030694, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.054269, batch error rate 2.000000%
# After epoch 26: valid_err_rate: 0.028100% currently going ot do 40 epochs
# At minibatch 13100, batch loss 0.041616, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.032979, batch error rate 1.000000%
# At minibatch 13300, batch loss 0.039962, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.047533, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.046193, batch error rate 1.000000%
# After epoch 27: valid_err_rate: 0.028300% currently going ot do 40 epochs
# At minibatch 13600, batch loss 0.051022, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.039765, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.012262, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.042997, batch error rate 2.000000%
# At minibatch 14000, batch loss 0.036086, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.028400% currently going ot do 40 epochs
# At minibatch 14100, batch loss 0.029588, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.050508, batch error rate 1.000000%
# At minibatch 14300, batch loss 0.031791, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.038374, batch error rate 1.000000%
# At minibatch 14500, batch loss 0.077627, batch error rate 2.000000%
# After epoch 29: valid_err_rate: 0.028000% currently going ot do 44 epochs
# At minibatch 14600, batch loss 0.082849, batch error rate 3.000000%
# At minibatch 14700, batch loss 0.043838, batch error rate 0.000000%
# At minibatch 14800, batch loss 0.032020, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.080679, batch error rate 3.000000%
# At minibatch 15000, batch loss 0.071094, batch error rate 2.000000%
# After epoch 30: valid_err_rate: 0.027800% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.049488, batch error rate 2.000000%
# At minibatch 15200, batch loss 0.016481, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.175132, batch error rate 4.000000%
# At minibatch 15400, batch loss 0.041074, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.067819, batch error rate 4.000000%
# After epoch 31: valid_err_rate: 0.029400% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.017050, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.037004, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.027366, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.039722, batch error rate 1.000000%
# At minibatch 16000, batch loss 0.040178, batch error rate 1.000000%
# After epoch 32: valid_err_rate: 0.028400% currently going ot do 46 epochs
# At minibatch 16100, batch loss 0.029330, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.058573, batch error rate 3.000000%
# At minibatch 16300, batch loss 0.031541, batch error rate 2.000000%
# At minibatch 16400, batch loss 0.026851, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.049855, batch error rate 2.000000%
# After epoch 33: valid_err_rate: 0.028000% currently going ot do 46 epochs
# At minibatch 16600, batch loss 0.046059, batch error rate 1.000000%
# At minibatch 16700, batch loss 0.071336, batch error rate 3.000000%
# At minibatch 16800, batch loss 0.022287, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.031197, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.028790, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.027300% currently going ot do 52 epochs
# At minibatch 17100, batch loss 0.031550, batch error rate 1.000000%
# At minibatch 17200, batch loss 0.054897, batch error rate 2.000000%
# At minibatch 17300, batch loss 0.033296, batch error rate 1.000000%
# At minibatch 17400, batch loss 0.019550, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.028226, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.027600% currently going ot do 52 epochs
# At minibatch 17600, batch loss 0.022493, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.014607, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.034119, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.057340, batch error rate 3.000000%
# At minibatch 18000, batch loss 0.077019, batch error rate 3.000000%
# After epoch 36: valid_err_rate: 0.027600% currently going ot do 52 epochs
# At minibatch 18100, batch loss 0.010235, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.035245, batch error rate 2.000000%
# At minibatch 18300, batch loss 0.026568, batch error rate 1.000000%
# At minibatch 18400, batch loss 0.029685, batch error rate 1.000000%
# At minibatch 18500, batch loss 0.030252, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.027600% currently going ot do 52 epochs
# At minibatch 18600, batch loss 0.010871, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.054031, batch error rate 1.000000%
# At minibatch 18800, batch loss 0.021869, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.036982, batch error rate 2.000000%
# At minibatch 19000, batch loss 0.035181, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.026200% currently going ot do 58 epochs
# At minibatch 19100, batch loss 0.049557, batch error rate 1.000000%
# At minibatch 19200, batch loss 0.070660, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.027362, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.020227, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.023287, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.027600% currently going ot do 58 epochs
# At minibatch 19600, batch loss 0.016124, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.016773, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.023929, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.069530, batch error rate 3.000000%
# At minibatch 20000, batch loss 0.050928, batch error rate 1.000000%
# After epoch 40: valid_err_rate: 0.027100% currently going ot do 58 epochs
# At minibatch 20100, batch loss 0.025227, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.051009, batch error rate 2.000000%
# At minibatch 20300, batch loss 0.036263, batch error rate 1.000000%
# At minibatch 20400, batch loss 0.010756, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.017694, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.027800% currently going ot do 58 epochs
# At minibatch 20600, batch loss 0.037508, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.054184, batch error rate 3.000000%
# At minibatch 20800, batch loss 0.030227, batch error rate 1.000000%
# At minibatch 20900, batch loss 0.023030, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.026286, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.028000% currently going ot do 58 epochs
# At minibatch 21100, batch loss 0.028018, batch error rate 1.000000%
# At minibatch 21200, batch loss 0.046938, batch error rate 1.000000%
# At minibatch 21300, batch loss 0.027628, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.035683, batch error rate 1.000000%
# At minibatch 21500, batch loss 0.042250, batch error rate 1.000000%
# After epoch 43: valid_err_rate: 0.026500% currently going ot do 58 epochs
# At minibatch 21600, batch loss 0.044957, batch error rate 1.000000%
# At minibatch 21700, batch loss 0.068787, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.031994, batch error rate 1.000000%
# At minibatch 21900, batch loss 0.009244, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.044189, batch error rate 1.000000%
# After epoch 44: valid_err_rate: 0.027800% currently going ot do 58 epochs
# At minibatch 22100, batch loss 0.026962, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.022178, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.021846, batch error rate 1.000000%
# At minibatch 22400, batch loss 0.016737, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.017079, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.026500% currently going ot do 58 epochs
# At minibatch 22600, batch loss 0.022509, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.056247, batch error rate 2.000000%
# At minibatch 22800, batch loss 0.038203, batch error rate 1.000000%
# At minibatch 22900, batch loss 0.024865, batch error rate 1.000000%
# At minibatch 23000, batch loss 0.033458, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.026800% currently going ot do 58 epochs
# At minibatch 23100, batch loss 0.058533, batch error rate 1.000000%
# At minibatch 23200, batch loss 0.013217, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.007450, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.017041, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.046130, batch error rate 2.000000%
# After epoch 47: valid_err_rate: 0.026600% currently going ot do 58 epochs
# At minibatch 23600, batch loss 0.017904, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.030132, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.016093, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.019960, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.026411, batch error rate 1.000000%
# After epoch 48: valid_err_rate: 0.026800% currently going ot do 58 epochs
# At minibatch 24100, batch loss 0.014931, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.067343, batch error rate 2.000000%
# At minibatch 24300, batch loss 0.023366, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.012890, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.023535, batch error rate 1.000000%
# After epoch 49: valid_err_rate: 0.026300% currently going ot do 58 epochs
# At minibatch 24600, batch loss 0.012337, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.082292, batch error rate 1.000000%
# At minibatch 24800, batch loss 0.012006, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.014142, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.024367, batch error rate 1.000000%
# After epoch 50: valid_err_rate: 0.026700% currently going ot do 58 epochs
# At minibatch 25100, batch loss 0.027661, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.021565, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.019328, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.014647, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.032735, batch error rate 1.000000%
# After epoch 51: valid_err_rate: 0.026300% currently going ot do 58 epochs
# At minibatch 25600, batch loss 0.015319, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.013820, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.022156, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.012439, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.021267, batch error rate 1.000000%
# After epoch 52: valid_err_rate: 0.026000% currently going ot do 79 epochs
# At minibatch 26100, batch loss 0.012942, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.033756, batch error rate 1.000000%
# At minibatch 26300, batch loss 0.016359, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.024710, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.020517, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.025400% currently going ot do 80 epochs
# At minibatch 26600, batch loss 0.010159, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.010037, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.017653, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.017797, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.013513, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.026000% currently going ot do 80 epochs
# At minibatch 27100, batch loss 0.027199, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.026245, batch error rate 1.000000%
# At minibatch 27300, batch loss 0.015406, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.009406, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.027301, batch error rate 1.000000%
# After epoch 55: valid_err_rate: 0.026000% currently going ot do 80 epochs
# At minibatch 27600, batch loss 0.058972, batch error rate 2.000000%
# At minibatch 27700, batch loss 0.019402, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.013911, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.011391, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.036618, batch error rate 1.000000%
# After epoch 56: valid_err_rate: 0.025000% currently going ot do 85 epochs
# At minibatch 28100, batch loss 0.028945, batch error rate 1.000000%
# At minibatch 28200, batch loss 0.013291, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.014958, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.009405, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.021509, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.026000% currently going ot do 85 epochs
# At minibatch 28600, batch loss 0.023120, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.028692, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.023751, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.020274, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.028096, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.026500% currently going ot do 85 epochs
# At minibatch 29100, batch loss 0.020991, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.050168, batch error rate 1.000000%
# At minibatch 29300, batch loss 0.010232, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.012878, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.018558, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.025000% currently going ot do 85 epochs
# At minibatch 29600, batch loss 0.020757, batch error rate 1.000000%
# At minibatch 29700, batch loss 0.030738, batch error rate 1.000000%
# At minibatch 29800, batch loss 0.016053, batch error rate 1.000000%
# At minibatch 29900, batch loss 0.054739, batch error rate 1.000000%
# At minibatch 30000, batch loss 0.026613, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.026400% currently going ot do 85 epochs
# At minibatch 30100, batch loss 0.018539, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.014437, batch error rate 0.000000%
# At minibatch 30300, batch loss 0.012668, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.010229, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.016627, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.025300% currently going ot do 85 epochs
# At minibatch 30600, batch loss 0.014591, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.026637, batch error rate 1.000000%
# At minibatch 30800, batch loss 0.019960, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.017883, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.016523, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.025500% currently going ot do 85 epochs
# At minibatch 31100, batch loss 0.016757, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.026110, batch error rate 1.000000%
# At minibatch 31300, batch loss 0.020026, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.021912, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.012910, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.026300% currently going ot do 85 epochs
# At minibatch 31600, batch loss 0.024434, batch error rate 1.000000%
# At minibatch 31700, batch loss 0.011512, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.008756, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.010802, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.015953, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.025600% currently going ot do 85 epochs
# At minibatch 32100, batch loss 0.010859, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.013090, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.035451, batch error rate 1.000000%
# At minibatch 32400, batch loss 0.021997, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.007758, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.026400% currently going ot do 85 epochs
# At minibatch 32600, batch loss 0.012236, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.022972, batch error rate 1.000000%
# At minibatch 32800, batch loss 0.013920, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.010830, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.005540, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.025600% currently going ot do 85 epochs
# At minibatch 33100, batch loss 0.011481, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.004473, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.016290, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.019424, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.011020, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.024900% currently going ot do 101 epochs
# At minibatch 33600, batch loss 0.015864, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.010887, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.014254, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.005565, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.011233, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.025600% currently going ot do 101 epochs
# At minibatch 34100, batch loss 0.019121, batch error rate 1.000000%
# At minibatch 34200, batch loss 0.007513, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.016440, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.012375, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.018244, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.025200% currently going ot do 101 epochs
# At minibatch 34600, batch loss 0.021646, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.013833, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.017731, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.016900, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.011006, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.025700% currently going ot do 101 epochs
# At minibatch 35100, batch loss 0.015454, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.009669, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.013291, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.015620, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.009136, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.025700% currently going ot do 101 epochs
# At minibatch 35600, batch loss 0.017487, batch error rate 1.000000%
# At minibatch 35700, batch loss 0.012410, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.013700, batch error rate 1.000000%
# At minibatch 35900, batch loss 0.016575, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.018602, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.025800% currently going ot do 101 epochs
# At minibatch 36100, batch loss 0.011065, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.017204, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.013163, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.023691, batch error rate 1.000000%
# At minibatch 36500, batch loss 0.019495, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.025200% currently going ot do 101 epochs
# At minibatch 36600, batch loss 0.019800, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.017229, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.012193, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.007793, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.012926, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.025800% currently going ot do 101 epochs
# At minibatch 37100, batch loss 0.015891, batch error rate 1.000000%
# At minibatch 37200, batch loss 0.020059, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.023477, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.011140, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.023237, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.025100% currently going ot do 101 epochs
# At minibatch 37600, batch loss 0.010822, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.027966, batch error rate 1.000000%
# At minibatch 37800, batch loss 0.020263, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.007753, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.008148, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.024700% currently going ot do 115 epochs
# At minibatch 38100, batch loss 0.017161, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.020945, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.017077, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.008977, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.008383, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.025100% currently going ot do 115 epochs
# At minibatch 38600, batch loss 0.013706, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.008560, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.012369, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.018423, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.006379, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.025000% currently going ot do 115 epochs
# At minibatch 39100, batch loss 0.013073, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.007220, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.012708, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.014717, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.012568, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.025200% currently going ot do 115 epochs
# At minibatch 39600, batch loss 0.007213, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.010377, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.007182, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.021783, batch error rate 1.000000%
# At minibatch 40000, batch loss 0.014372, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.025800% currently going ot do 115 epochs
# At minibatch 40100, batch loss 0.005708, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.008121, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.009072, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.003972, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.014837, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.025500% currently going ot do 115 epochs
# At minibatch 40600, batch loss 0.010325, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.011435, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.025098, batch error rate 1.000000%
# At minibatch 40900, batch loss 0.010217, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.006448, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.025100% currently going ot do 115 epochs
# At minibatch 41100, batch loss 0.010372, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.017914, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.011261, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.028272, batch error rate 1.000000%
# At minibatch 41500, batch loss 0.016789, batch error rate 1.000000%
# After epoch 83: valid_err_rate: 0.025400% currently going ot do 115 epochs
# At minibatch 41600, batch loss 0.020680, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.011234, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.010612, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.007007, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.018146, batch error rate 1.000000%
# After epoch 84: valid_err_rate: 0.025500% currently going ot do 115 epochs
# At minibatch 42100, batch loss 0.006421, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.014893, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.012210, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.006975, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.017159, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.025100% currently going ot do 115 epochs
# At minibatch 42600, batch loss 0.005679, batch error rate 0.000000%
# At minibatch 42700, batch loss 0.008400, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.012655, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.007003, batch error rate 0.000000%
# At minibatch 43000, batch loss 0.014775, batch error rate 0.000000%
# After epoch 86: valid_err_rate: 0.025300% currently going ot do 115 epochs
# At minibatch 43100, batch loss 0.006334, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.015315, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.009074, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.006226, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.009017, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.025000% currently going ot do 115 epochs
# At minibatch 43600, batch loss 0.015991, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.003383, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.015566, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.016514, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.011638, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.025500% currently going ot do 115 epochs
# At minibatch 44100, batch loss 0.014124, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.012981, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.008288, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.014296, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.012921, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.025700% currently going ot do 115 epochs
# At minibatch 44600, batch loss 0.010250, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.005311, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.008648, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.005350, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.004436, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.024700% currently going ot do 115 epochs
# At minibatch 45100, batch loss 0.006433, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.004479, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.009480, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.006819, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.011100, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.024900% currently going ot do 115 epochs
# At minibatch 45600, batch loss 0.010100, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.009646, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.015233, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.006378, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.014087, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.024900% currently going ot do 115 epochs
# At minibatch 46100, batch loss 0.011503, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.004598, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.010452, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.007648, batch error rate 0.000000%
# At minibatch 46500, batch loss 0.028686, batch error rate 2.000000%
# After epoch 93: valid_err_rate: 0.024600% currently going ot do 140 epochs
# At minibatch 46600, batch loss 0.007557, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.006363, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.009002, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.021008, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.003253, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.024500% currently going ot do 142 epochs
# At minibatch 47100, batch loss 0.012495, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.010069, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.018417, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.005431, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.007051, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.024300% currently going ot do 143 epochs
# At minibatch 47600, batch loss 0.011473, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.007017, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.004400, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.017821, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.017774, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.024800% currently going ot do 143 epochs
# At minibatch 48100, batch loss 0.016232, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.005961, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.005067, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.011571, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.006466, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.025700% currently going ot do 143 epochs
# At minibatch 48600, batch loss 0.006330, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.005092, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.006511, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.022570, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.011586, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.025000% currently going ot do 143 epochs
# At minibatch 49100, batch loss 0.004280, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.021376, batch error rate 1.000000%
# At minibatch 49300, batch loss 0.013976, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.009420, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.013183, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.024800% currently going ot do 143 epochs
# At minibatch 49600, batch loss 0.008122, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.011581, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.013305, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.012316, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.006588, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.025000% currently going ot do 143 epochs
# At minibatch 50100, batch loss 0.013198, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.013264, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.012600, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.007596, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.013021, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.024900% currently going ot do 143 epochs
# At minibatch 50600, batch loss 0.005510, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.004120, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.006910, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.014417, batch error rate 1.000000%
# At minibatch 51000, batch loss 0.009749, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.025800% currently going ot do 143 epochs
# At minibatch 51100, batch loss 0.008476, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.006563, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.011102, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.009978, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.007828, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.025400% currently going ot do 143 epochs
# At minibatch 51600, batch loss 0.006913, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.008970, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.008211, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.007552, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.011224, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.024700% currently going ot do 143 epochs
# At minibatch 52100, batch loss 0.008979, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.004787, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.010637, batch error rate 0.000000%
# At minibatch 52400, batch loss 0.010482, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.012483, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.025000% currently going ot do 143 epochs
# At minibatch 52600, batch loss 0.007301, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.011866, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.008246, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.005577, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.008153, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.024600% currently going ot do 143 epochs
# At minibatch 53100, batch loss 0.005912, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.011206, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.028200, batch error rate 1.000000%
# At minibatch 53400, batch loss 0.010591, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.012223, batch error rate 0.000000%
# After epoch 107: valid_err_rate: 0.025100% currently going ot do 143 epochs
# At minibatch 53600, batch loss 0.005287, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.006733, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.009868, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.012481, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.005536, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.024700% currently going ot do 143 epochs
# At minibatch 54100, batch loss 0.005909, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.023763, batch error rate 1.000000%
# At minibatch 54300, batch loss 0.007288, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.006729, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.027182, batch error rate 1.000000%
# After epoch 109: valid_err_rate: 0.024900% currently going ot do 143 epochs
# At minibatch 54600, batch loss 0.005791, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.017241, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.007892, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.012251, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.004950, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.024300% currently going ot do 143 epochs
# At minibatch 55100, batch loss 0.005115, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.002586, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.009957, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.009273, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.007523, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.024000% currently going ot do 167 epochs
# At minibatch 55600, batch loss 0.007166, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.009231, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.010991, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.008643, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.009850, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.024800% currently going ot do 167 epochs
# At minibatch 56100, batch loss 0.003970, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.004941, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.011105, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.012046, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.004519, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.024900% currently going ot do 167 epochs
# At minibatch 56600, batch loss 0.006007, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.010367, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.016943, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.009790, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.008126, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 57100, batch loss 0.004022, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.008672, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.017342, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.005324, batch error rate 0.000000%
# At minibatch 57500, batch loss 0.004712, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.024800% currently going ot do 167 epochs
# At minibatch 57600, batch loss 0.010193, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.007283, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.004992, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.009500, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.010984, batch error rate 0.000000%
# ...
# After epoch 130: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 65100, batch loss 0.008854, batch error rate 0.000000%
# At minibatch 65200, batch loss 0.005887, batch error rate 0.000000%
# At minibatch 65300, batch loss 0.005042, batch error rate 0.000000%
# At minibatch 65400, batch loss 0.005529, batch error rate 0.000000%
# At minibatch 65500, batch loss 0.008745, batch error rate 0.000000%
# After epoch 131: valid_err_rate: 0.024700% currently going ot do 167 epochs
# At minibatch 65600, batch loss 0.009959, batch error rate 0.000000%
# At minibatch 65700, batch loss 0.010428, batch error rate 0.000000%
# At minibatch 65800, batch loss 0.008508, batch error rate 0.000000%
# At minibatch 65900, batch loss 0.006568, batch error rate 0.000000%
# At minibatch 66000, batch loss 0.007589, batch error rate 0.000000%
# After epoch 132: valid_err_rate: 0.024000% currently going ot do 167 epochs
# At minibatch 66100, batch loss 0.009149, batch error rate 0.000000%
# At minibatch 66200, batch loss 0.005589, batch error rate 0.000000%
# At minibatch 66300, batch loss 0.004873, batch error rate 0.000000%
# At minibatch 66400, batch loss 0.007425, batch error rate 0.000000%
# At minibatch 66500, batch loss 0.005355, batch error rate 0.000000%
# After epoch 133: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 66600, batch loss 0.003613, batch error rate 0.000000%
# At minibatch 66700, batch loss 0.007410, batch error rate 0.000000%
# At minibatch 66800, batch loss 0.012203, batch error rate 0.000000%
# At minibatch 66900, batch loss 0.004421, batch error rate 0.000000%
# At minibatch 67000, batch loss 0.004823, batch error rate 0.000000%
# After epoch 134: valid_err_rate: 0.024900% currently going ot do 167 epochs
# At minibatch 67100, batch loss 0.005303, batch error rate 0.000000%
# At minibatch 67200, batch loss 0.006005, batch error rate 0.000000%
# At minibatch 67300, batch loss 0.002959, batch error rate 0.000000%
# At minibatch 67400, batch loss 0.010410, batch error rate 0.000000%
# At minibatch 67500, batch loss 0.006238, batch error rate 0.000000%
# After epoch 135: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 67600, batch loss 0.007437, batch error rate 0.000000%
# At minibatch 67700, batch loss 0.007517, batch error rate 0.000000%
# At minibatch 67800, batch loss 0.017938, batch error rate 1.000000%
# At minibatch 67900, batch loss 0.004844, batch error rate 0.000000%
# At minibatch 68000, batch loss 0.001967, batch error rate 0.000000%
# After epoch 136: valid_err_rate: 0.024700% currently going ot do 167 epochs
# At minibatch 68100, batch loss 0.007239, batch error rate 0.000000%
# At minibatch 68200, batch loss 0.007999, batch error rate 0.000000%
# At minibatch 68300, batch loss 0.009495, batch error rate 0.000000%
# At minibatch 68400, batch loss 0.005934, batch error rate 0.000000%
# At minibatch 68500, batch loss 0.003655, batch error rate 0.000000%
# After epoch 137: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 68600, batch loss 0.010427, batch error rate 0.000000%
# At minibatch 68700, batch loss 0.003477, batch error rate 0.000000%
# At minibatch 68800, batch loss 0.004552, batch error rate 0.000000%
# At minibatch 68900, batch loss 0.004567, batch error rate 0.000000%
# At minibatch 69000, batch loss 0.004732, batch error rate 0.000000%
# After epoch 138: valid_err_rate: 0.024600% currently going ot do 167 epochs
# At minibatch 69100, batch loss 0.003210, batch error rate 0.000000%
# At minibatch 69200, batch loss 0.007171, batch error rate 0.000000%
# At minibatch 69300, batch loss 0.007986, batch error rate 0.000000%
# At minibatch 69400, batch loss 0.010369, batch error rate 0.000000%
# At minibatch 69500, batch loss 0.007839, batch error rate 0.000000%
# After epoch 139: valid_err_rate: 0.024600% currently going ot do 167 epochs
# At minibatch 69600, batch loss 0.006249, batch error rate 0.000000%
# At minibatch 69700, batch loss 0.006308, batch error rate 0.000000%
# At minibatch 69800, batch loss 0.010058, batch error rate 0.000000%
# At minibatch 69900, batch loss 0.008506, batch error rate 0.000000%
# At minibatch 70000, batch loss 0.007613, batch error rate 0.000000%
# After epoch 140: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 70100, batch loss 0.011909, batch error rate 0.000000%
# At minibatch 70200, batch loss 0.004275, batch error rate 0.000000%
# At minibatch 70300, batch loss 0.008352, batch error rate 0.000000%
# At minibatch 70400, batch loss 0.010433, batch error rate 0.000000%
# At minibatch 70500, batch loss 0.005503, batch error rate 0.000000%
# After epoch 141: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 70600, batch loss 0.005195, batch error rate 0.000000%
# At minibatch 70700, batch loss 0.006991, batch error rate 0.000000%
# At minibatch 70800, batch loss 0.006099, batch error rate 0.000000%
# At minibatch 70900, batch loss 0.006327, batch error rate 0.000000%
# At minibatch 71000, batch loss 0.007128, batch error rate 0.000000%
# After epoch 142: valid_err_rate: 0.024900% currently going ot do 167 epochs
# At minibatch 71100, batch loss 0.005310, batch error rate 0.000000%
# At minibatch 71200, batch loss 0.004090, batch error rate 0.000000%
# At minibatch 71300, batch loss 0.005651, batch error rate 0.000000%
# At minibatch 71400, batch loss 0.006202, batch error rate 0.000000%
# At minibatch 71500, batch loss 0.004733, batch error rate 0.000000%
# After epoch 143: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 71600, batch loss 0.004885, batch error rate 0.000000%
# At minibatch 71700, batch loss 0.006391, batch error rate 0.000000%
# At minibatch 71800, batch loss 0.010031, batch error rate 0.000000%
# At minibatch 71900, batch loss 0.008173, batch error rate 0.000000%
# At minibatch 72000, batch loss 0.003774, batch error rate 0.000000%
# After epoch 144: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 72100, batch loss 0.005396, batch error rate 0.000000%
# At minibatch 72200, batch loss 0.007862, batch error rate 0.000000%
# At minibatch 72300, batch loss 0.004100, batch error rate 0.000000%
# At minibatch 72400, batch loss 0.008220, batch error rate 0.000000%
# At minibatch 72500, batch loss 0.007281, batch error rate 0.000000%
# After epoch 145: valid_err_rate: 0.024600% currently going ot do 167 epochs
# At minibatch 72600, batch loss 0.005026, batch error rate 0.000000%
# At minibatch 72700, batch loss 0.010712, batch error rate 0.000000%
# At minibatch 72800, batch loss 0.005659, batch error rate 0.000000%
# At minibatch 72900, batch loss 0.009206, batch error rate 0.000000%
# At minibatch 73000, batch loss 0.005808, batch error rate 0.000000%
# After epoch 146: valid_err_rate: 0.024600% currently going ot do 167 epochs
# At minibatch 73100, batch loss 0.005980, batch error rate 0.000000%
# At minibatch 73200, batch loss 0.002697, batch error rate 0.000000%
# At minibatch 73300, batch loss 0.011629, batch error rate 0.000000%
# At minibatch 73400, batch loss 0.005725, batch error rate 0.000000%
# At minibatch 73500, batch loss 0.009353, batch error rate 0.000000%
# After epoch 147: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 73600, batch loss 0.008130, batch error rate 0.000000%
# At minibatch 73700, batch loss 0.008970, batch error rate 0.000000%
# At minibatch 73800, batch loss 0.005476, batch error rate 0.000000%
# At minibatch 73900, batch loss 0.006600, batch error rate 0.000000%
# At minibatch 74000, batch loss 0.006726, batch error rate 0.000000%
# After epoch 148: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 74100, batch loss 0.008771, batch error rate 0.000000%
# At minibatch 74200, batch loss 0.004631, batch error rate 0.000000%
# At minibatch 74300, batch loss 0.005441, batch error rate 0.000000%
# At minibatch 74400, batch loss 0.006987, batch error rate 0.000000%
# At minibatch 74500, batch loss 0.005428, batch error rate 0.000000%
# After epoch 149: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 74600, batch loss 0.010277, batch error rate 0.000000%
# At minibatch 74700, batch loss 0.003119, batch error rate 0.000000%
# At minibatch 74800, batch loss 0.010111, batch error rate 0.000000%
# At minibatch 74900, batch loss 0.006117, batch error rate 0.000000%
# At minibatch 75000, batch loss 0.015395, batch error rate 0.000000%
# After epoch 150: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 75100, batch loss 0.006648, batch error rate 0.000000%
# At minibatch 75200, batch loss 0.007371, batch error rate 0.000000%
# At minibatch 75300, batch loss 0.007001, batch error rate 0.000000%
# At minibatch 75400, batch loss 0.003418, batch error rate 0.000000%
# At minibatch 75500, batch loss 0.007510, batch error rate 0.000000%
# After epoch 151: valid_err_rate: 0.024600% currently going ot do 167 epochs
# At minibatch 75600, batch loss 0.006327, batch error rate 0.000000%
# At minibatch 75700, batch loss 0.009076, batch error rate 0.000000%
# At minibatch 75800, batch loss 0.007720, batch error rate 0.000000%
# At minibatch 75900, batch loss 0.007268, batch error rate 0.000000%
# At minibatch 76000, batch loss 0.010369, batch error rate 0.000000%
# After epoch 152: valid_err_rate: 0.024100% currently going ot do 167 epochs
# At minibatch 76100, batch loss 0.004975, batch error rate 0.000000%
# At minibatch 76200, batch loss 0.010504, batch error rate 0.000000%
# At minibatch 76300, batch loss 0.004074, batch error rate 0.000000%
# At minibatch 76400, batch loss 0.005394, batch error rate 0.000000%
# At minibatch 76500, batch loss 0.005882, batch error rate 0.000000%
# After epoch 153: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 76600, batch loss 0.006481, batch error rate 0.000000%
# At minibatch 76700, batch loss 0.007335, batch error rate 0.000000%
# At minibatch 76800, batch loss 0.006046, batch error rate 0.000000%
# At minibatch 76900, batch loss 0.005788, batch error rate 0.000000%
# At minibatch 77000, batch loss 0.005375, batch error rate 0.000000%
# After epoch 154: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 77100, batch loss 0.007204, batch error rate 0.000000%
# At minibatch 77200, batch loss 0.004785, batch error rate 0.000000%
# At minibatch 77300, batch loss 0.003223, batch error rate 0.000000%
# At minibatch 77400, batch loss 0.004139, batch error rate 0.000000%
# At minibatch 77500, batch loss 0.005003, batch error rate 0.000000%
# After epoch 155: valid_err_rate: 0.024200% currently going ot do 167 epochs
# At minibatch 77600, batch loss 0.005769, batch error rate 0.000000%
# At minibatch 77700, batch loss 0.006764, batch error rate 0.000000%
# At minibatch 77800, batch loss 0.004057, batch error rate 0.000000%
# At minibatch 77900, batch loss 0.004555, batch error rate 0.000000%
# At minibatch 78000, batch loss 0.003203, batch error rate 0.000000%
# After epoch 156: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 78100, batch loss 0.011842, batch error rate 0.000000%
# At minibatch 78200, batch loss 0.006243, batch error rate 0.000000%
# At minibatch 78300, batch loss 0.009598, batch error rate 0.000000%
# At minibatch 78400, batch loss 0.005174, batch error rate 0.000000%
# At minibatch 78500, batch loss 0.005850, batch error rate 0.000000%
# After epoch 157: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 78600, batch loss 0.004820, batch error rate 0.000000%
# At minibatch 78700, batch loss 0.005817, batch error rate 0.000000%
# At minibatch 78800, batch loss 0.005177, batch error rate 0.000000%
# At minibatch 78900, batch loss 0.005891, batch error rate 0.000000%
# At minibatch 79000, batch loss 0.004261, batch error rate 0.000000%
# After epoch 158: valid_err_rate: 0.024500% currently going ot do 167 epochs
# At minibatch 79100, batch loss 0.004106, batch error rate 0.000000%
# At minibatch 79200, batch loss 0.008954, batch error rate 0.000000%
# At minibatch 79300, batch loss 0.008844, batch error rate 0.000000%
# At minibatch 79400, batch loss 0.004604, batch error rate 0.000000%
# At minibatch 79500, batch loss 0.008418, batch error rate 0.000000%
# After epoch 159: valid_err_rate: 0.024200% currently going ot do 167 epochs
# At minibatch 79600, batch loss 0.004620, batch error rate 0.000000%
# At minibatch 79700, batch loss 0.006783, batch error rate 0.000000%
# At minibatch 79800, batch loss 0.002524, batch error rate 0.000000%
# At minibatch 79900, batch loss 0.003701, batch error rate 0.000000%
# At minibatch 80000, batch loss 0.009556, batch error rate 0.000000%
# After epoch 160: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 80100, batch loss 0.006930, batch error rate 0.000000%
# At minibatch 80200, batch loss 0.008314, batch error rate 0.000000%
# At minibatch 80300, batch loss 0.008709, batch error rate 0.000000%
# At minibatch 80400, batch loss 0.006582, batch error rate 0.000000%
# At minibatch 80500, batch loss 0.007904, batch error rate 0.000000%
# After epoch 161: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 80600, batch loss 0.007307, batch error rate 0.000000%
# At minibatch 80700, batch loss 0.005338, batch error rate 0.000000%
# At minibatch 80800, batch loss 0.004087, batch error rate 0.000000%
# At minibatch 80900, batch loss 0.007836, batch error rate 0.000000%
# At minibatch 81000, batch loss 0.004147, batch error rate 0.000000%
# After epoch 162: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 81100, batch loss 0.004791, batch error rate 0.000000%
# At minibatch 81200, batch loss 0.003046, batch error rate 0.000000%
# At minibatch 81300, batch loss 0.006520, batch error rate 0.000000%
# At minibatch 81400, batch loss 0.002661, batch error rate 0.000000%
# At minibatch 81500, batch loss 0.003685, batch error rate 0.000000%
# After epoch 163: valid_err_rate: 0.024000% currently going ot do 167 epochs
# At minibatch 81600, batch loss 0.006549, batch error rate 0.000000%
# At minibatch 81700, batch loss 0.004498, batch error rate 0.000000%
# At minibatch 81800, batch loss 0.003838, batch error rate 0.000000%
# At minibatch 81900, batch loss 0.003176, batch error rate 0.000000%
# At minibatch 82000, batch loss 0.002311, batch error rate 0.000000%
# After epoch 164: valid_err_rate: 0.024200% currently going ot do 167 epochs
# At minibatch 82100, batch loss 0.004406, batch error rate 0.000000%
# At minibatch 82200, batch loss 0.005436, batch error rate 0.000000%
# At minibatch 82300, batch loss 0.004986, batch error rate 0.000000%
# At minibatch 82400, batch loss 0.005423, batch error rate 0.000000%
# At minibatch 82500, batch loss 0.003739, batch error rate 0.000000%
# After epoch 165: valid_err_rate: 0.024400% currently going ot do 167 epochs
# At minibatch 82600, batch loss 0.008568, batch error rate 0.000000%
# At minibatch 82700, batch loss 0.003576, batch error rate 0.000000%
# At minibatch 82800, batch loss 0.007120, batch error rate 0.000000%
# At minibatch 82900, batch loss 0.006527, batch error rate 0.000000%
# At minibatch 83000, batch loss 0.006311, batch error rate 0.000000%
# After epoch 166: valid_err_rate: 0.024300% currently going ot do 167 epochs
# At minibatch 83100, batch loss 0.004522, batch error rate 0.000000%
# At minibatch 83200, batch loss 0.004405, batch error rate 0.000000%
# At minibatch 83300, batch loss 0.003528, batch error rate 0.000000%
# At minibatch 83400, batch loss 0.005622, batch error rate 0.000000%
# At minibatch 83500, batch loss 0.006996, batch error rate 0.000000%
# After epoch 167: valid_err_rate: 0.024200% currently going ot do 167 epochs
# At minibatch 83600, batch loss 0.006734, batch error rate 0.000000%
# At minibatch 83700, batch loss 0.003198, batch error rate 0.000000%
# At minibatch 83800, batch loss 0.006871, batch error rate 0.000000%
# At minibatch 83900, batch loss 0.011243, batch error rate 0.000000%
# At minibatch 84000, batch loss 0.004393, batch error rate 0.000000%
# After epoch 168: valid_err_rate: 0.024200% currently going ot do 167 epochs
# Finished with 168 epochs (minibatch 84000), with best valid error rate 0.024000

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0258

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
